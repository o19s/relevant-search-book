# %% [markdown]
# # Setup Code (Listings 3 & 4) 5.2.1

# %%
import requests
import json
import os

# you'll need to have an API key for TMDB
# to run these examples,
# run export TMDB_API_KEY=<YourAPIKey>
tmdb_api_key = os.environ["TMDB_API_KEY"]

# Setup tmdb as its own session, caching requests
# (we only want to cache tmdb, not elasticsearch)
# Get your TMDB API key from
#  https://www.themoviedb.org/documentation/api
# then in shell do export TMDB_API_KEY=<Your Key>
tmdb_api = requests.Session()
tmdb_api.params={'api_key': tmdb_api_key}

# Optional, enable client-side caching for TMDB
# Requires: https://httpcache.readthedocs.org/en/latest/
#from httpcache import CachingHTTPAdapter
#tmdb_api.mount('https://', CachingHTTPAdapter())
#tmdb_api.mount('http://', CachingHTTPAdapter())

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
                        data=text)
    print resp.text
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, data=json.dumps(query))
    if httpResp.status_code != 200:
        print "Search Failed <%s>" % httpResp.status_code
        print "%s" % httpResp.text
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])
            if verbose:
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "DIRS %s" % directorNames
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     data=json.dumps({'query': query['query']}))
        print json.loads(httpResp.text)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print "Delete TMDB Index <%s>" % resp.status_code
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", data=json.dumps(settings))
    print "Create TMDB Index <%s>" % resp.status_code
    if resp.status_code != 200:
        print resp.text
    
    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    for id, movie in movieDict.iteritems():
        addCmd = {"index": {"_index": "tmdb", "_type": "movie", "_id": movie["id"]}}
        esDoc  = movie
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies)
    print "Bulk Index into TMDB Index <%s>" % resp.status_code


def movieList(maxMovies=10000):
    movieIds = [];
    numPages = maxMovies / 20    
    for page in range(1, numPages + 1):
        httpResp = tmdb_api.get('https://api.themoviedb.org/3/movie/top_rated', params={'page': page})  #(1)
        if httpResp.status_code != 200:
            print "top_rated: <%s>" % httpResp.status_code
            print " why? %s " % httpResp.text
        jsonResponse = json.loads(httpResp.text) #(2)
        movies = jsonResponse['results']
        if len(movies) == 0:
            break
        for movie in movies:
            movieIds.append(movie['id'])
    return movieIds

## Extract
## Extract accesses the TMDB endpoints required and creates an entry for each movie. Recall how we iterated
## over all the movie entries at an endpoint like 'top_rated'. There's one 
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass    
        
    movieDict = {}
    for movieId in movieIds:
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s" % movieId)
        movie = json.loads(httpResp.text)
        
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s/credits" % movieId)
        credits = json.loads(httpResp.text)
        cast = credits['cast']
        crew = credits['crew']
        directors = []
        actors = []
        for crewMember in crew:
            if crewMember['job'] == 'Director':
                directors.append(crewMember)
        movie['cast'] = cast
        movie['directors'] = directors
        
        movieDict[movieId] = movie
    
    # Store a file locally
    with open('tmdb.json', 'w') as f:
        f.write(json.dumps(movieDict))
        f.close()
    
    return movieDict

# %% [markdown]
# # 5.2.2 -- Listing 4, Index to ES, Search

# %%
movieDict = extract([])

analysis = {
    "analyzer" : {
      "default" : {
        "type" : "english"
        }
      }
   }

reindex(analysisSettings=analysis, movieDict=movieDict)

usersSearch = 'basketball with space aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>
# Num	Relevance Score		Movie Title
# 1	1.1681561		Space Jam
# 2	0.49025935		Independence Day
# 3	0.4289769		Battleship
# 4	0.41528594		Doom
# 5	0.41528594		The Invasion
# ===============
# Num	Relevance Score		Movie Title
# 1	1.1681561		Space Jam
# Space Jam
# Get ready to jam.
# Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.
# 2300
# DIRS [u'Joe Pytka']
# CAST [u'Michael Jordan', u'Wayne Knight', u'Billy West', u'Dee Bradley Baker', u'Theresa Randle', u'Danny DeVito', u'Brandon Hammond', u'Larry Bird', u'Bill Murray', u'Charles Barkley', u'Patrick Ewing', u'Tyrone Bogues', u'Larry Johnson', u'Shawn Bradley', u'Ahmad Rashad', u'Del Harris', u'Vlade Divac', u'Cedric Ceballos', u'Jim Rome', u'Paul Westphal', u'Danny Ainge', u'Alonzo Mourning', u'A.C. Green', u'Charles Oakley', u'Derek Harper', u'Jeff Malone', u'Anthony Miller', u'Sharone Wright']
# CHAR [u'Himself', u'Stan Podolak', u'Bugs Bunny/Elmer Fudd (voice)', u'Daffy Duck/Tazmanian Devil/Bull (voice)', u'Juanita Jordan', u'Mr. Swackhammer (voice)', u'Michael Jordan (at 10)', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself']
# 1.1681561, max of:
#   0.10532718, product of:
#     0.31598154, sum of:
#       0.31598154, weight(title:space in 107) [PerFieldSimilarity], result of:
#         0.31598154, score(doc=107,freq=1.0), product of:
#           0.07175091, queryWeight, product of:
#             7.0461893, idf(docFreq=5, maxDocs=2535)
#             0.010182939, queryNorm
#           4.403868, fieldWeight in 107, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.0461893, idf(docFreq=5, maxDocs=2535)
#             0.625, fieldNorm(doc=107)
#     0.33333334, coord(1/3)
#   1.1681561, product of:
#     1.7522342, sum of:
#       1.209229, weight(overview:basketbal in 107) [PerFieldSimilarity], result of:
#         1.209229, score(doc=107,freq=1.0), product of:
#           0.7018121, queryWeight, product of:
#             6.892039, idf(docFreq=6, maxDocs=2535)
#             0.10182939, queryNorm
#           1.7230097, fieldWeight in 107, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.892039, idf(docFreq=6, maxDocs=2535)
#             0.25, fieldNorm(doc=107)
#       0.54300517, weight(overview:alien in 107) [PerFieldSimilarity], result of:
#         0.54300517, score(doc=107,freq=1.0), product of:
#           0.47029302, queryWeight, product of:
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.10182939, queryNorm
#           1.1546103, fieldWeight in 107, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.25, fieldNorm(doc=107)
#     0.6666667, coord(2/3)
#
# *************************************
# 2	0.49025935		Independence Day
# Independence Day
# Earth. Take a good look. It might be your last.
# On July 2, a giant alien mothership enters orbit around Earth and deploys several dozen saucer-shaped "destroyer" spacecraft that quickly lay waste to major cities around the planet. On July 3, the United States conducts a coordinated counterattack that fails. On July 4 the a plan is devised to gain access to the interior of the alien mothership in space in order to plant a nuclear missile.
# 602
# DIRS [u'Roland Emmerich']
# CAST [u'Will Smith', u'Bill Pullman', u'Jeff Goldblum', u'Mary McDonnell', u'Judd Hirsch', u'Robert Loggia', u'Randy Quaid', u'Margaret Colin', u'Vivica A. Fox', u'James Rebhorn', u'Harvey Fierstein', u'Adam Baldwin', u'James Duval', u'Lisa Jakub', u'Giuseppe Andrews', u'Harry Connick Jr.', u'Mae Whitman', u'Kiersten Warren', u'John Storey', u'Frank Novak', u'Devon Gummersall', u'Leland Orser', u'Mirron E. Willis', u'Ross Lacy', u'David Pressman', u'Raphael Sbarge', u'Bobby Hosea', u'Dan Lauria', u'Steve Giannelli', u'Eric Paskel', u'Carlos Lac\xe1mara', u'John Bennett Perry', u'Troy Willis', u'Tim Kelleher', u'Wayne Wilderson', u'Jay Acovone', u'James Wong', u'Jana Marie Hupp', u'Robert Pine', u'David Channell', u'John Capodice', u'Greg Collins', u'Derek Webster', u'Mark Fite', u'Levan Uchaneishvili', u'Kristof Konrad', u'Kevin Sifuentes', u'Elston Ridgle', u'Randy Oglesby', u'Jack Moore', u'Barry Del Sherman', u'Lyman Ward', u'Anthony Crivello', u'Richard Speight Jr.', u'Joe Fowler', u'Sharon Tay', u'Peter J. Lucas', u'Yelena Danova', u'Johnny Kim', u'Vanessa J. Wells', u'Sayed Badreya', u'Adam Tomei', u'John Bradley', u'Kimberly Beck', u'Andrew Keegan', u'Jim Piddock', u'Pat Skipper', u'Erick Avari', u'Brent Spiner']
# CHAR [u'Captain Steven Hiller', u'President Thomas J. Whitmore', u'David Levinson', u'First Lady Marilyn Whitmore', u'Julius Levinson', u'General William Grey', u'Russell Casse', u'Constance Spano', u'Jasmine Dubrow', u'Albert Nimzicki', u'Marty Gilbert', u'Major Mitchell', u'Miguel Casse', u'Alicia Casse', u'Troy Casse', u'Captain Jimmy Wilder', u'Patricia Whitmore', u'Tiffany', u'Dr. Isaacs', u'Teddy', u'Philip', u'Technician/ Medical Assistant 1', u'Aide', u'Aide', u"Whitmore's Aide", u'Commander / Tech', u'Commanding Officer', u'Commanding Officer', u'Radar Technician', u'Radar Technician', u'Radar Operator', u'Secret Service Agent', u'Secret Service Agent', u'Technician', u'Area 51 Technician', u'Area 51 Guard', u'SETI Technician 1', u'SETI Technician 3', u'Chief of Staff', u'Secret Service Agent', u'Mario', u'Military Aide', u'Sky Crane Pilot', u'Pilot', u'Russian Pilot (Levani)', u'Russian Pilot', u'Tank Commander', u'Soldier', u'Mechanic', u'Mechanic', u'Street Preacher', u'Secret Service Agent', u'Lincoln', u'Ed', u'Reporter', u'Reporter', u'Russian Reporter', u'Russian Newscaster', u'Korean Newscaster', u'Newscaster', u'Arab Pilot', u'Sailor', u'Lucas', u'Housewife', u'Older Boy', u'Reginald', u'Redneck', u'SETI Chief', u'Dr. Brackish Okun']
# 0.4902593, max of:
#   0.4902593, product of:
#     0.73538893, sum of:
#       0.35142633, weight(overview:space in 365) [PerFieldSimilarity], result of:
#         0.35142633, score(doc=365,freq=1.0), product of:
#           0.53505534, queryWeight, product of:
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.10182939, queryNorm
#           0.6568037, fieldWeight in 365, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.125, fieldNorm(doc=365)
#       0.3839626, weight(overview:alien in 365) [PerFieldSimilarity], result of:
#         0.3839626, score(doc=365,freq=2.0), product of:
#           0.47029302, queryWeight, product of:
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.10182939, queryNorm
#           0.8164327, fieldWeight in 365, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.125, fieldNorm(doc=365)
#     0.6666667, coord(2/3)
#
# *************************************
# 3	0.4289769		Battleship
# Battleship
# The Battle for Earth Begins at Sea
# When mankind beams a radio signal into space, a reply comes from "Planet G", in the form of several alien crafts that splash down in the waters off Hawaii. Lieutenant Alex Hopper (Taylor Kitsch) is a navel weapons officer assigned to the ship USS John Paul Jones, part of an international naval coalition which becomes the world's last hope for survival as they engage the hostile alien force of unimaginable strength. While takng on the invaders, Hopper must also try to live up to the potential his brother Stone (Alexander Skarsgård) and his fiancée's father, Admiral Shane (Liam Neeson), expect of him.
# 44833
# DIRS [u'Peter Berg']
# CAST [u'Taylor Kitsch', u'Alexander Skarsg\xe5rd', u'Rihanna', u'Brooklyn Decker', u'Tadanobu Asano', u'Liam Neeson', u'Gregory D. Gadson', u'Hamish Linklater', u'Jesse Plemons', u'John Tui', u'Jerry Ferrara', u'David Jensen', u'Peter Berg', u'Adam Godley', u'Rico McClinton', u'Joji Yoshida', u'Stephen Bishop', u'Austin Naulty', u'James Rawlings', u'Dustin J. Reno', u'Rick Hoffman', u'Gary Grubbs']
# CHAR [u'Lieutenant Alex Hopper', u'Commander Stone Hopper', u'Petty Officer Cora', u'Sam', u'Captain Yugi Nagata', u'Admiral Shane', u'Lieutenant Colonel Mick Canales', u'Cal Zapata', u'Boatswain Mate Seaman Jimmy "Ordy" Ord', u'Chief Petty Officer Walter "The Beast" Lynch', u'Sampson JOOD Strodell', u'NASA Director', u'JPJ 2nd Gunner', u'Dr. Nogrady', u'Captain Browley', u'Chief Engineer Hiroki', u'JPJ OOD', u'JPJ Fireman', u'JPJ Scat', u'Electronic Warfare Supervisor', u'Chairman, Joint Chiefs of Staff', u'Air Force Chief of Staff']
# 0.4289769, max of:
#   0.4289769, product of:
#     0.64346534, sum of:
#       0.30749807, weight(overview:space in 125) [PerFieldSimilarity], result of:
#         0.30749807, score(doc=125,freq=1.0), product of:
#           0.53505534, queryWeight, product of:
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.10182939, queryNorm
#           0.5747033, fieldWeight in 125, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.109375, fieldNorm(doc=125)
#       0.33596727, weight(overview:alien in 125) [PerFieldSimilarity], result of:
#         0.33596727, score(doc=125,freq=2.0), product of:
#           0.47029302, queryWeight, product of:
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.10182939, queryNorm
#           0.7143786, fieldWeight in 125, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.109375, fieldNorm(doc=125)
#     0.6666667, coord(2/3)
#
# *************************************
# 4	0.41528594		Doom
# Doom
# No one gets out alive.
# A team of space marines known as the Rapid Response Tactical Squad, led by Sarge, is sent to a science facility on Mars after somebody reports a security breach. There, they learn that the alert came after a test subject, a mass murderer purposefully injected with alien DNA, broke free and began killing people. Dr. Grimm, who is related to team member Reaper, informs them all that the chromosome can mutate humans into monsters -- and is highly infectious.
# 8814
# DIRS [u'Andrzej Bartkowiak']
# CAST [u'Dwayne Johnson', u'Karl Urban', u'Rosamund Pike', u'Ben Daniels', u'Deobia Oparei', u'Razaaq Adoti', u'Richard Brake', u'Al Weaver', u'Dexter Fletcher', u'Brian Steele', u'Yao Chin', u'Robert Russell', u'Daniel York', u'Ian Hughes', u'Sara Houghton']
# CHAR [u'Sarge', u'John Grimm', u'Samantha Grimm', u'Goat', u'Destroyer', u'Duke', u'Corporal Dean Portman', u'The Kid', u'Pinky', u'Hell Knight / Curtis Stahl', u'Mac', u'Dr. Carmack', u'Lt. Huengs', u'Sanford Crosby', u'Dr. Jenna Willits']
# 0.41528594, max of:
#   0.41528594, product of:
#     0.6229289, sum of:
#       0.35142633, weight(overview:space in 190) [PerFieldSimilarity], result of:
#         0.35142633, score(doc=190,freq=1.0), product of:
#           0.53505534, queryWeight, product of:
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.10182939, queryNorm
#           0.6568037, fieldWeight in 190, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.125, fieldNorm(doc=190)
#       0.27150258, weight(overview:alien in 190) [PerFieldSimilarity], result of:
#         0.27150258, score(doc=190,freq=1.0), product of:
#           0.47029302, queryWeight, product of:
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.10182939, queryNorm
#           0.57730514, fieldWeight in 190, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.125, fieldNorm(doc=190)
#     0.6666667, coord(2/3)
#
# *************************************
# 5	0.41528594		The Invasion
# The Invasion
# Do not trust anyone. Do not show emotion. Do not fall asleep.
# Washington, D.C. psychologist Carol Bennell and her colleague Dr. Ben Driscoll are the only two people on Earth who are aware of an epidemic running rampant through the city. They discover an alien virus aboard a crashed space shuttle that transforms anyone who comes into contact with it into unfeeling drones while they sleep. Carol realizes her son holds the key to stopping the spread of the plague and she races to find him before it is too late.
# 4858
# DIRS [u'Oliver Hirschbiegel', u'James McTeigue']
# CAST [u'Nicole Kidman', u'Daniel Craig', u'Jeremy Northam', u'Jeffrey Wright', u'Jackson Bond', u'Veronica Cartwright', u'Josef Sommer', u'Celia Weston', u'Roger Rees', u'Eric Benjamin', u'Susan Floyd', u'Stephanie Berry', u'Alexis Raben', u'Adam LeFevre', u'Joanna Merlin']
# CHAR [u'Carol', u'Ben', u'Tucker', u'Dr. Galeano', u'Oliver', u'Wendy Lenk', u'Dr. Henryk Belicec', u'Ludmilla Belicec', u'Yorish', u'Gene', u'Pam', u'Carly', u"Belicec's Aide", u'Richard Lenk', u'Joan Kaufman']
# 0.41528594, max of:
#   0.41528594, product of:
#     0.6229289, sum of:
#       0.35142633, weight(overview:space in 390) [PerFieldSimilarity], result of:
#         0.35142633, score(doc=390,freq=1.0), product of:
#           0.53505534, queryWeight, product of:
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.10182939, queryNorm
#           0.6568037, fieldWeight in 390, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.25443, idf(docFreq=35, maxDocs=2535)
#             0.125, fieldNorm(doc=390)
#       0.27150258, weight(overview:alien in 390) [PerFieldSimilarity], result of:
#         0.27150258, score(doc=390,freq=1.0), product of:
#           0.47029302, queryWeight, product of:
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.10182939, queryNorm
#           0.57730514, fieldWeight in 390, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.618441, idf(docFreq=67, maxDocs=2535)
#             0.125, fieldNorm(doc=390)
#     0.6666667, coord(2/3)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((((title:basketbal title:space title:alien)^0.1) | (overview:basketbal overview:space overview:alien)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.2.4 -- Listing 5 Inspecting Nested Star Trek Docs

# %%
spaceJamId = 2300
httpResp = requests.get("http://localhost:9200/tmdb/movie/%s" % spaceJamId)
spaceJamDoc = json.loads(httpResp.text)
print json.dumps(spaceJamDoc['_source'], indent=True)
# Out:
# {
#  "poster_path": "/9T9ucCk6wO0crRBUIkBJMRAVcKp.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 230000000,
#  "overview": "Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.",
#  "video": false,
#  "id": 2300,
#  "genres": [
#   {
#    "id": 16,
#    "name": "Animation"
#   },
#   {
#    "id": 35,
#    "name": "Comedy"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 14,
#    "name": "Fantasy"
#   },
#   {
#    "id": 10751,
#    "name": "Family"
#   }
#  ],
#  "title": "Space Jam",
#  "tagline": "Get ready to jam.",
#  "vote_count": 275,
#  "homepage": "",
#  "belongs_to_collection": null,
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "cs",
#    "name": "\u010cesk\u00fd"
#   },
#   {
#    "iso_639_1": "fr",
#    "name": "Fran\u00e7ais"
#   },
#   {
#    "iso_639_1": "pl",
#    "name": "Polski"
#   },
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   }
#  ],
#  "imdb_id": "tt0117705",
#  "adult": false,
#  "backdrop_path": "/kBTdPNTAzagAY6UiwY957KCDGuu.jpg",
#  "production_companies": [
#   {
#    "name": "Warner Bros. Animation",
#    "id": 2785
#   },
#   {
#    "name": "Warner Bros. Entertainment",
#    "id": 17
#   }
#  ],
#  "release_date": "1996-11-15",
#  "popularity": 0.778260445788321,
#  "original_title": "Space Jam",
#  "budget": 80000000,
#  "cast": [
#   {
#    "name": "Michael Jordan",
#    "character": "Himself",
#    "id": 23678,
#    "credit_id": "52fe434bc3a36847f80496c9",
#    "cast_id": 2,
#    "profile_path": "/7y16frD57Ztzk2mY4JeI2pQQhan.jpg",
#    "order": 0
#   },
#   {
#    "name": "Wayne Knight",
#    "character": "Stan Podolak",
#    "id": 4201,
#    "credit_id": "52fe434bc3a36847f80496cd",
#    "cast_id": 3,
#    "profile_path": "/oW9aeZwkz1S1IMjQGtd9mnvlEax.jpg",
#    "order": 1
#   },
#   {
#    "name": "Billy West",
#    "character": "Bugs Bunny/Elmer Fudd (voice)",
#    "id": 23679,
#    "credit_id": "52fe434bc3a36847f80496d1",
#    "cast_id": 4,
#    "profile_path": "/9V9fsfmWjHEDbS8tB5EOdHkyMFg.jpg",
#    "order": 2
#   },
#   {
#    "name": "Dee Bradley Baker",
#    "character": "Daffy Duck/Tazmanian Devil/Bull (voice)",
#    "id": 23680,
#    "credit_id": "52fe434bc3a36847f80496d5",
#    "cast_id": 5,
#    "profile_path": "/zFXwtsdvUCeNkzCzYpYZdAmTkJY.jpg",
#    "order": 3
#   },
#   {
#    "name": "Theresa Randle",
#    "character": "Juanita Jordan",
#    "id": 4604,
#    "credit_id": "52fe434bc3a36847f80496d9",
#    "cast_id": 6,
#    "profile_path": "/18LVR034VKDGOFqDw1EA1VZQVoe.jpg",
#    "order": 4
#   },
#   {
#    "name": "Danny DeVito",
#    "character": "Mr. Swackhammer (voice)",
#    "id": 518,
#    "credit_id": "52fe434bc3a36847f80496dd",
#    "cast_id": 7,
#    "profile_path": "/zKuyzmKzPLG7RJo7lbbHjx6CCZc.jpg",
#    "order": 5
#   },
#   {
#    "name": "Brandon Hammond",
#    "character": "Michael Jordan (at 10)",
#    "id": 23681,
#    "credit_id": "52fe434bc3a36847f80496e1",
#    "cast_id": 8,
#    "profile_path": "/ooljlVi5IYf2w4Px3jqc8OQdjjS.jpg",
#    "order": 6
#   },
#   {
#    "name": "Larry Bird",
#    "character": "Himself",
#    "id": 23682,
#    "credit_id": "52fe434bc3a36847f80496e5",
#    "cast_id": 9,
#    "profile_path": "/1KRnQVsXS8mz4tHHWD1yPAQBXq2.jpg",
#    "order": 7
#   },
#   {
#    "name": "Bill Murray",
#    "character": "Himself",
#    "id": 1532,
#    "credit_id": "52fe434bc3a36847f80496e9",
#    "cast_id": 12,
#    "profile_path": "/eb58HuFIrxS0zUmbmW4d8YXTbje.jpg",
#    "order": 8
#   },
#   {
#    "name": "Charles Barkley",
#    "character": "Himself",
#    "id": 1211812,
#    "credit_id": "5361746b0e0a2649bf0004e6",
#    "cast_id": 37,
#    "profile_path": "/mqHWhTtrja9vI8kfI6z7tCq5gB1.jpg",
#    "order": 9
#   },
#   {
#    "name": "Patrick Ewing",
#    "character": "Himself",
#    "id": 1231141,
#    "credit_id": "53614c6cc3a368397e0001d2",
#    "cast_id": 19,
#    "profile_path": "/aaXM8PuixEHNTLmvBQJLH8vV1SV.jpg",
#    "order": 11
#   },
#   {
#    "name": "Tyrone Bogues",
#    "character": "Himself",
#    "id": 1232432,
#    "credit_id": "53614e44c3a36839650001b4",
#    "cast_id": 20,
#    "profile_path": null,
#    "order": 12
#   },
#   {
#    "name": "Larry Johnson",
#    "character": "Himself",
#    "id": 1225517,
#    "credit_id": "53614eb1c3a36839650001bc",
#    "cast_id": 21,
#    "profile_path": "/gbfwZWitnSrcQwkAughr5Ji4iT5.jpg",
#    "order": 13
#   },
#   {
#    "name": "Shawn Bradley",
#    "character": "Himself",
#    "id": 1234833,
#    "credit_id": "5361565a0e0a2649b800027a",
#    "cast_id": 22,
#    "profile_path": null,
#    "order": 14
#   },
#   {
#    "name": "Ahmad Rashad",
#    "character": "Himself",
#    "id": 1197748,
#    "credit_id": "5361566c0e0a2649a6000277",
#    "cast_id": 23,
#    "profile_path": null,
#    "order": 15
#   },
#   {
#    "name": "Del Harris",
#    "character": "Himself",
#    "id": 1251369,
#    "credit_id": "536156930e0a2649b800027f",
#    "cast_id": 24,
#    "profile_path": null,
#    "order": 16
#   },
#   {
#    "name": "Vlade Divac",
#    "character": "Himself",
#    "id": 193304,
#    "credit_id": "536156a50e0a2649a90002a3",
#    "cast_id": 25,
#    "profile_path": "/ivflYHUbWXKyDe5B9su5HSidMA9.jpg",
#    "order": 17
#   },
#   {
#    "name": "Cedric Ceballos",
#    "character": "Himself",
#    "id": 1230823,
#    "credit_id": "536156d20e0a2649b8000282",
#    "cast_id": 26,
#    "profile_path": null,
#    "order": 18
#   },
#   {
#    "name": "Jim Rome",
#    "character": "Himself",
#    "id": 1215304,
#    "credit_id": "536156e10e0a2649ad000272",
#    "cast_id": 27,
#    "profile_path": null,
#    "order": 19
#   },
#   {
#    "name": "Paul Westphal",
#    "character": "Himself",
#    "id": 1315402,
#    "credit_id": "536156ee0e0a2649b8000285",
#    "cast_id": 28,
#    "profile_path": null,
#    "order": 20
#   },
#   {
#    "name": "Danny Ainge",
#    "character": "Himself",
#    "id": 1315446,
#    "credit_id": "536156fe0e0a2649ad000275",
#    "cast_id": 29,
#    "profile_path": null,
#    "order": 21
#   },
#   {
#    "name": "Alonzo Mourning",
#    "character": "Himself",
#    "id": 180625,
#    "credit_id": "5361571f0e0a2649b8000287",
#    "cast_id": 30,
#    "profile_path": "/ukR2lS5Z8avrJnN3Kua1ks3Habf.jpg",
#    "order": 22
#   },
#   {
#    "name": "A.C. Green",
#    "character": "Himself",
#    "id": 1315447,
#    "credit_id": "5361572a0e0a2649bf000295",
#    "cast_id": 31,
#    "profile_path": null,
#    "order": 23
#   },
#   {
#    "name": "Charles Oakley",
#    "character": "Himself",
#    "id": 1315403,
#    "credit_id": "536157540e0a2649bf00029b",
#    "cast_id": 32,
#    "profile_path": "/l35FQsV529lOhDFvMGk8aJ82AV9.jpg",
#    "order": 24
#   },
#   {
#    "name": "Derek Harper",
#    "character": "Himself",
#    "id": 1315448,
#    "credit_id": "536157680e0a2649a90002b5",
#    "cast_id": 33,
#    "profile_path": null,
#    "order": 25
#   },
#   {
#    "name": "Jeff Malone",
#    "character": "Himself",
#    "id": 1315449,
#    "credit_id": "536157780e0a2649a6000287",
#    "cast_id": 34,
#    "profile_path": null,
#    "order": 26
#   },
#   {
#    "name": "Anthony Miller",
#    "character": "Himself",
#    "id": 1315450,
#    "credit_id": "536157ba0e0a2649bb0002d3",
#    "cast_id": 35,
#    "profile_path": null,
#    "order": 27
#   },
#   {
#    "name": "Sharone Wright",
#    "character": "Himself",
#    "id": 1315451,
#    "credit_id": "536157cb0e0a2649bf0002a7",
#    "cast_id": 36,
#    "profile_path": null,
#    "order": 28
#   }
#  ],
#  "directors": [
#   {
#    "name": "Joe Pytka",
#    "department": "Directing",
#    "job": "Director",
#    "credit_id": "52fe434bc3a36847f80496c5",
#    "profile_path": "/c46Ah1KxlfC4W8mHVrGDsJ7dMPJ.jpg",
#    "id": 23677
#   }
#  ],
#  "vote_average": 6.3,
#  "runtime": 88
# }

# %% [markdown]
# # 5.3.1, Listing 6 Star Trek Query Using Query from Ch 3

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name'],      
            'type': 'best_fields'
         }
    },
    'size': 50,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.4975834		Legion
# 2	1.4975834		Halo 4: Forward Unto Dawn
# 3	1.1420501		Drive Angry
# 4	1.1420501		Feast
# 5	1.1420501		District 13: Ultimatum
# 6	1.1420501		The Expendables 3
# 7	1.1420501		Underworld: Rise of the Lycans
# 8	0.9136401		Sex and the City 2
# 9	0.9136401		Sex and the City
# 10	0.48049		Vertigo
# 11	0.48049		Star Trek: Insurrection
# 12	0.48049		Gnomeo & Juliet
# 13	0.48049		Star Trek: First Contact
# 14	0.40040833		Conspiracy Theory
# 15	0.40040833		The Wolverine
# 16	0.40040833		Star Trek: Nemesis
# 17	0.40040833		Dune
# 18	0.40040833		Star Trek: Generations
# 19	0.40040833		X-Men
# 20	0.40040833		Panic Room
# 21	0.35628724		One Flew Over the Cuckoo's Nest
# 22	0.3266038		The Bounty Hunter
# 23	0.3203267		The Collector
# 24	0.3203267		Save the Last Dance
# 25	0.3203267		X2: X-Men United
# 26	0.3203267		TMNT
# 27	0.3203267		The Prince of Egypt
# 28	0.3203267		X-Men: The Last Stand
# 29	0.2770064		The Cabin in the Woods
# 30	0.26128304		The Beaver
# 31	0.26128304		Zathura: A Space Adventure
# 32	0.25434536		A Good Year
# 33	0.23752482		One for the Money
# 34	0.23752482		The SpongeBob Movie: Sponge Out of Water
# 35	0.23752482		The SpongeBob SquarePants Movie
# 36	0.23752482		10 Things I Hate About You
# 37	0.23083867		Chicken Little
# 38	0.20199351		Guess Who
# 39	0.17853872		The Inbetweeners Movie
# 40	0.17853872		Valhalla Rising
# 41	0.17814362		The Smurfs 2
# 42	0.17674433		Rope
# 43	0.17674433		Moon
# 44	0.16016334		300
# 45	0.15149513		Tangled Ever After
# 46	0.15149513		Dom Hemingway
# 47	0.15149513		The Lucky One
# 48	0.15149513		The Iron Lady
# 49	0.15149513		Father of the Bride
# 50	0.15149513		Still Alice
# ===============
# Num	Relevance Score		Movie Title
# 1	1.4975834		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 1.4975834, max of:
#   1.4975834, product of:
#     2.9951668, sum of:
#       2.9951668, weight(directors.name:stewart in 782) [PerFieldSimilarity], result of:
#         2.9951668, score(doc=782,freq=1.0), product of:
#           0.619209, queryWeight, product of:
#             7.7393365, idf(docFreq=2, maxDocs=2535)
#             0.08000802, queryNorm
#           4.8370852, fieldWeight in 782, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.7393365, idf(docFreq=2, maxDocs=2535)
#             0.625, fieldNorm(doc=782)
#     0.5, coord(1/2)
#
# *************************************
# 2	1.4975834		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# DIRS [u'Stewart Hendler']
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 1.4975834, max of:
#   1.4975834, product of:
#     2.9951668, sum of:
#       2.9951668, weight(directors.name:stewart in 899) [PerFieldSimilarity], result of:
#         2.9951668, score(doc=899,freq=1.0), product of:
#           0.619209, queryWeight, product of:
#             7.7393365, idf(docFreq=2, maxDocs=2535)
#             0.08000802, queryNorm
#           4.8370852, fieldWeight in 899, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.7393365, idf(docFreq=2, maxDocs=2535)
#             0.625, fieldNorm(doc=899)
#     0.5, coord(1/2)
#
# *************************************
# 3	1.1420501		Drive Angry
# Drive Angry
# One hell of a ride.
# Milton is a hardened felon who has broken out of Hell, intent on finding the vicious cult who brutally murdered his daughter and kidnapped her baby. He joins forces with Piper, a sexy, tough-as-nails waitress with a 69 Charger, who's also seeking redemption of her own. Caught in a deadly race against time, Milton has three days to avoid capture, avenge his daughter's death, and save her baby before she's mercilessly sacrificed by the cult.
# 47327
# DIRS [u'Patrick Lussier']
# CAST [u'Nicolas Cage', u'Amber Heard', u'William Fichtner', u'Billy Burke', u'David Morse', u'Katy Mixon', u'Charlotte Ross', u'Christa Campbell', u'Todd Farmer', u'Jack McGee', u'Tom Atkins', u'Wanetah Walmsley', u'Edrick Browne', u'Robin McGee', u'Fabian C. Moreno', u'Marc Macaulay', u'Pruitt Taylor Vince', u'Julius Washington', u'Jamie Teer', u'Bryan Massey', u'Timothy Walter', u'Kent Jude Bernard', u'Brent Phillip Henry', u'Gerry May', u'Sherri Talley', u'Arianne Margot', u'Con Schell', u'Nick Gomez', u'Joe Chrest', u'Oakley Lehman', u'Thirl Haston', u'Jake Brake', u'Tim J. Smith', u'Jeffrey J. Dashnaw', u'Tim Trella', u'James Landry H\xe9bert', u'Kenneth Wayne Bradley', u'Kendrick Hudson', u'Michael Papajohn', u'April Littlejohn', u'Henry Kingi', u'Simona Williams', u'Shelby Swatek', u'Joseph Blackstone', u'Dan Forest', u'Elise Fyke', u"Jonathan O'Rear", u'James Paul', u'Alice Searcy', u'Lanie Taylor', u'David Lee Valle']
# CHAR [u'Milton', u'Piper', u'Accountant', u'Jonah King', u'Webster', u'Norma Jean', u'Candy', u'Mona', u'Frank', u'Fat Lou', u'Cap', u'American Indian Mother', u'Rookie', u'Guy with Camera Phone', u'Latino Busboy', u'Sarge', u'Roy', u'Uniformed Officer', u'Babysitter', u'Trooper #1', u'Trooper #2', u'Teen #1', u'Teen #2', u'TV Male News Reporter #1', u'TV Female News Reporter #2', u"Milton's Daughter (Older)", u'Fucking Driver', u'Fucking Middle', u'Fucking Passenger', u'Cultist with Iron Pipe', u'Cultist with Sickle', u'Cultist with Machete', u'Cultist with Hatchet', u'Cowboy with Cattle Prod', u'Cultist with Sledge', u'Man in Leather Jacket', u'Man with Wig', u'Burly Dude', u'Tattooed Guy', u'Business Woman', u'Thin Old Man', u'Lady in Leopard Skin', u'Truck Driving Woman', u'Bar Patron', u'American Indian Dad', u'Laughing Cowgirl', u'Resturant Patron', u'Bar Patron', u'Restaurant Patron', u"Milton's Daughter - Younger", u'Highway Patrol']
# 1.1420501, max of:
#   1.1420501, product of:
#     2.2841003, sum of:
#       2.2841003, weight(directors.name:patrick in 62) [PerFieldSimilarity], result of:
#         2.2841003, score(doc=62,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           4.224067, fieldWeight in 62, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.625, fieldNorm(doc=62)
#     0.5, coord(1/2)
#
# *************************************
# 4	1.1420501		Feast
# Feast
#
# This Oscar-winning animated short film tells the story of one man's love life is seen through the eyes of his best friend and dog, Winston, and revealed bite by bite through the meals they share.
# 293299
# DIRS [u'Patrick Osborne']
# CAST [u'Tommy Snider', u'Katie Lowes', u'Ben Bledsoe']
# CHAR [u'James', u'Additional Voices (voice)', u'Additional Voices']
# 1.1420501, max of:
#   1.1420501, product of:
#     2.2841003, sum of:
#       2.2841003, weight(directors.name:patrick in 180) [PerFieldSimilarity], result of:
#         2.2841003, score(doc=180,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           4.224067, fieldWeight in 180, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.625, fieldNorm(doc=180)
#     0.5, coord(1/2)
#
# *************************************
# 5	1.1420501		District 13: Ultimatum
# District 13: Ultimatum
#
# Damien and Leito return to District 13 on a mission to bring peace to the troubled sector that is controlled by five different gang bosses, before the city's secret services take drastic measures to solve the problem.
# 15357
# DIRS [u'Patrick Alessandrin']
# CAST [u'Cyril Raffaelli', u'David Belle', u'Philippe Torreton', u'Daniel Duval', u'Elodie Yung', u"MC Jean Gab'1", u'James Deano', u'Laouni Mouhid', u'Fabrice Feltzinger', u'Pierre-Marie Mosconi', u'Johnny Amaro']
# CHAR [u'Damien', u'Le\xefto', u'Le Pr\xe9sident de la R\xe9publique', u'Walter Gassman', u'Tao', u'Molko', u'Karl le skin', u'Ali-K', u'Little Montana', u'Roland', u'Policier centre de contr\xf4le']
# 1.1420501, max of:
#   1.1420501, product of:
#     2.2841003, sum of:
#       2.2841003, weight(directors.name:patrick in 838) [PerFieldSimilarity], result of:
#         2.2841003, score(doc=838,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           4.224067, fieldWeight in 838, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.625, fieldNorm(doc=838)
#     0.5, coord(1/2)
#
# *************************************
# 6	1.1420501		The Expendables 3
# The Expendables 3
# New team. New attitude. New mission.
# Barney (Stallone), Christmas (Statham) and the rest of the team comes face-to-face with Conrad Stonebanks (Gibson), who years ago co-founded The Expendables with Barney. Stonebanks subsequently became a ruthless arms trader and someone who Barney was forced to kill... or so he thought. Stonebanks, who eluded death once before, now is making it his mission to end The Expendables -- but Barney has other plans. Barney decides that he has to fight old blood with new blood, and brings in a new era of Expendables team members, recruiting individuals who are younger, faster and more tech-savvy. The latest mission becomes a clash of classic old-school style versus high-tech expertise in the Expendables' most personal battle yet.
# 138103
# DIRS [u'Patrick Hughes']
# CAST [u'Sylvester Stallone', u'Jason Statham', u'Harrison Ford', u'Arnold Schwarzenegger', u'Mel Gibson', u'Wesley Snipes', u'Randy Couture', u'Dolph Lundgren', u'Terry Crews', u'Kelsey Grammer', u'Glen Powell', u'Antonio Banderas', u'Victor Ortiz', u'Ronda Rousey', u'Kellan Lutz', u'Jet Li', u'Ivan Kostadinov', u'Robert Davi', u'Nikolay Stoyanov Ilchev', u'Daniel Angelov', u'Slavi Slavov', u'Dimiter Doichinov', u'Nikolay Stanoev', u'Harry Anichkin', u'Boswell Maloka', u'Natalie Burn', u'Velizar Binev', u'Sarai Givaty', u'Liubomir Simeonov', u'Frank Pesce', u'Thomas Canestraro']
# CHAR [u'Barney Ross', u'Lee Christmas', u'Max Drummer', u'Trench', u'Conrad Stonebanks', u'Doc', u'Toll Road', u'Gunnar Jensen', u'Hale Caesar', u'Bonaparte', u'Thorn', u'Galgo', u'Mars', u'Luna', u'John Smilee', u'Yin Yang', u'Krug', u'Vata', u'Local Cop #1', u'Local Cop #2', u'Warden', u'Head Bodyguard', u'Tech Guy', u'Colonel', u'Somali Drug Warlord', u"Conrad's Wife", u'Art Broker', u'Camilla', u'Cyclops', u'Fight Watcher', u"Conrad's Henchman"]
# 1.1420501, max of:
#   1.1420501, product of:
#     2.2841003, sum of:
#       2.2841003, weight(directors.name:patrick in 952) [PerFieldSimilarity], result of:
#         2.2841003, score(doc=952,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           4.224067, fieldWeight in 952, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.625, fieldNorm(doc=952)
#     0.5, coord(1/2)
#
# *************************************
# 7	1.1420501		Underworld: Rise of the Lycans
# Underworld: Rise of the Lycans
# Every war has a beginning.
# A prequel to the first two Underworld films, this fantasy explains the origins of the feud between the Vampires and the Lycans. Aided by his secret love, Sonja, courageous Lucian leads the Lycans in battle against brutal Vampire king Viktor. Determined to break the king's enslavement of his people, Lucian faces off against the Death Dealer army in a bid for Lycan independence.
# 12437
# DIRS [u'Patrick Tatopoulos']
# CAST [u'Bill Nighy', u'Michael Sheen', u'Rhona Mitra', u'Shane Brolly', u'Steven Mackintosh', u'Kevin Grevioux', u'David Aston', u'Geraldine Brophy', u'Leighton Cardno', u'Alexander Carroll', u'Elizabeth Hawthorne', u'Jason Hood', u'Mark Mitchinson', u'Craig Parker', u'Timothy Raby', u'Tania Nolan', u'Kate Beckinsale']
# CHAR [u'Viktor', u'Lucian', u'Sonja', u'Kraven', u'Andreas Tanis', u'Raze', u'Coloman', u"Nobleman's Wife", u'Fearful Lycan', u'Young Lucian', u'Orsova', u'Death Dealer', u'Nobleman', u'Sabas', u'Janosh', u'Luka', u'Selene']
# 1.1420501, max of:
#   1.1420501, product of:
#     2.2841003, sum of:
#       2.2841003, weight(directors.name:patrick in 1337) [PerFieldSimilarity], result of:
#         2.2841003, score(doc=1337,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           4.224067, fieldWeight in 1337, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.625, fieldNorm(doc=1337)
#     0.5, coord(1/2)
#
# *************************************
# 8	0.9136401		Sex and the City 2
# Sex and the City 2
# Carrie on.
# Carrie (Sarah Jessica Parker), Charlotte (Kristin Davis), and Miranda (Cynthia Nixon) are all married now, but they're still up for a little fun in the sun. When Samantha (Kim Cattrall) gets the chance to visit one of the most extravagant vacation destinations on the planet and offers to bring them all along, they surmise that a women-only retreat may be the perfect excuse to eschew their responsibilities and remember what life was like before they decided to settle down.
# 37786
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kristin Davis', u'Cynthia Nixon', u'Kim Cattrall', u'David Eigenberg', u'Evan Handler', u'Alexandra Fong', u'Parker Fong', u'Mario Cantone', u'Willie Garson', u'Noah Mills', u'Liza Minnelli', u'Billy Stritch', u'Alice Eve', u'Jason Lewis', u'Max Ryan', u'Lynn Cohen', u'Amira Mor', u"Dhaffer L'Abidine", u'John Corbett', u'Raya Meddine', u'Jennifer Ferrin', u'Tet Wada']
# CHAR [u'Carrie Bradshaw', u'Charlotte York', u'Miranda Hobbes', u'Samantha Jones', u'Steve Brady', u'Harry Goldenblatt', u'Lily York Goldenblatt', u'Lily York Goldenblatt', u'Anthony Marantino', u'Stanford Blatch', u'Nicky', u'Herself', u'Band Leader', u'Erin', u"Jerry 'Smith' Jerrod", u'Rikard Spirit', u'Magda', u'', u'Mahmud (non cr\xe9dit\xe9)', u'Aidan Shaw', u'Annesha', u'Patience', u'VIP Party Patron']
# 0.9136401, max of:
#   0.9136401, product of:
#     1.8272802, sum of:
#       1.8272802, weight(directors.name:patrick in 182) [PerFieldSimilarity], result of:
#         1.8272802, score(doc=182,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           3.3792536, fieldWeight in 182, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.5, fieldNorm(doc=182)
#     0.5, coord(1/2)
#
# *************************************
# 9	0.9136401		Sex and the City
# Sex and the City
# Get carried away.
# A New York writer on sex and love is finally getting married to her Mr. Big. But her three best girlfriends must console her after one of them inadvertently leads Mr. Big to jilt her.
# 4564
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kim Cattrall', u'Cynthia Nixon', u'Kristin Davis', u'Chris Noth', u'Willie Garson', u'David Eigenberg', u'Evan Handler', u'Jennifer Hudson', u'Jason Lewis', u'Mario Cantone', u'Julie Halston', u'Lynn Cohen', u'Anne Meara', u'Candice Bergen', u"Lil' Kim", u'Alexandra Fong', u'Kerry Bish\xe9', u'Joseph Pupo', u'Gilles Marini']
# CHAR [u'Carrie Bradshaw', u'Samantha Jones', u'Miranda Hobbes', u'Charlotte York Goldenblatt', u'Mr. Big', u'Stanford', u'Steve Brady', u'Harry Goldenblatt', u"Louise, Carrie's assistant", u'Smith Jerrod', u'Anthony Marantino', u'Bitsy von Muffling', u'Magda', u'Mary Brady', u'Enid Frick', u'Herself', u'Lily York Goldenblatt', u'Twenty-Something Girl Dreaming', u'Brady', u'Dante']
# 0.9136401, max of:
#   0.9136401, product of:
#     1.8272802, sum of:
#       1.8272802, weight(directors.name:patrick in 232) [PerFieldSimilarity], result of:
#         1.8272802, score(doc=232,freq=1.0), product of:
#           0.5407348, queryWeight, product of:
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.08000802, queryNorm
#           3.3792536, fieldWeight in 232, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.7585073, idf(docFreq=7, maxDocs=2535)
#             0.5, fieldNorm(doc=232)
#     0.5, coord(1/2)
#
# *************************************
# 10	0.48049		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# DIRS [u'Alfred Hitchcock']
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.48049, max of:
#   0.48049, sum of:
#     0.17749974, weight(cast.name:patrick in 497) [PerFieldSimilarity], result of:
#       0.17749974, score(doc=497,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.6449599, fieldWeight in 497, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.1875, fieldNorm(doc=497)
#     0.30299026, weight(cast.name:stewart in 497) [PerFieldSimilarity], result of:
#       0.30299026, score(doc=497,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.8426519, fieldWeight in 497, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.1875, fieldNorm(doc=497)
#
# *************************************
# 11	0.48049		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.48049, max of:
#   0.48049, sum of:
#     0.17749974, weight(cast.name:patrick in 959) [PerFieldSimilarity], result of:
#       0.17749974, score(doc=959,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.6449599, fieldWeight in 959, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.1875, fieldNorm(doc=959)
#     0.30299026, weight(cast.name:stewart in 959) [PerFieldSimilarity], result of:
#       0.30299026, score(doc=959,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.8426519, fieldWeight in 959, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.1875, fieldNorm(doc=959)
#
# *************************************
# 12	0.48049		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.48049, max of:
#   0.48049, sum of:
#     0.17749974, weight(cast.name:patrick in 291) [PerFieldSimilarity], result of:
#       0.17749974, score(doc=291,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.6449599, fieldWeight in 291, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.1875, fieldNorm(doc=291)
#     0.30299026, weight(cast.name:stewart in 291) [PerFieldSimilarity], result of:
#       0.30299026, score(doc=291,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.8426519, fieldWeight in 291, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.1875, fieldNorm(doc=291)
#
# *************************************
# 13	0.48049		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.48049, max of:
#   0.48049, sum of:
#     0.17749974, weight(cast.name:patrick in 439) [PerFieldSimilarity], result of:
#       0.17749974, score(doc=439,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.6449599, fieldWeight in 439, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.1875, fieldNorm(doc=439)
#     0.30299026, weight(cast.name:stewart in 439) [PerFieldSimilarity], result of:
#       0.30299026, score(doc=439,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.8426519, fieldWeight in 439, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.1875, fieldNorm(doc=439)
#
# *************************************
# 14	0.40040833		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 8) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=8,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 8, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=8)
#     0.2524919, weight(cast.name:stewart in 8) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=8,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 8, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=8)
#
# *************************************
# 15	0.40040833		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 465) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=465,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 465, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=465)
#     0.2524919, weight(cast.name:stewart in 465) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=465,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 465, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=465)
#
# *************************************
# 16	0.40040833		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 958) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=958,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 958, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=958)
#     0.2524919, weight(cast.name:stewart in 958) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=958,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 958, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=958)
#
# *************************************
# 17	0.40040833		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# DIRS [u'David Lynch']
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 308) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=308,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 308, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=308)
#     0.2524919, weight(cast.name:stewart in 308) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=308,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 308, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=308)
#
# *************************************
# 18	0.40040833		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 447) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=447,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 447, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=447)
#     0.2524919, weight(cast.name:stewart in 447) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=447,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 447, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=447)
#
# *************************************
# 19	0.40040833		X-Men
# X-Men
# Evolution Begins
# Two mutants, Rogue and Wolverine, come to a private academy for their kind whose resident superhero team, the X-Men, must oppose a terrorist organization with similar powers.
# 36657
# DIRS [u'Bryan Singer']
# CAST [u'Hugh Jackman', u'Patrick Stewart', u'Ian McKellen', u'Famke Janssen', u'James Marsden', u'Halle Berry', u'Anna Paquin', u'Tyler Mane', u'Ray Park', u'Rebecca Romijn', u'Bruce Davison', u'Matthew Sharp', u'Rhona Shekter', u'Kenneth McGregor', u'Shawn Roberts', u'Stan Lee', u'Shawn Ashmore', u'Sumela Kay', u'Alex Burton']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier', u'Eric Lensherr / Magneto', u'Jean Grey', u'Scott Summers / Cyclops', u'Ororo Munroe / Storm', u"Rogue / Marie D'Ancanto", u'Sabretooth', u'Toad', u'Mystique', u'Senator Kelly', u'Henry Gyrich', u"Magneto's Mother", u"Magneto's Father", u"Rogue's Boyfriend", u'Hot Dog Vendor', u'Bobby Drake / Iceman', u'Kitty Pryde', u'John Allerdyce / Pyro']
# 0.40040833, max of:
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 554) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=554,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 554, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=554)
#     0.2524919, weight(cast.name:stewart in 554) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=554,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 554, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=554)
#
# *************************************
# 20	0.40040833		Panic Room
# Panic Room
# It was supposed to be the safest room in the house.
# Trapped in their New York brownstone's panic room, a hidden chamber built as a sanctuary in the event of break-ins, newly divorced Meg Altman (Jodie Foster) and her young daughter Sarah (Kristen Stewart) play a deadly game of cat-and-mouse with three intruders - Burnham (Forest Whitaker), Raoul (Dwight Yoakam) and Junior (Jared Leto) - during a brutal home invasion. But the room itself is the focal point because what the intruders really want is inside it.
# 4547
# DIRS [u'David Fincher']
# CAST [u'Jodie Foster', u'Kristen Stewart', u'Forest Whitaker', u'Dwight Yoakam', u'Jared Leto', u'Patrick Bauchau', u'Ann Magnuson', u'Ian Buchanan', u'Andrew Kevin Walker', u'Paul Schulze', u'Mel Rodriguez', u'Richard Conant', u'Paul Simon', u'Victor Thrash', u'Ken Turner']
# CHAR [u'Meg Altman', u'Sarah Altman', u'Burnham', u'Raoul', u'Junior', u'Stephen Altman', u'Lydia Lynch', u'Evan Kurlander', u'Sleepy Neighbor', u'Officer Keeney', u'Officer Morales', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop']
# 0.40040833, max of:
#   0.26128304, product of:
#     0.5225661, sum of:
#       0.5225661, weight(overview:stewart in 688) [PerFieldSimilarity], result of:
#         0.5225661, score(doc=688,freq=1.0), product of:
#           0.57833886, queryWeight, product of:
#             7.228511, idf(docFreq=4, maxDocs=2535)
#             0.08000802, queryNorm
#           0.90356386, fieldWeight in 688, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.228511, idf(docFreq=4, maxDocs=2535)
#             0.125, fieldNorm(doc=688)
#     0.5, coord(1/2)
#   0.40040833, sum of:
#     0.14791645, weight(cast.name:patrick in 688) [PerFieldSimilarity], result of:
#       0.14791645, score(doc=688,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.5374666, fieldWeight in 688, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.15625, fieldNorm(doc=688)
#     0.2524919, weight(cast.name:stewart in 688) [PerFieldSimilarity], result of:
#       0.2524919, score(doc=688,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.70220995, fieldWeight in 688, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.15625, fieldNorm(doc=688)
#
# *************************************
# 21	0.35628724		One Flew Over the Cuckoo's Nest
# One Flew Over the Cuckoo's Nest
# If he's crazy, what does that make you?
# While serving time for insanity at a state mental hospital, implacable rabble-rouser Randle Patrick McMurphy inspires his fellow patients to rebel against the authoritarian rule of head nurse Mildred Ratched.
# 510
# DIRS [u'Milo\u0161 Forman']
# CAST [u'Jack Nicholson', u'Louise Fletcher', u'Danny DeVito', u'William Redfield', u'Scatman Crothers', u'Brad Dourif', u'Christopher Lloyd', u'Will Sampson', u'Dean R. Brooks', u'Michael Berryman', u'Sydney Lassick', u'William Duell', u'Vincent Schiavelli']
# CHAR [u'Randle Patrick McMurphy', u'Nurse Mildred Ratched', u'Martini', u'Harding', u'Orderly Turkle', u'Billy Bibbit', u'Taber', u'Chief Bromden', u'Dr. John Spivey', u'Ellis', u'Charlie Cheswick', u'Jim Sefelt', u'Fredrickson']
# 0.35628724, max of:
#   0.35628724, product of:
#     0.7125745, sum of:
#       0.7125745, weight(overview:patrick in 879) [PerFieldSimilarity], result of:
#         0.7125745, score(doc=879,freq=1.0), product of:
#           0.5514184, queryWeight, product of:
#             6.892039, idf(docFreq=6, maxDocs=2535)
#             0.08000802, queryNorm
#           1.2922573, fieldWeight in 879, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.892039, idf(docFreq=6, maxDocs=2535)
#             0.1875, fieldNorm(doc=879)
#     0.5, coord(1/2)
#
# *************************************
# 22	0.3266038		The Bounty Hunter
# The Bounty Hunter
# It's a Job. It Isn't Personal. Well, Maybe a Little...
# Milo Boyd is a bounty hunter whose latest gig is rather satisfying, as he finds out that the bail-skipper he must chase down is his own ex-wife, Nicole -- but she has no intention of getting nabbed without a fight. Complicating matters, Nicole's wannabe-boyfriend, Stewart, joins the chase.
# 27573
# DIRS [u'Andy Tennant']
# CAST [u'Gerard Butler', u'Jennifer Aniston', u'Gio Perez', u'Siobhan Fallon', u'Joel Garland', u'Jason Kolotouros', u'Matt Malloy', u'Jason Sudeikis', u'Adam Rose', u'Christine Baranski', u'Dorian Missick', u'David Costabile', u'Lynda Gravatt', u'Peter Greene', u'Jeff Garlin', u'Charlie Hewson']
# CHAR [u'Milo Boyd', u'Nicole Hurley', u'Uncle Sam', u'Teresa (as Siobhan Fallon Hogan)', u'Dwight (as Joel Marsh Garland)', u'Gelman', u'Gary', u'Stewart', u'Jimmy', u'Kitty Hurley', u'Bobby Jenkins', u'Arthur', u'Judge', u'Earl Mahler', u'Sid', u'Rich Guy']
# 0.32660383, max of:
#   0.32660383, product of:
#     0.65320766, sum of:
#       0.65320766, weight(overview:stewart in 27) [PerFieldSimilarity], result of:
#         0.65320766, score(doc=27,freq=1.0), product of:
#           0.57833886, queryWeight, product of:
#             7.228511, idf(docFreq=4, maxDocs=2535)
#             0.08000802, queryNorm
#           1.1294549, fieldWeight in 27, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.228511, idf(docFreq=4, maxDocs=2535)
#             0.15625, fieldNorm(doc=27)
#     0.5, coord(1/2)
#
# *************************************
# 23	0.3203267		The Collector
# The Collector
# He always takes one
# Desperate to repay his debt to his ex-wife, an ex-con plots a heist at his new employer's country home, unaware that a second criminal has also targeted the property, and rigged it with a series of deadly traps.
# 21407
# DIRS [u'Marcus Dunstan']
# CAST [u'Josh Stewart', u'Michael Reilly Burke', u'Andrea Roth', u'Juan Fern\xe1ndez', u'Madeline Zima', u'Karley Scott Collins', u'Robert Wisdom', u'Daniella Alonso', u'Haley Pullos', u'Diane Ayala Goldner', u'Alex Feldman', u'Krystal Mayo', u'Gregory Alan Williams', u'Michael Showers', u'Bill Stinchcomb', u'Brett Forbes', u'Eric Kelly McFarland', u'Jabari Thomas', u'Hiro Koda', u'Colvin Roberson', u'John Snell', u'Jon Dainty', u'William Morse', u'David Pitt', u'Philip Poth', u'Patrick Rizzotti', u'Tom Gulager']
# CHAR [u'Arkin', u'Michael Chase', u'Victoria Chase', u'The Collector', u'Jill Chase', u'Hannah Chase', u'Roy', u'Lisa', u'Cindy (as Haley Alexis Pullos)', u'Gena Wharton', u'Chad', u'Bar Dancer', u'Sheriff', u'Deputy sheriff', u'Bar Patron', u'Office Hoss Wiggins', u'Firefighter', u'Medic', u'Medic #2', u"Roy's Driver / Bodyguard", u'Yard Worker', u'Strip Club Patron (uncredited)', u'Stabbed Man (uncredited)', u'Barman (uncredited)', u'Foreman (uncredited)', u'Bowling Ball Cleaner (uncredited)', u'Officer Gulager']
# 0.3203267, max of:
#   0.3203267, sum of:
#     0.11833316, weight(cast.name:patrick in 615) [PerFieldSimilarity], result of:
#       0.11833316, score(doc=615,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.42997327, fieldWeight in 615, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.125, fieldNorm(doc=615)
#     0.20199351, weight(cast.name:stewart in 615) [PerFieldSimilarity], result of:
#       0.20199351, score(doc=615,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.56176794, fieldWeight in 615, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.125, fieldNorm(doc=615)
#
# *************************************
# 24	0.3203267		Save the Last Dance
# Save the Last Dance
# The Only Person You Need To Be Is Yourself.
# A white midwestern girl moves to Chicago, where her new boyfriend is a black teen from the South Side with a rough, semi-criminal past.
# 9816
# DIRS [u'Thomas Carter']
# CAST [u'Julia Stiles', u'Sean Patrick Thomas', u'Kerry Washington', u'Fredro Starr', u'Terry Kinney', u'Bianca Lawson', u'Vince Green', u'Garland Whitt', u'Elisabeth Oas', u'Artel Great', u'Cory Stewart', u'Jennifer Anglin', u'Dorothy Martin', u'Kim Tlusty', u'Felicia Fields', u'Ora Jones', u'Tab Baker', u'Kevin Reid', u'Andrew Rothenberg', u'Mekdes Bruk', u'Jerod Howard']
# CHAR [u'Sara Johnson', u'Derek Reynolds', u'Chenille Reynolds', u'Malakai', u'Roy Johnson', u'Nikki', u'Snookie', u'Kenny', u'Diggy', u'Arvel', u'Lip', u'Glynn', u'Momma Dean', u'Lindsay Johnson', u'Woman on Train', u'Mrs. Gwynn', u'Mr. Campbell', u'Wonk', u'Stern Judge', u'Lakisha', u'']
# 0.3203267, max of:
#   0.3203267, sum of:
#     0.11833316, weight(cast.name:patrick in 187) [PerFieldSimilarity], result of:
#       0.11833316, score(doc=187,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.42997327, fieldWeight in 187, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.125, fieldNorm(doc=187)
# ...
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.21875, fieldNorm(doc=128)
#     0.5, coord(1/2)
#
# *************************************
# 43	0.17674433		Moon
# Moon
# The last place you'd ever expect to find yourself.
# With only three weeks left in his three year contract, Sam Bell is getting anxious to finally return to Earth. He is the only occupant of a Moon-based manufacturing facility along with his computer and assistant, GERTY. The long period of time alone however has resulted in him talking to himself for the most part, or to his plants. Direct communication with Earth is not possible due to a long-standing communication malfunction but he does get an occasional message from his wife Tess. When he has an accident however, he wakens to find that he is not alone. He also comes to realize that his world is not what he thought it was.
# 17431
# DIRS [u'Duncan Jones']
# CAST [u'Sam Rockwell', u'Kevin Spacey', u'Dominique McElligott', u'Rosie Shaw', u'Adrienne Shaw', u'Kaya Scodelario', u'Benedict Wong', u'Matthew Berry', u'Malcolm Stewart', u'Robin Chalk']
# CHAR [u'Sam Bell', u'Robot Gerty (Voice)', u'Tess Bell', u'Little Eve', u'Nanny', u'Eve', u'Thompson', u'Overmeyers', u'Technician', u'Sam Bell Clone']
# 0.17674431, max of:
#   0.17674431, product of:
#     0.35348862, sum of:
#       0.35348862, weight(cast.name:stewart in 704) [PerFieldSimilarity], result of:
#         0.35348862, score(doc=704,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.98309386, fieldWeight in 704, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.21875, fieldNorm(doc=704)
#     0.5, coord(1/2)
#
# *************************************
# 44	0.16016334		300
# 300
# Spartans, prepare for glory!
# Based on Frank Miller's graphic novel, "300" is very loosely based the 480 B.C. Battle of Thermopylae, where the King of Sparta led his army against the advancing Persians; the battle is said to have inspired all of Greece to band together against the Persians, and helped usher in the world's first democracy.
# 1271
# DIRS [u'Zack Snyder']
# CAST [u'Gerard Butler', u'Lena Headey', u'Dominic West', u'David Wenham', u'Vincent Regan', u'Michael Fassbender', u'Tom Wisdom', u'Andrew Tiernan', u'Andrew Pleavin', u'Rodrigo Santoro', u'Giovani Cimmino', u'Tyler Neitzel', u'Greg Kramer', u'Stephen McHattie', u'Alex Ivanovici', u'Kelly Craig', u'Eli Snyder', u'Tim Connolly', u'Marie-Julie Rivest', u'Sebastian St. Germain', u'Peter Mensah', u'Arthur Holden', u'Michael Sinelnikoff', u'John Dunn-Hill', u'Dennis St John', u'Neil Napier', u'Dylan Smith', u'Maurizio Terrazzano', u'Robert Paradis', u'Kwasi Songui', u'Alexandra Beaton', u'Fr\xe9d\xe9ric Smith', u'Loucas Minchillo', u'Nicholas Minchillo', u'Tom Rack', u'Tom Rack', u'David Francis', u'James Bradford', u'Andrew Shaver', u'Kent McQuaid', u'Marcel Jeannin', u'Jere Gillis', u'Jeremy Thibodeau', u'Tyrone Benskin', u'Robert Maillet', u'Patrick Sabongui', u'Leon Laderach', u'Dave Lapommeray', u'Vervi Mauricio', u'Charles Papasoff', u'Isabelle Champeau', u'Veronique-Natale Szalankiewicz', u'Ma\xe9va Nadon', u'David Thibodeau', u'David Schaap', u'Jean Michel Par\xe9', u'Stewart Myiow', u'Andreanne Ross', u'Sara Giacalone', u'Ariadne Bourbonni\xe8re', u'Isabelle Fournel', u'Sandrine Merette-Attiow', u'Elisabeth Etienne', u'Danielle Hubbard', u'Ruan Vibegaard', u'Genevieve Guilbault', u'Bonnie Mak', u'Am\xe9lie Sorel', u'Caroline Aspirot', u'Gina Gagnon', u'Tania Trudell', u'St\xe9phanie Aubry', u'Mercedes Leggett', u'Stephania Gambaroff', u'Chanelle Lamothe', u'Sabrina-Jasmine Guilbault', u'Manny Cortez Tuazon', u'Atif Y. Siddiqi', u'Camille Rizkallah', u'Trudi Hanley', u'Neon Cobran', u'Gary A. Hecker', u'Devin Delorme', u'Deke Richards', u'Darren Shahlavi', u'Marc Trottier', u'Duy Vo Van', u'Agnieshka Wnorowska']
# CHAR [u'King Leonidas', u'Queen Gorgo', u'Theron', u'Dilios', u'Captain', u'Stelios', u'Astinos', u'Ephialtes', u'Daxos', u'Xerxes', u'Pleistarchos', u'Leonidas at 15 yrs', u'Ephor #1', u'Loyalist', u'Ephor #2', u'Oracle Girl', u'Leonidas at 7 / 8 yrs', u"Leonidas' Father", u"Leonidas' Mother", u'Fighting Boy (12 yrs old)', u'Messenger', u'Partisan', u'Elder councilman', u'Councilman', u'Spartan Baby Inspector', u'Spartan with Stick', u'Sentry #1', u'Sentry #2', u'Spartan General', u'Persian', u'Burned Village Child', u'Statesman', u'Spartan Baby A', u'Spartan Baby B', u'Ephor #3', u'Ephor #4', u'Ephor #5', u'Free Greek-Potter', u'Free Greek-Sculptor', u'Free Greek-Blacksmith', u'Free Greek-Baker', u'Spartan General #2', u'Spartan Boy', u'Persian Emissary', u'Uber Immortal (Giant)', u'Persian General', u'Executioner', u'Persian General Slaughtered', u'Armless Concubine', u'Blacksmith', u'Mother at Market', u'Daughter at Market (3 / 5 years old)', u'Girl at Market', u'Boy #1 at Market', u'Potter', u'Other Council Guard', u'Persian General', u'Concubine #1', u'Concubine #2', u'Kissing Concubine #1', u'Kissing Concubine #2', u'Contortionist', u'Dancer', u'Dancer', u'Dancer', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Slave Girl', u'Transsexual (Asian) #1', u'Transsexual (Arabian) #3', u'Giant with Arrow', u'Long Neck Woman', u'Litter Bearer / Slave', u'Ubermortal Vocals (voice)', u'Market boy #2', u'Spartan Soldier (uncredited)', u'Persian (uncredited)', u'Spartan Warrior (uncredited)', u'Persian (uncredited)', u'Market woman (uncredited)']
# 0.16016334, max of:
#   0.16016334, sum of:
#     0.05916658, weight(cast.name:patrick in 853) [PerFieldSimilarity], result of:
#       0.05916658, score(doc=853,freq=1.0), product of:
#         0.2752105, queryWeight, product of:
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.08000802, queryNorm
#         0.21498664, fieldWeight in 853, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4397862, idf(docFreq=220, maxDocs=2535)
#           0.0625, fieldNorm(doc=853)
#     0.100996755, weight(cast.name:stewart in 853) [PerFieldSimilarity], result of:
#       0.100996755, score(doc=853,freq=1.0), product of:
#         0.35956752, queryWeight, product of:
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.08000802, queryNorm
#         0.28088397, fieldWeight in 853, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4941435, idf(docFreq=76, maxDocs=2535)
#           0.0625, fieldNorm(doc=853)
#
# *************************************
# 45	0.15149513		Tangled Ever After
# Tangled Ever After
#
# The kingdom is in a festive mood as everyone gathers for the royal wedding of Rapunzel and Flynn. However, when Pascal and Maximus, as flower chameleon and ring bearer, respectively, lose the gold bands, a frenzied search and recovery mission gets underway. As the desperate duo tries to find the rings before anyone discovers that they’re missing, they leave behind a trail of comical chaos that includes flying lanterns, a flock of doves, a wine barrel barricade and a very sticky finale. Will Maximus and Pascal save the day and make it to the church in time? And will they ever get Flynn’s nose right?
# 82881
# DIRS [u'Nathan Greno', u'Byron Howard']
# CAST [u'Mandy Moore', u'Zachary Levi', u'Alan Dale', u'Paul F. Tompkins', u'Kari Wahlgren', u'Mark Allan Stewart', u'Byron Howard', u'Nathan Greno', u'Matt Nolan', u'Robert Bagnell', u'Erin Matthews']
# CHAR [u'Rapunzel (voice)', u'Flynn Rider (voice)', u'Priest (voice)', u'Short Thug (voice)', u'Queen (voice)', u'Dove Caller (voice)', u'Lantern Wrangler / Chef (voice)', u'Maximus / Guard / Stabbington Brothers (voice)', u'Frying Pan Caller (voice)', u'Additional Voices', u'Additional Voices']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 328) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=328,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 328, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=328)
#     0.5, coord(1/2)
#
# *************************************
# 46	0.15149513		Dom Hemingway
# Dom Hemingway
# I want my money plus interest.... and a present
# After spending 12 years in prison for keeping his mouth shut, notorious safe-cracker Dom Hemingway is back on the streets of London looking to collect what he's owed.
# 192134
# DIRS [u'Richard Shepard']
# CAST [u'Jude Law', u'Demi\xe1n Bichir', u'Richard E. Grant', u'Matthew C. Martino', u'Emilia Clarke', u'Kerry Condon', u'M\u0103d\u0103lina Diana Ghenea', u'Deborah Rosan', u'Vic Waghorn', u'Emma Lock', u'Nathan Stewart-Jarrett']
# CHAR [u'Dom Hemingway', u'Mr. Fontaine', u'Dickie', u'Nightclubber', u'Evelyn', u'Melody', u'Paolina', u'Actress', u'Pedestrian', u'Hostess', u'Hugh']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 714) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=714,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 714, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=714)
#     0.5, coord(1/2)
#
# *************************************
# 47	0.15149513		The Lucky One
# The Lucky One
#
# U.S. Marine Sergeant Logan Thibault (Efron) returns from his third tour of duty in Iraq, with the one thing he credits with keeping him alive-a photograph he found of a woman he doesn't even know. Learning her name is Beth (Schilling) and where she lives, he shows up at her door, and ends up taking a job at her family-run local kennel. Despite her initial mistrust and the complications in her life, a romance develops between them, giving Logan hope that Beth could be much more than his good luck charm.
# 77877
# DIRS [u'Scott Hicks']
# CAST [u'Zac Efron', u'Blythe Danner', u'Taylor Schilling', u'Jay R. Ferguson', u'Riley Thomas Stewart', u'Joe Chrest', u'Jillian Batherson', u'Courtney J. Clark', u'Sharon Morris', u'Russell Durham Comegys']
# CHAR [u'Logan Thibault', u'Nana', u'Beth Clayton', u'Keith Clayton', u'Ben Clayton', u'Deputy Moore', u'Amanda', u'Logans`s Sister', u'Principal Miller', u'Roger Lyle']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 599) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=599,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 599, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=599)
#     0.5, coord(1/2)
#
# *************************************
# 48	0.15149513		The Iron Lady
# The Iron Lady
# Never compromise
# A look at the life of Margaret Thatcher (Meryl Streep), the former Prime Minister of the United Kingdom, with a focus on the price she paid for power.
# 71688
# DIRS [u'Phyllida Lloyd']
# CAST [u'Meryl Streep', u'Anthony Stewart Head', u'Harry Lloyd', u'Jim Broadbent', u'Susan Brown', u'Alice da Cunha', u'Phoebe Waller-Bridge', u'Iain Glen', u'Alexandra Roach', u'Victoria Bewick', u'Olivia Colman', u'Eloise Webb']
# CHAR [u'Margaret Thatcher', u'Geoffrey Howe', u'Young Denis Thatcher', u'Denis Thatcher', u'June', u'Cleaner', u'Susie', u'Alfred Roberts', u'Young Margaret Thatcher', u'Muriel Roberts', u'Carol Thatcher', u'Young Carol']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 915) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=915,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 915, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=915)
#     0.5, coord(1/2)
#
# *************************************
# 49	0.15149513		Father of the Bride
# Father of the Bride
# Love is wonderful. Until it happens to your only daughter.
# George Banks is an ordinary, middle-class man whose 21 year-old daughter Annie has decided to marry a man from an upper-class family, but George can't think of what life would be like without his daughter. He becomes slightly insane, but his wife tries to make him happy for Annie, but when the wedding takes place at their home and a foreign wedding planner takes over the ceremony.
# 11846
# DIRS [u'Charles Shyer']
# CAST [u'Steve Martin', u'Diane Keaton', u'Kimberly Williams-Paisley', u'George Newbern', u'Martin Short', u'Kieran Culkin', u'BD Wong', u'Peter Michael Goetz', u'Kate McGregor-Stewart']
# CHAR [u'George Stanley Banks', u'Nina Banks', u'Annie Banks', u'Bryan MacKenzie', u'Franck Eggelhoffer', u'Matty Banks', u'Howard Weinstein', u'John MacKenzie', u'Joanna MacKenzie']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 993) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=993,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 993, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=993)
#     0.5, coord(1/2)
#
# *************************************
# 50	0.15149513		Still Alice
# Still Alice
#
# Alice Howland, happily married with three grown children, is a renowned linguistics professor who starts to forget words. When she receives a devastating diagnosis, Alice and her family find their bonds tested.
# 284293
# DIRS [u'Richard Glatzer', u'Wash Westmoreland']
# CAST [u'Julianne Moore', u'Alec Baldwin', u'Kristen Stewart', u'Kate Bosworth', u'Hunter Parrish', u'Victoria Cartagena', u'Erin Darke', u'Shane McRae', u'Stephen Kunken', u'Eha Urbsalu', u'Cat Lynch']
# CHAR [u'Dr. Alice Howland', u'Dr. John Howland', u'Lydia Howland', u'Anna', u'Tom Howland', u'Prof. Hooper', u'Jenny', u'Charlie', u'Dr. Benjamin', u"Alice Howland's Mother", u'Pinkberry Worker']
# 0.15149513, max of:
#   0.15149513, product of:
#     0.30299026, sum of:
#       0.30299026, weight(cast.name:stewart in 1049) [PerFieldSimilarity], result of:
#         0.30299026, score(doc=1049,freq=1.0), product of:
#           0.35956752, queryWeight, product of:
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.08000802, queryNorm
#           0.8426519, fieldWeight in 1049, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4941435, idf(docFreq=76, maxDocs=2535)
#             0.1875, fieldNorm(doc=1049)
#     0.5, coord(1/2)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((directors.name:patrick directors.name:stewart) | (title:patrick title:stewart) | (overview:patrick overview:stewart) | (cast.name:patrick cast.name:stewart)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.3.2 -- Listing 7 -- Reducing the Impact of directors.name

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
                       'cast.name', 'directors.name^0.1'],  #A    
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.48049		Vertigo
# 2	0.48049		Star Trek: Insurrection
# 3	0.48049		Gnomeo & Juliet
# 4	0.48049		Star Trek: First Contact
# 5	0.40040833		Conspiracy Theory
# 6	0.40040833		The Wolverine
# 7	0.40040833		Star Trek: Nemesis
# 8	0.40040833		Dune
# 9	0.40040833		Star Trek: Generations
# 10	0.40040833		X-Men

# %% [markdown]
# # 5.3.3 -- Listings 8&9  – Analysis Extracting English Bigrams

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}


# From listing 9
mappingSettings = {
    'movie': {
        'properties': {
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }            
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # 5.3.3 -- Listing 10 -- Searching *.bigramed fields, reindexing

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.7239306		Star Trek: Insurrection
# 2	0.7239306		Gnomeo & Juliet
# 3	0.7239306		Star Trek: First Contact
# 4	0.7239306		Excalibur
# 5	0.6334393		Conspiracy Theory
# 6	0.6334393		The Wolverine
# 7	0.6334393		Star Trek: Nemesis
# 8	0.6334393		Dune
# 9	0.6334393		Star Trek: Generations
# 10	0.6334393		X-Men

# %% [markdown]
# # 5.3.4	Letting Losers Share The Glory (no listing number)

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'best_fields',
            'tie_breaker': 0.4
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.2915788		Star Trek
# 2	1.1068168		Star Trek: Generations
# 3	1.0999181		Star Trek: Insurrection
# 4	1.0999181		Star Trek: First Contact
# 5	1.0915862		Star Trek: Nemesis
# ===============
# Num	Relevance Score		Movie Title
# 1	1.2915788		Star Trek
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 1.2915788, max plus 0.4 times others of:
#   1.2915788, product of:
#     2.5831575, sum of:
#       1.1724579, weight(title:star in 638) [PerFieldSimilarity], result of:
#         1.1724579, score(doc=638,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           3.6798315, fieldWeight in 638, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.625, fieldNorm(doc=638)
#       1.4106996, weight(title:trek in 638) [PerFieldSimilarity], result of:
#         1.4106996, score(doc=638,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           4.0364223, fieldWeight in 638, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.625, fieldNorm(doc=638)
#     0.5, coord(2/4)
#
# *************************************
# 2	1.1068168		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 1.1068168, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 384) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=384,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 384, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=384)
#       1.1285597, weight(title:trek in 384) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=384,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 384, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=384)
#     0.5, coord(2/4)
#   0.038076136, product of:
#     0.15230455, sum of:
#       0.15230455, weight(overview:star in 384) [PerFieldSimilarity], result of:
#         0.15230455, score(doc=384,freq=1.0), product of:
#           0.22967151, queryWeight, product of:
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.054115467, queryNorm
#           0.6631408, fieldWeight in 384, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.15625, fieldNorm(doc=384)
#     0.25, coord(1/4)
#   0.14580819, product of:
#     0.43742457, sum of:
#       0.43742457, weight(cast.name.bigramed:patrick stewart in 384) [PerFieldSimilarity], result of:
#         0.43742457, score(doc=384,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.3297344, fieldWeight in 384, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.21875, fieldNorm(doc=384)
#     0.33333334, coord(1/3)
#
# *************************************
# 3	1.0999181		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 1.0999181, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 839) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=839,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 839, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=839)
#       1.1285597, weight(title:trek in 839) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=839,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 839, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=839)
#     0.5, coord(2/4)
#   0.16663793, product of:
#     0.49991378, sum of:
#       0.49991378, weight(cast.name.bigramed:patrick stewart in 839) [PerFieldSimilarity], result of:
#         0.49991378, score(doc=839,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.5196965, fieldWeight in 839, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.25, fieldNorm(doc=839)
#     0.33333334, coord(1/3)
#
# *************************************
# 4	1.0999181		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 1.0999181, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 376) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=376,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 376, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=376)
#       1.1285597, weight(title:trek in 376) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=376,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 376, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=376)
#     0.5, coord(2/4)
#   0.16663793, product of:
#     0.49991378, sum of:
#       0.49991378, weight(cast.name.bigramed:patrick stewart in 376) [PerFieldSimilarity], result of:
#         0.49991378, score(doc=376,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.5196965, fieldWeight in 376, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.25, fieldNorm(doc=376)
#     0.33333334, coord(1/3)
#
# *************************************
# 5	1.0915862		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 1.0915862, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 838) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=838,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 838, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=838)
#       1.1285597, weight(title:trek in 838) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=838,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 838, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=838)
#     0.5, coord(2/4)
#   0.14580819, product of:
#     0.43742457, sum of:
#       0.43742457, weight(cast.name.bigramed:patrick stewart in 838) [PerFieldSimilarity], result of:
#         0.43742457, score(doc=838,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.3297344, fieldWeight in 838, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.21875, fieldNorm(doc=838)
#     0.33333334, coord(1/3)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((title:star title:trek title:patrick title:stewart) | (overview:star overview:trek overview:patrick overview:stewart) | (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart) | (directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart))~0.4)->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.3.5, Listing 11 Counting Multiple Signals using Most Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.57795894		Star Trek: Generations
# 2	0.37984636		Star Trek: Insurrection
# 3	0.37984636		Star Trek: First Contact
# 4	0.37325242		Star Trek: Nemesis
# 5	0.20443419		Star Trek
# 6	0.16354734		Star Trek: The Motion Picture
# 7	0.16354734		Star Trek Into Darkness
# 8	0.14310393		Star Trek VI: The Undiscovered Country
# 9	0.14310393		Star Trek V: The Final Frontier
# 10	0.14310393		Star Trek IV: The Voyage Home

# %% [markdown]
# # 5.3.6, Listing 12	Boosting in Most-Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.2', 'overview',
 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.21602789		Star Trek: Generations
# 2	0.13754827		Star Trek: Insurrection
# 3	0.13754827		Star Trek: First Contact
# 4	0.12960409		Star Trek: Nemesis
# 5	0.046246767		Star Trek
# 6	0.04466839		The Beaver
# 7	0.036997415		Star Trek: The Motion Picture
# 8	0.036997415		Star Trek Into Darkness
# 9	0.035703447		Maps to the Stars
# 10	0.033136796		Dinosaur

# %% [markdown]
# # 5.3.7	When Additional Matches Don’t Matter (no listing number)

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
