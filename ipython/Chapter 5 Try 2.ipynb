# %%
import requests
import json
import os

# you'll need to have an API key for TMDB
# to run these examples,
# run export TMDB_API_KEY=<YourAPIKey>
tmdb_api_key = os.environ["TMDB_API_KEY"]

# Setup tmdb as its own session, caching requests
# (we only want to cache tmdb, not elasticsearch)
# Get your TMDB API key from
#  https://www.themoviedb.org/documentation/api
# then in shell do export TMDB_API_KEY=<Your Key>
tmdb_api = requests.Session()
tmdb_api.params={'api_key': tmdb_api_key}

# Optional, enable client-side caching for TMDB
# Requires: https://httpcache.readthedocs.org/en/latest/
#from httpcache import CachingHTTPAdapter
#tmdb_api.mount('https://', CachingHTTPAdapter())
#tmdb_api.mount('http://', CachingHTTPAdapter())

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
                        data=text)
    print resp.text
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, data=json.dumps(query))
    if httpResp.status_code != 200:
        print "Search Failed <%s>" % httpResp.status_code
        print "%s" % httpResp.text
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])
            if verbose:
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     data=json.dumps({'query': query['query']}))
        print json.loads(httpResp.text)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print "Delete TMDB Index <%s>" % resp.status_code
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", data=json.dumps(settings))
    print "Create TMDB Index <%s>" % resp.status_code
    if resp.status_code != 200:
        print resp.text
    
    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    for id, movie in movieDict.iteritems():
        addCmd = {"index": {"_index": "tmdb", "_type": "movie", "_id": movie["id"]}}
        esDoc  = movie
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies)
    print "Bulk Index into TMDB Index <%s>" % resp.status_code


def movieList(maxMovies=10000):
    movieIds = [];
    numPages = maxMovies / 20    
    for page in range(1, numPages + 1):
        httpResp = tmdb_api.get('https://api.themoviedb.org/3/movie/top_rated', params={'page': page})  #(1)
        if httpResp.status_code != 200:
            print "top_rated: <%s>" % httpResp.status_code
            print " why? %s " % httpResp.text
        jsonResponse = json.loads(httpResp.text) #(2)
        movies = jsonResponse['results']
        if len(movies) == 0:
            break
        for movie in movies:
            movieIds.append(movie['id'])
    return movieIds

## Extract
## Extract accesses the TMDB endpoints required and creates an entry for each movie. Recall how we iterated
## over all the movie entries at an endpoint like 'top_rated'. There's one 
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass    
        
    movieDict = {}
    for movieId in movieIds:
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s" % movieId)
        movie = json.loads(httpResp.text)
        
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s/credits" % movieId)
        credits = json.loads(httpResp.text)
        cast = credits['cast']
        crew = credits['crew']
        directors = []
        actors = []
        for crewMember in crew:
            if crewMember['job'] == 'Director':
                directors.append(crewMember)
        movie['cast'] = cast
        movie['directors'] = directors
        
        movieDict[movieId] = movie
    
    # Store a file locally
    with open('tmdb.json', 'w') as f:
        f.write(json.dumps(movieDict))
        f.close()
    
    return movieDict

# %% [markdown]
# # Pull Down Movie Info

# %%
movieDict = extract([])

# %%
analysis = {
    "analyzer" : {
      "default" : {
        "type" : "english"
        }
      }
   }

reindex(analysisSettings=analysis, movieDict=movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# ## Search From Chapter 3

# %%
usersSearch = 'basketball with space aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.1789474		Space Jam
# 2	0.48381874		Independence Day
# 3	0.4233414		Battleship
# 4	0.41026133		Doom
# 5	0.41026133		The Invasion
# ===============
# Num	Relevance Score		Movie Title
# 1	1.1789474		Space Jam
# Space Jam
# Get ready to jam.
# Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.
# 2300
# CAST [u'Michael Jordan', u'Wayne Knight', u'Billy West', u'Dee Bradley Baker', u'Theresa Randle', u'Danny DeVito', u'Brandon Hammond', u'Larry Bird', u'Bill Murray', u'Charles Barkley', u'Patrick Ewing', u'Tyrone Bogues', u'Larry Johnson', u'Shawn Bradley', u'Ahmad Rashad', u'Del Harris', u'Vlade Divac', u'Cedric Ceballos', u'Jim Rome', u'Paul Westphal', u'Danny Ainge', u'Alonzo Mourning', u'A.C. Green', u'Charles Oakley', u'Derek Harper', u'Jeff Malone', u'Anthony Miller', u'Sharone Wright']
# CHAR [u'Himself', u'Stan Podolak', u'Bugs Bunny/Elmer Fudd (voice)', u'Daffy Duck/Tazmanian Devil/Bull (voice)', u'Juanita Jordan', u'Mr. Swackhammer (voice)', u'Michael Jordan (at 10)', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself']
# 1.1789474, max of:
#   1.1789474, product of:
#     1.7684212, sum of:
#       1.235671, weight(overview:basketbal in 245) [PerFieldSimilarity], result of:
#         1.235671, score(doc=245,freq=1.0), product of:
#           0.707807, queryWeight, product of:
#             6.983096, idf(docFreq=5, maxDocs=2380)
#             0.10136005, queryNorm
#           1.745774, fieldWeight in 245, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.983096, idf(docFreq=5, maxDocs=2380)
#             0.25, fieldNorm(doc=245)
#       0.5327501, weight(overview:alien in 245) [PerFieldSimilarity], result of:
#         0.5327501, score(doc=245,freq=1.0), product of:
#           0.4647562, queryWeight, product of:
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.10136005, queryNorm
#           1.1463002, fieldWeight in 245, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.25, fieldNorm(doc=245)
#     0.6666667, coord(2/3)
#   0.1029726, product of:
#     0.3089178, sum of:
#       0.3089178, weight(title:space in 245) [PerFieldSimilarity], result of:
#         0.3089178, score(doc=245,freq=1.0), product of:
#           0.0707807, queryWeight, product of:
#             6.983096, idf(docFreq=5, maxDocs=2380)
#             0.0101360055, queryNorm
#           4.364435, fieldWeight in 245, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.983096, idf(docFreq=5, maxDocs=2380)
#             0.625, fieldNorm(doc=245)
#     0.33333334, coord(1/3)
#
# *************************************
# 2	0.48381874		Independence Day
# Independence Day
# Earth. Take a good look. It might be your last.
# On July 2, a giant alien mothership enters orbit around Earth and deploys several dozen saucer-shaped "destroyer" spacecraft that quickly lay waste to major cities around the planet. On July 3, the United States conducts a coordinated counterattack that fails. On July 4 the a plan is devised to gain access to the interior of the alien mothership in space in order to plant a nuclear missile.
# 602
# CAST [u'Will Smith', u'Bill Pullman', u'Jeff Goldblum', u'Mary McDonnell', u'Judd Hirsch', u'Robert Loggia', u'Randy Quaid', u'Margaret Colin', u'Vivica A. Fox', u'James Rebhorn', u'Harvey Fierstein', u'Adam Baldwin', u'James Duval', u'Lisa Jakub', u'Giuseppe Andrews', u'Harry Connick Jr.', u'Mae Whitman', u'Kiersten Warren', u'John Storey', u'Frank Novak', u'Devon Gummersall', u'Leland Orser', u'Mirron E. Willis', u'Ross Lacy', u'David Pressman', u'Raphael Sbarge', u'Bobby Hosea', u'Dan Lauria', u'Steve Giannelli', u'Eric Paskel', u'Carlos Lac\xe1mara', u'John Bennett Perry', u'Troy Willis', u'Tim Kelleher', u'Wayne Wilderson', u'Jay Acovone', u'James Wong', u'Jana Marie Hupp', u'Robert Pine', u'David Channell', u'John Capodice', u'Greg Collins', u'Derek Webster', u'Mark Fite', u'Levan Uchaneishvili', u'Kristof Konrad', u'Kevin Sifuentes', u'Elston Ridgle', u'Randy Oglesby', u'Jack Moore', u'Barry Del Sherman', u'Lyman Ward', u'Anthony Crivello', u'Richard Speight Jr.', u'Joe Fowler', u'Sharon Tay', u'Peter J. Lucas', u'Yelena Danova', u'Johnny Kim', u'Vanessa J. Wells', u'Sayed Badreya', u'Adam Tomei', u'John Bradley', u'Kimberly Beck', u'Andrew Keegan', u'Jim Piddock', u'Pat Skipper', u'Erick Avari', u'Brent Spiner']
# CHAR [u'Captain Steven Hiller', u'President Thomas J. Whitmore', u'David Levinson', u'First Lady Marilyn Whitmore', u'Julius Levinson', u'General William Grey', u'Russell Casse', u'Constance Spano', u'Jasmine Dubrow', u'Albert Nimzicki', u'Marty Gilbert', u'Major Mitchell', u'Miguel Casse', u'Alicia Casse', u'Troy Casse', u'Captain Jimmy Wilder', u'Patricia Whitmore', u'Tiffany', u'Dr. Isaacs', u'Teddy', u'Philip', u'Technician/ Medical Assistant 1', u'Aide', u'Aide', u"Whitmore's Aide", u'Commander / Tech', u'Commanding Officer', u'Commanding Officer', u'Radar Technician', u'Radar Technician', u'Radar Operator', u'Secret Service Agent', u'Secret Service Agent', u'Technician', u'Area 51 Technician', u'Area 51 Guard', u'SETI Technician 1', u'SETI Technician 3', u'Chief of Staff', u'Secret Service Agent', u'Mario', u'Military Aide', u'Sky Crane Pilot', u'Pilot', u'Russian Pilot (Levani)', u'Russian Pilot', u'Tank Commander', u'Soldier', u'Mechanic', u'Mechanic', u'Street Preacher', u'Secret Service Agent', u'Lincoln', u'Ed', u'Reporter', u'Reporter', u'Russian Reporter', u'Russian Newscaster', u'Korean Newscaster', u'Newscaster', u'Arab Pilot', u'Sailor', u'Lucas', u'Housewife', u'Older Boy', u'Reginald', u'Redneck', u'SETI Chief', u'Dr. Brackish Okun']
# 0.48381874, max of:
#   0.48381874, product of:
#     0.7257281, sum of:
#       0.34901688, weight(overview:space in 675) [PerFieldSimilarity], result of:
#         0.34901688, score(doc=675,freq=1.0), product of:
#           0.5319877, queryWeight, product of:
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.10136005, queryNorm
#           0.6560619, fieldWeight in 675, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.125, fieldNorm(doc=675)
#       0.37671122, weight(overview:alien in 675) [PerFieldSimilarity], result of:
#         0.37671122, score(doc=675,freq=2.0), product of:
#           0.4647562, queryWeight, product of:
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.10136005, queryNorm
#           0.81055665, fieldWeight in 675, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.125, fieldNorm(doc=675)
#     0.6666667, coord(2/3)
#
# *************************************
# 3	0.4233414		Battleship
# Battleship
# The Battle for Earth Begins at Sea
# When mankind beams a radio signal into space, a reply comes from "Planet G", in the form of several alien crafts that splash down in the waters off Hawaii. Lieutenant Alex Hopper (Taylor Kitsch) is a navel weapons officer assigned to the ship USS John Paul Jones, part of an international naval coalition which becomes the world's last hope for survival as they engage the hostile alien force of unimaginable strength. While takng on the invaders, Hopper must also try to live up to the potential his brother Stone (Alexander Skarsgård) and his fiancée's father, Admiral Shane (Liam Neeson), expect of him.
# 44833
# CAST [u'Taylor Kitsch', u'Alexander Skarsg\xe5rd', u'Rihanna', u'Brooklyn Decker', u'Tadanobu Asano', u'Liam Neeson', u'Gregory D. Gadson', u'Hamish Linklater', u'Jesse Plemons', u'John Tui', u'Jerry Ferrara', u'David Jensen', u'Peter Berg', u'Adam Godley', u'Rico McClinton', u'Joji Yoshida', u'Stephen Bishop', u'Austin Naulty', u'James Rawlings', u'Dustin J. Reno', u'Rick Hoffman', u'Gary Grubbs']
# CHAR [u'Lieutenant Alex Hopper', u'Commander Stone Hopper', u'Petty Officer Cora', u'Sam', u'Captain Yugi Nagata', u'Admiral Shane', u'Lieutenant Colonel Mick Canales', u'Cal Zapata', u'Boatswain Mate Seaman Jimmy "Ordy" Ord', u'Chief Petty Officer Walter "The Beast" Lynch', u'Sampson JOOD Strodell', u'NASA Director', u'JPJ 2nd Gunner', u'Dr. Nogrady', u'Captain Browley', u'Chief Engineer Hiroki', u'JPJ OOD', u'JPJ Fireman', u'JPJ Scat', u'Electronic Warfare Supervisor', u'Chairman, Joint Chiefs of Staff', u'Air Force Chief of Staff']
# 0.4233414, max of:
#   0.4233414, product of:
#     0.6350121, sum of:
#       0.30538976, weight(overview:space in 435) [PerFieldSimilarity], result of:
#         0.30538976, score(doc=435,freq=1.0), product of:
#           0.5319877, queryWeight, product of:
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.10136005, queryNorm
#           0.5740541, fieldWeight in 435, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.109375, fieldNorm(doc=435)
#       0.32962233, weight(overview:alien in 435) [PerFieldSimilarity], result of:
#         0.32962233, score(doc=435,freq=2.0), product of:
#           0.4647562, queryWeight, product of:
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.10136005, queryNorm
#           0.7092371, fieldWeight in 435, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.109375, fieldNorm(doc=435)
#     0.6666667, coord(2/3)
#
# *************************************
# 4	0.41026133		Doom
# Doom
# No one gets out alive.
# A team of space marines known as the Rapid Response Tactical Squad, led by Sarge, is sent to a science facility on Mars after somebody reports a security breach. There, they learn that the alert came after a test subject, a mass murderer purposefully injected with alien DNA, broke free and began killing people. Dr. Grimm, who is related to team member Reaper, informs them all that the chromosome can mutate humans into monsters -- and is highly infectious.
# 8814
# CAST [u'Dwayne Johnson', u'Karl Urban', u'Rosamund Pike', u'Ben Daniels', u'Deobia Oparei', u'Razaaq Adoti', u'Richard Brake', u'Al Weaver', u'Dexter Fletcher', u'Brian Steele', u'Yao Chin', u'Robert Russell', u'Daniel York', u'Ian Hughes', u'Sara Houghton']
# CHAR [u'Sarge', u'John Grimm', u'Samantha Grimm', u'Goat', u'Destroyer', u'Duke', u'Corporal Dean Portman', u'The Kid', u'Pinky', u'Hell Knight / Curtis Stahl', u'Mac', u'Dr. Carmack', u'Lt. Huengs', u'Sanford Crosby', u'Dr. Jenna Willits']
# 0.41026133, max of:
#   0.41026133, product of:
#     0.61539197, sum of:
#       0.34901688, weight(overview:space in 500) [PerFieldSimilarity], result of:
#         0.34901688, score(doc=500,freq=1.0), product of:
#           0.5319877, queryWeight, product of:
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.10136005, queryNorm
#           0.6560619, fieldWeight in 500, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.125, fieldNorm(doc=500)
#       0.26637506, weight(overview:alien in 500) [PerFieldSimilarity], result of:
#         0.26637506, score(doc=500,freq=1.0), product of:
#           0.4647562, queryWeight, product of:
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.10136005, queryNorm
#           0.5731501, fieldWeight in 500, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.125, fieldNorm(doc=500)
#     0.6666667, coord(2/3)
#
# *************************************
# 5	0.41026133		The Invasion
# The Invasion
# Do not trust anyone. Do not show emotion. Do not fall asleep.
# Washington, D.C. psychologist Carol Bennell and her colleague Dr. Ben Driscoll are the only two people on Earth who are aware of an epidemic running rampant through the city. They discover an alien virus aboard a crashed space shuttle that transforms anyone who comes into contact with it into unfeeling drones while they sleep. Carol realizes her son holds the key to stopping the spread of the plague and she races to find him before it is too late.
# 4858
# CAST [u'Nicole Kidman', u'Daniel Craig', u'Jeremy Northam', u'Jeffrey Wright', u'Jackson Bond', u'Veronica Cartwright', u'Josef Sommer', u'Celia Weston', u'Roger Rees', u'Eric Benjamin', u'Susan Floyd', u'Stephanie Berry', u'Alexis Raben', u'Adam LeFevre', u'Joanna Merlin']
# CHAR [u'Carol', u'Ben', u'Tucker', u'Dr. Galeano', u'Oliver', u'Wendy Lenk', u'Dr. Henryk Belicec', u'Ludmilla Belicec', u'Yorish', u'Gene', u'Pam', u'Carly', u"Belicec's Aide", u'Richard Lenk', u'Joan Kaufman']
# 0.41026133, max of:
#   0.41026133, product of:
#     0.61539197, sum of:
#       0.34901688, weight(overview:space in 700) [PerFieldSimilarity], result of:
#         0.34901688, score(doc=700,freq=1.0), product of:
#           0.5319877, queryWeight, product of:
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.10136005, queryNorm
#           0.6560619, fieldWeight in 700, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.248495, idf(docFreq=33, maxDocs=2380)
#             0.125, fieldNorm(doc=700)
#       0.26637506, weight(overview:alien in 700) [PerFieldSimilarity], result of:
#         0.26637506, score(doc=700,freq=1.0), product of:
#           0.4647562, queryWeight, product of:
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.10136005, queryNorm
#           0.5731501, fieldWeight in 700, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.585201, idf(docFreq=65, maxDocs=2380)
#             0.125, fieldNorm(doc=700)
#     0.6666667, coord(2/3)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:basketbal overview:space overview:alien) | ((title:basketbal title:space title:alien)^0.1)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Examining Space Jam

# %%
spaceJamId = 2300
httpResp = requests.get("http://localhost:9200/tmdb/movie/%s" % spaceJamId)
spaceJamDoc = json.loads(httpResp.text)
print json.dumps(spaceJamDoc['_source'], indent=True)
# Out:
# {
#  "poster_path": "/9T9ucCk6wO0crRBUIkBJMRAVcKp.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 230000000,
#  "overview": "Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.",
#  "video": false,
#  "id": 2300,
#  "genres": [
#   {
#    "id": 16,
#    "name": "Animation"
#   },
#   {
#    "id": 35,
#    "name": "Comedy"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 14,
#    "name": "Fantasy"
#   },
#   {
#    "id": 10751,
#    "name": "Family"
#   }
#  ],
#  "title": "Space Jam",
#  "tagline": "Get ready to jam.",
#  "vote_count": 275,
#  "homepage": "",
#  "belongs_to_collection": null,
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "cs",
#    "name": "\u010cesk\u00fd"
#   },
#   {
#    "iso_639_1": "fr",
#    "name": "Fran\u00e7ais"
#   },
#   {
#    "iso_639_1": "pl",
#    "name": "Polski"
#   },
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   }
#  ],
#  "imdb_id": "tt0117705",
#  "adult": false,
#  "backdrop_path": "/kBTdPNTAzagAY6UiwY957KCDGuu.jpg",
#  "production_companies": [
#   {
#    "name": "Warner Bros. Animation",
#    "id": 2785
#   },
#   {
#    "name": "Warner Bros. Entertainment",
#    "id": 17
#   }
#  ],
#  "release_date": "1996-11-15",
#  "popularity": 0.778260445788321,
#  "original_title": "Space Jam",
#  "budget": 80000000,
#  "cast": [
#   {
#    "name": "Michael Jordan",
#    "character": "Himself",
#    "id": 23678,
#    "credit_id": "52fe434bc3a36847f80496c9",
#    "cast_id": 2,
#    "profile_path": "/7y16frD57Ztzk2mY4JeI2pQQhan.jpg",
#    "order": 0
#   },
#   {
#    "name": "Wayne Knight",
#    "character": "Stan Podolak",
#    "id": 4201,
#    "credit_id": "52fe434bc3a36847f80496cd",
#    "cast_id": 3,
#    "profile_path": "/oW9aeZwkz1S1IMjQGtd9mnvlEax.jpg",
#    "order": 1
#   },
#   {
#    "name": "Billy West",
#    "character": "Bugs Bunny/Elmer Fudd (voice)",
#    "id": 23679,
#    "credit_id": "52fe434bc3a36847f80496d1",
#    "cast_id": 4,
#    "profile_path": "/9V9fsfmWjHEDbS8tB5EOdHkyMFg.jpg",
#    "order": 2
#   },
#   {
#    "name": "Dee Bradley Baker",
#    "character": "Daffy Duck/Tazmanian Devil/Bull (voice)",
#    "id": 23680,
#    "credit_id": "52fe434bc3a36847f80496d5",
#    "cast_id": 5,
#    "profile_path": "/zFXwtsdvUCeNkzCzYpYZdAmTkJY.jpg",
#    "order": 3
#   },
#   {
#    "name": "Theresa Randle",
#    "character": "Juanita Jordan",
#    "id": 4604,
#    "credit_id": "52fe434bc3a36847f80496d9",
#    "cast_id": 6,
#    "profile_path": "/18LVR034VKDGOFqDw1EA1VZQVoe.jpg",
#    "order": 4
#   },
#   {
#    "name": "Danny DeVito",
#    "character": "Mr. Swackhammer (voice)",
#    "id": 518,
#    "credit_id": "52fe434bc3a36847f80496dd",
#    "cast_id": 7,
#    "profile_path": "/zKuyzmKzPLG7RJo7lbbHjx6CCZc.jpg",
#    "order": 5
#   },
#   {
#    "name": "Brandon Hammond",
#    "character": "Michael Jordan (at 10)",
#    "id": 23681,
#    "credit_id": "52fe434bc3a36847f80496e1",
#    "cast_id": 8,
#    "profile_path": "/ooljlVi5IYf2w4Px3jqc8OQdjjS.jpg",
#    "order": 6
#   },
#   {
#    "name": "Larry Bird",
#    "character": "Himself",
#    "id": 23682,
#    "credit_id": "52fe434bc3a36847f80496e5",
#    "cast_id": 9,
#    "profile_path": "/1KRnQVsXS8mz4tHHWD1yPAQBXq2.jpg",
#    "order": 7
#   },
#   {
#    "name": "Bill Murray",
#    "character": "Himself",
#    "id": 1532,
#    "credit_id": "52fe434bc3a36847f80496e9",
#    "cast_id": 12,
#    "profile_path": "/eb58HuFIrxS0zUmbmW4d8YXTbje.jpg",
#    "order": 8
#   },
#   {
#    "name": "Charles Barkley",
#    "character": "Himself",
#    "id": 1211812,
#    "credit_id": "5361746b0e0a2649bf0004e6",
#    "cast_id": 37,
#    "profile_path": "/mqHWhTtrja9vI8kfI6z7tCq5gB1.jpg",
#    "order": 9
#   },
#   {
#    "name": "Patrick Ewing",
#    "character": "Himself",
#    "id": 1231141,
#    "credit_id": "53614c6cc3a368397e0001d2",
#    "cast_id": 19,
#    "profile_path": "/aaXM8PuixEHNTLmvBQJLH8vV1SV.jpg",
#    "order": 11
#   },
#   {
#    "name": "Tyrone Bogues",
#    "character": "Himself",
#    "id": 1232432,
#    "credit_id": "53614e44c3a36839650001b4",
#    "cast_id": 20,
#    "profile_path": null,
#    "order": 12
#   },
#   {
#    "name": "Larry Johnson",
#    "character": "Himself",
#    "id": 1225517,
#    "credit_id": "53614eb1c3a36839650001bc",
#    "cast_id": 21,
#    "profile_path": "/gbfwZWitnSrcQwkAughr5Ji4iT5.jpg",
#    "order": 13
#   },
#   {
#    "name": "Shawn Bradley",
#    "character": "Himself",
#    "id": 1234833,
#    "credit_id": "5361565a0e0a2649b800027a",
#    "cast_id": 22,
#    "profile_path": null,
#    "order": 14
#   },
#   {
#    "name": "Ahmad Rashad",
#    "character": "Himself",
#    "id": 1197748,
#    "credit_id": "5361566c0e0a2649a6000277",
#    "cast_id": 23,
#    "profile_path": null,
#    "order": 15
#   },
#   {
#    "name": "Del Harris",
#    "character": "Himself",
#    "id": 1251369,
#    "credit_id": "536156930e0a2649b800027f",
#    "cast_id": 24,
#    "profile_path": null,
#    "order": 16
#   },
#   {
#    "name": "Vlade Divac",
#    "character": "Himself",
#    "id": 193304,
#    "credit_id": "536156a50e0a2649a90002a3",
#    "cast_id": 25,
#    "profile_path": "/ivflYHUbWXKyDe5B9su5HSidMA9.jpg",
#    "order": 17
#   },
#   {
#    "name": "Cedric Ceballos",
#    "character": "Himself",
#    "id": 1230823,
#    "credit_id": "536156d20e0a2649b8000282",
#    "cast_id": 26,
#    "profile_path": null,
#    "order": 18
#   },
#   {
#    "name": "Jim Rome",
#    "character": "Himself",
#    "id": 1215304,
#    "credit_id": "536156e10e0a2649ad000272",
#    "cast_id": 27,
#    "profile_path": null,
#    "order": 19
#   },
#   {
#    "name": "Paul Westphal",
#    "character": "Himself",
#    "id": 1315402,
#    "credit_id": "536156ee0e0a2649b8000285",
#    "cast_id": 28,
#    "profile_path": null,
#    "order": 20
#   },
#   {
#    "name": "Danny Ainge",
#    "character": "Himself",
#    "id": 1315446,
#    "credit_id": "536156fe0e0a2649ad000275",
#    "cast_id": 29,
#    "profile_path": null,
#    "order": 21
#   },
#   {
#    "name": "Alonzo Mourning",
#    "character": "Himself",
#    "id": 180625,
#    "credit_id": "5361571f0e0a2649b8000287",
#    "cast_id": 30,
#    "profile_path": "/ukR2lS5Z8avrJnN3Kua1ks3Habf.jpg",
#    "order": 22
#   },
#   {
#    "name": "A.C. Green",
#    "character": "Himself",
#    "id": 1315447,
#    "credit_id": "5361572a0e0a2649bf000295",
#    "cast_id": 31,
#    "profile_path": null,
#    "order": 23
#   },
#   {
#    "name": "Charles Oakley",
#    "character": "Himself",
#    "id": 1315403,
#    "credit_id": "536157540e0a2649bf00029b",
#    "cast_id": 32,
#    "profile_path": "/l35FQsV529lOhDFvMGk8aJ82AV9.jpg",
#    "order": 24
#   },
#   {
#    "name": "Derek Harper",
#    "character": "Himself",
#    "id": 1315448,
#    "credit_id": "536157680e0a2649a90002b5",
#    "cast_id": 33,
#    "profile_path": null,
#    "order": 25
#   },
#   {
#    "name": "Jeff Malone",
#    "character": "Himself",
#    "id": 1315449,
#    "credit_id": "536157780e0a2649a6000287",
#    "cast_id": 34,
#    "profile_path": null,
#    "order": 26
#   },
#   {
#    "name": "Anthony Miller",
#    "character": "Himself",
#    "id": 1315450,
#    "credit_id": "536157ba0e0a2649bb0002d3",
#    "cast_id": 35,
#    "profile_path": null,
#    "order": 27
#   },
#   {
#    "name": "Sharone Wright",
#    "character": "Himself",
#    "id": 1315451,
#    "credit_id": "536157cb0e0a2649bf0002a7",
#    "cast_id": 36,
#    "profile_path": null,
#    "order": 28
#   }
#  ],
#  "directors": [
#   {
#    "name": "Joe Pytka",
#    "department": "Directing",
#    "job": "Director",
#    "credit_id": "52fe434bc3a36847f80496c5",
#    "profile_path": "/c46Ah1KxlfC4W8mHVrGDsJ7dMPJ.jpg",
#    "id": 23677
#   }
#  ],
#  "vote_average": 6.3,
#  "runtime": 88
# }

# %% [markdown]
# # Trying Some Star Trek Queries From Chapter 3's Search Config

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview', 'cast.name', 'directors.name'],
         }
    },
    'size': 50,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.5308861		Legion
# 2	0.5308861		Halo 4: Forward Unto Dawn
# 3	0.5308861		Priest
# 4	0.5308861		Dark Skies
# 5	0.42397094		Drive Angry
# 6	0.42397094		Feast
# 7	0.42397094		District 13: Ultimatum
# 8	0.42397094		The Expendables 3
# 9	0.42397094		Underworld: Rise of the Lycans
# 10	0.42397094		My Bloody Valentine
# 11	0.33917674		Sex and the City 2
# 12	0.33917674		Sex and the City
# 13	0.33917674		Doubt
# 14	0.33917674		Sinbad: Legend of the Seven Seas
# 15	0.336124		Hannah Montana: The Movie
# 16	0.27162924		The Beaver
# 17	0.19351654		Dinosaur
# 18	0.18290025		Vertigo
# 19	0.18290025		Star Trek: Insurrection
# 20	0.18290025		Gnomeo & Juliet
# 21	0.18290025		Star Trek: First Contact
# 22	0.18290025		Excalibur
# 23	0.1537503		X-Men: Days of Future Past
# 24	0.15241688		Conspiracy Theory
# 25	0.15241688		The Wolverine
# 26	0.15241688		Star Trek: Nemesis
# 27	0.15241688		Dune
# 28	0.15241688		Star Trek: Generations
# 29	0.15241688		X-Men
# 30	0.15241688		Panic Room
# 31	0.15241688		Robin Hood: Men in Tights
# 32	0.1516412		Homefront
# 33	0.14753689		Star Trek
# 34	0.1451374		The Lord of the Rings: The Two Towers
# 35	0.14062323		Ted
# 36	0.1397123		One Flew Over the Cuckoo's Nest
# 37	0.12627394		The Bounty Hunter
# 38	0.121933505		The Collector
# 39	0.121933505		Save the Last Dance
# 40	0.121933505		X2: X-Men United
# 41	0.121933505		TMNT
# 42	0.121933505		The Prince of Egypt
# 43	0.121933505		X-Men: The Last Stand
# 44	0.121933505		A Time to Kill
# 45	0.118029505		Star Trek: The Motion Picture
# 46	0.118029505		Star Trek Into Darkness
# 47	0.10669182		The Faculty
# 48	0.10546742		The Cabin in the Woods
# 49	0.104386374		London Boulevard
# 50	0.10327582		Star Trek VI: The Undiscovered Country
# ===============
# Num	Relevance Score		Movie Title
# 1	0.5308861		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 0.5308861, max of:
#   0.5308861, product of:
#     2.1235445, sum of:
#       2.1235445, weight(directors.name:stewart in 1092) [PerFieldSimilarity], result of:
#         2.1235445, score(doc=1092,freq=1.0), product of:
#           0.45829087, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.06181603, queryNorm
#           4.633617, fieldWeight in 1092, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=1092)
#     0.25, coord(1/4)
#
# *************************************
# 2	0.5308861		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 0.5308861, max of:
#   0.5308861, product of:
#     2.1235445, sum of:
#       2.1235445, weight(directors.name:stewart in 1209) [PerFieldSimilarity], result of:
#         2.1235445, score(doc=1209,freq=1.0), product of:
#           0.45829087, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.06181603, queryNorm
#           4.633617, fieldWeight in 1209, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=1209)
#     0.25, coord(1/4)
#
# *************************************
# 3	0.5308861		Priest
# Priest
# Vampire Killer
# In an alternate world, humanity and vampires have warred for centuries. After the last Vampire War, the veteran Warrior Priest lives in obscurity with other humans inside one of the Church's walled cities. When the Priest's niece is kidnapped by vampires, the Priest breaks his vows to hunt them down. He is accompanied by the niece's boyfriend, who is a wasteland sheriff, and a former Warrior Priestess.
# 38321
# CAST [u'Paul Bettany', u'Cam Gigandet', u'Karl Urban', u'Lily Collins', u'Maggie Q', u'Stephen Moyer', u'M\xe4dchen Amick', u'Christopher Plummer', u'Brad Dourif', u'Alan Dale']
# CHAR [u'Priest', u'Hicks', u'Black Hat', u'Lucy', u'Priestess', u'Aaron', u'Shannon', u'Monsignor Orelas', u'Salesman', u'Monsignor Chamberlain']
# 0.5308861, max of:
#   0.5308861, product of:
#     2.1235445, sum of:
#       2.1235445, weight(directors.name:stewart in 240) [PerFieldSimilarity], result of:
#         2.1235445, score(doc=240,freq=1.0), product of:
#           0.45829087, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.06181603, queryNorm
#           4.633617, fieldWeight in 240, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=240)
#     0.25, coord(1/4)
#
# *************************************
# 4	0.5308861		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 0.5308861, max of:
#   0.5308861, product of:
#     2.1235445, sum of:
#       2.1235445, weight(directors.name:stewart in 270) [PerFieldSimilarity], result of:
#         2.1235445, score(doc=270,freq=1.0), product of:
#           0.45829087, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.06181603, queryNorm
#           4.633617, fieldWeight in 270, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=270)
#     0.25, coord(1/4)
#   0.022560488, product of:
#     0.090241954, sum of:
#       0.090241954, weight(cast.name:patrick in 270) [PerFieldSimilarity], result of:
#         0.090241954, score(doc=270,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.42717782, fieldWeight in 270, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.125, fieldNorm(doc=270)
#     0.25, coord(1/4)
#
# *************************************
# 5	0.42397094		Drive Angry
# Drive Angry
# One hell of a ride.
# Milton is a hardened felon who has broken out of Hell, intent on finding the vicious cult who brutally murdered his daughter and kidnapped her baby. He joins forces with Piper, a sexy, tough-as-nails waitress with a 69 Charger, who's also seeking redemption of her own. Caught in a deadly race against time, Milton has three days to avoid capture, avenge his daughter's death, and save her baby before she's mercilessly sacrificed by the cult.
# 47327
# CAST [u'Nicolas Cage', u'Amber Heard', u'William Fichtner', u'Billy Burke', u'David Morse', u'Katy Mixon', u'Charlotte Ross', u'Christa Campbell', u'Todd Farmer', u'Jack McGee', u'Tom Atkins', u'Wanetah Walmsley', u'Edrick Browne', u'Robin McGee', u'Fabian C. Moreno', u'Marc Macaulay', u'Pruitt Taylor Vince', u'Julius Washington', u'Jamie Teer', u'Bryan Massey', u'Timothy Walter', u'Kent Jude Bernard', u'Brent Phillip Henry', u'Gerry May', u'Sherri Talley', u'Arianne Margot', u'Con Schell', u'Nick Gomez', u'Joe Chrest', u'Oakley Lehman', u'Thirl Haston', u'Jake Brake', u'Tim J. Smith', u'Jeffrey J. Dashnaw', u'Tim Trella', u'James Landry H\xe9bert', u'Kenneth Wayne Bradley', u'Kendrick Hudson', u'Michael Papajohn', u'April Littlejohn', u'Henry Kingi', u'Simona Williams', u'Shelby Swatek', u'Joseph Blackstone', u'Dan Forest', u'Elise Fyke', u"Jonathan O'Rear", u'James Paul', u'Alice Searcy', u'Lanie Taylor', u'David Lee Valle']
# CHAR [u'Milton', u'Piper', u'Accountant', u'Jonah King', u'Webster', u'Norma Jean', u'Candy', u'Mona', u'Frank', u'Fat Lou', u'Cap', u'American Indian Mother', u'Rookie', u'Guy with Camera Phone', u'Latino Busboy', u'Sarge', u'Roy', u'Uniformed Officer', u'Babysitter', u'Trooper #1', u'Trooper #2', u'Teen #1', u'Teen #2', u'TV Male News Reporter #1', u'TV Female News Reporter #2', u"Milton's Daughter (Older)", u'Fucking Driver', u'Fucking Middle', u'Fucking Passenger', u'Cultist with Iron Pipe', u'Cultist with Sickle', u'Cultist with Machete', u'Cultist with Hatchet', u'Cowboy with Cattle Prod', u'Cultist with Sledge', u'Man in Leather Jacket', u'Man with Wig', u'Burly Dude', u'Tattooed Guy', u'Business Woman', u'Thin Old Man', u'Lady in Leopard Skin', u'Truck Driving Woman', u'Bar Patron', u'American Indian Dad', u'Laughing Cowgirl', u'Resturant Patron', u'Bar Patron', u'Restaurant Patron', u"Milton's Daughter - Younger", u'Highway Patrol']
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 200) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=200,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 200, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=200)
#     0.25, coord(1/4)
#
# *************************************
# 6	0.42397094		Feast
# Feast
#
# This Oscar-winning animated short film tells the story of one man's love life is seen through the eyes of his best friend and dog, Winston, and revealed bite by bite through the meals they share.
# 293299
# CAST [u'Tommy Snider', u'Katie Lowes', u'Ben Bledsoe']
# CHAR [u'James', u'Additional Voices (voice)', u'Additional Voices']
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 318) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=318,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 318, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=318)
#     0.25, coord(1/4)
#
# *************************************
# 7	0.42397094		District 13: Ultimatum
# District 13: Ultimatum
#
# Damien and Leito return to District 13 on a mission to bring peace to the troubled sector that is controlled by five different gang bosses, before the city's secret services take drastic measures to solve the problem.
# 15357
# CAST [u'Cyril Raffaelli', u'David Belle', u'Philippe Torreton', u'Daniel Duval', u'Elodie Yung', u"MC Jean Gab'1", u'James Deano', u'Laouni Mouhid', u'Fabrice Feltzinger', u'Pierre-Marie Mosconi', u'Johnny Amaro']
# CHAR [u'Damien', u'Le\xefto', u'Le Pr\xe9sident de la R\xe9publique', u'Walter Gassman', u'Tao', u'Molko', u'Karl le skin', u'Ali-K', u'Little Montana', u'Roland', u'Policier centre de contr\xf4le']
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 1148) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=1148,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 1148, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=1148)
#     0.25, coord(1/4)
#
# *************************************
# 8	0.42397094		The Expendables 3
# The Expendables 3
# New team. New attitude. New mission.
# Barney (Stallone), Christmas (Statham) and the rest of the team comes face-to-face with Conrad Stonebanks (Gibson), who years ago co-founded The Expendables with Barney. Stonebanks subsequently became a ruthless arms trader and someone who Barney was forced to kill... or so he thought. Stonebanks, who eluded death once before, now is making it his mission to end The Expendables -- but Barney has other plans. Barney decides that he has to fight old blood with new blood, and brings in a new era of Expendables team members, recruiting individuals who are younger, faster and more tech-savvy. The latest mission becomes a clash of classic old-school style versus high-tech expertise in the Expendables' most personal battle yet.
# 138103
# CAST [u'Sylvester Stallone', u'Jason Statham', u'Harrison Ford', u'Arnold Schwarzenegger', u'Mel Gibson', u'Wesley Snipes', u'Randy Couture', u'Dolph Lundgren', u'Terry Crews', u'Kelsey Grammer', u'Glen Powell', u'Antonio Banderas', u'Victor Ortiz', u'Ronda Rousey', u'Kellan Lutz', u'Jet Li', u'Ivan Kostadinov', u'Robert Davi', u'Nikolay Stoyanov Ilchev', u'Daniel Angelov', u'Slavi Slavov', u'Dimiter Doichinov', u'Nikolay Stanoev', u'Harry Anichkin', u'Boswell Maloka', u'Natalie Burn', u'Velizar Binev', u'Sarai Givaty', u'Liubomir Simeonov', u'Frank Pesce', u'Thomas Canestraro']
# CHAR [u'Barney Ross', u'Lee Christmas', u'Max Drummer', u'Trench', u'Conrad Stonebanks', u'Doc', u'Toll Road', u'Gunnar Jensen', u'Hale Caesar', u'Bonaparte', u'Thorn', u'Galgo', u'Mars', u'Luna', u'John Smilee', u'Yin Yang', u'Krug', u'Vata', u'Local Cop #1', u'Local Cop #2', u'Warden', u'Head Bodyguard', u'Tech Guy', u'Colonel', u'Somali Drug Warlord', u"Conrad's Wife", u'Art Broker', u'Camilla', u'Cyclops', u'Fight Watcher', u"Conrad's Henchman"]
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 1262) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=1262,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 1262, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=1262)
#     0.25, coord(1/4)
#
# *************************************
# 9	0.42397094		Underworld: Rise of the Lycans
# Underworld: Rise of the Lycans
# Every war has a beginning.
# A prequel to the first two Underworld films, this fantasy explains the origins of the feud between the Vampires and the Lycans. Aided by his secret love, Sonja, courageous Lucian leads the Lycans in battle against brutal Vampire king Viktor. Determined to break the king's enslavement of his people, Lucian faces off against the Death Dealer army in a bid for Lycan independence.
# 12437
# CAST [u'Bill Nighy', u'Michael Sheen', u'Rhona Mitra', u'Shane Brolly', u'Steven Mackintosh', u'Kevin Grevioux', u'David Aston', u'Geraldine Brophy', u'Leighton Cardno', u'Alexander Carroll', u'Elizabeth Hawthorne', u'Jason Hood', u'Mark Mitchinson', u'Craig Parker', u'Timothy Raby', u'Tania Nolan', u'Kate Beckinsale']
# CHAR [u'Viktor', u'Lucian', u'Sonja', u'Kraven', u'Andreas Tanis', u'Raze', u'Coloman', u"Nobleman's Wife", u'Fearful Lycan', u'Young Lucian', u'Orsova', u'Death Dealer', u'Nobleman', u'Sabas', u'Janosh', u'Luka', u'Selene']
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 71) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=71,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 71, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=71)
#     0.25, coord(1/4)
#
# *************************************
# 10	0.42397094		My Bloody Valentine
# My Bloody Valentine
# He's gonna break your heart.
# Ten years ago, a tragedy changed the town of Harmony forever. Tom Hanniger, an inexperienced coal miner, caused an accident in the tunnels that trapped and killed five men and sent the only survivor, Harry Warden, into a permanent coma. But Harry Warden wanted revenge. Exactly one year later, on Valentine’s Day, he woke up…and brutally murdered twenty-two people with a pickaxe before being killed.
# 14435
# CAST [u'Jensen Ackles', u'Jaime King', u'Kerr Smith', u'Betsy Rue', u'Edi Gathegi', u'Tom Atkins', u'Kevin Tighe', u'Megan Boone', u'Karen Baum', u'Joy de la Paz', u'Marc Macaulay', u'Todd Farmer', u'Jeff Hochendoner', u"Bingo O'Malley", u'Liam Rhodes', u'Richard John Walters']
# CHAR [u'Tom Hanniger', u'Sarah Palmer', u'Axel Palmer', u'Irene', u'Deputy Martin', u'Sheriff Jim Burke', u'Ben Foley', u'Megan', u'Deputy Ferris', u'Rosa', u'Riggs', u'Frank the Trucker', u'Red', u'Officer Hinch', u'Michael', u'Harry Warden']
# 0.42397094, max of:
#   0.42397094, product of:
#     1.6958838, sum of:
#       1.6958838, weight(directors.name:patrick in 206) [PerFieldSimilarity], result of:
#         1.6958838, score(doc=206,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           4.140831, fieldWeight in 206, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=206)
#     0.25, coord(1/4)
#
# *************************************
# 11	0.33917674		Sex and the City 2
# Sex and the City 2
# Carrie on.
# Carrie (Sarah Jessica Parker), Charlotte (Kristin Davis), and Miranda (Cynthia Nixon) are all married now, but they're still up for a little fun in the sun. When Samantha (Kim Cattrall) gets the chance to visit one of the most extravagant vacation destinations on the planet and offers to bring them all along, they surmise that a women-only retreat may be the perfect excuse to eschew their responsibilities and remember what life was like before they decided to settle down.
# 37786
# CAST [u'Sarah Jessica Parker', u'Kristin Davis', u'Cynthia Nixon', u'Kim Cattrall', u'David Eigenberg', u'Evan Handler', u'Alexandra Fong', u'Parker Fong', u'Mario Cantone', u'Willie Garson', u'Noah Mills', u'Liza Minnelli', u'Billy Stritch', u'Alice Eve', u'Jason Lewis', u'Max Ryan', u'Lynn Cohen', u'Amira Mor', u"Dhaffer L'Abidine", u'John Corbett', u'Raya Meddine', u'Jennifer Ferrin', u'Tet Wada']
# CHAR [u'Carrie Bradshaw', u'Charlotte York', u'Miranda Hobbes', u'Samantha Jones', u'Steve Brady', u'Harry Goldenblatt', u'Lily York Goldenblatt', u'Lily York Goldenblatt', u'Anthony Marantino', u'Stanford Blatch', u'Nicky', u'Herself', u'Band Leader', u'Erin', u"Jerry 'Smith' Jerrod", u'Rikard Spirit', u'Magda', u'', u'Mahmud (non cr\xe9dit\xe9)', u'Aidan Shaw', u'Annesha', u'Patience', u'VIP Party Patron']
# 0.33917674, max of:
#   0.33917674, product of:
#     1.356707, sum of:
#       1.356707, weight(directors.name:patrick in 320) [PerFieldSimilarity], result of:
#         1.356707, score(doc=320,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           3.3126647, fieldWeight in 320, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=320)
#     0.25, coord(1/4)
#
# *************************************
# 12	0.33917674		Sex and the City
# Sex and the City
# Get carried away.
# A New York writer on sex and love is finally getting married to her Mr. Big. But her three best girlfriends must console her after one of them inadvertently leads Mr. Big to jilt her.
# 4564
# CAST [u'Sarah Jessica Parker', u'Kim Cattrall', u'Cynthia Nixon', u'Kristin Davis', u'Chris Noth', u'Willie Garson', u'David Eigenberg', u'Evan Handler', u'Jennifer Hudson', u'Jason Lewis', u'Mario Cantone', u'Julie Halston', u'Lynn Cohen', u'Anne Meara', u'Candice Bergen', u"Lil' Kim", u'Alexandra Fong', u'Kerry Bish\xe9', u'Joseph Pupo', u'Gilles Marini']
# CHAR [u'Carrie Bradshaw', u'Samantha Jones', u'Miranda Hobbes', u'Charlotte York Goldenblatt', u'Mr. Big', u'Stanford', u'Steve Brady', u'Harry Goldenblatt', u"Louise, Carrie's assistant", u'Smith Jerrod', u'Anthony Marantino', u'Bitsy von Muffling', u'Magda', u'Mary Brady', u'Enid Frick', u'Herself', u'Lily York Goldenblatt', u'Twenty-Something Girl Dreaming', u'Brady', u'Dante']
# 0.33917674, max of:
#   0.33917674, product of:
#     1.356707, sum of:
#       1.356707, weight(directors.name:patrick in 542) [PerFieldSimilarity], result of:
#         1.356707, score(doc=542,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           3.3126647, fieldWeight in 542, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=542)
#     0.25, coord(1/4)
#
# *************************************
# 13	0.33917674		Doubt
# Doubt
# There is no evidence. There are no witnesses. But for one, there is no doubt.
# In 1964, a Catholic school nun questions a priest's ambiguous relationship with a troubled young student, suspecting him of abuse. He denies the charges, and much of the film's quick-fire dialogue tackles themes of religion, morality, and authority.
# 14359
# CAST [u'Amy Adams', u'Philip Seymour Hoffman', u'Meryl Streep', u'Viola Davis', u'Alice Drummond']
# CHAR [u'Sister James', u'Father Brendan Flynn', u'Sister Aloysius Beauvier', u'Mrs. Miller', u'Sister Veronica']
# 0.33917674, max of:
#   0.33917674, product of:
#     1.356707, sum of:
#       1.356707, weight(directors.name:patrick in 231) [PerFieldSimilarity], result of:
#         1.356707, score(doc=231,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           3.3126647, fieldWeight in 231, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=231)
#     0.25, coord(1/4)
#
# *************************************
# 14	0.33917674		Sinbad: Legend of the Seven Seas
# Sinbad: Legend of the Seven Seas
#
# The sailor of legend is framed by the goddess Eris for the theft of the Book of Peace, and must travel to her realm at the end of the world to retrieve it and save the life of his childhood friend Prince Proteus.
# 14411
# CAST [u'Brad Pitt', u'Catherine Zeta-Jones', u'Michelle Pfeiffer', u'Joseph Fiennes', u'Dennis Haysbert', u'Timothy West', u'Timothy West', u'Raman Hui', u'Chung Chan', u'Jim Cummings', u'Conrad Vernon', u'Andrew Birch', u'Chris Miller']
# CHAR [u'Sinbad', u'Marina', u'Eris', u'Proteus', u'Kale', u'Dymas', u'Rat', u'Jin', u'Li', u'Luca', u'Jed', u'Grum / Chum', u'Tower guard']
# 0.33917674, max of:
#   0.33917674, product of:
#     1.356707, sum of:
#       1.356707, weight(directors.name:patrick in 632) [PerFieldSimilarity], result of:
#         1.356707, score(doc=632,freq=1.0), product of:
#           0.40955156, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.06181603, queryNorm
#           3.3126647, fieldWeight in 632, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=632)
#     0.25, coord(1/4)
#
# *************************************
# 15	0.336124		Hannah Montana: The Movie
# Hannah Montana: The Movie
# She has the best of both worlds...now she has to choose just one.
# When Miley Stewart (aka pop-star Hannah Montana) gets too caught up in the superstar celebrity lifestyle, her dad decides it's time for a total change of scenery. But sweet nibblets! Miley must trade in all the glitz and glamour of Hollywood for some ol' blue jeans on the family farm in Tennessee, and question if she can be both Miley Stewart and Hannah Montana. With a little help from her friends – and awesome guest stars Taylor Swift, Rascal Flatts and Vanessa Williams – will she figure out whether to choose Hannah or Miley?
# 18126
# CAST [u'Miley Cyrus', u'Billy Ray Cyrus', u'Emily Osment', u'Jason Earles', u'Taylor Swift', u'Lucas Till', u'Mitchel Musso', u'Mois\xe9s Arias', u'Vanessa Williams', u'Margo Martindale', u'Melora Hardin', u'Brooke Shields', u'Brandon Cyrus']
# CHAR [u'Miley Stewart/Hannah Montana', u'Billy Ray Stewart', u'Lilly Truscott', u'Jackson Rod Stewart', u'Herself', u'Travis Brody', u'Oliver Oken', u'Rico', u'Vita', u'Ruby', u'Lorelai', u"Miley's Mom", u'Extra']
# 0.33612403, max of:
#   0.33612403, product of:
#     0.67224807, sum of:
#       0.17222874, weight(overview:star in 416) [PerFieldSimilarity], result of:
#         0.17222874, score(doc=416,freq=2.0), product of:
#           0.26235348, queryWeight, product of:
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.06181603, queryNorm
#           0.6564759, fieldWeight in 416, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.109375, fieldNorm(doc=416)
#       0.5000193, weight(overview:stewart in 416) [PerFieldSimilarity], result of:
#         0.5000193, score(doc=416,freq=2.0), product of:
#           0.44702047, queryWeight, product of:
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.06181603, queryNorm
#           1.1185602, fieldWeight in 416, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.109375, fieldNorm(doc=416)
#     0.5, coord(2/4)
#
# *************************************
# 16	0.27162924		The Beaver
# The Beaver
# He's here to save Walter's life.
# Suffering from a severe case of depression, toy company CEO Walter Black (Mel Gibson) begins using a beaver hand puppet to help him open up to his family. With his father seemingly going insane, adolescent son Porter (Anton Yelchin) pushes for his parents to get a divorce. Jodie Foster directs and co-stars as Walter's wife in this dark comedy that also features Riley Thomas Stewart and Jennifer Lawrence.
# 50780
# CAST [u'Jodie Foster', u'Mel Gibson', u'Jennifer Lawrence', u'Anton Yelchin']
# CHAR [u'Meredith Black', u'Walter Black', u'Norah', u'Porter Black']
# 0.27162924, max of:
#   0.27162924, product of:
#     0.5432585, sum of:
#       0.13918184, weight(overview:star in 716) [PerFieldSimilarity], result of:
#         0.13918184, score(doc=716,freq=1.0), product of:
#           0.26235348, queryWeight, product of:
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.06181603, queryNorm
#           0.53051263, fieldWeight in 716, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.125, fieldNorm(doc=716)
#       0.40407664, weight(overview:stewart in 716) [PerFieldSimilarity], result of:
#         0.40407664, score(doc=716,freq=1.0), product of:
#           0.44702047, queryWeight, product of:
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.06181603, queryNorm
#           0.90393317, fieldWeight in 716, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.125, fieldNorm(doc=716)
#     0.5, coord(2/4)
#
# *************************************
# 17	0.19351654		Dinosaur
# Dinosaur
# You have never seen anything like this.
# An orphaned dinosaur raised by lemurs joins an arduous trek to a sancturary after a meteorite shower destroys his family home.
# 10567
# CAST [u' D.B. Sweeney', u'Alfre Woodard', u'Ossie Davis', u'Max Casella', u'Hayden Panettiere', u'Samuel E. Wright', u'Julianna Margulies', u'Peter Siragusa', u'Joan Plowright', u'Della Reese']
# CHAR [u'Aladar', u'Plio', u'Yar', u'Zini', u'Suri', u'Kron', u'Neera', u'Bruton', u'Baylene', u'Eema']
# 0.19351654, max of:
#   0.19351654, product of:
#     0.77406615, sum of:
#       0.77406615, weight(overview:trek in 733) [PerFieldSimilarity], result of:
#         0.77406615, score(doc=733,freq=1.0), product of:
#           0.43749148, queryWeight, product of:
#             7.0773144, idf(docFreq=6, maxDocs=3051)
#             0.06181603, queryNorm
#           1.7693286, fieldWeight in 733, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.0773144, idf(docFreq=6, maxDocs=3051)
#             0.25, fieldNorm(doc=733)
#     0.25, coord(1/4)
#
# *************************************
# 18	0.18290025		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.18290025, max of:
#   0.18290025, product of:
#     0.3658005, sum of:
#       0.13536294, weight(cast.name:patrick in 635) [PerFieldSimilarity], result of:
#         0.13536294, score(doc=635,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.64076674, fieldWeight in 635, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=635)
#       0.23043758, weight(cast.name:stewart in 635) [PerFieldSimilarity], result of:
#         0.23043758, score(doc=635,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.83603936, fieldWeight in 635, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=635)
#     0.5, coord(2/4)
#
# *************************************
# 19	0.18290025		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.18290025, max of:
#   0.18290025, product of:
#     0.3658005, sum of:
#       0.13536294, weight(cast.name:patrick in 293) [PerFieldSimilarity], result of:
#         0.13536294, score(doc=293,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.64076674, fieldWeight in 293, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=293)
#       0.23043758, weight(cast.name:stewart in 293) [PerFieldSimilarity], result of:
#         0.23043758, score(doc=293,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.83603936, fieldWeight in 293, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=293)
#     0.5, coord(2/4)
#   0.118029505, product of:
#     0.23605901, sum of:
#       0.10714378, weight(title:star in 293) [PerFieldSimilarity], result of:
#         0.10714378, score(doc=293,freq=1.0), product of:
#           0.036395613, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.006181603, queryNorm
#           2.9438653, fieldWeight in 293, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=293)
#       0.12891524, weight(title:trek in 293) [PerFieldSimilarity], result of:
#         0.12891524, score(doc=293,freq=1.0), product of:
#           0.039922494, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.006181603, queryNorm
#           3.2291377, fieldWeight in 293, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=293)
#     0.5, coord(2/4)
#
# *************************************
# 20	0.18290025		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.18290025, max of:
#   0.18290025, product of:
#     0.3658005, sum of:
#       0.13536294, weight(cast.name:patrick in 601) [PerFieldSimilarity], result of:
#         0.13536294, score(doc=601,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.64076674, fieldWeight in 601, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=601)
#       0.23043758, weight(cast.name:stewart in 601) [PerFieldSimilarity], result of:
#         0.23043758, score(doc=601,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.83603936, fieldWeight in 601, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=601)
#     0.5, coord(2/4)
#
# *************************************
# 21	0.18290025		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.18290025, max of:
#   0.18290025, product of:
#     0.3658005, sum of:
#       0.13536294, weight(cast.name:patrick in 749) [PerFieldSimilarity], result of:
#         0.13536294, score(doc=749,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.64076674, fieldWeight in 749, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=749)
#       0.23043758, weight(cast.name:stewart in 749) [PerFieldSimilarity], result of:
#         0.23043758, score(doc=749,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.83603936, fieldWeight in 749, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=749)
#     0.5, coord(2/4)
#   0.118029505, product of:
#     0.23605901, sum of:
#       0.10714378, weight(title:star in 749) [PerFieldSimilarity], result of:
#         0.10714378, score(doc=749,freq=1.0), product of:
#           0.036395613, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.006181603, queryNorm
#           2.9438653, fieldWeight in 749, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=749)
#       0.12891524, weight(title:trek in 749) [PerFieldSimilarity], result of:
#         0.12891524, score(doc=749,freq=1.0), product of:
#           0.039922494, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.006181603, queryNorm
#           3.2291377, fieldWeight in 749, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=749)
#     0.5, coord(2/4)
#
# *************************************
# 22	0.18290025		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.18290025, max of:
#   0.18290025, product of:
#     0.3658005, sum of:
#       0.13536294, weight(cast.name:patrick in 245) [PerFieldSimilarity], result of:
#         0.13536294, score(doc=245,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.64076674, fieldWeight in 245, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=245)
#       0.23043758, weight(cast.name:stewart in 245) [PerFieldSimilarity], result of:
#         0.23043758, score(doc=245,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.83603936, fieldWeight in 245, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=245)
#     0.5, coord(2/4)
#
# *************************************
# 23	0.1537503		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 0.1537503, max of:
#   0.1537503, product of:
#     0.3075006, sum of:
#       0.090241954, weight(cast.name:patrick in 247) [PerFieldSimilarity], result of:
#         0.090241954, score(doc=247,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.42717782, fieldWeight in 247, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.125, fieldNorm(doc=247)
#       0.21725863, weight(cast.name:stewart in 247) [PerFieldSimilarity], result of:
#         0.21725863, score(doc=247,freq=2.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.7882255, fieldWeight in 247, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.125, fieldNorm(doc=247)
#     0.5, coord(2/4)
#
# *************************************
# 24	0.15241688		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.15241688, max of:
#   0.15241688, product of:
#     0.30483377, sum of:
#       0.11280244, weight(cast.name:patrick in 146) [PerFieldSimilarity], result of:
#         0.11280244, score(doc=146,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.53397226, fieldWeight in 146, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.15625, fieldNorm(doc=146)
#       0.19203132, weight(cast.name:stewart in 146) [PerFieldSimilarity], result of:
#         0.19203132, score(doc=146,freq=1.0), product of:
# ...
# 54138
# CAST [u'Chris Pine', u'Zachary Quinto', u'Zoe Saldana', u'Karl Urban', u'Simon Pegg', u'John Cho', u'Benedict Cumberbatch', u'Anton Yelchin', u'Bruce Greenwood', u'Peter Weller', u'Alice Eve', u'Noel Clarke', u'Nazneen Contractor', u'Amanda Foreman', u'Jay Scully', u'Jonathan Dixon', u'Aisha Hinds', u'Joseph Gatt', u'Jeremy Raymond', u'Tony Guma', u'Kimberly Arland', u'Sean Blakemore', u'Nick E. Tarabay', u'Beau Billingslea', u'Deep Roy', u'Anjini Taneja Azhar', u'Jack Laufer', u'Katie Cockrell', u'Kellie Cockrell', u'Jason Matthew Smith', u'Chris Hemsworth', u'Jennifer Morrison', u'Seth Ayott', u'Marco Sanchez', u'Lee Reherman', u'Scott Lawrence', u'Usman Ally', u'Nolan North', u'James Hiroyuki Liao', u'Rob Moran', u'Berit Francis', u'Akiva Goldsman', u'Benjamin P. Binswanger', u'Christopher Doohan', u'Andy Demetrio', u'Gianna Simone', u'Rene Rosado', u'Jacquelynn King', u'Long Tran', u'Ningning Deng', u'Jodi Johnston', u'Colleen Harris', u'Jeff Chase', u'Monisola Akiwowo', u'Paul K. Daniel', u"Ser'Darius Blain", u'Heather Langenkamp', u'David C. Waite', u'Melissa Paulo', u'Cynthia Addai-Robinson', u'Drew Grey', u'Douglas Weng', u'Charlie Haugk', u'Max Chernov', u'Marc Primiani', u'Jesper Inglis', u'Jacob Rhodes', u'Kentucky Rhodes', u'Anthony Wilson', u'Eric Greitens', u'Melissa Steinman', u'Adam McCann', u'Jon Orvasky', u'Gerald W. Abrams', u'James McGrath', u'Brian T. Delaney', u'Arlen Escarpeta', u'Chris Gardner', u'Joe Hanna', u'David Acord', u'Joe Moses', u'Kevin Michael Richardson', u'David Sobolov', u'Matthew Wood', u'Fred Tatasciore', u'Kiff VandenHeuvel', u'Julianne Buescher', u'Ellie Newlands', u'Candice Renee', u'Audrey Wasilewski', u'Emily Towers', u'Gina Hirsch', u'Bill Hader', u'Leonard Nimoy', u'Tom Archdeacon', u'Jon Lee Brody', u'Britanni Johnson', u'Hiram A. Murray']
# CHAR [u'Kirk', u'Spock', u'Uhura', u'Bones', u'Scotty', u'Sulu', u'Khan', u'Chekov', u'Pike', u'Marcus', u'Carol', u'Thomas Harewood', u'Rima Harewood', u'Ensign Brackett', u'Lieutenant Chapin', u'Ensign Froman', u'Navigation Officer Darwin', u'Science Officer 0718', u'Lead Nibiran', u'Nibiran', u'Madeline', u'Klingon', u'Klingon', u'Captain Abbot', u'Keenser', u'Lucille Harewood', u'Doctor', u'Girl', u'Girl', u'Cupcake', u'George Kirk', u'Winona Kirk', u'U.S.S. Enterprise Shuttle Ensign', u'Torpedo Security', u'Uniformed Mercenary', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Ensign', u'Starfleet Admiral', u'Starfleet Admiral', u'Starfleet Admiral', u'Transport Officer', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'Lady V', u'U.S.S. Enterprise Security', u'U.S.S. Enterprise Nurse', u'Shuttle Pilot', u'U.S.S. Enterprise Red Shirt', u'Moto', u'U.S.S. Enterprise Crew', u'Bar Girl', u'San Francisco Woman', u'San Francisco Bar Patron', u'U.S.S. Vengeance Security', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'Nibiru Child', u'Nibiru Child', u'Shaku', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Memorial Admiral', u'Starfleet Memorial Admiral', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Spock Prime', u'Ensign Spyke (uncredited)', u'U.S.S. Enterprise Security (uncredited)', u'NYU Nurse (uncredited)', u'Bar Patron (uncredited)']
# 0.118029505, max of:
#   0.118029505, product of:
#     0.23605901, sum of:
#       0.10714378, weight(title:star in 1542) [PerFieldSimilarity], result of:
#         0.10714378, score(doc=1542,freq=1.0), product of:
#           0.036395613, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.006181603, queryNorm
#           2.9438653, fieldWeight in 1542, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=1542)
#       0.12891524, weight(title:trek in 1542) [PerFieldSimilarity], result of:
#         0.12891524, score(doc=1542,freq=1.0), product of:
#           0.039922494, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.006181603, queryNorm
#           3.2291377, fieldWeight in 1542, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=1542)
#     0.5, coord(2/4)
#
# *************************************
# 47	0.10669182		The Faculty
# The Faculty
# Take me to your teacher.
# When some very creepy things start happening around school, the kids at Herrington High make a chilling discovery that confirms their worst suspicions: their teachers really are from another planet! As mind-controlling parasites rapidly begin spreading from the faculty to the students' bodies, it's ultimately up to the few who are left – an unlikely collection of loners, leaders, nerds and jocks – to save the world from alien domination.
# 9276
# CAST [u'Jordana Brewster', u'Elijah Wood', u'Clea DuVall', u'Laura Harris', u'Josh Hartnett', u'Shawn Hatosy', u'Salma Hayek', u'Famke Janssen', u'Usher Raymond', u'Robert Patrick', u'Piper Laurie', u'Christopher McDonald', u'Bebe Neuwirth', u'Jon Stewart', u'Daniel von Bargen', u'Jon Abrahams', u'Summer Phoenix', u'Susan Willis', u'Pete Janssen', u'Tina Rodriguez', u'Danny Masterson', u'Wiley Wiggins', u'Harry Jay Knowles', u'Donna Casey', u'Louis Black', u'Eric Jungmann', u'Chris Viteychuk', u'Jim Johnston', u'Libby Villari', u'Duane Martin', u'Katherine Willis', u'Mike Lutz', u'Douglas Aarniokoski']
# CHAR [u'Delilah Profitt', u'Casey Connor', u"Stokely 'Stokes' Mitchell", u'Marybeth Louise Hutchinson', u'Zeke Tyler', u'Stan Rosado', u'Nurse Rosa Harper', u'Miss Elizabeth Burke', u'Gabe Santora', u'Coach Joe Willis', u'Mrs. Karen Olson', u'Mr. Frank Connor', u'Principal Valerie Drake', u'Prof. Edward Furlong', u'Mr. John Tate', u'F*** You Boy', u'F*** You Girl', u'Mrs. Jessica Brummel', u"Eddie 'Meat' McIvey", u'Tattoo Girl', u'F*** Up #1', u'F*** Up #2', u'Mr. Knowles', u'Tina', u'Mr. Lewis', u'Freshman #1', u'Freshman #2', u'P.E. Teacher', u"Casey's Mom", u'Officer #1', u'Officer #2', u'Hornet Mascot', u'Brun Coach']
# 0.10669181, max of:
#   0.10669181, product of:
#     0.21338362, sum of:
#       0.07896171, weight(cast.name:patrick in 316) [PerFieldSimilarity], result of:
#         0.07896171, score(doc=316,freq=1.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.37378058, fieldWeight in 316, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.109375, fieldNorm(doc=316)
#       0.13442191, weight(cast.name:stewart in 316) [PerFieldSimilarity], result of:
#         0.13442191, score(doc=316,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.4876896, fieldWeight in 316, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.109375, fieldNorm(doc=316)
#     0.5, coord(2/4)
#
# *************************************
# 48	0.10546742		The Cabin in the Woods
# The Cabin in the Woods
# If you hear a strange sound outside... have sex
# Five college friends spend the weekend at a remote cabin in the woods, where they get more than they bargained for. Together, they must discover the truth behind the cabin in the woods.
# 22970
# CAST [u'Kristen Connolly', u'Chris Hemsworth', u'Anna Hutchison', u'Fran Kranz', u'Jesse Williams', u'Richard Jenkins', u'Bradley Whitford', u'Brian J. White', u'Amy Acker', u'Tim De Zarn', u'Tom Lenk', u'Dan Payne', u'Jodelle Ferland', u'Dan Shea', u'Maya Massar', u'Matt Drake', u'Nels Lennarson', u'Rukiya Bernard', u'Peter Kelamis', u'Adrian Holmes', u'Chelah Horsdal', u'Terry Chen', u'Heather Doerksen', u'Patrick Sabongui', u'Phillip Mitchell', u'Naomi Dane', u'Ellie Harvie', u'Patrick Gilmore', u'Brad Dryborough', u'Emili Kawashima', u'Aya Furukawa', u'Maria Go', u'Serena Akane Chi', u'Abbey Imai', u'Marina Ishibashi', u'Miku Katsuura', u'Alicia Takase Lui', u'Jodi Tabuchi', u'Sara Taira', u'Alyssandra Yamamoto', u'Richard Cetrone', u'Phoebe Galvan', u'Simon Pidgeon', u'Matt Phillips', u'Lori Stewart', u'Greg Zach', u'Sigourney Weaver', u'Terry Notary']
# CHAR [u'Dana Polk', u'Curt Vaughn', u'Jules Louden', u'Marty Mikalski', u'Holden McCrea', u'Richard Sitterson', u'Steve Hadley', u'Daniel Truman (as Brian White)', u'Wendy Lin', u'Mordecai (as Tim DeZarn)', u'Ronald The Intern', u'Matthew Buckner', u'Patience Buckner', u'Father Buckner', u'Mother Buckner', u'Judah Buckner', u'Clean Man', u'Labcoat Girl', u'Demo Guy', u'Demo Guy', u'Demo Girl', u'Operations Guy', u'Accountant', u'Elevator Guard', u'Lead Guard', u'Japanese Floaty Girl', u'Military Liaison', u'Werewolf Wrangler', u'Chem Department Guy', u'Japanese Frog Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Japanese School Girl', u'Werewolf/Merman', u'Sugarplum Fairy', u'Dismemberment Goblin', u'Dismemberment Goblin', u'Floating Witch', u'Fornicus, Lord of Bondage and Pain (as Gregory Zach)', u'The Director', u'The Clown (uncredited)']
# 0.10546742, max of:
#   0.10546742, product of:
#     0.21093483, sum of:
#       0.095716044, weight(cast.name:patrick in 838) [PerFieldSimilarity], result of:
#         0.095716044, score(doc=838,freq=2.0), product of:
#           0.2112515, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.06181603, queryNorm
#           0.4530905, fieldWeight in 838, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.09375, fieldNorm(doc=838)
#       0.11521879, weight(cast.name:stewart in 838) [PerFieldSimilarity], result of:
#         0.11521879, score(doc=838,freq=1.0), product of:
#           0.27563006, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.06181603, queryNorm
#           0.41801968, fieldWeight in 838, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.09375, fieldNorm(doc=838)
#     0.5, coord(2/4)
#
# *************************************
# 49	0.104386374		London Boulevard
# London Boulevard
# Not every criminal wants to be one.
# A parolee battles a gangster for the affections of a reclusive movie star.
# 48838
# CAST [u'Keira Knightley', u'Colin Farrell', u'Anna Friel', u'Ray Winstone', u'Jamie Campbell Bower', u'David Thewlis', u'Ophelia Lovibond', u'Eddie Marsan', u'Ben Chaplin', u'Matt King', u'Donald Sumpter', u'Velibor Topi\u0107', u'Lee Boardman', u'Andrew Havill', u'Stephen Graham', u'Jonny Coyne']
# CHAR [u'Charlotte', u'Mitchell', u'Briony', u'Gant', u'White Boy', u'Jordan', u'Penny', u'DI Bailey', u'Billy', u'Fletcher', u'Pentonville Governor', u'Storbor', u'Lee', u'Unlikely Vagrant', u'Danny', u'Heavy One (as Jonathan Coyne)']
# 0.10438638, max of:
#   0.10438638, product of:
#     0.41754553, sum of:
#       0.41754553, weight(overview:star in 1357) [PerFieldSimilarity], result of:
#         0.41754553, score(doc=1357,freq=1.0), product of:
#           0.26235348, queryWeight, product of:
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.06181603, queryNorm
#           1.591538, fieldWeight in 1357, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.375, fieldNorm(doc=1357)
#     0.25, coord(1/4)
#
# *************************************
# 50	0.10327582		Star Trek VI: The Undiscovered Country
# Star Trek VI: The Undiscovered Country
# The battle for peace has begun.
# The crews of the Enterprise and the Excelsior must stop a plot to prevent a peace treaty between the Klingon Empire and the Federation
# 174
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'Christopher Plummer', u'Kim Cattrall', u'David Warner', u'Rosanna DeSoto', u'Brock Peters', u'Kurtwood Smith', u'Iman', u'Mark Lenard', u'Grace Lee Whitney', u'Leon Russom', u'John Schuck', u'Michael Dor', u'Paul Rossilli', u'Robert Easton', u'Michael Dorn']
# CHAR [u'James Tiberius Kirk', u'Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Hikaru Sulu', u'Uhura', u'Pavel Chekov', u'General Chang', u'Lieutenant Valeris', u'Chancellor Gorkon', u'Azetbur', u'Admiral Cartwright', u'Federation President', u'Martia', u'Sarek', u'Excelsior Communications Officer', u'Chief in Command', u'Klingon Ambassador', u'Klingon Defense Attorney', u'Kerla', u'Klingon Judge', u'Klingon Defense Attorney']
# 0.10327582, max of:
#   0.10327582, product of:
#     0.20655164, sum of:
#       0.09375081, weight(title:star in 281) [PerFieldSimilarity], result of:
#         0.09375081, score(doc=281,freq=1.0), product of:
#           0.036395613, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.006181603, queryNorm
#           2.5758822, fieldWeight in 281, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.4375, fieldNorm(doc=281)
#       0.11280083, weight(title:trek in 281) [PerFieldSimilarity], result of:
#         0.11280083, score(doc=281,freq=1.0), product of:
#           0.039922494, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.006181603, queryNorm
#           2.8254955, fieldWeight in 281, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.4375, fieldNorm(doc=281)
#     0.5, coord(2/4)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:star overview:trek overview:patrick overview:stewart) | (directors.name:star directors.name:trek directors.name:patrick directors.name:stewart) | (cast.name:star cast.name:trek cast.name:patrick cast.name:stewart) | ((title:star title:trek title:patrick title:stewart)^0.1)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# ## Try again with 'most fields'

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview', 'cast.name', 'directors.name'],
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.18147723		Dark Skies
# 2	0.15441354		Star Trek: Generations
# 3	0.09867601		Star Trek: Insurrection
# 4	0.09867601		Star Trek: First Contact
# 5	0.0886804		Star Trek: Nemesis
# ===============
# Num	Relevance Score		Movie Title
# 1	0.18147723		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 0.18147725, product of:
#   0.3629545, sum of:
#     0.34815916, product of:
#       1.3926367, sum of:
#         1.3926367, weight(directors.name:stewart in 82) [PerFieldSimilarity], result of:
#           1.3926367, score(doc=82,freq=1.0), product of:
#             0.30055067, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.040539425, queryNorm
#             4.633617, fieldWeight in 82, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=82)
#       0.25, coord(1/4)
#     0.014795341, product of:
#       0.059181362, sum of:
#         0.059181362, weight(cast.name:patrick in 82) [PerFieldSimilarity], result of:
#           0.059181362, score(doc=82,freq=1.0), product of:
#             0.13854034, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.040539425, queryNorm
#             0.42717782, fieldWeight in 82, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.125, fieldNorm(doc=82)
#       0.25, coord(1/4)
#   0.5, coord(2/4)
#
# *************************************
# 2	0.15441354		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.15441354, product of:
#   0.20588471, sum of:
#     0.028523909, product of:
#       0.114095636, sum of:
#         0.114095636, weight(overview:star in 664) [PerFieldSimilarity], result of:
#           0.114095636, score(doc=664,freq=1.0), product of:
#             0.17205341, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040539425, queryNorm
#             0.6631408, fieldWeight in 664, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=664)
#       0.25, coord(1/4)
#     0.099956155, product of:
#       0.19991231, sum of:
#         0.0739767, weight(cast.name:patrick in 664) [PerFieldSimilarity], result of:
#           0.0739767, score(doc=664,freq=1.0), product of:
#             0.13854034, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.040539425, queryNorm
#             0.53397226, fieldWeight in 664, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.15625, fieldNorm(doc=664)
#         0.1259356, weight(cast.name:stewart in 664) [PerFieldSimilarity], result of:
#           0.1259356, score(doc=664,freq=1.0), product of:
#             0.1807603, queryWeight, product of:
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.040539425, queryNorm
#             0.6966995, fieldWeight in 664, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.15625, fieldNorm(doc=664)
#       0.5, coord(2/4)
#     0.07740465, product of:
#       0.1548093, sum of:
#         0.07026571, weight(title:star in 664) [PerFieldSimilarity], result of:
#           0.07026571, score(doc=664,freq=1.0), product of:
#             0.02386852, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.0040539424, queryNorm
#             2.9438653, fieldWeight in 664, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=664)
#         0.08454359, weight(title:trek in 664) [PerFieldSimilarity], result of:
#           0.08454359, score(doc=664,freq=1.0), product of:
#             0.026181476, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.0040539424, queryNorm
#             3.2291377, fieldWeight in 664, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=664)
#       0.5, coord(2/4)
#   0.75, coord(3/4)
#
# *************************************
# 3	0.09867601		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.09867601, product of:
#   0.19735202, sum of:
#     0.11994738, product of:
#       0.23989476, sum of:
#         0.08877204, weight(cast.name:patrick in 200) [PerFieldSimilarity], result of:
#           0.08877204, score(doc=200,freq=1.0), product of:
#             0.13854034, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.040539425, queryNorm
#             0.64076674, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.1875, fieldNorm(doc=200)
#         0.15112272, weight(cast.name:stewart in 200) [PerFieldSimilarity], result of:
#           0.15112272, score(doc=200,freq=1.0), product of:
#             0.1807603, queryWeight, product of:
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.040539425, queryNorm
#             0.83603936, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.1875, fieldNorm(doc=200)
#       0.5, coord(2/4)
#     0.07740465, product of:
#       0.1548093, sum of:
#         0.07026571, weight(title:star in 200) [PerFieldSimilarity], result of:
#           0.07026571, score(doc=200,freq=1.0), product of:
#             0.02386852, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.0040539424, queryNorm
#             2.9438653, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=200)
#         0.08454359, weight(title:trek in 200) [PerFieldSimilarity], result of:
#           0.08454359, score(doc=200,freq=1.0), product of:
#             0.026181476, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.0040539424, queryNorm
#             3.2291377, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=200)
#       0.5, coord(2/4)
#   0.5, coord(2/4)
#
# *************************************
# 4	0.09867601		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.09867601, product of:
#   0.19735202, sum of:
#     0.11994738, product of:
#       0.23989476, sum of:
#         0.08877204, weight(cast.name:patrick in 656) [PerFieldSimilarity], result of:
#           0.08877204, score(doc=656,freq=1.0), product of:
#             0.13854034, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.040539425, queryNorm
#             0.64076674, fieldWeight in 656, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.1875, fieldNorm(doc=656)
#         0.15112272, weight(cast.name:stewart in 656) [PerFieldSimilarity], result of:
#           0.15112272, score(doc=656,freq=1.0), product of:
#             0.1807603, queryWeight, product of:
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.040539425, queryNorm
#             0.83603936, fieldWeight in 656, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.1875, fieldNorm(doc=656)
#       0.5, coord(2/4)
#     0.07740465, product of:
#       0.1548093, sum of:
#         0.07026571, weight(title:star in 656) [PerFieldSimilarity], result of:
#           0.07026571, score(doc=656,freq=1.0), product of:
#             0.02386852, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.0040539424, queryNorm
#             2.9438653, fieldWeight in 656, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=656)
#         0.08454359, weight(title:trek in 656) [PerFieldSimilarity], result of:
#           0.08454359, score(doc=656,freq=1.0), product of:
#             0.026181476, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.0040539424, queryNorm
#             3.2291377, fieldWeight in 656, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=656)
#       0.5, coord(2/4)
#   0.5, coord(2/4)
#
# *************************************
# 5	0.0886804		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.0886804, product of:
#   0.1773608, sum of:
#     0.099956155, product of:
#       0.19991231, sum of:
#         0.0739767, weight(cast.name:patrick in 199) [PerFieldSimilarity], result of:
#           0.0739767, score(doc=199,freq=1.0), product of:
#             0.13854034, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.040539425, queryNorm
#             0.53397226, fieldWeight in 199, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.15625, fieldNorm(doc=199)
#         0.1259356, weight(cast.name:stewart in 199) [PerFieldSimilarity], result of:
#           0.1259356, score(doc=199,freq=1.0), product of:
#             0.1807603, queryWeight, product of:
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.040539425, queryNorm
#             0.6966995, fieldWeight in 199, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.15625, fieldNorm(doc=199)
#       0.5, coord(2/4)
#     0.07740465, product of:
#       0.1548093, sum of:
#         0.07026571, weight(title:star in 199) [PerFieldSimilarity], result of:
#           0.07026571, score(doc=199,freq=1.0), product of:
#             0.02386852, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.0040539424, queryNorm
#             2.9438653, fieldWeight in 199, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=199)
#         0.08454359, weight(title:trek in 199) [PerFieldSimilarity], result of:
#           0.08454359, score(doc=199,freq=1.0), product of:
#             0.026181476, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.0040539424, queryNorm
#             3.2291377, fieldWeight in 199, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=199)
#       0.5, coord(2/4)
#   0.5, coord(2/4)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((overview:star overview:trek overview:patrick overview:stewart) (directors.name:star directors.name:trek directors.name:patrick directors.name:stewart) (cast.name:star cast.name:trek cast.name:patrick cast.name:stewart) ((title:star title:trek title:patrick title:stewart)^0.1))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# ## Enable Bigram Matching, Try Again

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}

            
mappingSettings = {
    'movie': {
        'properties': {
            "title": {
                'type': 'string',
                "analyzer": "english",
                'fields': {
                    "bigramed": {
                        "type": "string",
                        "analyzer": "english_bigrams"
                    }
                }
            },
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# ## Search using bigram fields

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview', 'title.bigramed', 'cast.name', 'cast.name.bigramed', 'directors.name'],
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.31862077		Dark Skies
# 2	0.26967403		Star Trek: Insurrection
# 3	0.26967403		Gnomeo & Juliet
# 4	0.26967403		Star Trek: First Contact
# 5	0.26967403		Excalibur
# ===============
# Num	Relevance Score		Movie Title
# 1	0.31862077		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 0.31862077, product of:
#   0.9558623, sum of:
#     0.9168979, product of:
#       1.8337958, sum of:
#         1.8337958, weight(directors.name:stewart in 823) [PerFieldSimilarity], result of:
#           1.8337958, score(doc=823,freq=1.0), product of:
#             0.39575905, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.0533815, queryNorm
#             4.633617, fieldWeight in 823, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=823)
#       0.5, coord(1/2)
#     0.038964413, product of:
#       0.077928826, sum of:
#         0.077928826, weight(cast.name:patrick in 823) [PerFieldSimilarity], result of:
#           0.077928826, score(doc=823,freq=1.0), product of:
#             0.18242714, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.0533815, queryNorm
#             0.42717782, fieldWeight in 823, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.125, fieldNorm(doc=823)
#       0.5, coord(1/2)
#   0.33333334, coord(2/6)
#
# *************************************
# 2	0.26967403		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.26967403, product of:
#   0.80902207, sum of:
#     0.3158886, sum of:
#       0.11689324, weight(cast.name:patrick in 576) [PerFieldSimilarity], result of:
#         0.11689324, score(doc=576,freq=1.0), product of:
#           0.18242714, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0533815, queryNorm
#           0.64076674, fieldWeight in 576, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=576)
#       0.19899537, weight(cast.name:stewart in 576) [PerFieldSimilarity], result of:
#         0.19899537, score(doc=576,freq=1.0), product of:
#           0.23802152, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0533815, queryNorm
#           0.83603936, fieldWeight in 576, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=576)
#     0.49313343, weight(cast.name.bigramed:patrick stewart in 576) [PerFieldSimilarity], result of:
#       0.49313343, score(doc=576,freq=1.0), product of:
#         0.3244947, queryWeight, product of:
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.0533815, queryNorm
#         1.5196965, fieldWeight in 576, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.25, fieldNorm(doc=576)
#   0.33333334, coord(2/6)
#
# *************************************
# 3	0.26967403		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.26967403, product of:
#   0.80902207, sum of:
#     0.3158886, sum of:
#       0.11689324, weight(cast.name:patrick in 884) [PerFieldSimilarity], result of:
#         0.11689324, score(doc=884,freq=1.0), product of:
#           0.18242714, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0533815, queryNorm
#           0.64076674, fieldWeight in 884, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=884)
#       0.19899537, weight(cast.name:stewart in 884) [PerFieldSimilarity], result of:
#         0.19899537, score(doc=884,freq=1.0), product of:
#           0.23802152, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0533815, queryNorm
#           0.83603936, fieldWeight in 884, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=884)
#     0.49313343, weight(cast.name.bigramed:patrick stewart in 884) [PerFieldSimilarity], result of:
#       0.49313343, score(doc=884,freq=1.0), product of:
#         0.3244947, queryWeight, product of:
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.0533815, queryNorm
#         1.5196965, fieldWeight in 884, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.25, fieldNorm(doc=884)
#   0.33333334, coord(2/6)
#
# *************************************
# 4	0.26967403		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.26967403, product of:
#   0.80902207, sum of:
#     0.3158886, sum of:
#       0.11689324, weight(cast.name:patrick in 1032) [PerFieldSimilarity], result of:
#         0.11689324, score(doc=1032,freq=1.0), product of:
#           0.18242714, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0533815, queryNorm
#           0.64076674, fieldWeight in 1032, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=1032)
#       0.19899537, weight(cast.name:stewart in 1032) [PerFieldSimilarity], result of:
#         0.19899537, score(doc=1032,freq=1.0), product of:
#           0.23802152, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0533815, queryNorm
#           0.83603936, fieldWeight in 1032, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=1032)
#     0.49313343, weight(cast.name.bigramed:patrick stewart in 1032) [PerFieldSimilarity], result of:
#       0.49313343, score(doc=1032,freq=1.0), product of:
#         0.3244947, queryWeight, product of:
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.0533815, queryNorm
#         1.5196965, fieldWeight in 1032, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.25, fieldNorm(doc=1032)
#   0.33333334, coord(2/6)
#
# *************************************
# 5	0.26967403		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.26967403, product of:
#   0.80902207, sum of:
#     0.3158886, sum of:
#       0.11689324, weight(cast.name:patrick in 798) [PerFieldSimilarity], result of:
#         0.11689324, score(doc=798,freq=1.0), product of:
#           0.18242714, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0533815, queryNorm
#           0.64076674, fieldWeight in 798, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=798)
#       0.19899537, weight(cast.name:stewart in 798) [PerFieldSimilarity], result of:
#         0.19899537, score(doc=798,freq=1.0), product of:
#           0.23802152, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0533815, queryNorm
#           0.83603936, fieldWeight in 798, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=798)
#     0.49313343, weight(cast.name.bigramed:patrick stewart in 798) [PerFieldSimilarity], result of:
#       0.49313343, score(doc=798,freq=1.0), product of:
#         0.3244947, queryWeight, product of:
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.0533815, queryNorm
#         1.5196965, fieldWeight in 798, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           6.078786, idf(docFreq=18, maxDocs=3051)
#           0.25, fieldNorm(doc=798)
#   0.33333334, coord(2/6)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((overview:patrick overview:stewart) (directors.name:patrick directors.name:stewart) title.bigramed:patrick stewart (cast.name:patrick cast.name:stewart) ((title:patrick title:stewart)^0.1) cast.name.bigramed:patrick stewart)->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Search One -- Source Data Model

# %%
usersSearch = 'kirk and picard movie'
usersSearch = 'enterprise D star trek'
query = {
    'query': {
        'bool': {
            'should': [
                {'multi_match': { 
                    'query': usersSearch,  #User's query
                    'fields': ['cast.name', 'cast.character'],
                    'type': 'most_fields'
                  }},
                {'multi_match': { 
                    'query': usersSearch,  #User's query
                    'fields': ['title', 'overview', 'tagline'],
                    'type': 'cross_fields'
                }}
            ]
        }
    },
    'size': '100',
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title		Overview
# 1	1.1002183		Star Trek Into Darkness		[u'J.J. Abrams']
# Star Trek Into Darkness
# Earth Will Fall
# When the crew of the Enterprise is called back home, they find an unstoppable force of terror from within their own organization has detonated the fleet and everything it stands for, leaving our world in a state of crisis.  With a personal score to settle, Captain Kirk leads a manhunt to a war-zone world to capture a one man weapon of mass destruction. As our heroes are propelled into an epic chess game of life and death, love will be challenged, friendships will be torn apart, and sacrifices must be made for the only family Kirk has left: his crew.
# 54138
# CAST [u'Chris Pine', u'Zachary Quinto', u'Zoe Saldana', u'Karl Urban', u'Simon Pegg', u'John Cho', u'Benedict Cumberbatch', u'Anton Yelchin', u'Bruce Greenwood', u'Peter Weller', u'Alice Eve', u'Noel Clarke', u'Nazneen Contractor', u'Amanda Foreman', u'Jay Scully', u'Jonathan Dixon', u'Aisha Hinds', u'Joseph Gatt', u'Jeremy Raymond', u'Tony Guma', u'Kimberly Arland', u'Sean Blakemore', u'Nick E. Tarabay', u'Beau Billingslea', u'Deep Roy', u'Anjini Taneja Azhar', u'Jack Laufer', u'Katie Cockrell', u'Kellie Cockrell', u'Jason Matthew Smith', u'Chris Hemsworth', u'Jennifer Morrison', u'Seth Ayott', u'Marco Sanchez', u'Lee Reherman', u'Scott Lawrence', u'Usman Ally', u'Nolan North', u'James Hiroyuki Liao', u'Rob Moran', u'Berit Francis', u'Akiva Goldsman', u'Benjamin P. Binswanger', u'Christopher Doohan', u'Andy Demetrio', u'Gianna Simone', u'Rene Rosado', u'Jacquelynn King', u'Long Tran', u'Ningning Deng', u'Jodi Johnston', u'Colleen Harris', u'Jeff Chase', u'Monisola Akiwowo', u'Paul K. Daniel', u"Ser'Darius Blain", u'Heather Langenkamp', u'David C. Waite', u'Melissa Paulo', u'Cynthia Addai-Robinson', u'Drew Grey', u'Douglas Weng', u'Charlie Haugk', u'Max Chernov', u'Marc Primiani', u'Jesper Inglis', u'Jacob Rhodes', u'Kentucky Rhodes', u'Anthony Wilson', u'Eric Greitens', u'Melissa Steinman', u'Adam McCann', u'Jon Orvasky', u'Gerald W. Abrams', u'James McGrath', u'Brian T. Delaney', u'Arlen Escarpeta', u'Chris Gardner', u'Joe Hanna', u'David Acord', u'Joe Moses', u'Kevin Michael Richardson', u'David Sobolov', u'Matthew Wood', u'Fred Tatasciore', u'Kiff VandenHeuvel', u'Julianne Buescher', u'Ellie Newlands', u'Candice Renee', u'Audrey Wasilewski', u'Emily Towers', u'Gina Hirsch', u'Bill Hader', u'Leonard Nimoy', u'Tom Archdeacon', u'Jon Lee Brody', u'Britanni Johnson', u'Hiram A. Murray']
# CHAR [u'Kirk', u'Spock', u'Uhura', u'Bones', u'Scotty', u'Sulu', u'Khan', u'Chekov', u'Pike', u'Marcus', u'Carol', u'Thomas Harewood', u'Rima Harewood', u'Ensign Brackett', u'Lieutenant Chapin', u'Ensign Froman', u'Navigation Officer Darwin', u'Science Officer 0718', u'Lead Nibiran', u'Nibiran', u'Madeline', u'Klingon', u'Klingon', u'Captain Abbot', u'Keenser', u'Lucille Harewood', u'Doctor', u'Girl', u'Girl', u'Cupcake', u'George Kirk', u'Winona Kirk', u'U.S.S. Enterprise Shuttle Ensign', u'Torpedo Security', u'Uniformed Mercenary', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Ensign', u'Starfleet Admiral', u'Starfleet Admiral', u'Starfleet Admiral', u'Transport Officer', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'Lady V', u'U.S.S. Enterprise Security', u'U.S.S. Enterprise Nurse', u'Shuttle Pilot', u'U.S.S. Enterprise Red Shirt', u'Moto', u'U.S.S. Enterprise Crew', u'Bar Girl', u'San Francisco Woman', u'San Francisco Bar Patron', u'U.S.S. Vengeance Security', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'Nibiru Child', u'Nibiru Child', u'Shaku', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Memorial Admiral', u'Starfleet Memorial Admiral', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Spock Prime', u'Ensign Spyke (uncredited)', u'U.S.S. Enterprise Security (uncredited)', u'NYU Nurse (uncredited)', u'Bar Patron (uncredited)']
# 1.1002182, sum of:
#   0.06914862, product of:
#     0.13829724, sum of:
#       0.13829724, product of:
#         0.553189, sum of:
#           0.553189, weight(cast.character:enterpris in 98) [PerFieldSimilarity], result of:
#             0.553189, score(doc=98,freq=13.0), product of:
#               0.30977318, queryWeight, product of:
#                 7.9246125, idf(docFreq=2, maxDocs=3051)
#                 0.039090008, queryNorm
#               1.7857872, fieldWeight in 98, product of:
#                 3.6055512, tf(freq=13.0), with freq of:
#                   13.0, termFreq=13.0
#                 7.9246125, idf(docFreq=2, maxDocs=3051)
#                 0.0625, fieldNorm(doc=98)
#         0.25, coord(1/4)
#     0.5, coord(1/2)
#   1.0310695, product of:
#     1.3747594, sum of:
#       0.20888528, max of:
#         0.20888528, weight(overview:enterpris in 98) [PerFieldSimilarity], result of:
#           0.20888528, score(doc=98,freq=1.0), product of:
#             0.2555829, queryWeight, product of:
#               6.538318, idf(docFreq=11, maxDocs=3051)
#               0.039090008, queryNorm
#             0.81728977, fieldWeight in 98, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.538318, idf(docFreq=11, maxDocs=3051)
#               0.125, fieldNorm(doc=98)
#       0.3506654, max of:
#         0.3506654, weight(title:star in 98) [PerFieldSimilarity], result of:
#           0.3506654, score(doc=98,freq=1.0), product of:
#             0.16557483, queryWeight, product of:
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.039090008, queryNorm
#             2.1178665, fieldWeight in 98, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.5, fieldNorm(doc=98)
#       0.81520885, max of:
#         0.81520885, weight(title:trek in 98) [PerFieldSimilarity], result of:
#           0.81520885, score(doc=98,freq=1.0), product of:
#             0.25245404, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.039090008, queryNorm
#             3.2291377, fieldWeight in 98, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=98)
#     0.75, coord(3/4)
#
# *************************************
# 2	0.99778336		Star Trek		[u'J.J. Abrams']
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 0.9977834, sum of:
#   0.269112, sum of:
#     0.011967215, product of:
#       0.04786886, sum of:
#         0.04786886, weight(cast.name:d in 122) [PerFieldSimilarity], result of:
#           0.04786886, score(doc=122,freq=1.0), product of:
#             0.19979692, queryWeight, product of:
#               5.111202, idf(docFreq=49, maxDocs=3051)
#               0.039090008, queryNorm
#             0.23958758, fieldWeight in 122, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.111202, idf(docFreq=49, maxDocs=3051)
#               0.046875, fieldNorm(doc=122)
#       0.25, coord(1/4)
#     0.25714478, product of:
#       0.51428956, sum of:
#         0.43943185, weight(cast.character:enterpris in 122) [PerFieldSimilarity], result of:
#           0.43943185, score(doc=122,freq=21.0), product of:
#             0.30977318, queryWeight, product of:
#               7.9246125, idf(docFreq=2, maxDocs=3051)
#               0.039090008, queryNorm
#             1.41856, fieldWeight in 122, product of:
#               4.582576, tf(freq=21.0), with freq of:
#                 21.0, termFreq=21.0
#               7.9246125, idf(docFreq=2, maxDocs=3051)
#               0.0390625, fieldNorm(doc=122)
#         0.07485773, weight(cast.character:star in 122) [PerFieldSimilarity], result of:
#           0.07485773, score(doc=122,freq=2.0), product of:
#             0.23015143, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.039090008, queryNorm
#             0.32525423, fieldWeight in 122, product of:
#               1.4142135, tf(freq=2.0), with freq of:
#                 2.0, termFreq=2.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.0390625, fieldNorm(doc=122)
#       0.5, coord(2/4)
#   0.72867143, product of:
#     1.4573429, sum of:
#       0.43833175, max of:
#         0.43833175, weight(title:star in 122) [PerFieldSimilarity], result of:
#           0.43833175, score(doc=122,freq=1.0), product of:
#             0.16557483, queryWeight, product of:
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.039090008, queryNorm
#             2.6473331, fieldWeight in 122, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.625, fieldNorm(doc=122)
#       1.0190111, max of:
#         1.0190111, weight(title:trek in 122) [PerFieldSimilarity], result of:
#           1.0190111, score(doc=122,freq=1.0), product of:
#             0.25245404, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.039090008, queryNorm
#             4.0364223, fieldWeight in 122, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.625, fieldNorm(doc=122)
#     0.5, coord(2/4)
#
# *************************************
# 3	0.8813461		Star Trek: Generations		[u'David Carson']
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.8813461, product of:
#   1.7626922, sum of:
#     1.7626922, sum of:
#       0.2611066, max of:
#         0.2611066, weight(overview:enterpris in 788) [PerFieldSimilarity], result of:
#           0.2611066, score(doc=788,freq=1.0), product of:
#             0.2555829, queryWeight, product of:
#               6.538318, idf(docFreq=11, maxDocs=3051)
#               0.039090008, queryNorm
#             1.0216122, fieldWeight in 788, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.538318, idf(docFreq=11, maxDocs=3051)
#               0.15625, fieldNorm(doc=788)
#       0.33571133, max of:
#         0.33571133, weight(overview:d in 788) [PerFieldSimilarity], result of:
#           0.33571133, score(doc=788,freq=1.0), product of:
#             0.289805, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.039090008, queryNorm
#             1.1584042, fieldWeight in 788, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.15625, fieldNorm(doc=788)
#       0.3506654, max of:
#         0.110016346, weight(overview:star in 788) [PerFieldSimilarity], result of:
#           0.110016346, score(doc=788,freq=1.0), product of:
#             0.16590194, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.039090008, queryNorm
#             0.6631408, fieldWeight in 788, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=788)
#         0.3506654, weight(title:star in 788) [PerFieldSimilarity], result of:
#           0.3506654, score(doc=788,freq=1.0), product of:
#             0.16557483, queryWeight, product of:
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.039090008, queryNorm
#             2.1178665, fieldWeight in 788, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.235733, idf(docFreq=119, maxDocs=3051)
#               0.5, fieldNorm(doc=788)
#       0.81520885, max of:
#         0.81520885, weight(title:trek in 788) [PerFieldSimilarity], result of:
#           0.81520885, score(doc=788,freq=1.0), product of:
#             0.25245404, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.039090008, queryNorm
#             3.2291377, fieldWeight in 788, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=788)
#   0.5, coord(1/2)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((cast.name:enterpris cast.name:d cast.name:star cast.name:trek) (cast.character:enterpris cast.character:d cast.character:star cast.character:trek)) (blended(terms: [overview:enterpris, tagline:enterpris, title:enterpris]) blended(terms: [overview:d, tagline:d, title:d]) blended(terms: [overview:star, tagline:star, title:star]) blended(terms: [overview:trek, tagline:trek, title:trek])))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Search 2 -- subphrase matching, use right multifield strategy

# %% [markdown]
# ## Modify mapping to shingle title and people

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}

            
mappingSettings = {
    'movie': {
        'properties': {
            "title": {
                'type': 'string',
                "analyzer": "english",
                'fields': {
                    "bigramed": {
                        "type": "string",
                        "analyzer": "english_bigrams"
                    }
                }
            },
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3050 movies
# Bulk Index into TMDB Index <200>

# %%
analyze(text="Jean luc picard", field="cast.name.bigramed")
# Out:
# ---
# tokens:
# - token: "jean luc"
#   start_offset: 0
#   end_offset: 8
#   type: "shingle"
#   position: 1
# - token: "luc picard"
#   start_offset: 5
#   end_offset: 15
#   type: "shingle"
#   position: 2

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'bool': {
            'should': [
                { 'multi_match': { 
                    'query': usersSearch,  #User's query
                    'fields': ['title.bigramed', 'cast.name.bigramed'],
                    'type': 'most_fields',
                    'minimum_should_match': 1
                    
                  }
                }
            ]
        }
    },
    'size': '100',
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title		Overview
# 1	0.58523685		Star Trek: Insurrection		[u'Jonathan Frakes']
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# 0.58523685, sum of:
#   0.4321098, product of:
#     1.2963294, sum of:
#       1.2963294, weight(title.bigramed:star trek in 632) [PerFieldSimilarity], result of:
#         1.2963294, score(doc=632,freq=1.0), product of:
#           0.32117432, queryWeight, product of:
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.049733188, queryNorm
#           4.036217, fieldWeight in 632, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.625, fieldNorm(doc=632)
#     0.33333334, coord(1/3)
#   0.15312704, product of:
#     0.4593811, sum of:
#       0.4593811, weight(cast.name.bigramed:patrick stewart in 632) [PerFieldSimilarity], result of:
#         0.4593811, score(doc=632,freq=1.0), product of:
#           0.30230108, queryWeight, product of:
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.049733188, queryNorm
#           1.5196145, fieldWeight in 632, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.25, fieldNorm(doc=632)
#     0.33333334, coord(1/3)
#
# *************************************
# 2	0.56609595		Star Trek: Nemesis		[u'Stuart Baird']
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# 0.56609595, sum of:
#   0.4321098, product of:
#     1.2963294, sum of:
#       1.2963294, weight(title.bigramed:star trek in 631) [PerFieldSimilarity], result of:
#         1.2963294, score(doc=631,freq=1.0), product of:
#           0.32117432, queryWeight, product of:
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.049733188, queryNorm
#           4.036217, fieldWeight in 631, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.625, fieldNorm(doc=631)
#     0.33333334, coord(1/3)
#   0.13398616, product of:
#     0.40195847, sum of:
#       0.40195847, weight(cast.name.bigramed:patrick stewart in 631) [PerFieldSimilarity], result of:
#         0.40195847, score(doc=631,freq=1.0), product of:
#           0.30230108, queryWeight, product of:
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.049733188, queryNorm
#           1.3296627, fieldWeight in 631, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.21875, fieldNorm(doc=631)
#     0.33333334, coord(1/3)
#
# *************************************
# 3	0.56609595		Star Trek: Generations		[u'David Carson']
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# 0.56609595, sum of:
#   0.4321098, product of:
#     1.2963294, sum of:
#       1.2963294, weight(title.bigramed:star trek in 1095) [PerFieldSimilarity], result of:
#         1.2963294, score(doc=1095,freq=1.0), product of:
#           0.32117432, queryWeight, product of:
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.049733188, queryNorm
#           4.036217, fieldWeight in 1095, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4579477, idf(docFreq=12, maxDocs=3050)
#             0.625, fieldNorm(doc=1095)
#     0.33333334, coord(1/3)
#   0.13398616, product of:
#     0.40195847, sum of:
#       0.40195847, weight(cast.name.bigramed:patrick stewart in 1095) [PerFieldSimilarity], result of:
#         0.40195847, score(doc=1095,freq=1.0), product of:
#           0.30230108, queryWeight, product of:
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.049733188, queryNorm
#           1.3296627, fieldWeight in 1095, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078458, idf(docFreq=18, maxDocs=3050)
#             0.21875, fieldNorm(doc=1095)
#     0.33333334, coord(1/3)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((((title.bigramed:star trek title.bigramed:trek patrick title.bigramed:patrick stewart)~1) ((cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart)~1)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Search 3 -- combine fields to merge IDFs (especially useful for short snippets; title, overview, etc)
