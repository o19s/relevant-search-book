# %% [markdown]
# # Setup Code (Listings 3 & 4) 5.2.1

# %%
import requests
import json
import os

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
                        data=text)
    print resp.text
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, data=json.dumps(query))
    if httpResp.status_code != 200:
        print "Search Failed <%s>" % httpResp.status_code
        print "%s" % httpResp.text
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])
            if verbose:
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "DIRS %s" % directorNames
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     data=json.dumps({'query': query['query']}))
        print json.loads(httpResp.text)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print "Delete TMDB Index <%s>" % resp.status_code
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", data=json.dumps(settings))
    print "Create TMDB Index <%s>" % resp.status_code
    if resp.status_code != 200:
        print resp.text
    
    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    for id, movie in movieDict.iteritems():
        addCmd = {"index": {"_index": "tmdb", "_type": "movie", "_id": movie["id"]}}
        esDoc  = movie
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies)
    print "Bulk Index into TMDB Index <%s>" % resp.status_code

## Extract
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass       
    return movieDict

# %% [markdown]
# # 5.2.2 -- Listing 4, Index to ES, Search

# %%
movieDict = extract()

analysis = {
    "analyzer" : {
      "default" : {
        "type" : "english"
        }
      }
   }

reindex(analysisSettings=analysis, movieDict=movieDict)

usersSearch = 'basketball with cartoon aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>
# Num	Relevance Score		Movie Title
# 1	1.0018479		Space Jam
# 2	0.29904303		Grown Ups
# 3	0.27935582		Speed Racer
# 4	0.27935582		The Flintstones
# 5	0.2563226		White Men Can't Jump
# ===============
# Num	Relevance Score		Movie Title
# 1	1.0018479		Space Jam
# Space Jam
# Get ready to jam.
# Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.
# 2300
# DIRS [u'Joe Pytka']
# CAST [u'Michael Jordan', u'Wayne Knight', u'Billy West', u'Dee Bradley Baker', u'Theresa Randle', u'Danny DeVito', u'Brandon Hammond', u'Larry Bird', u'Bill Murray', u'Charles Barkley', u'Patrick Ewing', u'Tyrone Bogues', u'Larry Johnson', u'Shawn Bradley', u'Ahmad Rashad', u'Del Harris', u'Vlade Divac', u'Cedric Ceballos', u'Jim Rome', u'Paul Westphal', u'Danny Ainge', u'Alonzo Mourning', u'A.C. Green', u'Charles Oakley', u'Derek Harper', u'Jeff Malone', u'Anthony Miller', u'Sharone Wright']
# CHAR [u'Himself', u'Stan Podolak', u'Bugs Bunny/Elmer Fudd (voice)', u'Daffy Duck/Tazmanian Devil/Bull (voice)', u'Juanita Jordan', u'Mr. Swackhammer (voice)', u'Michael Jordan (at 10)', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself']
# 1.0018479, sum of:
#   1.0018479, max of:
#     1.0018479, product of:
#       1.5027717, sum of:
#         1.0252904, weight(overview:basketbal in 185) [PerFieldSimilarity], result of:
#           1.0252904, score(doc=185,freq=1.0), product of:
#             0.6004586, queryWeight, product of:
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.08791426, queryNorm
#             1.707512, fieldWeight in 185, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.25, fieldNorm(doc=185)
#         0.47748137, weight(overview:alien in 185) [PerFieldSimilarity], result of:
#           0.47748137, score(doc=185,freq=1.0), product of:
#             0.40976784, queryWeight, product of:
#               4.660994, idf(docFreq=69, maxDocs=2723)
#               0.08791426, queryNorm
#             1.1652485, fieldWeight in 185, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.660994, idf(docFreq=69, maxDocs=2723)
#               0.25, fieldNorm(doc=185)
#       0.6666667, coord(2/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.08791426, _type:movie, product of:
#       1.0, boost
#       0.08791426, queryNorm
#
# *************************************
# 2	0.29904303		Grown Ups
# Grown Ups
# Boys will be boys. . . some longer than others.
# After their high school basketball coach passes away, five good friends and former teammates reunite for a Fourth of July holiday weekend.
# 38365
# DIRS [u'Dennis Dugan']
# CAST [u'Adam Sandler', u'Salma Hayek', u'Maria Bello', u'Steve Buscemi', u'Maya Rudolph', u'Kevin James', u'Rob Schneider', u'Chris Rock', u'Jamie Chung', u'David Spade', u'Ebony Jo-Ann', u'Di Quon', u'Colin Quinn', u'Tim Meadows', u'Madison Riley', u'Dan Patrick']
# CHAR [u'Lenny Feder', u'Roxanne Chase-Feder', u'Sally Lamonsoff', u'Wiley', u'Deanne McKenzie', u'Eric Lamonsoff', u'Rob Hilliard', u'Kurt McKenzie', u'Amber Hilliard', u'Marcus Higgins', u'Mama Ronzoni', u'Rita', u'Dickie Bailey', u'Malcolm', u'Jasmine Hilliard', u'Norby The Ride Guy']
# 0.29904303, sum of:
#   0.29904303, max of:
#     0.29904303, product of:
#       0.89712906, sum of:
#         0.89712906, weight(overview:basketbal in 1398) [PerFieldSimilarity], result of:
#           0.89712906, score(doc=1398,freq=1.0), product of:
#             0.6004586, queryWeight, product of:
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.08791426, queryNorm
#             1.494073, fieldWeight in 1398, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.21875, fieldNorm(doc=1398)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.08791426, _type:movie, product of:
#       1.0, boost
#       0.08791426, queryNorm
#
# *************************************
# 3	0.27935582		Speed Racer
# Speed Racer
# Go!
# Speed racer is the tale of a young and brilliant racing driver. When corruption in the racing leagues costs his brother his life, he must team up with the police and the mysterious Racer X to bring and end to the corruption and criminal activities. Inspired by the cartoon series.
# 7459
# DIRS [u'Lana Wachowski', u'Andy Wachowski']
# CAST [u'Emile Hirsch', u'Christina Ricci', u'Matthew Fox', u'Susan Sarandon', u'Scott Porter', u'John Goodman', u'Hiroyuki Sanada', u'Art LaFleur', u'Richard Roundtree', u'Togo Igawa', u'Nan Yu', u'Cosma Shiva Hagen', u'Roger Allam', u'Nayo Wallace', u'Rain', u'Moritz Bleibtreu', u'Benno F\xfcrmann', u'Ralph Herforth']
# CHAR [u'Speed Racer', u'Trixie', u'Racer X', u'Mom Racer', u'Rex Racer', u'Pops Racer', u'Mr. Musha', u'Fuji Announcer', u'Ben Burns', u'Mr. Togokahn', u'Horuko Togokahn', u'Gennie', u'Royalton', u'Minx', u'Taejo Togokahn', u'Grey Ghost', u'Inspektor Detektor', u'Cannonball Taylor']
# 0.27935582, sum of:
#   0.27935582, max of:
#     0.27935582, product of:
#       0.8380674, sum of:
#         0.8380674, weight(overview:cartoon in 147) [PerFieldSimilarity], result of:
#           0.8380674, score(doc=147,freq=1.0), product of:
#             0.68668747, queryWeight, product of:
#               7.8108773, idf(docFreq=2, maxDocs=2723)
#               0.08791426, queryNorm
#             1.2204496, fieldWeight in 147, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.8108773, idf(docFreq=2, maxDocs=2723)
#               0.15625, fieldNorm(doc=147)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.08791426, _type:movie, product of:
#       1.0, boost
#       0.08791426, queryNorm
#
# *************************************
# 4	0.27935582		The Flintstones
# The Flintstones
# Yabba-Dabba-Doo!
# Modern Stone Age family the Flintstones hit the big screen in this live-action version of the classic cartoon. Fred helps Barney adopt a child. Barney sees an opportunity to repay him when Slate Mining tests its employees to find a new executive. But no good deed goes unpunished.
# 888
# DIRS [u'William Hanna', u'Joseph Barbera', u'Brian Levant']
# CAST [u'John Goodman', u'Elizabeth Perkins', u'Rick Moranis', u"Rosie O'Donnell", u'Kyle MacLachlan', u'Halle Berry', u'Elizabeth Taylor', u'Dann Florek', u'Richard Moll', u'Irwin Keyes', u'Jonathan Winters', u'Harvey Korman', u'Corey Burton', u'Roger L. Jackson', u'Jean Vander Pyl']
# CHAR [u'Fred Flintstone', u'Wilma Flintstone', u'Barney Rubble', u'Betty Rubble', u'Cliff Vandercave', u'Rosetta Stone', u'Pearl Slaghoople', u'Mr. Slate', u'Hoagie', u'Joe Rockhead', u'Gobo The Grizzled Man', u"Ali / Dicabird / Blossom's Adopted Doll Son Ali", u'Triple X / Green Goose', u'Bobo', u'Tanya Slag']
# 0.27935582, sum of:
#   0.27935582, max of:
#     0.27935582, product of:
#       0.8380674, sum of:
#         0.8380674, weight(overview:cartoon in 777) [PerFieldSimilarity], result of:
#           0.8380674, score(doc=777,freq=1.0), product of:
#             0.68668747, queryWeight, product of:
#               7.8108773, idf(docFreq=2, maxDocs=2723)
#               0.08791426, queryNorm
#             1.2204496, fieldWeight in 777, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.8108773, idf(docFreq=2, maxDocs=2723)
#               0.15625, fieldNorm(doc=777)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.08791426, _type:movie, product of:
#       1.0, boost
#       0.08791426, queryNorm
#
# *************************************
# 5	0.2563226		White Men Can't Jump
# White Men Can't Jump
# It ain't easy being this good.
# Billy Hoyle (Woody Harrelson) and Sidney Deane (Wesley Snipes) are an unlikely pair of basketball hustlers. They team up to con their way across the courts of Los Angeles, playing a game that's fast dangerous - and funny.
# 10158
# DIRS [u'Ron Shelton']
# CAST [u'Wesley Snipes', u'Woody Harrelson', u'Rosie Perez', u'Tyra Ferrell']
# CHAR [u'Sidney Deane', u'Billy Hoyle', u'Gloria Clement', u'Rhonda Deane']
# 0.2563226, sum of:
#   0.2563226, max of:
#     0.2563226, product of:
#       0.76896775, sum of:
#         0.76896775, weight(overview:basketbal in 248) [PerFieldSimilarity], result of:
#           0.76896775, score(doc=248,freq=1.0), product of:
#             0.6004586, queryWeight, product of:
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.08791426, queryNorm
#             1.280634, fieldWeight in 248, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.830048, idf(docFreq=7, maxDocs=2723)
#               0.1875, fieldNorm(doc=248)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.08791426, _type:movie, product of:
#       1.0, boost
#       0.08791426, queryNorm
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'+(((title:basketbal title:cartoon title:alien)^0.1) | (overview:basketbal overview:cartoon overview:alien)) #QueryWrapperFilter(+ConstantScore(_type:movie))', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.2.4 -- Listing 5 Inspecting Nested Star Trek Docs

# %%
spaceJamId = 2300
httpResp = requests.get("http://localhost:9200/tmdb/movie/%s" % spaceJamId)
spaceJamDoc = json.loads(httpResp.text)
print json.dumps(spaceJamDoc['_source'], indent=True)
# Out:
# {
#  "poster_path": "/9T9ucCk6wO0crRBUIkBJMRAVcKp.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 230000000,
#  "overview": "Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.",
#  "video": false,
#  "id": 2300,
#  "genres": [
#   {
#    "id": 16,
#    "name": "Animation"
#   },
#   {
#    "id": 35,
#    "name": "Comedy"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 14,
#    "name": "Fantasy"
#   },
#   {
#    "id": 10751,
#    "name": "Family"
#   }
#  ],
#  "title": "Space Jam",
#  "tagline": "Get ready to jam.",
#  "vote_count": 275,
#  "homepage": "",
#  "belongs_to_collection": null,
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "cs",
#    "name": "\u010cesk\u00fd"
#   },
#   {
#    "iso_639_1": "fr",
#    "name": "Fran\u00e7ais"
#   },
#   {
#    "iso_639_1": "pl",
#    "name": "Polski"
#   },
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   }
#  ],
#  "imdb_id": "tt0117705",
#  "adult": false,
#  "backdrop_path": "/kBTdPNTAzagAY6UiwY957KCDGuu.jpg",
#  "production_companies": [
#   {
#    "name": "Warner Bros. Animation",
#    "id": 2785
#   },
#   {
#    "name": "Warner Bros. Entertainment",
#    "id": 17
#   }
#  ],
#  "release_date": "1996-11-15",
#  "popularity": 0.778260445788321,
#  "original_title": "Space Jam",
#  "budget": 80000000,
#  "cast": [
#   {
#    "name": "Michael Jordan",
#    "character": "Himself",
#    "id": 23678,
#    "credit_id": "52fe434bc3a36847f80496c9",
#    "cast_id": 2,
#    "profile_path": "/7y16frD57Ztzk2mY4JeI2pQQhan.jpg",
#    "order": 0
#   },
#   {
#    "name": "Wayne Knight",
#    "character": "Stan Podolak",
#    "id": 4201,
#    "credit_id": "52fe434bc3a36847f80496cd",
#    "cast_id": 3,
#    "profile_path": "/oW9aeZwkz1S1IMjQGtd9mnvlEax.jpg",
#    "order": 1
#   },
#   {
#    "name": "Billy West",
#    "character": "Bugs Bunny/Elmer Fudd (voice)",
#    "id": 23679,
#    "credit_id": "52fe434bc3a36847f80496d1",
#    "cast_id": 4,
#    "profile_path": "/9V9fsfmWjHEDbS8tB5EOdHkyMFg.jpg",
#    "order": 2
#   },
#   {
#    "name": "Dee Bradley Baker",
#    "character": "Daffy Duck/Tazmanian Devil/Bull (voice)",
#    "id": 23680,
#    "credit_id": "52fe434bc3a36847f80496d5",
#    "cast_id": 5,
#    "profile_path": "/zFXwtsdvUCeNkzCzYpYZdAmTkJY.jpg",
#    "order": 3
#   },
#   {
#    "name": "Theresa Randle",
#    "character": "Juanita Jordan",
#    "id": 4604,
#    "credit_id": "52fe434bc3a36847f80496d9",
#    "cast_id": 6,
#    "profile_path": "/18LVR034VKDGOFqDw1EA1VZQVoe.jpg",
#    "order": 4
#   },
#   {
#    "name": "Danny DeVito",
#    "character": "Mr. Swackhammer (voice)",
#    "id": 518,
#    "credit_id": "52fe434bc3a36847f80496dd",
#    "cast_id": 7,
#    "profile_path": "/zKuyzmKzPLG7RJo7lbbHjx6CCZc.jpg",
#    "order": 5
#   },
#   {
#    "name": "Brandon Hammond",
#    "character": "Michael Jordan (at 10)",
#    "id": 23681,
#    "credit_id": "52fe434bc3a36847f80496e1",
#    "cast_id": 8,
#    "profile_path": "/ooljlVi5IYf2w4Px3jqc8OQdjjS.jpg",
#    "order": 6
#   },
#   {
#    "name": "Larry Bird",
#    "character": "Himself",
#    "id": 23682,
#    "credit_id": "52fe434bc3a36847f80496e5",
#    "cast_id": 9,
#    "profile_path": "/1KRnQVsXS8mz4tHHWD1yPAQBXq2.jpg",
#    "order": 7
#   },
#   {
#    "name": "Bill Murray",
#    "character": "Himself",
#    "id": 1532,
#    "credit_id": "52fe434bc3a36847f80496e9",
#    "cast_id": 12,
#    "profile_path": "/eb58HuFIrxS0zUmbmW4d8YXTbje.jpg",
#    "order": 8
#   },
#   {
#    "name": "Charles Barkley",
#    "character": "Himself",
#    "id": 1211812,
#    "credit_id": "5361746b0e0a2649bf0004e6",
#    "cast_id": 37,
#    "profile_path": "/mqHWhTtrja9vI8kfI6z7tCq5gB1.jpg",
#    "order": 9
#   },
#   {
#    "name": "Patrick Ewing",
#    "character": "Himself",
#    "id": 1231141,
#    "credit_id": "53614c6cc3a368397e0001d2",
#    "cast_id": 19,
#    "profile_path": "/aaXM8PuixEHNTLmvBQJLH8vV1SV.jpg",
#    "order": 11
#   },
#   {
#    "name": "Tyrone Bogues",
#    "character": "Himself",
#    "id": 1232432,
#    "credit_id": "53614e44c3a36839650001b4",
#    "cast_id": 20,
#    "profile_path": null,
#    "order": 12
#   },
#   {
#    "name": "Larry Johnson",
#    "character": "Himself",
#    "id": 1225517,
#    "credit_id": "53614eb1c3a36839650001bc",
#    "cast_id": 21,
#    "profile_path": "/gbfwZWitnSrcQwkAughr5Ji4iT5.jpg",
#    "order": 13
#   },
#   {
#    "name": "Shawn Bradley",
#    "character": "Himself",
#    "id": 1234833,
#    "credit_id": "5361565a0e0a2649b800027a",
#    "cast_id": 22,
#    "profile_path": null,
#    "order": 14
#   },
#   {
#    "name": "Ahmad Rashad",
#    "character": "Himself",
#    "id": 1197748,
#    "credit_id": "5361566c0e0a2649a6000277",
#    "cast_id": 23,
#    "profile_path": null,
#    "order": 15
#   },
#   {
#    "name": "Del Harris",
#    "character": "Himself",
#    "id": 1251369,
#    "credit_id": "536156930e0a2649b800027f",
#    "cast_id": 24,
#    "profile_path": null,
#    "order": 16
#   },
#   {
#    "name": "Vlade Divac",
#    "character": "Himself",
#    "id": 193304,
#    "credit_id": "536156a50e0a2649a90002a3",
#    "cast_id": 25,
#    "profile_path": "/ivflYHUbWXKyDe5B9su5HSidMA9.jpg",
#    "order": 17
#   },
#   {
#    "name": "Cedric Ceballos",
#    "character": "Himself",
#    "id": 1230823,
#    "credit_id": "536156d20e0a2649b8000282",
#    "cast_id": 26,
#    "profile_path": null,
#    "order": 18
#   },
#   {
#    "name": "Jim Rome",
#    "character": "Himself",
#    "id": 1215304,
#    "credit_id": "536156e10e0a2649ad000272",
#    "cast_id": 27,
#    "profile_path": null,
#    "order": 19
#   },
#   {
#    "name": "Paul Westphal",
#    "character": "Himself",
#    "id": 1315402,
#    "credit_id": "536156ee0e0a2649b8000285",
#    "cast_id": 28,
#    "profile_path": null,
#    "order": 20
#   },
#   {
#    "name": "Danny Ainge",
#    "character": "Himself",
#    "id": 1315446,
#    "credit_id": "536156fe0e0a2649ad000275",
#    "cast_id": 29,
#    "profile_path": null,
#    "order": 21
#   },
#   {
#    "name": "Alonzo Mourning",
#    "character": "Himself",
#    "id": 180625,
#    "credit_id": "5361571f0e0a2649b8000287",
#    "cast_id": 30,
#    "profile_path": "/ukR2lS5Z8avrJnN3Kua1ks3Habf.jpg",
#    "order": 22
#   },
#   {
#    "name": "A.C. Green",
#    "character": "Himself",
#    "id": 1315447,
#    "credit_id": "5361572a0e0a2649bf000295",
#    "cast_id": 31,
#    "profile_path": null,
#    "order": 23
#   },
#   {
#    "name": "Charles Oakley",
#    "character": "Himself",
#    "id": 1315403,
#    "credit_id": "536157540e0a2649bf00029b",
#    "cast_id": 32,
#    "profile_path": "/l35FQsV529lOhDFvMGk8aJ82AV9.jpg",
#    "order": 24
#   },
#   {
#    "name": "Derek Harper",
#    "character": "Himself",
#    "id": 1315448,
#    "credit_id": "536157680e0a2649a90002b5",
#    "cast_id": 33,
#    "profile_path": null,
#    "order": 25
#   },
#   {
#    "name": "Jeff Malone",
#    "character": "Himself",
#    "id": 1315449,
#    "credit_id": "536157780e0a2649a6000287",
#    "cast_id": 34,
#    "profile_path": null,
#    "order": 26
#   },
#   {
#    "name": "Anthony Miller",
#    "character": "Himself",
#    "id": 1315450,
#    "credit_id": "536157ba0e0a2649bb0002d3",
#    "cast_id": 35,
#    "profile_path": null,
#    "order": 27
#   },
#   {
#    "name": "Sharone Wright",
#    "character": "Himself",
#    "id": 1315451,
#    "credit_id": "536157cb0e0a2649bf0002a7",
#    "cast_id": 36,
#    "profile_path": null,
#    "order": 28
#   }
#  ],
#  "directors": [
#   {
#    "name": "Joe Pytka",
#    "department": "Directing",
#    "job": "Director",
#    "credit_id": "52fe434bc3a36847f80496c5",
#    "profile_path": "/c46Ah1KxlfC4W8mHVrGDsJ7dMPJ.jpg",
#    "id": 23677
#   }
#  ],
#  "vote_average": 6.3,
#  "runtime": 88
# }

# %% [markdown]
# # 5.3.1, Listing 6 Star Trek Query Using Query from Ch 3

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name'],      
            'type': 'best_fields'
         }
    },
    'size': 50,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.346026		Legion
# 2	1.346026		Halo 4: Forward Unto Dawn
# 3	1.346026		Priest
# 4	1.346026		Dark Skies
# 5	1.0749499		Drive Angry
# 6	1.0749499		Feast
# 7	1.0749499		District 13: Ultimatum
# 8	1.0749499		The Expendables 3
# 9	1.0749499		Underworld: Rise of the Lycans
# 10	1.0749499		My Bloody Valentine
# 11	0.8599599		Sex and the City 2
# 12	0.8599599		Sex and the City
# 13	0.8599599		Doubt
# 14	0.8599599		Sinbad: Legend of the Seven Seas
# 15	0.46373135		Vertigo
# 16	0.46373135		Star Trek: Insurrection
# 17	0.46373135		Gnomeo & Juliet
# 18	0.46373135		Star Trek: First Contact
# 19	0.46373135		Excalibur
# 20	0.38982356		X-Men: Days of Future Past
# 21	0.38644278		Conspiracy Theory
# 22	0.38644278		The Wolverine
# 23	0.38644278		Star Trek: Nemesis
# 24	0.38644278		Dune
# 25	0.38644278		Star Trek: Generations
# 26	0.38644278		X-Men
# 27	0.38644278		Panic Room
# 28	0.38644278		Robin Hood: Men in Tights
# 29	0.35654074		Ted
# 30	0.3542312		One Flew Over the Cuckoo's Nest
# 31	0.32015914		The Bounty Hunter
# 32	0.31694135		Hannah Montana: The Movie
# 33	0.3091542		The Collector
# 34	0.3091542		Save the Last Dance
# 35	0.3091542		X2: X-Men United
# 36	0.3091542		TMNT
# 37	0.3091542		The Prince of Egypt
# 38	0.3091542		X-Men: The Last Stand
# 39	0.3091542		A Time to Kill
# 40	0.27050993		The Faculty
# 41	0.26740557		The Cabin in the Woods
# 42	0.2561273		The Beaver
# 43	0.2561273		Zathura: A Space Adventure
# 44	0.24556357		A Good Year
# 45	0.23615414		One for the Money
# 46	0.23615414		The SpongeBob Movie: Sponge Out of Water
# 47	0.23615414		The SpongeBob SquarePants Movie
# 48	0.23615414		10 Things I Hate About You
# 49	0.23615414		The Kings of Summer
# 50	0.22283797		Chicken Little
# ===============
# Num	Relevance Score		Movie Title
# 1	1.346026		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 1.3460261, sum of:
#   1.3460261, max of:
#     1.3460261, product of:
#       2.6920521, sum of:
#         2.6920521, weight(directors.name:stewart in 376) [PerFieldSimilarity], result of:
#           2.6920521, score(doc=376,freq=1.0), product of:
#             0.58098286, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.0783652, queryNorm
#             4.633617, fieldWeight in 376, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=376)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 2	1.346026		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# DIRS [u'Stewart Hendler']
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 1.3460261, sum of:
#   1.3460261, max of:
#     1.3460261, product of:
#       2.6920521, sum of:
#         2.6920521, weight(directors.name:stewart in 493) [PerFieldSimilarity], result of:
#           2.6920521, score(doc=493,freq=1.0), product of:
#             0.58098286, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.0783652, queryNorm
#             4.633617, fieldWeight in 493, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=493)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 3	1.346026		Priest
# Priest
# Vampire Killer
# In an alternate world, humanity and vampires have warred for centuries. After the last Vampire War, the veteran Warrior Priest lives in obscurity with other humans inside one of the Church's walled cities. When the Priest's niece is kidnapped by vampires, the Priest breaks his vows to hunt them down. He is accompanied by the niece's boyfriend, who is a wasteland sheriff, and a former Warrior Priestess.
# 38321
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Cam Gigandet', u'Karl Urban', u'Lily Collins', u'Maggie Q', u'Stephen Moyer', u'M\xe4dchen Amick', u'Christopher Plummer', u'Brad Dourif', u'Alan Dale']
# CHAR [u'Priest', u'Hicks', u'Black Hat', u'Lucy', u'Priestess', u'Aaron', u'Shannon', u'Monsignor Orelas', u'Salesman', u'Monsignor Chamberlain']
# 1.3460261, sum of:
#   1.3460261, max of:
#     1.3460261, product of:
#       2.6920521, sum of:
#         2.6920521, weight(directors.name:stewart in 1100) [PerFieldSimilarity], result of:
#           2.6920521, score(doc=1100,freq=1.0), product of:
#             0.58098286, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.0783652, queryNorm
#             4.633617, fieldWeight in 1100, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=1100)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 4	1.346026		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# DIRS [u'Scott Stewart']
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 1.3460261, sum of:
#   1.3460261, max of:
#     1.3460261, product of:
#       2.6920521, sum of:
#         2.6920521, weight(directors.name:stewart in 1130) [PerFieldSimilarity], result of:
#           2.6920521, score(doc=1130,freq=1.0), product of:
#             0.58098286, queryWeight, product of:
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.0783652, queryNorm
#             4.633617, fieldWeight in 1130, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.413787, idf(docFreq=4, maxDocs=3051)
#               0.625, fieldNorm(doc=1130)
#       0.5, coord(1/2)
#     0.057200607, product of:
#       0.114401214, sum of:
#         0.114401214, weight(cast.name:patrick in 1130) [PerFieldSimilarity], result of:
#           0.114401214, score(doc=1130,freq=1.0), product of:
#             0.267807, queryWeight, product of:
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.0783652, queryNorm
#             0.42717782, fieldWeight in 1130, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               3.4174225, idf(docFreq=271, maxDocs=3051)
#               0.125, fieldNorm(doc=1130)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 5	1.0749499		Drive Angry
# Drive Angry
# One hell of a ride.
# Milton is a hardened felon who has broken out of Hell, intent on finding the vicious cult who brutally murdered his daughter and kidnapped her baby. He joins forces with Piper, a sexy, tough-as-nails waitress with a 69 Charger, who's also seeking redemption of her own. Caught in a deadly race against time, Milton has three days to avoid capture, avenge his daughter's death, and save her baby before she's mercilessly sacrificed by the cult.
# 47327
# DIRS [u'Patrick Lussier']
# CAST [u'Nicolas Cage', u'Amber Heard', u'William Fichtner', u'Billy Burke', u'David Morse', u'Katy Mixon', u'Charlotte Ross', u'Christa Campbell', u'Todd Farmer', u'Jack McGee', u'Tom Atkins', u'Wanetah Walmsley', u'Edrick Browne', u'Robin McGee', u'Fabian C. Moreno', u'Marc Macaulay', u'Pruitt Taylor Vince', u'Julius Washington', u'Jamie Teer', u'Bryan Massey', u'Timothy Walter', u'Kent Jude Bernard', u'Brent Phillip Henry', u'Gerry May', u'Sherri Talley', u'Arianne Margot', u'Con Schell', u'Nick Gomez', u'Joe Chrest', u'Oakley Lehman', u'Thirl Haston', u'Jake Brake', u'Tim J. Smith', u'Jeffrey J. Dashnaw', u'Tim Trella', u'James Landry H\xe9bert', u'Kenneth Wayne Bradley', u'Kendrick Hudson', u'Michael Papajohn', u'April Littlejohn', u'Henry Kingi', u'Simona Williams', u'Shelby Swatek', u'Joseph Blackstone', u'Dan Forest', u'Elise Fyke', u"Jonathan O'Rear", u'James Paul', u'Alice Searcy', u'Lanie Taylor', u'David Lee Valle']
# CHAR [u'Milton', u'Piper', u'Accountant', u'Jonah King', u'Webster', u'Norma Jean', u'Candy', u'Mona', u'Frank', u'Fat Lou', u'Cap', u'American Indian Mother', u'Rookie', u'Guy with Camera Phone', u'Latino Busboy', u'Sarge', u'Roy', u'Uniformed Officer', u'Babysitter', u'Trooper #1', u'Trooper #2', u'Teen #1', u'Teen #2', u'TV Male News Reporter #1', u'TV Female News Reporter #2', u"Milton's Daughter (Older)", u'Fucking Driver', u'Fucking Middle', u'Fucking Passenger', u'Cultist with Iron Pipe', u'Cultist with Sickle', u'Cultist with Machete', u'Cultist with Hatchet', u'Cowboy with Cattle Prod', u'Cultist with Sledge', u'Man in Leather Jacket', u'Man with Wig', u'Burly Dude', u'Tattooed Guy', u'Business Woman', u'Thin Old Man', u'Lady in Leopard Skin', u'Truck Driving Woman', u'Bar Patron', u'American Indian Dad', u'Laughing Cowgirl', u'Resturant Patron', u'Bar Patron', u'Restaurant Patron', u"Milton's Daughter - Younger", u'Highway Patrol']
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 91) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=91,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 91, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=91)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 6	1.0749499		Feast
# Feast
#
# This Oscar-winning animated short film tells the story of one man's love life is seen through the eyes of his best friend and dog, Winston, and revealed bite by bite through the meals they share.
# 293299
# DIRS [u'Patrick Osborne']
# CAST [u'Tommy Snider', u'Katie Lowes', u'Ben Bledsoe']
# CHAR [u'James', u'Additional Voices (voice)', u'Additional Voices']
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 209) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=209,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 209, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=209)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 7	1.0749499		District 13: Ultimatum
# District 13: Ultimatum
#
# Damien and Leito return to District 13 on a mission to bring peace to the troubled sector that is controlled by five different gang bosses, before the city's secret services take drastic measures to solve the problem.
# 15357
# DIRS [u'Patrick Alessandrin']
# CAST [u'Cyril Raffaelli', u'David Belle', u'Philippe Torreton', u'Daniel Duval', u'Elodie Yung', u"MC Jean Gab'1", u'James Deano', u'Laouni Mouhid', u'Fabrice Feltzinger', u'Pierre-Marie Mosconi', u'Johnny Amaro']
# CHAR [u'Damien', u'Le\xefto', u'Le Pr\xe9sident de la R\xe9publique', u'Walter Gassman', u'Tao', u'Molko', u'Karl le skin', u'Ali-K', u'Little Montana', u'Roland', u'Policier centre de contr\xf4le']
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 432) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=432,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 432, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=432)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 8	1.0749499		The Expendables 3
# The Expendables 3
# New team. New attitude. New mission.
# Barney (Stallone), Christmas (Statham) and the rest of the team comes face-to-face with Conrad Stonebanks (Gibson), who years ago co-founded The Expendables with Barney. Stonebanks subsequently became a ruthless arms trader and someone who Barney was forced to kill... or so he thought. Stonebanks, who eluded death once before, now is making it his mission to end The Expendables -- but Barney has other plans. Barney decides that he has to fight old blood with new blood, and brings in a new era of Expendables team members, recruiting individuals who are younger, faster and more tech-savvy. The latest mission becomes a clash of classic old-school style versus high-tech expertise in the Expendables' most personal battle yet.
# 138103
# DIRS [u'Patrick Hughes']
# CAST [u'Sylvester Stallone', u'Jason Statham', u'Harrison Ford', u'Arnold Schwarzenegger', u'Mel Gibson', u'Wesley Snipes', u'Randy Couture', u'Dolph Lundgren', u'Terry Crews', u'Kelsey Grammer', u'Glen Powell', u'Antonio Banderas', u'Victor Ortiz', u'Ronda Rousey', u'Kellan Lutz', u'Jet Li', u'Ivan Kostadinov', u'Robert Davi', u'Nikolay Stoyanov Ilchev', u'Daniel Angelov', u'Slavi Slavov', u'Dimiter Doichinov', u'Nikolay Stanoev', u'Harry Anichkin', u'Boswell Maloka', u'Natalie Burn', u'Velizar Binev', u'Sarai Givaty', u'Liubomir Simeonov', u'Frank Pesce', u'Thomas Canestraro']
# CHAR [u'Barney Ross', u'Lee Christmas', u'Max Drummer', u'Trench', u'Conrad Stonebanks', u'Doc', u'Toll Road', u'Gunnar Jensen', u'Hale Caesar', u'Bonaparte', u'Thorn', u'Galgo', u'Mars', u'Luna', u'John Smilee', u'Yin Yang', u'Krug', u'Vata', u'Local Cop #1', u'Local Cop #2', u'Warden', u'Head Bodyguard', u'Tech Guy', u'Colonel', u'Somali Drug Warlord', u"Conrad's Wife", u'Art Broker', u'Camilla', u'Cyclops', u'Fight Watcher', u"Conrad's Henchman"]
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 546) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=546,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 546, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=546)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 9	1.0749499		Underworld: Rise of the Lycans
# Underworld: Rise of the Lycans
# Every war has a beginning.
# A prequel to the first two Underworld films, this fantasy explains the origins of the feud between the Vampires and the Lycans. Aided by his secret love, Sonja, courageous Lucian leads the Lycans in battle against brutal Vampire king Viktor. Determined to break the king's enslavement of his people, Lucian faces off against the Death Dealer army in a bid for Lycan independence.
# 12437
# DIRS [u'Patrick Tatopoulos']
# CAST [u'Bill Nighy', u'Michael Sheen', u'Rhona Mitra', u'Shane Brolly', u'Steven Mackintosh', u'Kevin Grevioux', u'David Aston', u'Geraldine Brophy', u'Leighton Cardno', u'Alexander Carroll', u'Elizabeth Hawthorne', u'Jason Hood', u'Mark Mitchinson', u'Craig Parker', u'Timothy Raby', u'Tania Nolan', u'Kate Beckinsale']
# CHAR [u'Viktor', u'Lucian', u'Sonja', u'Kraven', u'Andreas Tanis', u'Raze', u'Coloman', u"Nobleman's Wife", u'Fearful Lycan', u'Young Lucian', u'Orsova', u'Death Dealer', u'Nobleman', u'Sabas', u'Janosh', u'Luka', u'Selene']
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 931) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=931,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 931, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=931)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 10	1.0749499		My Bloody Valentine
# My Bloody Valentine
# He's gonna break your heart.
# Ten years ago, a tragedy changed the town of Harmony forever. Tom Hanniger, an inexperienced coal miner, caused an accident in the tunnels that trapped and killed five men and sent the only survivor, Harry Warden, into a permanent coma. But Harry Warden wanted revenge. Exactly one year later, on Valentine’s Day, he woke up…and brutally murdered twenty-two people with a pickaxe before being killed.
# 14435
# DIRS [u'Patrick Lussier']
# CAST [u'Jensen Ackles', u'Jaime King', u'Kerr Smith', u'Betsy Rue', u'Edi Gathegi', u'Tom Atkins', u'Kevin Tighe', u'Megan Boone', u'Karen Baum', u'Joy de la Paz', u'Marc Macaulay', u'Todd Farmer', u'Jeff Hochendoner', u"Bingo O'Malley", u'Liam Rhodes', u'Richard John Walters']
# CHAR [u'Tom Hanniger', u'Sarah Palmer', u'Axel Palmer', u'Irene', u'Deputy Martin', u'Sheriff Jim Burke', u'Ben Foley', u'Megan', u'Deputy Ferris', u'Rosa', u'Riggs', u'Frank the Trucker', u'Red', u'Officer Hinch', u'Michael', u'Harry Warden']
# 1.0749499, sum of:
#   1.0749499, max of:
#     1.0749499, product of:
#       2.1498997, sum of:
#         2.1498997, weight(directors.name:patrick in 1066) [PerFieldSimilarity], result of:
#           2.1498997, score(doc=1066,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             4.140831, fieldWeight in 1066, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.625, fieldNorm(doc=1066)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 11	0.8599599		Sex and the City 2
# Sex and the City 2
# Carrie on.
# Carrie (Sarah Jessica Parker), Charlotte (Kristin Davis), and Miranda (Cynthia Nixon) are all married now, but they're still up for a little fun in the sun. When Samantha (Kim Cattrall) gets the chance to visit one of the most extravagant vacation destinations on the planet and offers to bring them all along, they surmise that a women-only retreat may be the perfect excuse to eschew their responsibilities and remember what life was like before they decided to settle down.
# 37786
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kristin Davis', u'Cynthia Nixon', u'Kim Cattrall', u'David Eigenberg', u'Evan Handler', u'Alexandra Fong', u'Parker Fong', u'Mario Cantone', u'Willie Garson', u'Noah Mills', u'Liza Minnelli', u'Billy Stritch', u'Alice Eve', u'Jason Lewis', u'Max Ryan', u'Lynn Cohen', u'Amira Mor', u"Dhaffer L'Abidine", u'John Corbett', u'Raya Meddine', u'Jennifer Ferrin', u'Tet Wada']
# CHAR [u'Carrie Bradshaw', u'Charlotte York', u'Miranda Hobbes', u'Samantha Jones', u'Steve Brady', u'Harry Goldenblatt', u'Lily York Goldenblatt', u'Lily York Goldenblatt', u'Anthony Marantino', u'Stanford Blatch', u'Nicky', u'Herself', u'Band Leader', u'Erin', u"Jerry 'Smith' Jerrod", u'Rikard Spirit', u'Magda', u'', u'Mahmud (non cr\xe9dit\xe9)', u'Aidan Shaw', u'Annesha', u'Patience', u'VIP Party Patron']
# 0.8599599, sum of:
#   0.8599599, max of:
#     0.8599599, product of:
#       1.7199198, sum of:
#         1.7199198, weight(directors.name:patrick in 211) [PerFieldSimilarity], result of:
#           1.7199198, score(doc=211,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             3.3126647, fieldWeight in 211, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.5, fieldNorm(doc=211)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 12	0.8599599		Sex and the City
# Sex and the City
# Get carried away.
# A New York writer on sex and love is finally getting married to her Mr. Big. But her three best girlfriends must console her after one of them inadvertently leads Mr. Big to jilt her.
# 4564
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kim Cattrall', u'Cynthia Nixon', u'Kristin Davis', u'Chris Noth', u'Willie Garson', u'David Eigenberg', u'Evan Handler', u'Jennifer Hudson', u'Jason Lewis', u'Mario Cantone', u'Julie Halston', u'Lynn Cohen', u'Anne Meara', u'Candice Bergen', u"Lil' Kim", u'Alexandra Fong', u'Kerry Bish\xe9', u'Joseph Pupo', u'Gilles Marini']
# CHAR [u'Carrie Bradshaw', u'Samantha Jones', u'Miranda Hobbes', u'Charlotte York Goldenblatt', u'Mr. Big', u'Stanford', u'Steve Brady', u'Harry Goldenblatt', u"Louise, Carrie's assistant", u'Smith Jerrod', u'Anthony Marantino', u'Bitsy von Muffling', u'Magda', u'Mary Brady', u'Enid Frick', u'Herself', u'Lily York Goldenblatt', u'Twenty-Something Girl Dreaming', u'Brady', u'Dante']
# 0.8599599, sum of:
#   0.8599599, max of:
#     0.8599599, product of:
#       1.7199198, sum of:
#         1.7199198, weight(directors.name:patrick in 1237) [PerFieldSimilarity], result of:
#           1.7199198, score(doc=1237,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             3.3126647, fieldWeight in 1237, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.5, fieldNorm(doc=1237)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 13	0.8599599		Doubt
# Doubt
# There is no evidence. There are no witnesses. But for one, there is no doubt.
# In 1964, a Catholic school nun questions a priest's ambiguous relationship with a troubled young student, suspecting him of abuse. He denies the charges, and much of the film's quick-fire dialogue tackles themes of religion, morality, and authority.
# 14359
# DIRS [u'John Patrick Shanley']
# CAST [u'Amy Adams', u'Philip Seymour Hoffman', u'Meryl Streep', u'Viola Davis', u'Alice Drummond']
# CHAR [u'Sister James', u'Father Brendan Flynn', u'Sister Aloysius Beauvier', u'Mrs. Miller', u'Sister Veronica']
# 0.8599599, sum of:
#   0.8599599, max of:
#     0.8599599, product of:
#       1.7199198, sum of:
#         1.7199198, weight(directors.name:patrick in 1091) [PerFieldSimilarity], result of:
#           1.7199198, score(doc=1091,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             3.3126647, fieldWeight in 1091, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.5, fieldNorm(doc=1091)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 14	0.8599599		Sinbad: Legend of the Seven Seas
# Sinbad: Legend of the Seven Seas
#
# The sailor of legend is framed by the goddess Eris for the theft of the Book of Peace, and must travel to her realm at the end of the world to retrieve it and save the life of his childhood friend Prince Proteus.
# 14411
# DIRS [u'Tim Johnson', u'Patrick Gilmore']
# CAST [u'Brad Pitt', u'Catherine Zeta-Jones', u'Michelle Pfeiffer', u'Joseph Fiennes', u'Dennis Haysbert', u'Timothy West', u'Timothy West', u'Raman Hui', u'Chung Chan', u'Jim Cummings', u'Conrad Vernon', u'Andrew Birch', u'Chris Miller']
# CHAR [u'Sinbad', u'Marina', u'Eris', u'Proteus', u'Kale', u'Dymas', u'Rat', u'Jin', u'Li', u'Luca', u'Jed', u'Grum / Chum', u'Tower guard']
# 0.8599599, sum of:
#   0.8599599, max of:
#     0.8599599, product of:
#       1.7199198, sum of:
#         1.7199198, weight(directors.name:patrick in 1492) [PerFieldSimilarity], result of:
#           1.7199198, score(doc=1492,freq=1.0), product of:
#             0.51919526, queryWeight, product of:
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.0783652, queryNorm
#             3.3126647, fieldWeight in 1492, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.6253295, idf(docFreq=10, maxDocs=3051)
#               0.5, fieldNorm(doc=1492)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 15	0.46373135		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# DIRS [u'Alfred Hitchcock']
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.46373135, sum of:
#   0.46373135, max of:
#     0.46373135, sum of:
#       0.17160182, weight(cast.name:patrick in 526) [PerFieldSimilarity], result of:
#         0.17160182, score(doc=526,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.64076674, fieldWeight in 526, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=526)
#       0.29212952, weight(cast.name:stewart in 526) [PerFieldSimilarity], result of:
#         0.29212952, score(doc=526,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.83603936, fieldWeight in 526, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=526)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 16	0.46373135		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.46373135, sum of:
#   0.46373135, max of:
#     0.46373135, sum of:
#       0.17160182, weight(cast.name:patrick in 988) [PerFieldSimilarity], result of:
#         0.17160182, score(doc=988,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.64076674, fieldWeight in 988, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=988)
#       0.29212952, weight(cast.name:stewart in 988) [PerFieldSimilarity], result of:
#         0.29212952, score(doc=988,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.83603936, fieldWeight in 988, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=988)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 17	0.46373135		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.46373135, sum of:
#   0.46373135, max of:
#     0.46373135, sum of:
#       0.17160182, weight(cast.name:patrick in 1296) [PerFieldSimilarity], result of:
#         0.17160182, score(doc=1296,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.64076674, fieldWeight in 1296, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=1296)
#       0.29212952, weight(cast.name:stewart in 1296) [PerFieldSimilarity], result of:
#         0.29212952, score(doc=1296,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.83603936, fieldWeight in 1296, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=1296)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 18	0.46373135		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.46373135, sum of:
#   0.46373135, max of:
#     0.46373135, sum of:
#       0.17160182, weight(cast.name:patrick in 33) [PerFieldSimilarity], result of:
#         0.17160182, score(doc=33,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.64076674, fieldWeight in 33, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=33)
#       0.29212952, weight(cast.name:stewart in 33) [PerFieldSimilarity], result of:
#         0.29212952, score(doc=33,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.83603936, fieldWeight in 33, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=33)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 19	0.46373135		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# DIRS [u'John Boorman']
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.46373135, sum of:
#   0.46373135, max of:
#     0.46373135, sum of:
#       0.17160182, weight(cast.name:patrick in 1105) [PerFieldSimilarity], result of:
#         0.17160182, score(doc=1105,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.64076674, fieldWeight in 1105, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.1875, fieldNorm(doc=1105)
#       0.29212952, weight(cast.name:stewart in 1105) [PerFieldSimilarity], result of:
#         0.29212952, score(doc=1105,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.83603936, fieldWeight in 1105, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.1875, fieldNorm(doc=1105)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 20	0.38982356		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# DIRS [u'Bryan Singer']
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 0.38982356, sum of:
#   0.38982356, max of:
#     0.38982356, sum of:
#       0.114401214, weight(cast.name:patrick in 1107) [PerFieldSimilarity], result of:
#         0.114401214, score(doc=1107,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.42717782, fieldWeight in 1107, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.125, fieldNorm(doc=1107)
#       0.27542233, weight(cast.name:stewart in 1107) [PerFieldSimilarity], result of:
#         0.27542233, score(doc=1107,freq=2.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.7882255, fieldWeight in 1107, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.125, fieldNorm(doc=1107)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 21	0.38644278		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.38644278, sum of:
#   0.38644278, max of:
#     0.38644278, sum of:
#       0.14300151, weight(cast.name:patrick in 37) [PerFieldSimilarity], result of:
#         0.14300151, score(doc=37,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.53397226, fieldWeight in 37, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.15625, fieldNorm(doc=37)
#       0.24344127, weight(cast.name:stewart in 37) [PerFieldSimilarity], result of:
#         0.24344127, score(doc=37,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.6966995, fieldWeight in 37, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.15625, fieldNorm(doc=37)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 22	0.38644278		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.38644278, sum of:
#   0.38644278, max of:
#     0.38644278, sum of:
#       0.14300151, weight(cast.name:patrick in 494) [PerFieldSimilarity], result of:
#         0.14300151, score(doc=494,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.53397226, fieldWeight in 494, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.15625, fieldNorm(doc=494)
#       0.24344127, weight(cast.name:stewart in 494) [PerFieldSimilarity], result of:
#         0.24344127, score(doc=494,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.6966995, fieldWeight in 494, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.15625, fieldNorm(doc=494)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 23	0.38644278		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# ...
# 228165
# DIRS [u'Paul Tibbitt']
# CAST [u'Tom Kenny', u'Bill Fagerbakke', u'Rodger Bumpass', u'Clancy Brown', u'Carolyn Lawrence', u'Mr. Lawrence', u'Antonio Banderas', u'Eric Bauza', u'Tim Conway', u'Eddie Deezen', u'Rob Paulsen', u'Kevin Michael Richardson', u'April Stewart', u'Cree Summer', u'Billy West', u'Carlos Alazraqui', u'Nolan North', u'Paul Tibbitt', u'Jill Talley', u'Dee Bradley Baker', u'Sirena Irwin', u'Mary Jo Catlett', u'Mark Fite', u'Thomas F. Wilson', u'Riki Lindhome', u'Kate Micucci', u'Matt Berry', u'Ezra James Colbert', u'Lillian Ellen Jones', u'Brody Rose', u'Noah Lomax', u'Jesica Ahlberg', u' Nina Repeta', u'Corinne Engstrom', u'Chip Lane', u'Brick Jackson', u'Keller Moore', u'Bailey Campbell', u'Henry Davis Morales', u'Nicolette Noble', u'Kari Klinkenborg', u'Lisa Datz', u'Dane Northcutt', u'Meredith Jackson', u'Ella Adele Burns', u'Mike Benitez', u'Kron Moore', u'Eamon Sheehan', u'Matteo Spears Satriano', u'John Brown', u'David Dickson', u'Ashley Nicole Hudson', u'Amy Lynn Tuttle', u'Marian Green', u'Jake Kilfoyle', u'Dean Neistat', u'Ashley Siloac', u'Epic Lloyd', u'Nice Peter', u'Stephen Hillenburg', u'Lori Alan']
# CHAR [u'SpongeBob / Gary / Agreeable Mob Member / Waffle (voice)', u'Patrick / Male Fish / Eager Customer (voice)', u'Doctor / Squidward / Angry Mob Member #2 / Doughnut / Squidasaurus Rex (voice)', u'Mr.Krabs (voice)', u'Sandy (voice)', u'Plankton / Plankton Robot / News Anchor Fish / Mob Member (voice)', u'Burger Beard', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull / Dead Parrot (voice)', u'Seagull / Dead Parrot / Pigeon Cabbie (voice)', u'Kyle / Helpful Angry Mob Member (voice)', u'Karen (the Computer Wife) / Harold\u2019s Wife / Ice Cream Cone #2 (voice)', u'Sandals / Customer #1 / Fish on Bubble / Perch Perkins / Angry Fish / Maple Syrup Jar / Waffle / Ice Cream Cone #1 / Furballs / Giant Cute Kitty / Rainbow / Spotlight Guard / Angry Guard #1 / Tough Mob Member (voice)', u'Computer Voice / Shocked Mob Member (voice)', u'Mrs. Puff (voice)', u'Customer #2 (voice)', u'Angry Customer #1 (voice)', u'Popsicle (voice)', u'Popsicle (voice)', u'Bubbles (voice)', u'Boy on the Beach', u'Sandcastle Girl', u'Kicking Boy', u'Mikey', u'Tanning Woman', u'Woman with Stroller', u'Young Woman Customer', u'Customer', u'Customer', u'Older Boy Customer', u'Boy Customer #2', u'Young Boy with Cone', u'Surfer Girl with Cone', u'Woman on Sidewalk #1', u'Amy', u'Nut Vendor Customer', u'Mother with Cone', u'Young Girl with Cone', u'Nut Vendor', u'Woman on Sidewalk', u'Young Father', u'Little Boy on Lifeguard Chair', u'Food Truck Patron', u'Man Eating Krabby Patty', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'Beach Goer', u'Surfer Dude (voice)', u'Surfer Dude', u'Baby in Stroller (voice)', u'Pearl (voice)']
# 0.23615414, sum of:
#   0.23615414, max of:
#     0.23615414, product of:
#       0.47230828, sum of:
#         0.47230828, weight(overview:patrick in 679) [PerFieldSimilarity], result of:
#           0.47230828, score(doc=679,freq=1.0), product of:
#             0.54415095, queryWeight, product of:
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.0783652, queryNorm
#             0.8679729, fieldWeight in 679, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.125, fieldNorm(doc=679)
#       0.5, coord(1/2)
#     0.060860317, product of:
#       0.121720634, sum of:
#         0.121720634, weight(cast.name:stewart in 679) [PerFieldSimilarity], result of:
#           0.121720634, score(doc=679,freq=1.0), product of:
#             0.34942076, queryWeight, product of:
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.0783652, queryNorm
#             0.34834975, fieldWeight in 679, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.4588766, idf(docFreq=95, maxDocs=3051)
#               0.078125, fieldNorm(doc=679)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 47	0.23615414		The SpongeBob SquarePants Movie
# The SpongeBob SquarePants Movie
# Bigger. Better. More absorbent.
# There's trouble brewing in Bikini Bottom. Someone has stolen King Neptune's crown, and it looks like Mr. Krab, SpongeBob's boss, is the culprit. Though he's just been passed over for the promotion of his dreams, SpongeBob stands by his boss, and along with his best pal Patrick, sets out on a treacherous mission to Shell City to reclaim the crown and save Mr. Krab's life.
# 11836
# DIRS [u'Stephen Hillenburg']
# CAST [u'Tom Kenny', u'Clancy Brown', u'Rodger Bumpass', u'Bill Fagerbakke', u'Carolyn Lawrence', u'Jeffrey Tambor', u'Scarlett Johansson', u'Alec Baldwin', u'David Hasselhoff', u'Mr. Lawrence', u'Mr. Lawrence']
# CHAR [u'Spongebob', u'Mr. Krabs (voice)', u'Squidward (voice)', u'Patrick Star (voice)', u'Sandy (voice)', u'King Neptune (voice)', u'Mindy (voice)', u'Dennis (voice)', u'Himself', u'Plankton', u'Plankton']
# 0.23615414, sum of:
#   0.23615414, max of:
#     0.23615414, product of:
#       0.47230828, sum of:
#         0.47230828, weight(overview:patrick in 829) [PerFieldSimilarity], result of:
#           0.47230828, score(doc=829,freq=1.0), product of:
#             0.54415095, queryWeight, product of:
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.0783652, queryNorm
#             0.8679729, fieldWeight in 829, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.125, fieldNorm(doc=829)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 48	0.23615414		10 Things I Hate About You
# 10 Things I Hate About You
# How do I loathe thee? Let me count the ways.
# Bianca, a tenth grader has never gone on a date, but she isn't allowed to go out with boys until her older sister gets a boyfriend. The problem is, Kat rubs nearly everyone the wrong way. But Bianca and the guy she has her eye on, Joey, are eager, so Joey fixes Kat up with Patrick, a new kid in town just bitter enough for Kat.
# 4951
# DIRS [u'Gil Junger']
# CAST [u'Heath Ledger', u'Julia Stiles', u'Joseph Gordon-Levitt', u'Larisa Oleynik', u'David Krumholtz', u'Andrew Keegan', u'Susan May Pratt', u'Gabrielle Union', u'Larry Miller', u'Daryl Mitchell', u'Allison Janney', u'David Leisure', u'Kyle Cease', u'Greg Jackson', u'Terence Heuston', u'Cameron Fraser', u'Eric Riedmann', u'Quinn Maixner', u'Demegio Kimbrough', u'Todd Butler', u'Dennis Mosley', u'Bianca Kajlich', u'Nick Vukelic', u'Ben Laurance', u'Aidan Kennedy', u'Jelani Quinn', u'Jesse Dyer', u'Aaron Therol', u'Carlos Lac\xe1mara', u'Joshua Thorpe', u'J.R. Johnson', u'Wendy Gottlieb', u'Brian Hood', u'Travis Muller', u'Ari Karczag', u'Laura Kenny', u'Alice Evans', u'Jesper Inglis', u'Nick Brown', u'Monique Powell', u'Brian Mashburn', u'Kay Hanley', u'Michael Eisenstein', u'Michelle Babin', u'Tim Bennett', u'Shelsie Blake', u'Gil Junger', u'Daniel Kountz', u'Alisa Mackay', u'Katy Magnuson', u'Amber Matthews', u'Maher McClung', u'Joshua Mosley', u"Bridget O'Neill", u'Tommy Snider', u'Jay Zorich']
# CHAR [u'Patrick Verona', u'Kat Stratford', u'Cameron James', u'Bianca Stratford', u'Michael', u'Joey Donner', u'Mandella', u'Chastity', u'Walter Stratford', u'Mr. Morgan', u'Ms. Perky', u'Mr. Chapin', u'Bogie Lowenstien', u'Scruvy', u'Derek', u'Trevor', u'Audio Visual Guy', u'Beautiful Jock', u'Coffee Kid #1', u'Coffee Kid #2', u'Cohort', u'Coffee Girl', u'Drugged Out Loser', u'Wimpy Loser (as Benjamin Laurance)', u'Laughing Loser', u'Crying Loser', u'Screaming Loser', u'Detention Student', u'Bartender', u'Jock', u'Mba Guy at Party', u'Heather', u'Clem', u'Cowboy', u'Kissing Guy', u'Judith', u'Perky Girl', u'Buckaroo Bartender', u'Biker', u'Save Ferris Singer', u'Save Ferris Singer', u'Letters To Cleo Singer', u'Letters To Cleo Singer', u'Girl in Night Club (uncredited)', u'School Administrator (uncredited)', u'Bookstore Patron (uncredited)', u'Teacher (uncredited)', u'Admirer #1 (uncredited)', u'Coffee Girl #2 (uncredited)', u'Beautiful Girl (uncredited)', u'Club Dancer #1 (uncredited)', u'Frisbee Thrower (uncredited)', u'Cohort (uncredited)', u'Beautiful Girl (uncredited)', u'Student (uncredited)', u'Roland / High School Security Cop (uncredited)']
# 0.23615414, sum of:
#   0.23615414, max of:
#     0.23615414, product of:
#       0.47230828, sum of:
#         0.47230828, weight(overview:patrick in 90) [PerFieldSimilarity], result of:
#           0.47230828, score(doc=90,freq=1.0), product of:
#             0.54415095, queryWeight, product of:
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.0783652, queryNorm
#             0.8679729, fieldWeight in 90, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.125, fieldNorm(doc=90)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 49	0.23615414		The Kings of Summer
# The Kings of Summer
# Why live when you can rule.
# Joe Toy, on the verge of adolescence, finds himself increasingly frustrated by his single father, Frank's attempts to manage his life. Declaring his freedom once and for all, he escapes to a clearing in the woods with his best friend, Patrick, and a strange kid named Biaggio. He announces that they are going to build a house there, free from responsibility and parents. Once their makeshift abode is finished, the three young men find themselves masters of their own destiny, alone in the woods.
# 156700
# DIRS [u'Jordan Vogt-Roberts']
# CAST [u'Nick Robinson', u'Gabriel Basso', u'Mois\xe9s Arias', u'Alison Brie', u'Nick Offerman', u'Megan Mullally', u'Mary Lynn Rajskub', u'Angela Trimbur', u'Erin Moriarty', u'Lili Reinhart', u'Marc Evan Jackson', u'Kumail Nanjiani', u'Hannibal Buress', u'Nathan Keyes', u'Austin Abrams', u'Thomas Middleditch']
# CHAR [u'Joe Toy', u'Patrick Keenan', u'Biaggio', u'Heather Toy', u'Frank Toy', u'Mrs. Keenan', u'Captain Davis', u'FacePaint', u'Kelly', u'Vicki', u'Mr. Keenan', u'Delivery Guy', u'Bus Driver', u'Paul', u'Aaron', u'Rookie Cop']
# 0.23615414, sum of:
#   0.23615414, max of:
#     0.23615414, product of:
#       0.47230828, sum of:
#         0.47230828, weight(overview:patrick in 1303) [PerFieldSimilarity], result of:
#           0.47230828, score(doc=1303,freq=1.0), product of:
#             0.54415095, queryWeight, product of:
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.0783652, queryNorm
#             0.8679729, fieldWeight in 1303, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.9437833, idf(docFreq=7, maxDocs=3051)
#               0.125, fieldNorm(doc=1303)
#       0.5, coord(1/2)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# 50	0.22283797		Chicken Little
# Chicken Little
# When it comes to saving the world, it helps to be a little chicken.
# When a tiny acorn bonks Chicken Little on the head, he causes widespread panic and gets on the bad side of the entire town. But when he's hit on the head by a real piece of sky, it's up to Chicken Little and his friends to save the world.
# 9982
# DIRS [u'Mark Dindal']
# CAST [u'Zach Braff', u'Garry Marshall', u'Don Knotts', u'Patrick Stewart', u'Amy Sedaris', u'Steve Zahn', u'Joan Cusack', u'Wallace Shawn', u'Harry Shearer', u'Fred Willard', u"Catherine O'Hara", u'Patrick Warburton', u'Adam West', u'Dan Molina', u'Joe Whyte', u'Mark Walton', u'Sean Elmore', u'Matthew Josten', u'Evan Dunn', u'Mark Dindal', u'Kelly Hoover', u'Will Finn', u'Dara McGarry', u'Mark Kennedy', u'Brad Abrell', u'Tom Amundsen', u'Steve Bencich', u'Greg Berg', u'Julianne Buescher', u'David Cowgill', u'Terri Douglas', u'Chris Edgerly', u'Amanda Fein', u'Caitlin Fein', u'Pat Fraley', u'Eddie Frierson', u'Jackie Gonneau', u'Archie Hahn', u'Jason Harris', u'Brittney Lee Harvey', u'Brian Herskowitz', u'Mandy Kaplan', u'Nathan Kress', u'Anne Lockhart', u'Connor Matheus', u'Mona Marshall', u'Scott Menville', u'Rene Mujica', u'Jonathan Nichols', u'Paul Pape', u'Aaron Spann', u'Pepper Sweeney', u'David Carmon', u'Scott Conrad', u'Nancy Gassner-Clayton', u"Ivan 'Flipz' Velez"]
# CHAR [u'Chicken Little (voice)', u'Buck Cluck (voice)', u'Mayor Turkey Lurkey (voice)', u'Mr. Woolensworth (voice)', u'Foxy Loxy (voice)', u'Runt of the Litter (voice)', u'Abby Mallard (voice)', u'Principal Fetchit (voice)', u'Dog Announcer (voice)', u'Melvin - Alien Dad (voice)', u'Tina - Alien Mom (voice)', u'Alien Cop (voice)', u'Ace - Hollywood Chicken Little (voice)', u'Fish Out of Water (voice)', u'Rodriguez / Acorn Mascot / Umpire (voice)', u'Goosey Loosey (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Morkubine Porcupine / Coach (voice)', u'Mama Runt (voice)', u'Hollywood Fish (voice)', u'Hollywood Abby (voice)', u'Hollywood Runt (voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Patrick Fraley)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Amanda Kaplan)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'Runt - Dancer (uncredited)', u'(uncredited)', u'Choir (uncredited)', u'Chicken Little (dance) (uncredited)']
# 0.22283798, sum of:
#   0.22283798, max of:
#     0.22283798, sum of:
#       0.10111734, weight(cast.name:patrick in 300) [PerFieldSimilarity], result of:
#         0.10111734, score(doc=300,freq=2.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.37757543, fieldWeight in 300, product of:
#             1.4142135, tf(freq=2.0), with freq of:
#               2.0, termFreq=2.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.078125, fieldNorm(doc=300)
#       0.121720634, weight(cast.name:stewart in 300) [PerFieldSimilarity], result of:
#         0.121720634, score(doc=300,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.34834975, fieldWeight in 300, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.078125, fieldNorm(doc=300)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0783652, _type:movie, product of:
#       1.0, boost
#       0.0783652, queryNorm
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'+((directors.name:patrick directors.name:stewart) | (title:patrick title:stewart) | (overview:patrick overview:stewart) | (cast.name:patrick cast.name:stewart)) #QueryWrapperFilter(+ConstantScore(_type:movie))', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.3.2 -- Listing 7 -- Reducing the Impact of directors.name

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
                       'cast.name', 'directors.name^0.1'],  #A    
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.46373135		Vertigo
# 2	0.46373135		Star Trek: Insurrection
# 3	0.46373135		Gnomeo & Juliet
# 4	0.46373135		Star Trek: First Contact
# 5	0.46373135		Excalibur
# 6	0.38982356		X-Men: Days of Future Past
# 7	0.38644278		Conspiracy Theory
# 8	0.38644278		The Wolverine
# 9	0.38644278		Star Trek: Nemesis
# 10	0.38644278		Dune

# %% [markdown]
# # 5.3.3 -- Listings 8&9  – Analysis Extracting English Bigrams

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}


# From listing 9
mappingSettings = {
    'movie': {
        'properties': {
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }            
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # 5.3.3 -- Listing 10 -- Searching *.bigramed fields, reindexing

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.7283101		Star Trek: Insurrection
# 2	0.7283101		Gnomeo & Juliet
# 3	0.7283101		Star Trek: First Contact
# 4	0.7283101		Excalibur
# 5	0.63727134		Conspiracy Theory
# 6	0.63727134		The Wolverine
# 7	0.63727134		Star Trek: Nemesis
# 8	0.63727134		Dune
# 9	0.63727134		Star Trek: Generations
# 10	0.63727134		X-Men

# %% [markdown]
# # 5.3.4	Letting Losers Share The Glory (no listing number)

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed^5', 'directors.name.bigramed'],      
            'type': 'best_fields',
            'tie_breaker': 0.4
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.35363546		Star Trek: Insurrection
# 2	0.35363546		Star Trek: First Contact
# 3	0.34679613		Star Trek: Generations
# 4	0.34285474		Star Trek: Nemesis
# 5	0.33423716		Star Trek
# ===============
# Num	Relevance Score		Movie Title
# 1	0.35363546		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.35363546, sum of:
#   0.35363546, max plus 0.4 times others of:
#     0.2673897, product of:
#       0.5347794, sum of:
#         0.24272868, weight(title:star in 822) [PerFieldSimilarity], result of:
#           0.24272868, score(doc=822,freq=1.0), product of:
#             0.08245237, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.014004101, queryNorm
#             2.9438653, fieldWeight in 822, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=822)
#         0.29205075, weight(title:trek in 822) [PerFieldSimilarity], result of:
#           0.29205075, score(doc=822,freq=1.0), product of:
#             0.09044234, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.014004101, queryNorm
#             3.2291377, fieldWeight in 822, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=822)
#       0.5, coord(2/4)
#     0.21561436, product of:
#       0.6468431, sum of:
#         0.6468431, weight(cast.name.bigramed:patrick stewart in 822) [PerFieldSimilarity], result of:
#           0.6468431, score(doc=822,freq=1.0), product of:
#             0.42563966, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.070020504, queryNorm
#             1.5196965, fieldWeight in 822, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=822)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.014004101, _type:movie, product of:
#       1.0, boost
#       0.014004101, queryNorm
#
# *************************************
# 2	0.35363546		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.35363546, sum of:
#   0.35363546, max plus 0.4 times others of:
#     0.2673897, product of:
#       0.5347794, sum of:
#         0.24272868, weight(title:star in 192) [PerFieldSimilarity], result of:
#           0.24272868, score(doc=192,freq=1.0), product of:
#             0.08245237, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.014004101, queryNorm
#             2.9438653, fieldWeight in 192, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=192)
#         0.29205075, weight(title:trek in 192) [PerFieldSimilarity], result of:
#           0.29205075, score(doc=192,freq=1.0), product of:
#             0.09044234, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.014004101, queryNorm
#             3.2291377, fieldWeight in 192, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=192)
#       0.5, coord(2/4)
#     0.21561436, product of:
#       0.6468431, sum of:
#         0.6468431, weight(cast.name.bigramed:patrick stewart in 192) [PerFieldSimilarity], result of:
#           0.6468431, score(doc=192,freq=1.0), product of:
#             0.42563966, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.070020504, queryNorm
#             1.5196965, fieldWeight in 192, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=192)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.014004101, _type:movie, product of:
#       1.0, boost
#       0.014004101, queryNorm
#
# *************************************
# 3	0.34679613		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.34679613, sum of:
#   0.34679613, max plus 0.4 times others of:
#     0.2673897, product of:
#       0.5347794, sum of:
#         0.24272868, weight(title:star in 200) [PerFieldSimilarity], result of:
#           0.24272868, score(doc=200,freq=1.0), product of:
#             0.08245237, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.014004101, queryNorm
#             2.9438653, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=200)
#         0.29205075, weight(title:trek in 200) [PerFieldSimilarity], result of:
#           0.29205075, score(doc=200,freq=1.0), product of:
#             0.09044234, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.014004101, queryNorm
#             3.2291377, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=200)
#       0.5, coord(2/4)
#     0.009853413, product of:
#       0.039413653, sum of:
#         0.039413653, weight(overview:star in 200) [PerFieldSimilarity], result of:
#           0.039413653, score(doc=200,freq=1.0), product of:
#             0.05943482, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.014004101, queryNorm
#             0.6631408, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=200)
#       0.25, coord(1/4)
#     0.18866257, product of:
#       0.5659877, sum of:
#         0.5659877, weight(cast.name.bigramed:patrick stewart in 200) [PerFieldSimilarity], result of:
#           0.5659877, score(doc=200,freq=1.0), product of:
#             0.42563966, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.070020504, queryNorm
#             1.3297344, fieldWeight in 200, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=200)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.014004101, _type:movie, product of:
#       1.0, boost
#       0.014004101, queryNorm
#
# *************************************
# 4	0.34285474		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.34285474, sum of:
#   0.34285474, max plus 0.4 times others of:
#     0.2673897, product of:
#       0.5347794, sum of:
#         0.24272868, weight(title:star in 821) [PerFieldSimilarity], result of:
#           0.24272868, score(doc=821,freq=1.0), product of:
#             0.08245237, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.014004101, queryNorm
#             2.9438653, fieldWeight in 821, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=821)
#         0.29205075, weight(title:trek in 821) [PerFieldSimilarity], result of:
#           0.29205075, score(doc=821,freq=1.0), product of:
#             0.09044234, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.014004101, queryNorm
#             3.2291377, fieldWeight in 821, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=821)
#       0.5, coord(2/4)
#     0.18866257, product of:
#       0.5659877, sum of:
#         0.5659877, weight(cast.name.bigramed:patrick stewart in 821) [PerFieldSimilarity], result of:
#           0.5659877, score(doc=821,freq=1.0), product of:
#             0.42563966, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.070020504, queryNorm
#             1.3297344, fieldWeight in 821, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=821)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.014004101, _type:movie, product of:
#       1.0, boost
#       0.014004101, queryNorm
#
# *************************************
# 5	0.33423716		Star Trek
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 0.33423716, sum of:
#   0.33423716, max plus 0.4 times others of:
#     0.33423716, product of:
#       0.6684743, sum of:
#         0.30341083, weight(title:star in 621) [PerFieldSimilarity], result of:
#           0.30341083, score(doc=621,freq=1.0), product of:
#             0.08245237, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.014004101, queryNorm
#             3.6798315, fieldWeight in 621, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.625, fieldNorm(doc=621)
#         0.36506346, weight(title:trek in 621) [PerFieldSimilarity], result of:
#           0.36506346, score(doc=621,freq=1.0), product of:
#             0.09044234, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.014004101, queryNorm
#             4.0364223, fieldWeight in 621, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.625, fieldNorm(doc=621)
#       0.5, coord(2/4)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.014004101, _type:movie, product of:
#       1.0, boost
#       0.014004101, queryNorm
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'+((title:star title:trek title:patrick title:stewart) | (overview:star overview:trek overview:patrick overview:stewart) | ((cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart)^5.0) | (directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart))~0.4 #QueryWrapperFilter(+ConstantScore(_type:movie))', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 5.3.5, Listing 11 Counting Multiple Signals using Most Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.57795894		Star Trek: Generations
# 2	0.37984636		Star Trek: Insurrection
# 3	0.37984636		Star Trek: First Contact
# 4	0.37325242		Star Trek: Nemesis
# 5	0.20443419		Star Trek
# 6	0.16354734		Star Trek: The Motion Picture
# 7	0.16354734		Star Trek Into Darkness
# 8	0.14310393		Star Trek VI: The Undiscovered Country
# 9	0.14310393		Star Trek V: The Final Frontier
# 10	0.14310393		Star Trek IV: The Voyage Home

# %% [markdown]
# # 5.3.6, Listing 12	Boosting in Most-Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.2', 'overview',
 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.21698442		Star Trek: Generations
# 2	0.13826816		Star Trek: Insurrection
# 3	0.13826816		Star Trek: First Contact
# 4	0.13055275		Star Trek: Nemesis
# 5	0.054496057		Hannah Montana: The Movie
# 6	0.04985989		Ted
# 7	0.047840547		Star Trek
# 8	0.044039465		The Beaver
# 9	0.038272437		Star Trek: The Motion Picture
# 10	0.038272437		Star Trek Into Darkness

# %% [markdown]
# # 5.3.7	When Additional Matches Don’t Matter (no listing number)

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.5415871		Star Trek V: The Final Frontier
# 2	0.39785004		Star Trek: Generations
# 3	0.35108924		Star Trek IV: The Voyage Home
# 4	0.3037074		Star Trek: Nemesis
# 5	0.19542062		Star Trek: Insurrection
