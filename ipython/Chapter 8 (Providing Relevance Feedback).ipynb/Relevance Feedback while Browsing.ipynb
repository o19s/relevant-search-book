# %% [markdown]
# # Setup

# %%
from elasticsearch import (
    Elasticsearch,
    helpers
)
import pickle

# %%
#initialize
es = Elasticsearch()

# %%
movies=pickle.load(open("../../movies_list.p","rb"))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-860a74a233fd> in <module>()
# ----> 1 movies=pickle.load(open("../../movies_list.p","rb"))
#
# IOError: [Errno 2] No such file or directory: '../../movies_list.p'

# %%
try:
    es.indices.delete("tmdb")
except:
    pass

#create index here?
# genres.name needs to be keyword tokenized so that 'science fiction' doesn't get split on white space
# maybe create a text field with title and overview to search against
body = {
    "mappings": {
      "movie": {
        "properties": {
          "genres": {
            "properties": {
              "name": { 
                "type": "string",
                "index": "not_analyzed"}}},
          "title": {
            "type": "string",
            "analyzer": "english"}}}}}
es.indices.create("tmdb",body=body)
# Out:
# {u'acknowledged': True}

# %%
#doc indexer
def format_doc(doc):
    action = {
        "_index": "tmdb",
        "_type": "movie",
        "_id": doc['id'],
        "_source": doc
        }
    return action

def index_movies():
    actions = (format_doc(doc) for doc in movies)
    results = [details for success,details in helpers.streaming_bulk(es, actions) if not success]
    return results

# %%
results = index_movies()

# %% [markdown]
# # Examples

# %%
# basic facet example
body = {
    "aggs": {
        "genres": {
            "terms": {
                "field": "genres.name"
            }
        },
    }
}
es.search(index="tmdb",body=body,size=0)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'genres': {u'buckets': [{u'doc_count': 7546,
#      u'key': u'Drama'},
#     {u'doc_count': 5342, u'key': u'Comedy'},
#     {u'doc_count': 3878, u'key': u'Thriller'},
#     {u'doc_count': 3753, u'key': u'Action'},
#     {u'doc_count': 2623, u'key': u'Romance'},
#     {u'doc_count': 2165, u'key': u'Adventure'},
#     {u'doc_count': 1981, u'key': u'Horror'},
#     {u'doc_count': 1861, u'key': u'Crime'},
#     {u'doc_count': 1640, u'key': u'Family'},
#     {u'doc_count': 1597, u'key': u'Science Fiction'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 7479}},
#  u'hits': {u'hits': [], u'max_score': 0.0, u'total': 19868},
#  u'timed_out': False,
#  u'took': 7}

# %%
# facet with a filter in place - notice the different aggregation numbers
body = {
    "fields":["title"],
    "query": {
        "bool": {
            "filter": [
              {"term": {"genres.name": "Science Fiction"}}
            ]
        }
    },
    "aggs": {
        "genres": {
            "terms": {
                "field": "genres.name"
            }
        },
    }

}
es.search(index="tmdb",body=body,size=5)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 1, u'total': 1},
#  u'aggregations': {u'genres': {u'buckets': [],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 0}},
#  u'hits': {u'hits': [], u'max_score': None, u'total': 0},
#  u'timed_out': False,
#  u'took': 96}

# %% [markdown]
# # Scratch

# %%
# see how the genre doc conuts tum to 209 while the original language counts sum to 90 (the num docs)
body = {
    "fields":["title"],
    "query":{
        "match":{
            "genres.name": "Science Fiction"}},
    "aggs": {
        "genres": {
            "terms": {
                "field": "genres.name"
            }
        },
    }

}
es.search(index="tmdb",body=body,size=100)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'genres': {u'buckets': [{u'doc_count': 1597,
#      u'key': u'Science Fiction'},
#     {u'doc_count': 753, u'key': u'Action'},
#     {u'doc_count': 502, u'key': u'Thriller'},
#     {u'doc_count': 466, u'key': u'Adventure'},
#     {u'doc_count': 337, u'key': u'Drama'},
#     {u'doc_count': 336, u'key': u'Fantasy'},
#     {u'doc_count': 327, u'key': u'Horror'},
#     {u'doc_count': 299, u'key': u'Comedy'},
#     {u'doc_count': 188, u'key': u'Animation'},
#     {u'doc_count': 164, u'key': u'Family'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 361}},
#  u'hits': {u'hits': [{u'_id': u'19',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Metropolis']}},
#    {u'_id': u'38',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Eternal Sunshine of the Spotless Mind']}},
#    {u'_id': u'95',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Armageddon']}},
#    {u'_id': u'165',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Back to the Future Part II']}},
#    {u'_id': u'172',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek V: The Final Frontier']}},
#    {u'_id': u'196',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Back to the Future Part III']}},
#    {u'_id': u'196830',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Stranded']}},
#    {u'_id': u'280',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Terminator 2: Judgment Day']}},
#    {u'_id': u'329',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Jurassic Park']}},
#    {u'_id': u'331',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Jurassic Park III']}},
#    {u'_id': u'348',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Alien']}},
#    {u'_id': u'262504',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Divergent Series: Allegiant - Part 1']}},
#    {u'_id': u'284053',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Thor: Ragnarok']}},
#    {u'_id': u'437',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Cube 2: Hypercube']}},
#    {u'_id': u'603',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Matrix']}},
#    {u'_id': u'608',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Men in Black II']}},
#    {u'_id': u'754',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Face/Off']}},
#    {u'_id': u'817',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Austin Powers: The Spy Who Shagged Me']}},
#    {u'_id': u'263115',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Wolverine 3']}},
#    {u'_id': u'197624',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'AE Apocalypse Earth']}},
#    {u'_id': u'1272',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Sunshine']}},
#    {u'_id': u'34086',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Spaced Invaders']}},
#    {u'_id': u'1450',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Blood: The Last Vampire']}},
#    {u'_id': u'1498',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Teenage Mutant Ninja Turtles']}},
#    {u'_id': u'34276',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'First Men in the Moon']}},
#    {u'_id': u'1551',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Flatliners']}},
#    {u'_id': u'33045',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Parasite Eve']}},
#    {u'_id': u'1688',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Conquest of the Planet of the Apes']}},
#    {u'_id': u'1811',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Nowhere']}},
#    {u'_id': u'1892',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode VI - Return of the Jedi']}},
#    {u'_id': u'1924',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Superman']}},
#    {u'_id': u'2080',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'X-Men Origins: Wolverine']}},
#    {u'_id': u'16774',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Hellboy Animated: Sword of Storms']}},
#    {u'_id': u'328084',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'HyperGalaxy: Ascension']}},
#    {u'_id': u'2605',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Short Circuit']}},
#    {u'_id': u'2612',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Mr. Destiny']}},
#    {u'_id': u'297544',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Age of Ice']}},
#    {u'_id': u'68179',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Escape from Planet Earth']}},
#    {u'_id': u'297556',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Justice League: Throne of Atlantis']}},
#    {u'_id': u'2756',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Abyss']}},
#    {u'_id': u'2787',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Pitch Black']}},
#    {u'_id': u'2927',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Moon 44']}},
#    {u'_id': u'329621',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Unbelievable!!!!!']}},
#    {u'_id': u'3019',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Dr. Jekyll and Mr. Hyde']}},
#    {u'_id': u'3103',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'House of Frankenstein']}},
#    {u'_id': u'3115',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Godzilla vs. The Sea Monster']}},
#    {u'_id': u'3146',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The War of the Gargantuas']}},
#    {u'_id': u'3160',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Frankenstein Conquers the World']}},
#    {u'_id': u'331373',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'C.4: The Code of Money and Death']}},
#    {u'_id': u'36657',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'X-Men']}},
#    {u'_id': u'266037',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Kamen Rider Wizard in Magic Land']}},
#    {u'_id': u'76122',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Marvel One-Shot: The Consultant']}},
#    {u'_id': u'120846',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Jurassic Shark']}},
#    {u'_id': u'6171',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Dreamcatcher']}},
#    {u'_id': u'102899',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Ant-Man']}},
#    {u'_id': u'299538',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Inhumans']}},
#    {u'_id': u'135915',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Psychic School Wars']}},
#    {u'_id': u'37686',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Super 8']}},
#    {u'_id': u'4923',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Zardoz']}},
#    {u'_id': u'65632',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The 10th Victim']}},
#    {u'_id': u'70530',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'A Chinese Fairy Tale']}},
#    {u'_id': u'103551',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Hirokin: The Last Samurai']}},
#    {u'_id': u'202214',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Real Playing Game']}},
#    {u'_id': u'71254',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Arena']}},
#    {u'_id': u'125675',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Mantera']}},
#    {u'_id': u'137113',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Edge of Tomorrow']}},
#    {u'_id': u'6102',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Tornado']}},
#    {u'_id': u'6479',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'I Am Legend']}},
#    {u'_id': u'72098',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Samir we Shahir we Bahir']}},
#    {u'_id': u'39466',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Godzilla vs. SpaceGodzilla']}},
#    {u'_id': u'6950',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Outbreak']}},
#    {u'_id': u'206487',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Predestination']}},
#    {u'_id': u'28510',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Universal Soldier: Regeneration']}},
#    {u'_id': u'7249',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u"Futurama: Bender's Big Score"]}},
#    {u'_id': u'7299',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Equilibrium']}},
#    {u'_id': u'7453',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u"The Hitchhiker's Guide to the Galaxy"]}},
#    {u'_id': u'73262',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Hell']}},
#    {u'_id': u'7737',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Resident Evil: Extinction']}},
#    {u'_id': u'97370',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Under the Skin']}},
#    {u'_id': u'302797',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Encounters']}},
#    {u'_id': u'8069',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Barbarella']}},
#    {u'_id': u'8247',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Jumper']}},
#    {u'_id': u'8285',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Spirit']}},
#    {u'_id': u'8413',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Event Horizon']}},
#    {u'_id': u'8487',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Wild Wild West']}},
#    {u'_id': u'41517',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Ra.One']}},
#    {u'_id': u'8766',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Hellraiser: Bloodline']}},
#    {u'_id': u'8831',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Timecop']}},
#    {u'_id': u'8836',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The X Files: I Want to Believe']}},
#    {u'_id': u'8843',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Cell']}},
#    {u'_id': u'8850',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Shadow']}},
#    {u'_id': u'9067',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Tank Girl']}},
#    {u'_id': u'9271',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Virtuosity']}},
#    {u'_id': u'9276',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Faculty']}},
#    {u'_id': u'10973',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Creature from the Black Lagoon']}},
#    {u'_id': u'9327',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Nutty Professor']}},
#    {u'_id': u'9341',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Core']}},
#    {u'_id': u'9389',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Renaissance']}},
#    {u'_id': u'9423',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Virus']}},
#    {u'_id': u'198184',
#     u'_index': u'tmdb',
#     u'_score': 3.5879924,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Chappie']}}],
#   u'max_score': 3.5879924,
#   u'total': 1597},
#  u'timed_out': False,
#  u'took': 41}

# %%
# facet with a filter in place
body = {
    "fields":["title"],
    "query": {
        "filtered": {
            "query": {
                "match":{
                    "title": "star trek"}},
            "filter": {
                "term": {
                    "genres.name": "Science Fiction"}}}},
    "aggs": {
        "genres": {
            "terms": {
                "field": "genres.name"
            }
        },
    }

}
es.search(index="tmdb",body=body,size=100)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'genres': {u'buckets': [{u'doc_count': 36,
#      u'key': u'Science Fiction'},
#     {u'doc_count': 28, u'key': u'Adventure'},
#     {u'doc_count': 27, u'key': u'Action'},
#     {u'doc_count': 9, u'key': u'Thriller'},
#     {u'doc_count': 6, u'key': u'Fantasy'},
#     {u'doc_count': 4, u'key': u'Animation'},
#     {u'doc_count': 4, u'key': u'Comedy'},
#     {u'doc_count': 3, u'key': u'Drama'},
#     {u'doc_count': 2, u'key': u'Family'},
#     {u'doc_count': 1, u'key': u'Mystery'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 1}},
#  u'hits': {u'hits': [{u'_id': u'13475',
#     u'_index': u'tmdb',
#     u'_score': 6.032624,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek']}},
#    {u'_id': u'152',
#     u'_index': u'tmdb',
#     u'_score': 5.22185,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: The Motion Picture']}},
#    {u'_id': u'193',
#     u'_index': u'tmdb',
#     u'_score': 5.0279865,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: Generations']}},
#    {u'_id': u'201',
#     u'_index': u'tmdb',
#     u'_score': 5.0279865,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: Nemesis']}},
#    {u'_id': u'200',
#     u'_index': u'tmdb',
#     u'_score': 4.966011,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: Insurrection']}},
#    {u'_id': u'329625',
#     u'_index': u'tmdb',
#     u'_score': 4.966011,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: Axanar']}},
#    {u'_id': u'188927',
#     u'_index': u'tmdb',
#     u'_score': 4.966011,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek 3']}},
#    {u'_id': u'199',
#     u'_index': u'tmdb',
#     u'_score': 4.826099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: First Contact']}},
#    {u'_id': u'329628',
#     u'_index': u'tmdb',
#     u'_score': 4.826099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek: Horizon']}},
#    {u'_id': u'54138',
#     u'_index': u'tmdb',
#     u'_score': 4.826099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek Into Darkness']}},
#    {u'_id': u'172',
#     u'_index': u'tmdb',
#     u'_score': 4.791781,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek V: The Final Frontier']}},
#    {u'_id': u'157',
#     u'_index': u'tmdb',
#     u'_score': 4.5691185,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek III: The Search for Spock']}},
#    {u'_id': u'174',
#     u'_index': u'tmdb',
#     u'_score': 4.3994884,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek VI: The Undiscovered Country']}},
#    {u'_id': u'154',
#     u'_index': u'tmdb',
#     u'_score': 4.3452597,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek II: The Wrath of Khan']}},
#    {u'_id': u'168',
#     u'_index': u'tmdb',
#     u'_score': 4.2228365,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Trek IV: The Voyage Home']}},
#    {u'_id': u'54007',
#     u'_index': u'tmdb',
#     u'_score': 1.2643117,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Kid']}},
#    {u'_id': u'1410',
#     u'_index': u'tmdb',
#     u'_score': 1.194533,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Dark Star']}},
#    {u'_id': u'181812',
#     u'_index': u'tmdb',
#     u'_score': 1.0544652,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode IX']}},
#    {u'_id': u'80829',
#     u'_index': u'tmdb',
#     u'_score': 1.0114493,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Revelations']}},
#    {u'_id': u'15493',
#     u'_index': u'tmdb',
#     u'_score': 0.99763477,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wreck: In the Pirkinning']}},
#    {u'_id': u'12180',
#     u'_index': u'tmdb',
#     u'_score': 0.9578099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: The Clone Wars']}},
#    {u'_id': u'14460',
#     u'_index': u'tmdb',
#     u'_score': 0.9578099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Battle Beyond the Stars']}},
#    {u'_id': u'74849',
#     u'_index': u'tmdb',
#     u'_score': 0.9578099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'The Star Wars Holiday Special']}},
#    {u'_id': u'327212',
#     u'_index': u'tmdb',
#     u'_score': 0.9578099,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars Despecialized Edition']}},
#    {u'_id': u'42979',
#     u'_index': u'tmdb',
#     u'_score': 0.95562637,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Robot Chicken: Star Wars']}},
#    {u'_id': u'181808',
#     u'_index': u'tmdb',
#     u'_score': 0.95562637,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode VIII']}},
#    {u'_id': u'311145',
#     u'_index': u'tmdb',
#     u'_score': 0.8380837,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Supernova : Knight , Princess , & Shooting Star']}},
#    {u'_id': u'80518',
#     u'_index': u'tmdb',
#     u'_score': 0.83617306,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Fullmetal Alchemist: The Sacred Star of Milos']}},
#    {u'_id': u'1892',
#     u'_index': u'tmdb',
#     u'_score': 0.79084885,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode VI - Return of the Jedi']}},
#    {u'_id': u'1891',
#     u'_index': u'tmdb',
#     u'_score': 0.758587,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode V - The Empire Strikes Back']}},
#    {u'_id': u'1893',
#     u'_index': u'tmdb',
#     u'_score': 0.74822605,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode I - The Phantom Menace']}},
#    {u'_id': u'11',
#     u'_index': u'tmdb',
#     u'_score': 0.71835744,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode IV - A New Hope']}},
#    {u'_id': u'1894',
#     u'_index': u'tmdb',
#     u'_score': 0.71835744,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode II - Attack of the Clones']}},
#    {u'_id': u'267963',
#     u'_index': u'tmdb',
#     u'_score': 0.71835744,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Space Battleship Yamato 2199: Star-Voyaging Ark']}},
#    {u'_id': u'1895',
#     u'_index': u'tmdb',
#     u'_score': 0.71671975,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode III - Revenge of the Sith']}},
#    {u'_id': u'140607',
#     u'_index': u'tmdb',
#     u'_score': 0.71671975,
#     u'_type': u'movie',
#     u'fields': {u'title': [u'Star Wars: Episode VII - The Force Awakens']}}],
#   u'max_score': 6.032624,
#   u'total': 36},
#  u'timed_out': False,
#  u'took': 10}

# %% [markdown]
# #Trash

# %%
{ "query": {
    "filtered": {
      "filter": {
        "term": {
          "genres.name": "Science Fiction"}}}},
  "aggs": {
    "genres": {
      "terms": {
        "field": "genres.name"}}}}
# Out:
# {'aggs': {'genres': {'terms': {'field': 'genres.name'}}},
#  'query': {'filtered': {'filter': {'term': {'genres.name': 'Science Fiction'}}}}}

# %%
x= [
    {'doc_count': 7546, 'key': 'Drama'},
    {'doc_count': 5342, 'key': 'Comedy'},
    {'doc_count': 3878, 'key': 'Thriller'},
    {'doc_count': 3753, 'key': 'Action'},
    {'doc_count': 2623, 'key': 'Romance'},
    {'doc_count': 2165, 'key': 'Adventure'},
    {'doc_count': 1981, 'key': 'Horror'},
    {'doc_count': 1861, 'key': 'Crime'},
    {'doc_count': 1640, 'key': 'Family'},
    {'doc_count': 1597, 'key': 'Science Fiction'}]
sum([y['doc_count'] for y in x])
# Out:
# 32386

# %%
es.cluster.stats()['indices'].keys()
# Out:
# [u'count',
#  u'completion',
#  u'fielddata',
#  u'docs',
#  u'segments',
#  u'shards',
#  u'id_cache',
#  u'filter_cache',
#  u'percolate',
#  u'store']
