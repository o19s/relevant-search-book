# %%
import requests
import json
import os

# you'll need to have an API key for TMDB
# to run these examples,
# run export TMDB_API_KEY=<YourAPIKey>
tmdb_api_key = os.environ["TMDB_API_KEY"]

# Setup tmdb as its own session, caching requests
# (we only want to cache tmdb, not elasticsearch)
# Get your TMDB API key from
#  https://www.themoviedb.org/documentation/api
# then in shell do export TMDB_API_KEY=<Your Key>
tmdb_api = requests.Session()
tmdb_api.params={'api_key': tmdb_api_key}

# Optional, enable client-side caching for TMDB
# Requires: https://httpcache.readthedocs.org/en/latest/
#from httpcache import CachingHTTPAdapter
#tmdb_api.mount('https://', CachingHTTPAdapter())
#tmdb_api.mount('http://', CachingHTTPAdapter())

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
                        data=text)
    print resp.text
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, data=json.dumps(query))
    if httpResp.status_code != 200:
        print "Search Failed <%s>" % httpResp.status_code
        print "%s" % httpResp.text
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])
            if verbose:
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "DIRS %s" % directorNames
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     data=json.dumps({'query': query['query']}))
        print json.loads(httpResp.text)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print "Delete TMDB Index <%s>" % resp.status_code
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", data=json.dumps(settings))
    print "Create TMDB Index <%s>" % resp.status_code
    if resp.status_code != 200:
        print resp.text
    
    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    for id, movie in movieDict.iteritems():
        addCmd = {"index": {"_index": "tmdb", "_type": "movie", "_id": movie["id"]}}
        esDoc  = movie
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies)
    print "Bulk Index into TMDB Index <%s>" % resp.status_code


def movieList(maxMovies=10000):
    movieIds = [];
    numPages = maxMovies / 20    
    for page in range(1, numPages + 1):
        httpResp = tmdb_api.get('https://api.themoviedb.org/3/movie/top_rated', params={'page': page})  #(1)
        if httpResp.status_code != 200:
            print "top_rated: <%s>" % httpResp.status_code
            print " why? %s " % httpResp.text
        jsonResponse = json.loads(httpResp.text) #(2)
        movies = jsonResponse['results']
        if len(movies) == 0:
            break
        for movie in movies:
            movieIds.append(movie['id'])
    return movieIds

## Extract
## Extract accesses the TMDB endpoints required and creates an entry for each movie. Recall how we iterated
## over all the movie entries at an endpoint like 'top_rated'. There's one 
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass    
        
    movieDict = {}
    for movieId in movieIds:
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s" % movieId)
        movie = json.loads(httpResp.text)
        
        httpResp = tmdb_api.get("https://api.themoviedb.org/3/movie/%s/credits" % movieId)
        credits = json.loads(httpResp.text)
        cast = credits['cast']
        crew = credits['crew']
        directors = []
        actors = []
        for crewMember in crew:
            if crewMember['job'] == 'Director':
                directors.append(crewMember)
        movie['cast'] = cast
        movie['directors'] = directors
        
        movieDict[movieId] = movie
    
    # Store a file locally
    with open('tmdb.json', 'w') as f:
        f.write(json.dumps(movieDict))
        f.close()
    
    return movieDict

# %% [markdown]
# # Index to ES

# %%
movieDict = extract([])

analysis = {
    "analyzer" : {
      "default" : {
        "type" : "english"
        }
      }
   }

reindex(analysisSettings=analysis, movieDict=movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # Field Centric Search

# %% [markdown]
# ## Best Fields Search

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name'],      
            'type': 'best_fields'
         }
    },
    'size': 50,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.346026		Legion
# 2	1.346026		Halo 4: Forward Unto Dawn
# 3	1.346026		Priest
# 4	1.346026		Dark Skies
# 5	1.0749499		Drive Angry
# 6	1.0749499		Feast
# 7	1.0749499		District 13: Ultimatum
# 8	1.0749499		The Expendables 3
# 9	1.0749499		Underworld: Rise of the Lycans
# 10	1.0749499		My Bloody Valentine
# 11	0.8599599		Sex and the City 2
# 12	0.8599599		Sex and the City
# 13	0.8599599		Doubt
# 14	0.8599599		Sinbad: Legend of the Seven Seas
# 15	0.46373135		Vertigo
# 16	0.46373135		Star Trek: Insurrection
# 17	0.46373135		Gnomeo & Juliet
# 18	0.46373135		Star Trek: First Contact
# 19	0.46373135		Excalibur
# 20	0.38982356		X-Men: Days of Future Past
# 21	0.38644278		Conspiracy Theory
# 22	0.38644278		The Wolverine
# 23	0.38644278		Star Trek: Nemesis
# 24	0.38644278		Dune
# 25	0.38644278		Star Trek: Generations
# 26	0.38644278		X-Men
# 27	0.38644278		Panic Room
# 28	0.38644278		Robin Hood: Men in Tights
# 29	0.35654074		Ted
# 30	0.3542312		One Flew Over the Cuckoo's Nest
# 31	0.32015914		The Bounty Hunter
# 32	0.31694135		Hannah Montana: The Movie
# 33	0.3091542		The Collector
# 34	0.3091542		Save the Last Dance
# 35	0.3091542		X2: X-Men United
# 36	0.3091542		TMNT
# 37	0.3091542		The Prince of Egypt
# 38	0.3091542		X-Men: The Last Stand
# 39	0.3091542		A Time to Kill
# 40	0.27050993		The Faculty
# 41	0.26740557		The Cabin in the Woods
# 42	0.2561273		The Beaver
# 43	0.2561273		Zathura: A Space Adventure
# 44	0.24556357		A Good Year
# 45	0.23615414		One for the Money
# 46	0.23615414		The SpongeBob Movie: Sponge Out of Water
# 47	0.23615414		The SpongeBob SquarePants Movie
# 48	0.23615414		10 Things I Hate About You
# 49	0.23615414		The Kings of Summer
# 50	0.22283797		Chicken Little
# ===============
# Num	Relevance Score		Movie Title
# 1	1.346026		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 1.3460261, max of:
#   1.3460261, product of:
#     2.6920521, sum of:
#       2.6920521, weight(directors.name:stewart in 1225) [PerFieldSimilarity], result of:
#         2.6920521, score(doc=1225,freq=1.0), product of:
#           0.58098286, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.0783652, queryNorm
#           4.633617, fieldWeight in 1225, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=1225)
#     0.5, coord(1/2)
#
# *************************************
# 2	1.346026		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# DIRS [u'Stewart Hendler']
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 1.3460261, max of:
#   1.3460261, product of:
#     2.6920521, sum of:
#       2.6920521, weight(directors.name:stewart in 39) [PerFieldSimilarity], result of:
#         2.6920521, score(doc=39,freq=1.0), product of:
#           0.58098286, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.0783652, queryNorm
#           4.633617, fieldWeight in 39, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=39)
#     0.5, coord(1/2)
#
# *************************************
# 3	1.346026		Priest
# Priest
# Vampire Killer
# In an alternate world, humanity and vampires have warred for centuries. After the last Vampire War, the veteran Warrior Priest lives in obscurity with other humans inside one of the Church's walled cities. When the Priest's niece is kidnapped by vampires, the Priest breaks his vows to hunt them down. He is accompanied by the niece's boyfriend, who is a wasteland sheriff, and a former Warrior Priestess.
# 38321
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Cam Gigandet', u'Karl Urban', u'Lily Collins', u'Maggie Q', u'Stephen Moyer', u'M\xe4dchen Amick', u'Christopher Plummer', u'Brad Dourif', u'Alan Dale']
# CHAR [u'Priest', u'Hicks', u'Black Hat', u'Lucy', u'Priestess', u'Aaron', u'Shannon', u'Monsignor Orelas', u'Salesman', u'Monsignor Chamberlain']
# 1.3460261, max of:
#   1.3460261, product of:
#     2.6920521, sum of:
#       2.6920521, weight(directors.name:stewart in 646) [PerFieldSimilarity], result of:
#         2.6920521, score(doc=646,freq=1.0), product of:
#           0.58098286, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.0783652, queryNorm
#           4.633617, fieldWeight in 646, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=646)
#     0.5, coord(1/2)
#
# *************************************
# 4	1.346026		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# DIRS [u'Scott Stewart']
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 1.3460261, max of:
#   1.3460261, product of:
#     2.6920521, sum of:
#       2.6920521, weight(directors.name:stewart in 676) [PerFieldSimilarity], result of:
#         2.6920521, score(doc=676,freq=1.0), product of:
#           0.58098286, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.0783652, queryNorm
#           4.633617, fieldWeight in 676, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=676)
#     0.5, coord(1/2)
#   0.057200607, product of:
#     0.114401214, sum of:
#       0.114401214, weight(cast.name:patrick in 676) [PerFieldSimilarity], result of:
#         0.114401214, score(doc=676,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.42717782, fieldWeight in 676, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.125, fieldNorm(doc=676)
#     0.5, coord(1/2)
#
# *************************************
# 5	1.0749499		Drive Angry
# Drive Angry
# One hell of a ride.
# Milton is a hardened felon who has broken out of Hell, intent on finding the vicious cult who brutally murdered his daughter and kidnapped her baby. He joins forces with Piper, a sexy, tough-as-nails waitress with a 69 Charger, who's also seeking redemption of her own. Caught in a deadly race against time, Milton has three days to avoid capture, avenge his daughter's death, and save her baby before she's mercilessly sacrificed by the cult.
# 47327
# DIRS [u'Patrick Lussier']
# CAST [u'Nicolas Cage', u'Amber Heard', u'William Fichtner', u'Billy Burke', u'David Morse', u'Katy Mixon', u'Charlotte Ross', u'Christa Campbell', u'Todd Farmer', u'Jack McGee', u'Tom Atkins', u'Wanetah Walmsley', u'Edrick Browne', u'Robin McGee', u'Fabian C. Moreno', u'Marc Macaulay', u'Pruitt Taylor Vince', u'Julius Washington', u'Jamie Teer', u'Bryan Massey', u'Timothy Walter', u'Kent Jude Bernard', u'Brent Phillip Henry', u'Gerry May', u'Sherri Talley', u'Arianne Margot', u'Con Schell', u'Nick Gomez', u'Joe Chrest', u'Oakley Lehman', u'Thirl Haston', u'Jake Brake', u'Tim J. Smith', u'Jeffrey J. Dashnaw', u'Tim Trella', u'James Landry H\xe9bert', u'Kenneth Wayne Bradley', u'Kendrick Hudson', u'Michael Papajohn', u'April Littlejohn', u'Henry Kingi', u'Simona Williams', u'Shelby Swatek', u'Joseph Blackstone', u'Dan Forest', u'Elise Fyke', u"Jonathan O'Rear", u'James Paul', u'Alice Searcy', u'Lanie Taylor', u'David Lee Valle']
# CHAR [u'Milton', u'Piper', u'Accountant', u'Jonah King', u'Webster', u'Norma Jean', u'Candy', u'Mona', u'Frank', u'Fat Lou', u'Cap', u'American Indian Mother', u'Rookie', u'Guy with Camera Phone', u'Latino Busboy', u'Sarge', u'Roy', u'Uniformed Officer', u'Babysitter', u'Trooper #1', u'Trooper #2', u'Teen #1', u'Teen #2', u'TV Male News Reporter #1', u'TV Female News Reporter #2', u"Milton's Daughter (Older)", u'Fucking Driver', u'Fucking Middle', u'Fucking Passenger', u'Cultist with Iron Pipe', u'Cultist with Sickle', u'Cultist with Machete', u'Cultist with Hatchet', u'Cowboy with Cattle Prod', u'Cultist with Sledge', u'Man in Leather Jacket', u'Man with Wig', u'Burly Dude', u'Tattooed Guy', u'Business Woman', u'Thin Old Man', u'Lady in Leopard Skin', u'Truck Driving Woman', u'Bar Patron', u'American Indian Dad', u'Laughing Cowgirl', u'Resturant Patron', u'Bar Patron', u'Restaurant Patron', u"Milton's Daughter - Younger", u'Highway Patrol']
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 200) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=200,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 200, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=200)
#     0.5, coord(1/2)
#
# *************************************
# 6	1.0749499		Feast
# Feast
#
# This Oscar-winning animated short film tells the story of one man's love life is seen through the eyes of his best friend and dog, Winston, and revealed bite by bite through the meals they share.
# 293299
# DIRS [u'Patrick Osborne']
# CAST [u'Tommy Snider', u'Katie Lowes', u'Ben Bledsoe']
# CHAR [u'James', u'Additional Voices (voice)', u'Additional Voices']
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 318) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=318,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 318, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=318)
#     0.5, coord(1/2)
#
# *************************************
# 7	1.0749499		District 13: Ultimatum
# District 13: Ultimatum
#
# Damien and Leito return to District 13 on a mission to bring peace to the troubled sector that is controlled by five different gang bosses, before the city's secret services take drastic measures to solve the problem.
# 15357
# DIRS [u'Patrick Alessandrin']
# CAST [u'Cyril Raffaelli', u'David Belle', u'Philippe Torreton', u'Daniel Duval', u'Elodie Yung', u"MC Jean Gab'1", u'James Deano', u'Laouni Mouhid', u'Fabrice Feltzinger', u'Pierre-Marie Mosconi', u'Johnny Amaro']
# CHAR [u'Damien', u'Le\xefto', u'Le Pr\xe9sident de la R\xe9publique', u'Walter Gassman', u'Tao', u'Molko', u'Karl le skin', u'Ali-K', u'Little Montana', u'Roland', u'Policier centre de contr\xf4le']
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 1281) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=1281,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 1281, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=1281)
#     0.5, coord(1/2)
#
# *************************************
# 8	1.0749499		The Expendables 3
# The Expendables 3
# New team. New attitude. New mission.
# Barney (Stallone), Christmas (Statham) and the rest of the team comes face-to-face with Conrad Stonebanks (Gibson), who years ago co-founded The Expendables with Barney. Stonebanks subsequently became a ruthless arms trader and someone who Barney was forced to kill... or so he thought. Stonebanks, who eluded death once before, now is making it his mission to end The Expendables -- but Barney has other plans. Barney decides that he has to fight old blood with new blood, and brings in a new era of Expendables team members, recruiting individuals who are younger, faster and more tech-savvy. The latest mission becomes a clash of classic old-school style versus high-tech expertise in the Expendables' most personal battle yet.
# 138103
# DIRS [u'Patrick Hughes']
# CAST [u'Sylvester Stallone', u'Jason Statham', u'Harrison Ford', u'Arnold Schwarzenegger', u'Mel Gibson', u'Wesley Snipes', u'Randy Couture', u'Dolph Lundgren', u'Terry Crews', u'Kelsey Grammer', u'Glen Powell', u'Antonio Banderas', u'Victor Ortiz', u'Ronda Rousey', u'Kellan Lutz', u'Jet Li', u'Ivan Kostadinov', u'Robert Davi', u'Nikolay Stoyanov Ilchev', u'Daniel Angelov', u'Slavi Slavov', u'Dimiter Doichinov', u'Nikolay Stanoev', u'Harry Anichkin', u'Boswell Maloka', u'Natalie Burn', u'Velizar Binev', u'Sarai Givaty', u'Liubomir Simeonov', u'Frank Pesce', u'Thomas Canestraro']
# CHAR [u'Barney Ross', u'Lee Christmas', u'Max Drummer', u'Trench', u'Conrad Stonebanks', u'Doc', u'Toll Road', u'Gunnar Jensen', u'Hale Caesar', u'Bonaparte', u'Thorn', u'Galgo', u'Mars', u'Luna', u'John Smilee', u'Yin Yang', u'Krug', u'Vata', u'Local Cop #1', u'Local Cop #2', u'Warden', u'Head Bodyguard', u'Tech Guy', u'Colonel', u'Somali Drug Warlord', u"Conrad's Wife", u'Art Broker', u'Camilla', u'Cyclops', u'Fight Watcher', u"Conrad's Henchman"]
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 92) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=92,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 92, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=92)
#     0.5, coord(1/2)
#
# *************************************
# 9	1.0749499		Underworld: Rise of the Lycans
# Underworld: Rise of the Lycans
# Every war has a beginning.
# A prequel to the first two Underworld films, this fantasy explains the origins of the feud between the Vampires and the Lycans. Aided by his secret love, Sonja, courageous Lucian leads the Lycans in battle against brutal Vampire king Viktor. Determined to break the king's enslavement of his people, Lucian faces off against the Death Dealer army in a bid for Lycan independence.
# 12437
# DIRS [u'Patrick Tatopoulos']
# CAST [u'Bill Nighy', u'Michael Sheen', u'Rhona Mitra', u'Shane Brolly', u'Steven Mackintosh', u'Kevin Grevioux', u'David Aston', u'Geraldine Brophy', u'Leighton Cardno', u'Alexander Carroll', u'Elizabeth Hawthorne', u'Jason Hood', u'Mark Mitchinson', u'Craig Parker', u'Timothy Raby', u'Tania Nolan', u'Kate Beckinsale']
# CHAR [u'Viktor', u'Lucian', u'Sonja', u'Kraven', u'Andreas Tanis', u'Raze', u'Coloman', u"Nobleman's Wife", u'Fearful Lycan', u'Young Lucian', u'Orsova', u'Death Dealer', u'Nobleman', u'Sabas', u'Janosh', u'Luka', u'Selene']
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 477) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=477,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 477, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=477)
#     0.5, coord(1/2)
#
# *************************************
# 10	1.0749499		My Bloody Valentine
# My Bloody Valentine
# He's gonna break your heart.
# Ten years ago, a tragedy changed the town of Harmony forever. Tom Hanniger, an inexperienced coal miner, caused an accident in the tunnels that trapped and killed five men and sent the only survivor, Harry Warden, into a permanent coma. But Harry Warden wanted revenge. Exactly one year later, on Valentine’s Day, he woke up…and brutally murdered twenty-two people with a pickaxe before being killed.
# 14435
# DIRS [u'Patrick Lussier']
# CAST [u'Jensen Ackles', u'Jaime King', u'Kerr Smith', u'Betsy Rue', u'Edi Gathegi', u'Tom Atkins', u'Kevin Tighe', u'Megan Boone', u'Karen Baum', u'Joy de la Paz', u'Marc Macaulay', u'Todd Farmer', u'Jeff Hochendoner', u"Bingo O'Malley", u'Liam Rhodes', u'Richard John Walters']
# CHAR [u'Tom Hanniger', u'Sarah Palmer', u'Axel Palmer', u'Irene', u'Deputy Martin', u'Sheriff Jim Burke', u'Ben Foley', u'Megan', u'Deputy Ferris', u'Rosa', u'Riggs', u'Frank the Trucker', u'Red', u'Officer Hinch', u'Michael', u'Harry Warden']
# 1.0749499, max of:
#   1.0749499, product of:
#     2.1498997, sum of:
#       2.1498997, weight(directors.name:patrick in 612) [PerFieldSimilarity], result of:
#         2.1498997, score(doc=612,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           4.140831, fieldWeight in 612, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.625, fieldNorm(doc=612)
#     0.5, coord(1/2)
#
# *************************************
# 11	0.8599599		Sex and the City 2
# Sex and the City 2
# Carrie on.
# Carrie (Sarah Jessica Parker), Charlotte (Kristin Davis), and Miranda (Cynthia Nixon) are all married now, but they're still up for a little fun in the sun. When Samantha (Kim Cattrall) gets the chance to visit one of the most extravagant vacation destinations on the planet and offers to bring them all along, they surmise that a women-only retreat may be the perfect excuse to eschew their responsibilities and remember what life was like before they decided to settle down.
# 37786
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kristin Davis', u'Cynthia Nixon', u'Kim Cattrall', u'David Eigenberg', u'Evan Handler', u'Alexandra Fong', u'Parker Fong', u'Mario Cantone', u'Willie Garson', u'Noah Mills', u'Liza Minnelli', u'Billy Stritch', u'Alice Eve', u'Jason Lewis', u'Max Ryan', u'Lynn Cohen', u'Amira Mor', u"Dhaffer L'Abidine", u'John Corbett', u'Raya Meddine', u'Jennifer Ferrin', u'Tet Wada']
# CHAR [u'Carrie Bradshaw', u'Charlotte York', u'Miranda Hobbes', u'Samantha Jones', u'Steve Brady', u'Harry Goldenblatt', u'Lily York Goldenblatt', u'Lily York Goldenblatt', u'Anthony Marantino', u'Stanford Blatch', u'Nicky', u'Herself', u'Band Leader', u'Erin', u"Jerry 'Smith' Jerrod", u'Rikard Spirit', u'Magda', u'', u'Mahmud (non cr\xe9dit\xe9)', u'Aidan Shaw', u'Annesha', u'Patience', u'VIP Party Patron']
# 0.8599599, max of:
#   0.8599599, product of:
#     1.7199198, sum of:
#       1.7199198, weight(directors.name:patrick in 320) [PerFieldSimilarity], result of:
#         1.7199198, score(doc=320,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           3.3126647, fieldWeight in 320, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=320)
#     0.5, coord(1/2)
#
# *************************************
# 12	0.8599599		Sex and the City
# Sex and the City
# Get carried away.
# A New York writer on sex and love is finally getting married to her Mr. Big. But her three best girlfriends must console her after one of them inadvertently leads Mr. Big to jilt her.
# 4564
# DIRS [u'Michael Patrick King']
# CAST [u'Sarah Jessica Parker', u'Kim Cattrall', u'Cynthia Nixon', u'Kristin Davis', u'Chris Noth', u'Willie Garson', u'David Eigenberg', u'Evan Handler', u'Jennifer Hudson', u'Jason Lewis', u'Mario Cantone', u'Julie Halston', u'Lynn Cohen', u'Anne Meara', u'Candice Bergen', u"Lil' Kim", u'Alexandra Fong', u'Kerry Bish\xe9', u'Joseph Pupo', u'Gilles Marini']
# CHAR [u'Carrie Bradshaw', u'Samantha Jones', u'Miranda Hobbes', u'Charlotte York Goldenblatt', u'Mr. Big', u'Stanford', u'Steve Brady', u'Harry Goldenblatt', u"Louise, Carrie's assistant", u'Smith Jerrod', u'Anthony Marantino', u'Bitsy von Muffling', u'Magda', u'Mary Brady', u'Enid Frick', u'Herself', u'Lily York Goldenblatt', u'Twenty-Something Girl Dreaming', u'Brady', u'Dante']
# 0.8599599, max of:
#   0.8599599, product of:
#     1.7199198, sum of:
#       1.7199198, weight(directors.name:patrick in 675) [PerFieldSimilarity], result of:
#         1.7199198, score(doc=675,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           3.3126647, fieldWeight in 675, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=675)
#     0.5, coord(1/2)
#
# *************************************
# 13	0.8599599		Doubt
# Doubt
# There is no evidence. There are no witnesses. But for one, there is no doubt.
# In 1964, a Catholic school nun questions a priest's ambiguous relationship with a troubled young student, suspecting him of abuse. He denies the charges, and much of the film's quick-fire dialogue tackles themes of religion, morality, and authority.
# 14359
# DIRS [u'John Patrick Shanley']
# CAST [u'Amy Adams', u'Philip Seymour Hoffman', u'Meryl Streep', u'Viola Davis', u'Alice Drummond']
# CHAR [u'Sister James', u'Father Brendan Flynn', u'Sister Aloysius Beauvier', u'Mrs. Miller', u'Sister Veronica']
# 0.8599599, max of:
#   0.8599599, product of:
#     1.7199198, sum of:
#       1.7199198, weight(directors.name:patrick in 637) [PerFieldSimilarity], result of:
#         1.7199198, score(doc=637,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           3.3126647, fieldWeight in 637, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=637)
#     0.5, coord(1/2)
#
# *************************************
# 14	0.8599599		Sinbad: Legend of the Seven Seas
# Sinbad: Legend of the Seven Seas
#
# The sailor of legend is framed by the goddess Eris for the theft of the Book of Peace, and must travel to her realm at the end of the world to retrieve it and save the life of his childhood friend Prince Proteus.
# 14411
# DIRS [u'Tim Johnson', u'Patrick Gilmore']
# CAST [u'Brad Pitt', u'Catherine Zeta-Jones', u'Michelle Pfeiffer', u'Joseph Fiennes', u'Dennis Haysbert', u'Timothy West', u'Timothy West', u'Raman Hui', u'Chung Chan', u'Jim Cummings', u'Conrad Vernon', u'Andrew Birch', u'Chris Miller']
# CHAR [u'Sinbad', u'Marina', u'Eris', u'Proteus', u'Kale', u'Dymas', u'Rat', u'Jin', u'Li', u'Luca', u'Jed', u'Grum / Chum', u'Tower guard']
# 0.8599599, max of:
#   0.8599599, product of:
#     1.7199198, sum of:
#       1.7199198, weight(directors.name:patrick in 1038) [PerFieldSimilarity], result of:
#         1.7199198, score(doc=1038,freq=1.0), product of:
#           0.51919526, queryWeight, product of:
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.0783652, queryNorm
#           3.3126647, fieldWeight in 1038, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.6253295, idf(docFreq=10, maxDocs=3051)
#             0.5, fieldNorm(doc=1038)
#     0.5, coord(1/2)
#
# *************************************
# 15	0.46373135		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# DIRS [u'Alfred Hitchcock']
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 635) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=635,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 635, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=635)
#     0.29212952, weight(cast.name:stewart in 635) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=635,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 635, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=635)
#
# *************************************
# 16	0.46373135		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 426) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=426,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 426, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=426)
#     0.29212952, weight(cast.name:stewart in 426) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=426,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 426, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=426)
#
# *************************************
# 17	0.46373135		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 734) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=734,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=734)
#     0.29212952, weight(cast.name:stewart in 734) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=734,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=734)
#
# *************************************
# 18	0.46373135		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 882) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=882,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 882, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=882)
#     0.29212952, weight(cast.name:stewart in 882) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=882,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 882, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=882)
#
# *************************************
# 19	0.46373135		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# DIRS [u'John Boorman']
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 651) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=651,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 651, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=651)
#     0.29212952, weight(cast.name:stewart in 651) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=651,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 651, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=651)
#
# *************************************
# 20	0.38982356		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# DIRS [u'Bryan Singer']
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 0.38982356, max of:
#   0.38982356, sum of:
#     0.114401214, weight(cast.name:patrick in 653) [PerFieldSimilarity], result of:
#       0.114401214, score(doc=653,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.42717782, fieldWeight in 653, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.125, fieldNorm(doc=653)
#     0.27542233, weight(cast.name:stewart in 653) [PerFieldSimilarity], result of:
#       0.27542233, score(doc=653,freq=2.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.7882255, fieldWeight in 653, product of:
#           1.4142135, tf(freq=2.0), with freq of:
#             2.0, termFreq=2.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.125, fieldNorm(doc=653)
#
# *************************************
# 21	0.38644278		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 146) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=146,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#     0.24344127, weight(cast.name:stewart in 146) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=146,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#
# *************************************
# 22	0.38644278		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 603) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=603,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 603, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=603)
#     0.24344127, weight(cast.name:stewart in 603) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=603,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 603, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=603)
#
# *************************************
# 23	0.38644278		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 425) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=425,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 425, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=425)
#     0.24344127, weight(cast.name:stewart in 425) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=425,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 425, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=425)
#
# *************************************
# 24	0.38644278		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# DIRS [u'David Lynch']
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 751) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=751,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 751, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=751)
#     0.24344127, weight(cast.name:stewart in 751) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=751,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 751, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=751)
#
# *************************************
# 25	0.38644278		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# ...
#     0.5, coord(1/2)
#   0.114401214, product of:
#     0.22880243, sum of:
#       0.22880243, weight(cast.name:patrick in 384) [PerFieldSimilarity], result of:
#         0.22880243, score(doc=384,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.85435563, fieldWeight in 384, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.25, fieldNorm(doc=384)
#     0.5, coord(1/2)
#
# *************************************
# 46	0.23615414		The SpongeBob Movie: Sponge Out of Water
# The SpongeBob Movie: Sponge Out of Water
# He's leaving his world behind, to redeem himself of these past 10 years
# Burger Beard is a pirate who is in search of the final page of a magical book that makes any evil plan he writes in it come true, which happens to be the Krabby Patty secret formula. When the entire city of Bikini Bottom is put in danger, SpongeBob, Patrick, Mr. Krabs, Squidward, Sandy, and Plankton need to go on a quest that takes them to the surface. In order to get back the recipe and save their city, the gang must retrieve the book and transform themselves into superheroes.
# 228165
# DIRS [u'Paul Tibbitt']
# CAST [u'Tom Kenny', u'Bill Fagerbakke', u'Rodger Bumpass', u'Clancy Brown', u'Carolyn Lawrence', u'Mr. Lawrence', u'Antonio Banderas', u'Eric Bauza', u'Tim Conway', u'Eddie Deezen', u'Rob Paulsen', u'Kevin Michael Richardson', u'April Stewart', u'Cree Summer', u'Billy West', u'Carlos Alazraqui', u'Nolan North', u'Paul Tibbitt', u'Jill Talley', u'Dee Bradley Baker', u'Sirena Irwin', u'Mary Jo Catlett', u'Mark Fite', u'Thomas F. Wilson', u'Riki Lindhome', u'Kate Micucci', u'Matt Berry', u'Ezra James Colbert', u'Lillian Ellen Jones', u'Brody Rose', u'Noah Lomax', u'Jesica Ahlberg', u' Nina Repeta', u'Corinne Engstrom', u'Chip Lane', u'Brick Jackson', u'Keller Moore', u'Bailey Campbell', u'Henry Davis Morales', u'Nicolette Noble', u'Kari Klinkenborg', u'Lisa Datz', u'Dane Northcutt', u'Meredith Jackson', u'Ella Adele Burns', u'Mike Benitez', u'Kron Moore', u'Eamon Sheehan', u'Matteo Spears Satriano', u'John Brown', u'David Dickson', u'Ashley Nicole Hudson', u'Amy Lynn Tuttle', u'Marian Green', u'Jake Kilfoyle', u'Dean Neistat', u'Ashley Siloac', u'Epic Lloyd', u'Nice Peter', u'Stephen Hillenburg', u'Lori Alan']
# CHAR [u'SpongeBob / Gary / Agreeable Mob Member / Waffle (voice)', u'Patrick / Male Fish / Eager Customer (voice)', u'Doctor / Squidward / Angry Mob Member #2 / Doughnut / Squidasaurus Rex (voice)', u'Mr.Krabs (voice)', u'Sandy (voice)', u'Plankton / Plankton Robot / News Anchor Fish / Mob Member (voice)', u'Burger Beard', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull / Dead Parrot (voice)', u'Seagull / Dead Parrot / Pigeon Cabbie (voice)', u'Kyle / Helpful Angry Mob Member (voice)', u'Karen (the Computer Wife) / Harold\u2019s Wife / Ice Cream Cone #2 (voice)', u'Sandals / Customer #1 / Fish on Bubble / Perch Perkins / Angry Fish / Maple Syrup Jar / Waffle / Ice Cream Cone #1 / Furballs / Giant Cute Kitty / Rainbow / Spotlight Guard / Angry Guard #1 / Tough Mob Member (voice)', u'Computer Voice / Shocked Mob Member (voice)', u'Mrs. Puff (voice)', u'Customer #2 (voice)', u'Angry Customer #1 (voice)', u'Popsicle (voice)', u'Popsicle (voice)', u'Bubbles (voice)', u'Boy on the Beach', u'Sandcastle Girl', u'Kicking Boy', u'Mikey', u'Tanning Woman', u'Woman with Stroller', u'Young Woman Customer', u'Customer', u'Customer', u'Older Boy Customer', u'Boy Customer #2', u'Young Boy with Cone', u'Surfer Girl with Cone', u'Woman on Sidewalk #1', u'Amy', u'Nut Vendor Customer', u'Mother with Cone', u'Young Girl with Cone', u'Nut Vendor', u'Woman on Sidewalk', u'Young Father', u'Little Boy on Lifeguard Chair', u'Food Truck Patron', u'Man Eating Krabby Patty', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'Beach Goer', u'Surfer Dude (voice)', u'Surfer Dude', u'Baby in Stroller (voice)', u'Pearl (voice)']
# 0.23615414, max of:
#   0.23615414, product of:
#     0.47230828, sum of:
#       0.47230828, weight(overview:patrick in 117) [PerFieldSimilarity], result of:
#         0.47230828, score(doc=117,freq=1.0), product of:
#           0.54415095, queryWeight, product of:
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.0783652, queryNorm
#           0.8679729, fieldWeight in 117, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.125, fieldNorm(doc=117)
#     0.5, coord(1/2)
#   0.060860317, product of:
#     0.121720634, sum of:
#       0.121720634, weight(cast.name:stewart in 117) [PerFieldSimilarity], result of:
#         0.121720634, score(doc=117,freq=1.0), product of:
#           0.34942076, queryWeight, product of:
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.0783652, queryNorm
#           0.34834975, fieldWeight in 117, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.4588766, idf(docFreq=95, maxDocs=3051)
#             0.078125, fieldNorm(doc=117)
#     0.5, coord(1/2)
#
# *************************************
# 47	0.23615414		The SpongeBob SquarePants Movie
# The SpongeBob SquarePants Movie
# Bigger. Better. More absorbent.
# There's trouble brewing in Bikini Bottom. Someone has stolen King Neptune's crown, and it looks like Mr. Krab, SpongeBob's boss, is the culprit. Though he's just been passed over for the promotion of his dreams, SpongeBob stands by his boss, and along with his best pal Patrick, sets out on a treacherous mission to Shell City to reclaim the crown and save Mr. Krab's life.
# 11836
# DIRS [u'Stephen Hillenburg']
# CAST [u'Tom Kenny', u'Clancy Brown', u'Rodger Bumpass', u'Bill Fagerbakke', u'Carolyn Lawrence', u'Jeffrey Tambor', u'Scarlett Johansson', u'Alec Baldwin', u'David Hasselhoff', u'Mr. Lawrence', u'Mr. Lawrence']
# CHAR [u'Spongebob', u'Mr. Krabs (voice)', u'Squidward (voice)', u'Patrick Star (voice)', u'Sandy (voice)', u'King Neptune (voice)', u'Mindy (voice)', u'Dennis (voice)', u'Himself', u'Plankton', u'Plankton']
# 0.23615414, max of:
#   0.23615414, product of:
#     0.47230828, sum of:
#       0.47230828, weight(overview:patrick in 267) [PerFieldSimilarity], result of:
#         0.47230828, score(doc=267,freq=1.0), product of:
#           0.54415095, queryWeight, product of:
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.0783652, queryNorm
#           0.8679729, fieldWeight in 267, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.125, fieldNorm(doc=267)
#     0.5, coord(1/2)
#
# *************************************
# 48	0.23615414		10 Things I Hate About You
# 10 Things I Hate About You
# How do I loathe thee? Let me count the ways.
# Bianca, a tenth grader has never gone on a date, but she isn't allowed to go out with boys until her older sister gets a boyfriend. The problem is, Kat rubs nearly everyone the wrong way. But Bianca and the guy she has her eye on, Joey, are eager, so Joey fixes Kat up with Patrick, a new kid in town just bitter enough for Kat.
# 4951
# DIRS [u'Gil Junger']
# CAST [u'Heath Ledger', u'Julia Stiles', u'Joseph Gordon-Levitt', u'Larisa Oleynik', u'David Krumholtz', u'Andrew Keegan', u'Susan May Pratt', u'Gabrielle Union', u'Larry Miller', u'Daryl Mitchell', u'Allison Janney', u'David Leisure', u'Kyle Cease', u'Greg Jackson', u'Terence Heuston', u'Cameron Fraser', u'Eric Riedmann', u'Quinn Maixner', u'Demegio Kimbrough', u'Todd Butler', u'Dennis Mosley', u'Bianca Kajlich', u'Nick Vukelic', u'Ben Laurance', u'Aidan Kennedy', u'Jelani Quinn', u'Jesse Dyer', u'Aaron Therol', u'Carlos Lac\xe1mara', u'Joshua Thorpe', u'J.R. Johnson', u'Wendy Gottlieb', u'Brian Hood', u'Travis Muller', u'Ari Karczag', u'Laura Kenny', u'Alice Evans', u'Jesper Inglis', u'Nick Brown', u'Monique Powell', u'Brian Mashburn', u'Kay Hanley', u'Michael Eisenstein', u'Michelle Babin', u'Tim Bennett', u'Shelsie Blake', u'Gil Junger', u'Daniel Kountz', u'Alisa Mackay', u'Katy Magnuson', u'Amber Matthews', u'Maher McClung', u'Joshua Mosley', u"Bridget O'Neill", u'Tommy Snider', u'Jay Zorich']
# CHAR [u'Patrick Verona', u'Kat Stratford', u'Cameron James', u'Bianca Stratford', u'Michael', u'Joey Donner', u'Mandella', u'Chastity', u'Walter Stratford', u'Mr. Morgan', u'Ms. Perky', u'Mr. Chapin', u'Bogie Lowenstien', u'Scruvy', u'Derek', u'Trevor', u'Audio Visual Guy', u'Beautiful Jock', u'Coffee Kid #1', u'Coffee Kid #2', u'Cohort', u'Coffee Girl', u'Drugged Out Loser', u'Wimpy Loser (as Benjamin Laurance)', u'Laughing Loser', u'Crying Loser', u'Screaming Loser', u'Detention Student', u'Bartender', u'Jock', u'Mba Guy at Party', u'Heather', u'Clem', u'Cowboy', u'Kissing Guy', u'Judith', u'Perky Girl', u'Buckaroo Bartender', u'Biker', u'Save Ferris Singer', u'Save Ferris Singer', u'Letters To Cleo Singer', u'Letters To Cleo Singer', u'Girl in Night Club (uncredited)', u'School Administrator (uncredited)', u'Bookstore Patron (uncredited)', u'Teacher (uncredited)', u'Admirer #1 (uncredited)', u'Coffee Girl #2 (uncredited)', u'Beautiful Girl (uncredited)', u'Club Dancer #1 (uncredited)', u'Frisbee Thrower (uncredited)', u'Cohort (uncredited)', u'Beautiful Girl (uncredited)', u'Student (uncredited)', u'Roland / High School Security Cop (uncredited)']
# 0.23615414, max of:
#   0.23615414, product of:
#     0.47230828, sum of:
#       0.47230828, weight(overview:patrick in 939) [PerFieldSimilarity], result of:
#         0.47230828, score(doc=939,freq=1.0), product of:
#           0.54415095, queryWeight, product of:
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.0783652, queryNorm
#           0.8679729, fieldWeight in 939, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.125, fieldNorm(doc=939)
#     0.5, coord(1/2)
#
# *************************************
# 49	0.23615414		The Kings of Summer
# The Kings of Summer
# Why live when you can rule.
# Joe Toy, on the verge of adolescence, finds himself increasingly frustrated by his single father, Frank's attempts to manage his life. Declaring his freedom once and for all, he escapes to a clearing in the woods with his best friend, Patrick, and a strange kid named Biaggio. He announces that they are going to build a house there, free from responsibility and parents. Once their makeshift abode is finished, the three young men find themselves masters of their own destiny, alone in the woods.
# 156700
# DIRS [u'Jordan Vogt-Roberts']
# CAST [u'Nick Robinson', u'Gabriel Basso', u'Mois\xe9s Arias', u'Alison Brie', u'Nick Offerman', u'Megan Mullally', u'Mary Lynn Rajskub', u'Angela Trimbur', u'Erin Moriarty', u'Lili Reinhart', u'Marc Evan Jackson', u'Kumail Nanjiani', u'Hannibal Buress', u'Nathan Keyes', u'Austin Abrams', u'Thomas Middleditch']
# CHAR [u'Joe Toy', u'Patrick Keenan', u'Biaggio', u'Heather Toy', u'Frank Toy', u'Mrs. Keenan', u'Captain Davis', u'FacePaint', u'Kelly', u'Vicki', u'Mr. Keenan', u'Delivery Guy', u'Bus Driver', u'Paul', u'Aaron', u'Rookie Cop']
# 0.23615414, max of:
#   0.23615414, product of:
#     0.47230828, sum of:
#       0.47230828, weight(overview:patrick in 849) [PerFieldSimilarity], result of:
#         0.47230828, score(doc=849,freq=1.0), product of:
#           0.54415095, queryWeight, product of:
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.0783652, queryNorm
#           0.8679729, fieldWeight in 849, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.9437833, idf(docFreq=7, maxDocs=3051)
#             0.125, fieldNorm(doc=849)
#     0.5, coord(1/2)
#
# *************************************
# 50	0.22283797		Chicken Little
# Chicken Little
# When it comes to saving the world, it helps to be a little chicken.
# When a tiny acorn bonks Chicken Little on the head, he causes widespread panic and gets on the bad side of the entire town. But when he's hit on the head by a real piece of sky, it's up to Chicken Little and his friends to save the world.
# 9982
# DIRS [u'Mark Dindal']
# CAST [u'Zach Braff', u'Garry Marshall', u'Don Knotts', u'Patrick Stewart', u'Amy Sedaris', u'Steve Zahn', u'Joan Cusack', u'Wallace Shawn', u'Harry Shearer', u'Fred Willard', u"Catherine O'Hara", u'Patrick Warburton', u'Adam West', u'Dan Molina', u'Joe Whyte', u'Mark Walton', u'Sean Elmore', u'Matthew Josten', u'Evan Dunn', u'Mark Dindal', u'Kelly Hoover', u'Will Finn', u'Dara McGarry', u'Mark Kennedy', u'Brad Abrell', u'Tom Amundsen', u'Steve Bencich', u'Greg Berg', u'Julianne Buescher', u'David Cowgill', u'Terri Douglas', u'Chris Edgerly', u'Amanda Fein', u'Caitlin Fein', u'Pat Fraley', u'Eddie Frierson', u'Jackie Gonneau', u'Archie Hahn', u'Jason Harris', u'Brittney Lee Harvey', u'Brian Herskowitz', u'Mandy Kaplan', u'Nathan Kress', u'Anne Lockhart', u'Connor Matheus', u'Mona Marshall', u'Scott Menville', u'Rene Mujica', u'Jonathan Nichols', u'Paul Pape', u'Aaron Spann', u'Pepper Sweeney', u'David Carmon', u'Scott Conrad', u'Nancy Gassner-Clayton', u"Ivan 'Flipz' Velez"]
# CHAR [u'Chicken Little (voice)', u'Buck Cluck (voice)', u'Mayor Turkey Lurkey (voice)', u'Mr. Woolensworth (voice)', u'Foxy Loxy (voice)', u'Runt of the Litter (voice)', u'Abby Mallard (voice)', u'Principal Fetchit (voice)', u'Dog Announcer (voice)', u'Melvin - Alien Dad (voice)', u'Tina - Alien Mom (voice)', u'Alien Cop (voice)', u'Ace - Hollywood Chicken Little (voice)', u'Fish Out of Water (voice)', u'Rodriguez / Acorn Mascot / Umpire (voice)', u'Goosey Loosey (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Morkubine Porcupine / Coach (voice)', u'Mama Runt (voice)', u'Hollywood Fish (voice)', u'Hollywood Abby (voice)', u'Hollywood Runt (voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Patrick Fraley)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Amanda Kaplan)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'Runt - Dancer (uncredited)', u'(uncredited)', u'Choir (uncredited)', u'Chicken Little (dance) (uncredited)']
# 0.22283798, max of:
#   0.22283798, sum of:
#     0.10111734, weight(cast.name:patrick in 409) [PerFieldSimilarity], result of:
#       0.10111734, score(doc=409,freq=2.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.37757543, fieldWeight in 409, product of:
#           1.4142135, tf(freq=2.0), with freq of:
#             2.0, termFreq=2.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.078125, fieldNorm(doc=409)
#     0.121720634, weight(cast.name:stewart in 409) [PerFieldSimilarity], result of:
#       0.121720634, score(doc=409,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.34834975, fieldWeight in 409, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.078125, fieldNorm(doc=409)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:patrick overview:stewart) | (directors.name:patrick directors.name:stewart) | (cast.name:patrick cast.name:stewart) | (title:patrick title:stewart)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# - this does poorly, picks a winner
# - scores between fields are not comparable
# - could we tweak boosts to make the winnre calc saner?
# - Yes but, this is a pretty rare director compared to the common patrick stewart.
# - Sometimes best fields works cross purposes, when there's even just a smidge of overlap
# - and this is just one case of fields that might overlap, what if we also search for titles?

# %% [markdown]
# ## Best Fields Try 2

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name^0.3'],      
         }
    },
    'size': 15,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.46373135		Vertigo
# 2	0.46373135		Star Trek: Insurrection
# 3	0.46373135		Gnomeo & Juliet
# 4	0.46373135		Star Trek: First Contact
# 5	0.46373135		Excalibur
# 6	0.40380782		Legion
# 7	0.40380782		Halo 4: Forward Unto Dawn
# 8	0.40380782		Priest
# 9	0.40380782		Dark Skies
# 10	0.38982356		X-Men: Days of Future Past
# 11	0.38644278		Conspiracy Theory
# 12	0.38644278		The Wolverine
# 13	0.38644278		Star Trek: Nemesis
# 14	0.38644278		Dune
# 15	0.38644278		Star Trek: Generations
# ===============
# Num	Relevance Score		Movie Title
# 1	0.46373135		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 273) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=273,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 273, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=273)
#     0.29212952, weight(cast.name:stewart in 273) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=273,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 273, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=273)
#
# *************************************
# 2	0.46373135		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 735) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=735,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 735, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=735)
#     0.29212952, weight(cast.name:stewart in 735) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=735,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 735, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=735)
#
# *************************************
# 3	0.46373135		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 1043) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=1043,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 1043, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=1043)
#     0.29212952, weight(cast.name:stewart in 1043) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=1043,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 1043, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=1043)
#
# *************************************
# 4	0.46373135		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 43) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=43,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 43, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=43)
#     0.29212952, weight(cast.name:stewart in 43) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=43,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 43, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=43)
#
# *************************************
# 5	0.46373135		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 1115) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=1115,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 1115, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=1115)
#     0.29212952, weight(cast.name:stewart in 1115) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=1115,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 1115, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=1115)
#
# *************************************
# 6	0.40380782		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 0.40380785, max of:
#   0.40380785, product of:
#     0.8076157, sum of:
#       0.8076157, weight(directors.name:stewart in 386) [PerFieldSimilarity], result of:
#         0.8076157, score(doc=386,freq=1.0), product of:
#           0.17429487, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.02350956, queryNorm
#           4.633617, fieldWeight in 386, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=386)
#     0.5, coord(1/2)
#
# *************************************
# 7	0.40380782		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 0.40380785, max of:
#   0.40380785, product of:
#     0.8076157, sum of:
#       0.8076157, weight(directors.name:stewart in 503) [PerFieldSimilarity], result of:
#         0.8076157, score(doc=503,freq=1.0), product of:
#           0.17429487, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.02350956, queryNorm
#           4.633617, fieldWeight in 503, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=503)
#     0.5, coord(1/2)
#
# *************************************
# 8	0.40380782		Priest
# Priest
# Vampire Killer
# In an alternate world, humanity and vampires have warred for centuries. After the last Vampire War, the veteran Warrior Priest lives in obscurity with other humans inside one of the Church's walled cities. When the Priest's niece is kidnapped by vampires, the Priest breaks his vows to hunt them down. He is accompanied by the niece's boyfriend, who is a wasteland sheriff, and a former Warrior Priestess.
# 38321
# CAST [u'Paul Bettany', u'Cam Gigandet', u'Karl Urban', u'Lily Collins', u'Maggie Q', u'Stephen Moyer', u'M\xe4dchen Amick', u'Christopher Plummer', u'Brad Dourif', u'Alan Dale']
# CHAR [u'Priest', u'Hicks', u'Black Hat', u'Lucy', u'Priestess', u'Aaron', u'Shannon', u'Monsignor Orelas', u'Salesman', u'Monsignor Chamberlain']
# 0.40380785, max of:
#   0.40380785, product of:
#     0.8076157, sum of:
#       0.8076157, weight(directors.name:stewart in 1110) [PerFieldSimilarity], result of:
#         0.8076157, score(doc=1110,freq=1.0), product of:
#           0.17429487, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.02350956, queryNorm
#           4.633617, fieldWeight in 1110, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=1110)
#     0.5, coord(1/2)
#
# *************************************
# 9	0.40380782		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 0.40380785, max of:
#   0.40380785, product of:
#     0.8076157, sum of:
#       0.8076157, weight(directors.name:stewart in 1140) [PerFieldSimilarity], result of:
#         0.8076157, score(doc=1140,freq=1.0), product of:
#           0.17429487, queryWeight, product of:
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.02350956, queryNorm
#           4.633617, fieldWeight in 1140, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.413787, idf(docFreq=4, maxDocs=3051)
#             0.625, fieldNorm(doc=1140)
#     0.5, coord(1/2)
#   0.057200607, product of:
#     0.114401214, sum of:
#       0.114401214, weight(cast.name:patrick in 1140) [PerFieldSimilarity], result of:
#         0.114401214, score(doc=1140,freq=1.0), product of:
#           0.267807, queryWeight, product of:
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.0783652, queryNorm
#           0.42717782, fieldWeight in 1140, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             3.4174225, idf(docFreq=271, maxDocs=3051)
#             0.125, fieldNorm(doc=1140)
#     0.5, coord(1/2)
#
# *************************************
# 10	0.38982356		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 0.38982356, max of:
#   0.38982356, sum of:
#     0.114401214, weight(cast.name:patrick in 1117) [PerFieldSimilarity], result of:
#       0.114401214, score(doc=1117,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.42717782, fieldWeight in 1117, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.125, fieldNorm(doc=1117)
#     0.27542233, weight(cast.name:stewart in 1117) [PerFieldSimilarity], result of:
#       0.27542233, score(doc=1117,freq=2.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.7882255, fieldWeight in 1117, product of:
#           1.4142135, tf(freq=2.0), with freq of:
#             2.0, termFreq=2.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.125, fieldNorm(doc=1117)
#
# *************************************
# 11	0.38644278		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 146) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=146,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#     0.24344127, weight(cast.name:stewart in 146) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=146,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#
# *************************************
# 12	0.38644278		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 241) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=241,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 241, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=241)
#     0.24344127, weight(cast.name:stewart in 241) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=241,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 241, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=241)
#
# *************************************
# 13	0.38644278		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 734) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=734,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=734)
#     0.24344127, weight(cast.name:stewart in 734) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=734,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=734)
#
# *************************************
# 14	0.38644278		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 1060) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=1060,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 1060, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=1060)
#     0.24344127, weight(cast.name:stewart in 1060) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=1060,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 1060, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=1060)
#
# *************************************
# 15	0.38644278		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 51) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=51,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 51, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=51)
#     0.24344127, weight(cast.name:stewart in 51) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=51,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 51, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=51)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:patrick overview:stewart) | ((directors.name:patrick directors.name:stewart)^0.3) | (cast.name:patrick cast.name:stewart) | (title:patrick title:stewart)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# - not bad, but still random listing of Star Trek movies, no bias towards Patrick Stewart
# - could enable tie breaker, still fairly brittle

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name^0.1'],      
         }
    },
    'size': 15,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.46373135		Vertigo
# 2	0.46373135		Star Trek: Insurrection
# 3	0.46373135		Gnomeo & Juliet
# 4	0.46373135		Star Trek: First Contact
# 5	0.46373135		Excalibur
# 6	0.38982356		X-Men: Days of Future Past
# 7	0.38644278		Conspiracy Theory
# 8	0.38644278		The Wolverine
# 9	0.38644278		Star Trek: Nemesis
# 10	0.38644278		Dune
# 11	0.38644278		Star Trek: Generations
# 12	0.38644278		X-Men
# 13	0.38644278		Panic Room
# 14	0.38644278		Robin Hood: Men in Tights
# 15	0.35654074		Ted
# ===============
# Num	Relevance Score		Movie Title
# 1	0.46373135		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 273) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=273,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 273, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=273)
#     0.29212952, weight(cast.name:stewart in 273) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=273,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 273, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=273)
#
# *************************************
# 2	0.46373135		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 735) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=735,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 735, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=735)
#     0.29212952, weight(cast.name:stewart in 735) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=735,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 735, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=735)
#
# *************************************
# 3	0.46373135		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 1043) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=1043,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 1043, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=1043)
#     0.29212952, weight(cast.name:stewart in 1043) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=1043,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 1043, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=1043)
#
# *************************************
# 4	0.46373135		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 43) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=43,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 43, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=43)
#     0.29212952, weight(cast.name:stewart in 43) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=43,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 43, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=43)
#
# *************************************
# 5	0.46373135		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.46373135, max of:
#   0.46373135, sum of:
#     0.17160182, weight(cast.name:patrick in 1115) [PerFieldSimilarity], result of:
#       0.17160182, score(doc=1115,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.64076674, fieldWeight in 1115, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.1875, fieldNorm(doc=1115)
#     0.29212952, weight(cast.name:stewart in 1115) [PerFieldSimilarity], result of:
#       0.29212952, score(doc=1115,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.83603936, fieldWeight in 1115, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.1875, fieldNorm(doc=1115)
#
# *************************************
# 6	0.38982356		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 0.38982356, max of:
#   0.38982356, sum of:
#     0.114401214, weight(cast.name:patrick in 1117) [PerFieldSimilarity], result of:
#       0.114401214, score(doc=1117,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.42717782, fieldWeight in 1117, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.125, fieldNorm(doc=1117)
#     0.27542233, weight(cast.name:stewart in 1117) [PerFieldSimilarity], result of:
#       0.27542233, score(doc=1117,freq=2.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.7882255, fieldWeight in 1117, product of:
#           1.4142135, tf(freq=2.0), with freq of:
#             2.0, termFreq=2.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.125, fieldNorm(doc=1117)
#
# *************************************
# 7	0.38644278		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 146) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=146,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#     0.24344127, weight(cast.name:stewart in 146) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=146,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 146, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=146)
#
# *************************************
# 8	0.38644278		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 241) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=241,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 241, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=241)
#     0.24344127, weight(cast.name:stewart in 241) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=241,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 241, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=241)
#
# *************************************
# 9	0.38644278		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 734) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=734,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=734)
#     0.24344127, weight(cast.name:stewart in 734) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=734,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 734, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=734)
#
# *************************************
# 10	0.38644278		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 1060) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=1060,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 1060, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=1060)
#     0.24344127, weight(cast.name:stewart in 1060) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=1060,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 1060, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=1060)
#
# *************************************
# 11	0.38644278		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 51) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=51,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 51, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=51)
#     0.24344127, weight(cast.name:stewart in 51) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=51,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 51, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=51)
#
# *************************************
# 12	0.38644278		X-Men
# X-Men
# Evolution Begins
# Two mutants, Rogue and Wolverine, come to a private academy for their kind whose resident superhero team, the X-Men, must oppose a terrorist organization with similar powers.
# 36657
# CAST [u'Hugh Jackman', u'Patrick Stewart', u'Ian McKellen', u'Famke Janssen', u'James Marsden', u'Halle Berry', u'Anna Paquin', u'Tyler Mane', u'Ray Park', u'Rebecca Romijn', u'Bruce Davison', u'Matthew Sharp', u'Rhona Shekter', u'Kenneth McGregor', u'Shawn Roberts', u'Stan Lee', u'Shawn Ashmore', u'Sumela Kay', u'Alex Burton']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier', u'Eric Lensherr / Magneto', u'Jean Grey', u'Scott Summers / Cyclops', u'Ororo Munroe / Storm', u"Rogue / Marie D'Ancanto", u'Sabretooth', u'Toad', u'Mystique', u'Senator Kelly', u'Henry Gyrich', u"Magneto's Mother", u"Magneto's Father", u"Rogue's Boyfriend", u'Hot Dog Vendor', u'Bobby Drake / Iceman', u'Kitty Pryde', u'John Allerdyce / Pyro']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 158) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=158,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 158, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=158)
#     0.24344127, weight(cast.name:stewart in 158) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=158,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 158, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=158)
#
# *************************************
# 13	0.38644278		Panic Room
# Panic Room
# It was supposed to be the safest room in the house.
# Trapped in their New York brownstone's panic room, a hidden chamber built as a sanctuary in the event of break-ins, newly divorced Meg Altman (Jodie Foster) and her young daughter Sarah (Kristen Stewart) play a deadly game of cat-and-mouse with three intruders - Burnham (Forest Whitaker), Raoul (Dwight Yoakam) and Junior (Jared Leto) - during a brutal home invasion. But the room itself is the focal point because what the intruders really want is inside it.
# 4547
# CAST [u'Jodie Foster', u'Kristen Stewart', u'Forest Whitaker', u'Dwight Yoakam', u'Jared Leto', u'Patrick Bauchau', u'Ann Magnuson', u'Ian Buchanan', u'Andrew Kevin Walker', u'Paul Schulze', u'Mel Rodriguez', u'Richard Conant', u'Paul Simon', u'Victor Thrash', u'Ken Turner']
# CHAR [u'Meg Altman', u'Sarah Altman', u'Burnham', u'Raoul', u'Junior', u'Stephen Altman', u'Lydia Lynch', u'Evan Kurlander', u'Sleepy Neighbor', u'Officer Keeney', u'Officer Morales', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop']
# 0.38644278, max of:
#   0.2561273, product of:
#     0.5122546, sum of:
#       0.5122546, weight(overview:stewart in 292) [PerFieldSimilarity], result of:
#         0.5122546, score(doc=292,freq=1.0), product of:
#           0.5666952, queryWeight, product of:
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.0783652, queryNorm
#           0.90393317, fieldWeight in 292, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.2314653, idf(docFreq=5, maxDocs=3051)
#             0.125, fieldNorm(doc=292)
#     0.5, coord(1/2)
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 292) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=292,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 292, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=292)
#     0.24344127, weight(cast.name:stewart in 292) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=292,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 292, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=292)
#
# *************************************
# 14	0.38644278		Robin Hood: Men in Tights
# Robin Hood: Men in Tights
# The legend had it coming... Find out where Robin Hood put his Little John, what made Will Scarlet, and what did Friar Tuck into his tights that Maid Marion all of a quiver?
# Robin Hood comes home after fighting in the Crusades to learn that the noble King Richard is in exile and that the despotic King John now rules England, with the help of the Sheriff of Rottingham. Robin Hood assembles a band of fellow patriots to do battle with King John and the Sheriff.
# 8005
# CAST [u'Cary Elwes', u'Dom DeLuise', u'Roger Rees', u'Dave Chappelle', u'Eric Allan Kramer', u'Patrick Stewart', u'Megan Cavanagh', u'Richard Lewis', u'Isaac Hayes', u'Amy Yasbeck', u'Mark Blankfield', u'Matthew Porretta', u'Tracey Ullman', u'Dick Van Patten', u'Robert Ridgely', u'Mel Brooks']
# CHAR [u'Robin Hood', u'Don Giovanni', u'Sheriff of Rotingham', u'Ahchoo', u'Little John', u'King Richard', u'Broomhilde', u'Prince John', u'Asneeze', u'Maid Marian', u'Blinkin', u"Will Scarlet O'Hara", u'Latrine', u'The Abbot', u'The Hangman', u'Rabbi Tuckman']
# 0.38644278, max of:
#   0.38644278, sum of:
#     0.14300151, weight(cast.name:patrick in 1453) [PerFieldSimilarity], result of:
#       0.14300151, score(doc=1453,freq=1.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.53397226, fieldWeight in 1453, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.15625, fieldNorm(doc=1453)
#     0.24344127, weight(cast.name:stewart in 1453) [PerFieldSimilarity], result of:
#       0.24344127, score(doc=1453,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6966995, fieldWeight in 1453, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.15625, fieldNorm(doc=1453)
#
# *************************************
# 15	0.35654074		Ted
# Ted
# Ted is coming.
# Family Guy creator Seth MacFarlane brings his boundary-pushing brand of humor to the big screen for the first time as writer, director and voice star of Ted. In the live action/CG-animated comedy, he tells the story of John Bennett, a grown man who must deal with the cherished teddy bear who came to life as the result of a childhood wish, and has refused to leave his side ever since.
# 72105
# CAST [u'Mark Wahlberg', u'Mila Kunis', u'Seth MacFarlane', u'Joel McHale', u'Giovanni Ribisi', u'Patrick Warburton', u'Matt Walsh', u'Jessica Barth', u'Aedin Mincks', u'Bill Smitrovich', u'Patrick Stewart', u'Laura Vandervoort', u'Bretton Manley', u'Alex Borstein', u'Jessica Stroup', u'Tara Strong', u'Norah Jones', u'Sam J. Jones', u'Robert Wu', u'John Viener', u'Ginger Gonzaga', u'Melissa Ordway', u'Max Harris', u'Tom Skerritt', u'Kristina Ellery', u'Katelyn Lorren', u'Chanty Sok', u'Sarah Fischer', u'Ryan Reynolds', u'Ted Danson']
# CHAR [u'John Bennett', u'Lori Collins', u'Ted (voice)', u'Rex', u'Donny', u'Guy', u'Thomas', u'Tami-Lynn', u'Robert', u'Frank', u'Narrator', u'Tanya', u'Young John', u"John's Mom", u'Tracy', u'Bellybutton', u'Herself', u'Himself', u"Asian Man 'Ming'", u'Alix', u'Gina', u'Michelle', u'Greenbaum Kid', u'Himself', u'Heavenly', u'Cherene', u'Angelique', u'Sauvignon Blanc', u'Jared (uncredited)', u'Ted Danson (uncredited)']
# 0.35654074, max of:
#   0.35654074, sum of:
#     0.16178775, weight(cast.name:patrick in 1295) [PerFieldSimilarity], result of:
#       0.16178775, score(doc=1295,freq=2.0), product of:
#         0.267807, queryWeight, product of:
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.0783652, queryNorm
#         0.6041207, fieldWeight in 1295, product of:
#           1.4142135, tf(freq=2.0), with freq of:
#             2.0, termFreq=2.0
#           3.4174225, idf(docFreq=271, maxDocs=3051)
#           0.125, fieldNorm(doc=1295)
#     0.194753, weight(cast.name:stewart in 1295) [PerFieldSimilarity], result of:
#       0.194753, score(doc=1295,freq=1.0), product of:
#         0.34942076, queryWeight, product of:
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.0783652, queryNorm
#         0.5573596, fieldWeight in 1295, product of:
#           1.0, tf(freq=1.0), with freq of:
#             1.0, termFreq=1.0
#           4.4588766, idf(docFreq=95, maxDocs=3051)
#           0.125, fieldNorm(doc=1295)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:patrick overview:stewart) | ((directors.name:patrick directors.name:stewart)^0.1) | (cast.name:patrick cast.name:stewart) | (title:patrick title:stewart)))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}

            
mappingSettings = {
    'movie': {
        'properties': {
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }            
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # Best Fields with Shingles

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
    'size': 15,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.7781657		Star Trek: Insurrection
# 2	0.7781657		Gnomeo & Juliet
# 3	0.7781657		Star Trek: First Contact
# 4	0.680895		Conspiracy Theory
# 5	0.680895		The Wolverine
# 6	0.680895		Star Trek: Nemesis
# 7	0.680895		Dune
# 8	0.680895		Star Trek: Generations
# 9	0.38908285		Chicken Little
# 10	0.34918416		The Bounty Hunter
# 11	0.34298176		One Flew Over the Cuckoo's Nest
# 12	0.27934733		The Beaver
# 13	0.2286545		One for the Money
# 14	0.2286545		The SpongeBob Movie: Sponge Out of Water
# 15	0.2286545		The SpongeBob SquarePants Movie
# ===============
# Num	Relevance Score		Movie Title
# 1	0.7781657		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.7781657, max of:
#   0.7781657, weight(cast.name.bigramed:patrick stewart in 714) [PerFieldSimilarity], result of:
#     0.7781657, score(doc=714,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.5178542, fieldWeight in 714, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.25, fieldNorm(doc=714)
#
# *************************************
# 2	0.7781657		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.7781657, max of:
#   0.7781657, weight(cast.name.bigramed:patrick stewart in 1022) [PerFieldSimilarity], result of:
#     0.7781657, score(doc=1022,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.5178542, fieldWeight in 1022, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.25, fieldNorm(doc=1022)
#
# *************************************
# 3	0.7781657		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.7781657, max of:
#   0.7781657, weight(cast.name.bigramed:patrick stewart in 1170) [PerFieldSimilarity], result of:
#     0.7781657, score(doc=1170,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.5178542, fieldWeight in 1170, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.25, fieldNorm(doc=1170)
#
# *************************************
# 4	0.680895		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.680895, max of:
#   0.680895, weight(cast.name.bigramed:patrick stewart in 146) [PerFieldSimilarity], result of:
#     0.680895, score(doc=146,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.3281224, fieldWeight in 146, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.21875, fieldNorm(doc=146)
#
# *************************************
# 5	0.680895		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.680895, max of:
#   0.680895, weight(cast.name.bigramed:patrick stewart in 220) [PerFieldSimilarity], result of:
#     0.680895, score(doc=220,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.3281224, fieldWeight in 220, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.21875, fieldNorm(doc=220)
#
# *************************************
# 6	0.680895		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.680895, max of:
#   0.680895, weight(cast.name.bigramed:patrick stewart in 713) [PerFieldSimilarity], result of:
#     0.680895, score(doc=713,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.3281224, fieldWeight in 713, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.21875, fieldNorm(doc=713)
#
# *************************************
# 7	0.680895		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# DIRS [u'David Lynch']
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.680895, max of:
#   0.680895, weight(cast.name.bigramed:patrick stewart in 1039) [PerFieldSimilarity], result of:
#     0.680895, score(doc=1039,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.3281224, fieldWeight in 1039, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.21875, fieldNorm(doc=1039)
#
# *************************************
# 8	0.680895		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.680895, max of:
#   0.680895, weight(cast.name.bigramed:patrick stewart in 1178) [PerFieldSimilarity], result of:
#     0.680895, score(doc=1178,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       1.3281224, fieldWeight in 1178, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.21875, fieldNorm(doc=1178)
#
# *************************************
# 9	0.38908285		Chicken Little
# Chicken Little
# When it comes to saving the world, it helps to be a little chicken.
# When a tiny acorn bonks Chicken Little on the head, he causes widespread panic and gets on the bad side of the entire town. But when he's hit on the head by a real piece of sky, it's up to Chicken Little and his friends to save the world.
# 9982
# DIRS [u'Mark Dindal']
# CAST [u'Zach Braff', u'Garry Marshall', u'Don Knotts', u'Patrick Stewart', u'Amy Sedaris', u'Steve Zahn', u'Joan Cusack', u'Wallace Shawn', u'Harry Shearer', u'Fred Willard', u"Catherine O'Hara", u'Patrick Warburton', u'Adam West', u'Dan Molina', u'Joe Whyte', u'Mark Walton', u'Sean Elmore', u'Matthew Josten', u'Evan Dunn', u'Mark Dindal', u'Kelly Hoover', u'Will Finn', u'Dara McGarry', u'Mark Kennedy', u'Brad Abrell', u'Tom Amundsen', u'Steve Bencich', u'Greg Berg', u'Julianne Buescher', u'David Cowgill', u'Terri Douglas', u'Chris Edgerly', u'Amanda Fein', u'Caitlin Fein', u'Pat Fraley', u'Eddie Frierson', u'Jackie Gonneau', u'Archie Hahn', u'Jason Harris', u'Brittney Lee Harvey', u'Brian Herskowitz', u'Mandy Kaplan', u'Nathan Kress', u'Anne Lockhart', u'Connor Matheus', u'Mona Marshall', u'Scott Menville', u'Rene Mujica', u'Jonathan Nichols', u'Paul Pape', u'Aaron Spann', u'Pepper Sweeney', u'David Carmon', u'Scott Conrad', u'Nancy Gassner-Clayton', u"Ivan 'Flipz' Velez"]
# CHAR [u'Chicken Little (voice)', u'Buck Cluck (voice)', u'Mayor Turkey Lurkey (voice)', u'Mr. Woolensworth (voice)', u'Foxy Loxy (voice)', u'Runt of the Litter (voice)', u'Abby Mallard (voice)', u'Principal Fetchit (voice)', u'Dog Announcer (voice)', u'Melvin - Alien Dad (voice)', u'Tina - Alien Mom (voice)', u'Alien Cop (voice)', u'Ace - Hollywood Chicken Little (voice)', u'Fish Out of Water (voice)', u'Rodriguez / Acorn Mascot / Umpire (voice)', u'Goosey Loosey (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Kirby - Alien Kid (voice)', u'Morkubine Porcupine / Coach (voice)', u'Mama Runt (voice)', u'Hollywood Fish (voice)', u'Hollywood Abby (voice)', u'Hollywood Runt (voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Patrick Fraley)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice) (as Amanda Kaplan)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'(voice)', u'Runt - Dancer (uncredited)', u'(uncredited)', u'Choir (uncredited)', u'Chicken Little (dance) (uncredited)']
# 0.38908285, max of:
#   0.38908285, weight(cast.name.bigramed:patrick stewart in 26) [PerFieldSimilarity], result of:
#     0.38908285, score(doc=26,freq=1.0), product of:
#       0.51267487, queryWeight, product of:
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.08444073, queryNorm
#       0.7589271, fieldWeight in 26, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.071417, idf(docFreq=9, maxDocs=1594)
#         0.125, fieldNorm(doc=26)
#
# *************************************
# 10	0.34918416		The Bounty Hunter
# The Bounty Hunter
# It's a Job. It Isn't Personal. Well, Maybe a Little...
# Milo Boyd is a bounty hunter whose latest gig is rather satisfying, as he finds out that the bail-skipper he must chase down is his own ex-wife, Nicole -- but she has no intention of getting nabbed without a fight. Complicating matters, Nicole's wannabe-boyfriend, Stewart, joins the chase.
# 27573
# DIRS [u'Andy Tennant']
# CAST [u'Gerard Butler', u'Jennifer Aniston', u'Gio Perez', u'Siobhan Fallon', u'Joel Garland', u'Jason Kolotouros', u'Matt Malloy', u'Jason Sudeikis', u'Adam Rose', u'Christine Baranski', u'Dorian Missick', u'David Costabile', u'Lynda Gravatt', u'Peter Greene', u'Jeff Garlin', u'Charlie Hewson']
# CHAR [u'Milo Boyd', u'Nicole Hurley', u'Uncle Sam', u'Teresa (as Siobhan Fallon Hogan)', u'Dwight (as Joel Marsh Garland)', u'Gelman', u'Gary', u'Stewart', u'Jimmy', u'Kitty Hurley', u'Bobby Jenkins', u'Arthur', u'Judge', u'Earl Mahler', u'Sid', u'Rich Guy']
# 0.3491842, max of:
#   0.3491842, product of:
#     0.6983684, sum of:
#       0.6983684, weight(overview:stewart in 165) [PerFieldSimilarity], result of:
#         0.6983684, score(doc=165,freq=1.0), product of:
#           0.61433923, queryWeight, product of:
#             7.2753897, idf(docFreq=2, maxDocs=1594)
#             0.08444073, queryNorm
#           1.1367797, fieldWeight in 165, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.2753897, idf(docFreq=2, maxDocs=1594)
#             0.15625, fieldNorm(doc=165)
#     0.5, coord(1/2)
#
# *************************************
# 11	0.34298176		One Flew Over the Cuckoo's Nest
# One Flew Over the Cuckoo's Nest
# If he's crazy, what does that make you?
# While serving time for insanity at a state mental hospital, implacable rabble-rouser Randle Patrick McMurphy inspires his fellow patients to rebel against the authoritarian rule of head nurse Mildred Ratched.
# 510
# DIRS [u'Milo\u0161 Forman']
# CAST [u'Jack Nicholson', u'Louise Fletcher', u'Danny DeVito', u'William Redfield', u'Scatman Crothers', u'Brad Dourif', u'Christopher Lloyd', u'Will Sampson', u'Dean R. Brooks', u'Michael Berryman', u'Sydney Lassick', u'William Duell', u'Vincent Schiavelli']
# CHAR [u'Randle Patrick McMurphy', u'Nurse Mildred Ratched', u'Martini', u'Harding', u'Orderly Turkle', u'Billy Bibbit', u'Taber', u'Chief Bromden', u'Dr. John Spivey', u'Ellis', u'Charlie Cheswick', u'Jim Sefelt', u'Fredrickson']
# 0.34298176, max of:
#   0.34298176, product of:
#     0.6859635, sum of:
#       0.6859635, weight(overview:patrick in 634) [PerFieldSimilarity], result of:
#         0.6859635, score(doc=634,freq=1.0), product of:
#           0.5558094, queryWeight, product of:
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.08444073, queryNorm
#           1.2341704, fieldWeight in 634, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.1875, fieldNorm(doc=634)
#     0.5, coord(1/2)
#
# *************************************
# 12	0.27934733		The Beaver
# The Beaver
# He's here to save Walter's life.
# Suffering from a severe case of depression, toy company CEO Walter Black (Mel Gibson) begins using a beaver hand puppet to help him open up to his family. With his father seemingly going insane, adolescent son Porter (Anton Yelchin) pushes for his parents to get a divorce. Jodie Foster directs and co-stars as Walter's wife in this dark comedy that also features Riley Thomas Stewart and Jennifer Lawrence.
# 50780
# DIRS [u'Jodie Foster']
# CAST [u'Jodie Foster', u'Mel Gibson', u'Jennifer Lawrence', u'Anton Yelchin']
# CHAR [u'Meredith Black', u'Walter Black', u'Norah', u'Porter Black']
# 0.27934733, max of:
#   0.27934733, product of:
#     0.55869466, sum of:
#       0.55869466, weight(overview:stewart in 1137) [PerFieldSimilarity], result of:
#         0.55869466, score(doc=1137,freq=1.0), product of:
#           0.61433923, queryWeight, product of:
#             7.2753897, idf(docFreq=2, maxDocs=1594)
#             0.08444073, queryNorm
#           0.9094237, fieldWeight in 1137, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             7.2753897, idf(docFreq=2, maxDocs=1594)
#             0.125, fieldNorm(doc=1137)
#     0.5, coord(1/2)
#
# *************************************
# 13	0.2286545		One for the Money
# One for the Money
# She's looking for a few not-so-good men
# Stephanie Plum (Katherine Heigl), an unemployed lingerie buyer, convinces her bail bondsman cousin, Vinnie (Patrick Fischler), to give her a shot as a bounty hunter. Her first assignment is to track down a former cop, Joe Morelli (Jason O'Mara), on the run for murder -- the same man who broke her heart years before. With the help of some friends and the best bounty hunter in the business, Ranger (Daniel Sunjata), she slowly learns what it takes to be a true bounty hunter.
# 54054
# DIRS [u'Julie Anne Robinson']
# CAST [u'Katherine Heigl', u'John Leguizamo', u'Debbie Reynolds', u'Sherri Shepherd', u'Patrick Fischler', u'Daniel Sunjata', u"Jason O'Mara"]
# CHAR [u'Stephanie Plum', u'Jimmy Alpha', u'Grandma Mazur', u'Lula', u'Vinnie Plum', u'Ranger', u'Joseph Morelli']
# 0.2286545, max of:
#   0.2286545, product of:
#     0.457309, sum of:
#       0.457309, weight(overview:patrick in 1) [PerFieldSimilarity], result of:
#         0.457309, score(doc=1,freq=1.0), product of:
#           0.5558094, queryWeight, product of:
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.08444073, queryNorm
#           0.8227803, fieldWeight in 1, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.125, fieldNorm(doc=1)
#     0.5, coord(1/2)
#
# *************************************
# 14	0.2286545		The SpongeBob Movie: Sponge Out of Water
# The SpongeBob Movie: Sponge Out of Water
# He's leaving his world behind, to redeem himself of these past 10 years
# Burger Beard is a pirate who is in search of the final page of a magical book that makes any evil plan he writes in it come true, which happens to be the Krabby Patty secret formula. When the entire city of Bikini Bottom is put in danger, SpongeBob, Patrick, Mr. Krabs, Squidward, Sandy, and Plankton need to go on a quest that takes them to the surface. In order to get back the recipe and save their city, the gang must retrieve the book and transform themselves into superheroes.
# 228165
# DIRS [u'Paul Tibbitt']
# CAST [u'Tom Kenny', u'Bill Fagerbakke', u'Rodger Bumpass', u'Clancy Brown', u'Carolyn Lawrence', u'Mr. Lawrence', u'Antonio Banderas', u'Eric Bauza', u'Tim Conway', u'Eddie Deezen', u'Rob Paulsen', u'Kevin Michael Richardson', u'April Stewart', u'Cree Summer', u'Billy West', u'Carlos Alazraqui', u'Nolan North', u'Paul Tibbitt', u'Jill Talley', u'Dee Bradley Baker', u'Sirena Irwin', u'Mary Jo Catlett', u'Mark Fite', u'Thomas F. Wilson', u'Riki Lindhome', u'Kate Micucci', u'Matt Berry', u'Ezra James Colbert', u'Lillian Ellen Jones', u'Brody Rose', u'Noah Lomax', u'Jesica Ahlberg', u' Nina Repeta', u'Corinne Engstrom', u'Chip Lane', u'Brick Jackson', u'Keller Moore', u'Bailey Campbell', u'Henry Davis Morales', u'Nicolette Noble', u'Kari Klinkenborg', u'Lisa Datz', u'Dane Northcutt', u'Meredith Jackson', u'Ella Adele Burns', u'Mike Benitez', u'Kron Moore', u'Eamon Sheehan', u'Matteo Spears Satriano', u'John Brown', u'David Dickson', u'Ashley Nicole Hudson', u'Amy Lynn Tuttle', u'Marian Green', u'Jake Kilfoyle', u'Dean Neistat', u'Ashley Siloac', u'Epic Lloyd', u'Nice Peter', u'Stephen Hillenburg', u'Lori Alan']
# CHAR [u'SpongeBob / Gary / Agreeable Mob Member / Waffle (voice)', u'Patrick / Male Fish / Eager Customer (voice)', u'Doctor / Squidward / Angry Mob Member #2 / Doughnut / Squidasaurus Rex (voice)', u'Mr.Krabs (voice)', u'Sandy (voice)', u'Plankton / Plankton Robot / News Anchor Fish / Mob Member (voice)', u'Burger Beard', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull (voice)', u'Seagull / Dead Parrot (voice)', u'Seagull / Dead Parrot / Pigeon Cabbie (voice)', u'Kyle / Helpful Angry Mob Member (voice)', u'Karen (the Computer Wife) / Harold\u2019s Wife / Ice Cream Cone #2 (voice)', u'Sandals / Customer #1 / Fish on Bubble / Perch Perkins / Angry Fish / Maple Syrup Jar / Waffle / Ice Cream Cone #1 / Furballs / Giant Cute Kitty / Rainbow / Spotlight Guard / Angry Guard #1 / Tough Mob Member (voice)', u'Computer Voice / Shocked Mob Member (voice)', u'Mrs. Puff (voice)', u'Customer #2 (voice)', u'Angry Customer #1 (voice)', u'Popsicle (voice)', u'Popsicle (voice)', u'Bubbles (voice)', u'Boy on the Beach', u'Sandcastle Girl', u'Kicking Boy', u'Mikey', u'Tanning Woman', u'Woman with Stroller', u'Young Woman Customer', u'Customer', u'Customer', u'Older Boy Customer', u'Boy Customer #2', u'Young Boy with Cone', u'Surfer Girl with Cone', u'Woman on Sidewalk #1', u'Amy', u'Nut Vendor Customer', u'Mother with Cone', u'Young Girl with Cone', u'Nut Vendor', u'Woman on Sidewalk', u'Young Father', u'Little Boy on Lifeguard Chair', u'Food Truck Patron', u'Man Eating Krabby Patty', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'ND Beach Goer', u'Beach Goer', u'Surfer Dude (voice)', u'Surfer Dude', u'Baby in Stroller (voice)', u'Pearl (voice)']
# 0.2286545, max of:
#   0.2286545, product of:
#     0.457309, sum of:
#       0.457309, weight(overview:patrick in 405) [PerFieldSimilarity], result of:
#         0.457309, score(doc=405,freq=1.0), product of:
#           0.5558094, queryWeight, product of:
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.08444073, queryNorm
#           0.8227803, fieldWeight in 405, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.125, fieldNorm(doc=405)
#     0.5, coord(1/2)
#
# *************************************
# 15	0.2286545		The SpongeBob SquarePants Movie
# The SpongeBob SquarePants Movie
# Bigger. Better. More absorbent.
# There's trouble brewing in Bikini Bottom. Someone has stolen King Neptune's crown, and it looks like Mr. Krab, SpongeBob's boss, is the culprit. Though he's just been passed over for the promotion of his dreams, SpongeBob stands by his boss, and along with his best pal Patrick, sets out on a treacherous mission to Shell City to reclaim the crown and save Mr. Krab's life.
# 11836
# DIRS [u'Stephen Hillenburg']
# CAST [u'Tom Kenny', u'Clancy Brown', u'Rodger Bumpass', u'Bill Fagerbakke', u'Carolyn Lawrence', u'Jeffrey Tambor', u'Scarlett Johansson', u'Alec Baldwin', u'David Hasselhoff', u'Mr. Lawrence', u'Mr. Lawrence']
# CHAR [u'Spongebob', u'Mr. Krabs (voice)', u'Squidward (voice)', u'Patrick Star (voice)', u'Sandy (voice)', u'King Neptune (voice)', u'Mindy (voice)', u'Dennis (voice)', u'Himself', u'Plankton', u'Plankton']
# 0.2286545, max of:
#   0.2286545, product of:
#     0.457309, sum of:
#       0.457309, weight(overview:patrick in 555) [PerFieldSimilarity], result of:
#         0.457309, score(doc=555,freq=1.0), product of:
#           0.5558094, queryWeight, product of:
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.08444073, queryNorm
#           0.8227803, fieldWeight in 555, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.5822425, idf(docFreq=5, maxDocs=1594)
#             0.125, fieldNorm(doc=555)
#     0.5, coord(1/2)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:patrick overview:stewart) | directors.name.bigramed:patrick stewart | (title:patrick title:stewart) | cast.name.bigramed:patrick stewart))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
    'size': 15,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.7239306		Star Trek: Insurrection
# 2	0.7239306		Gnomeo & Juliet
# 3	0.7239306		Star Trek: First Contact
# 4	0.7239306		Excalibur
# 5	0.6334393		Conspiracy Theory
# 6	0.6334393		The Wolverine
# 7	0.6334393		Star Trek: Nemesis
# 8	0.6334393		Dune
# 9	0.6334393		Star Trek: Generations
# 10	0.6334393		X-Men
# 11	0.6334393		Robin Hood: Men in Tights
# 12	0.54294795		X2: X-Men United
# 13	0.54294795		TMNT
# 14	0.54294795		The Prince of Egypt
# 15	0.54294795		X-Men: The Last Stand
# ===============
# Num	Relevance Score		Movie Title
# 1	0.7239306		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.7239306, max of:
#   0.7239306, weight(cast.name.bigramed:patrick stewart in 426) [PerFieldSimilarity], result of:
#     0.7239306, score(doc=426,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.5196965, fieldWeight in 426, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.25, fieldNorm(doc=426)
#
# *************************************
# 2	0.7239306		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 0.7239306, max of:
#   0.7239306, weight(cast.name.bigramed:patrick stewart in 734) [PerFieldSimilarity], result of:
#     0.7239306, score(doc=734,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.5196965, fieldWeight in 734, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.25, fieldNorm(doc=734)
#
# *************************************
# 3	0.7239306		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.7239306, max of:
#   0.7239306, weight(cast.name.bigramed:patrick stewart in 882) [PerFieldSimilarity], result of:
#     0.7239306, score(doc=882,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.5196965, fieldWeight in 882, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.25, fieldNorm(doc=882)
#
# *************************************
# 4	0.7239306		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# DIRS [u'John Boorman']
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 0.7239306, max of:
#   0.7239306, weight(cast.name.bigramed:patrick stewart in 651) [PerFieldSimilarity], result of:
#     0.7239306, score(doc=651,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.5196965, fieldWeight in 651, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.25, fieldNorm(doc=651)
#
# *************************************
# 5	0.6334393		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 146) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=146,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 146, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=146)
#
# *************************************
# 6	0.6334393		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 603) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=603,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 603, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=603)
#
# *************************************
# 7	0.6334393		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 425) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=425,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 425, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=425)
#
# *************************************
# 8	0.6334393		Dune
# Dune
# A world beyond your experience, beyond your imagination.
# In the year 10,191, the world is at war for control of the desert planet Dune -- the only place where the time-travel substance Spice can be found. But when one leader gives up control, it's only so he can stage a coup with some unsavory characters.
# 841
# DIRS [u'David Lynch']
# CAST [u'Kyle MacLachlan', u'Francesca Annis', u'Leonardo Cimino', u'Brad Dourif', u'Jos\xe9 Ferrer', u'Linda Hunt', u'Freddie Jones', u'Richard Jordan', u'Virginia Madsen', u'Silvana Mangano', u'Everett McGill', u'Kenneth McMillan', u'Jack Nance', u'Si\xe2n Phillips', u'J\xfcrgen Prochnow', u'Patrick Stewart', u'Sting', u'Dean Stockwell', u'Max von Sydow', u'Sean Young']
# CHAR [u"Paul Usul Muad'Dib Atreides", u'Lady Jessica', u"The Baron's Doctor", u'Piter De Vries', u'Padishah Emperor Shaddam IV', u'Shadout Mapes', u'Thufir Hawat', u'Duncan Idaho', u'Princess Irulan', u'Rev. Mother Ramallo', u'Stilgar', u'Baron Vladimir Harkonnen', u'Capt. Iakin Nefud', u'Rev. Mother Gaius Helen Mohiam', u'Duke Leto Atreides', u'Gurney Halleck', u'Feyd-Rautha', u'Dr. Wellington Yueh', u'Dr. Kynes', u'Chani']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 751) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=751,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 751, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=751)
#
# *************************************
# 9	0.6334393		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 890) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=890,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 890, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=890)
#
# *************************************
# 10	0.6334393		X-Men
# X-Men
# Evolution Begins
# Two mutants, Rogue and Wolverine, come to a private academy for their kind whose resident superhero team, the X-Men, must oppose a terrorist organization with similar powers.
# 36657
# DIRS [u'Bryan Singer']
# CAST [u'Hugh Jackman', u'Patrick Stewart', u'Ian McKellen', u'Famke Janssen', u'James Marsden', u'Halle Berry', u'Anna Paquin', u'Tyler Mane', u'Ray Park', u'Rebecca Romijn', u'Bruce Davison', u'Matthew Sharp', u'Rhona Shekter', u'Kenneth McGregor', u'Shawn Roberts', u'Stan Lee', u'Shawn Ashmore', u'Sumela Kay', u'Alex Burton']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier', u'Eric Lensherr / Magneto', u'Jean Grey', u'Scott Summers / Cyclops', u'Ororo Munroe / Storm', u"Rogue / Marie D'Ancanto", u'Sabretooth', u'Toad', u'Mystique', u'Senator Kelly', u'Henry Gyrich', u"Magneto's Mother", u"Magneto's Father", u"Rogue's Boyfriend", u'Hot Dog Vendor', u'Bobby Drake / Iceman', u'Kitty Pryde', u'John Allerdyce / Pyro']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 997) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=997,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 997, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=997)
#
# *************************************
# 11	0.6334393		Robin Hood: Men in Tights
# Robin Hood: Men in Tights
# The legend had it coming... Find out where Robin Hood put his Little John, what made Will Scarlet, and what did Friar Tuck into his tights that Maid Marion all of a quiver?
# Robin Hood comes home after fighting in the Crusades to learn that the noble King Richard is in exile and that the despotic King John now rules England, with the help of the Sheriff of Rottingham. Robin Hood assembles a band of fellow patriots to do battle with King John and the Sheriff.
# 8005
# DIRS [u'Mel Brooks']
# CAST [u'Cary Elwes', u'Dom DeLuise', u'Roger Rees', u'Dave Chappelle', u'Eric Allan Kramer', u'Patrick Stewart', u'Megan Cavanagh', u'Richard Lewis', u'Isaac Hayes', u'Amy Yasbeck', u'Mark Blankfield', u'Matthew Porretta', u'Tracey Ullman', u'Dick Van Patten', u'Robert Ridgely', u'Mel Brooks']
# CHAR [u'Robin Hood', u'Don Giovanni', u'Sheriff of Rotingham', u'Ahchoo', u'Little John', u'King Richard', u'Broomhilde', u'Prince John', u'Asneeze', u'Maid Marian', u'Blinkin', u"Will Scarlet O'Hara", u'Latrine', u'The Abbot', u'The Hangman', u'Rabbi Tuckman']
# 0.6334393, max of:
#   0.6334393, weight(cast.name.bigramed:patrick stewart in 989) [PerFieldSimilarity], result of:
#     0.6334393, score(doc=989,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.3297344, fieldWeight in 989, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.21875, fieldNorm(doc=989)
#
# *************************************
# 12	0.54294795		X2: X-Men United
# X2: X-Men United
# The time has come for those who are different to stand united.
# Professor Charles Xavier and his team of genetically gifted superheroes face a rising tide of anti-mutant sentiment led by Col. William Stryker in this sequel to the Marvel Comics-based blockbuster X-Men. Storm, Wolverine and Jean Grey must join their usual nemeses Magneto and Mystique to unhinge Stryker's scheme to exterminate all mutants.
# 36658
# DIRS [u'Bryan Singer']
# CAST [u'Patrick Stewart', u'Hugh Jackman', u'Ian McKellen', u'Halle Berry', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Rebecca Romijn', u'Brian Cox', u'Alan Cumming', u'Bruce Davison', u'Aaron Stanford', u'Shawn Ashmore', u'Kelly Hu', u'Katie Stuart', u'Kea Wong', u'Cotter Smith', u'Chiara Zanni', u'Bryce Hodgson', u'Shauna Kain', u'Daniel Cudmore', u'Bryan Singer']
# CHAR [u'Professor Charles Xavier', u'Logan / Wolverine', u'Eric Lensherr / Magneto', u'Ororo Munroe / Storm', u'Jean Grey / Phoenix', u'Scott Summers / Cyclops', u'Anna Marie / Rogue', u'Raven Darkholme / Mystique', u'William Stryker', u'Kurt Wagner / Nightcrawler', u'Senator Kelly', u'John Allerdyce / Pyro', u'Bobby Drake / Iceman', u'Yuriko Oyama / Lady Deathstrike', u'Kitty Pryde / Sprite', u'Jubilee', u'President McKenna', u'White House Tour Guide', u'Artie', u'Theresa Cassidy / Siryn', u'Piotr Rasputin / Colossus', u'Prison Security Officer (uncredited)']
# 0.542948, max of:
#   0.542948, weight(cast.name.bigramed:patrick stewart in 991) [PerFieldSimilarity], result of:
#     0.542948, score(doc=991,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.1397724, fieldWeight in 991, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.1875, fieldNorm(doc=991)
#
# *************************************
# 13	0.54294795		TMNT
# TMNT
# Raising Shell In 2007
# The continued adventures of the four adolescent mutated turtles gifted in the art of the ninja, as they attempt to stop a mysterious evil that threatens to end the world
# 1273
# DIRS [u'Kevin Munroe']
# CAST [u'Chris Evans', u'Sarah Michelle Gellar', u'Mako', u'Kevin Smith', u'Patrick Stewart', u'Zhang Ziyi', u'Laurence Fishburne', u'Mitchell Whitfield', u'James Arnold Taylor', u'Mikey Kelley', u'Nolan North', u'John DiMaggio', u'Paula Mattioli', u'Kevin Michael Richardson', u'Fred Tatasciore', u'Dee Bradley Baker', u'Jim Cummings', u'Phil LaMarr', u'Tara Strong', u'Billy West']
# CHAR [u'Casey (voice)', u"April O'Neil (voice)", u'Splinter (voice)', u'Diner Cook (voice)', u'Winters (voice)', u'Karai (voice)', u'Narrator (voice)', u'Donatello / Additional Voices (voice)', u'Leonardo (voice)', u'Michelangelo (voice)', u'Raphael / Nightwatcher (voice)', u'Colonel Santino (voice)', u'General Serpiente (voice)', u'General Aguila / Additional Voices (voice)', u'General Gato / Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)']
# 0.542948, max of:
#   0.542948, weight(cast.name.bigramed:patrick stewart in 1029) [PerFieldSimilarity], result of:
#     0.542948, score(doc=1029,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.1397724, fieldWeight in 1029, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.1875, fieldNorm(doc=1029)
#
# *************************************
# 14	0.54294795		The Prince of Egypt
# The Prince of Egypt
# The Power Is Real.
# This is the extraordinary tale of two brothers named Moses and Ramses, one born of royal blood, and one an orphan with a secret past. Growing up the best of friends, they share a strong bond of free-spirited youth and good-natured rivalry. But the truth will ultimately set them at odds, as one becomes the ruler of the most powerful empire on earth, and the other the chosen leader of his people! Their final confrontation will forever change their lives and the world.
# 9837
# DIRS [u'Brenda Chapman', u'Steve Hickner', u'Simon Wells']
# CAST [u'Val Kilmer', u'Ralph Fiennes', u'Patrick Stewart', u'Michelle Pfeiffer', u'Sandra Bullock', u'Jeff Goldblum', u'Danny Glover', u'Helen Mirren', u'Steve Martin', u'Martin Short', u'James Avery', u'Amick Byram', u'Aria Curzon', u'Sally Dworsky', u'Ofra Haza', u'Brian Stokes Mitchell', u'Bobby Motown', u'Eden Riegel', u'Shira Roth', u'Stephanie Sawyer', u'Linda Shayne', u'Francesca Smith']
# CHAR [u'Moses/God', u'Ramesses II', u'Pharaoh Seti I', u'Zipporah', u'Miriam', u'Aaron', u'Jethro', u'The Queen', u'Hotep', u'Huy', u'Additional Voices', u'Moses (singing voice)', u'Additional Voices', u'Miriam (singing voice)', u'Yocheved', u'Jethro (singing voice)', u'Rameses Son', u'Young Miriam', u'Hebrew Child (singing voice)', u'Additional Voices', u'The Queen (singing voice)', u'Additional Voices']
# 0.542948, max of:
#   0.542948, weight(cast.name.bigramed:patrick stewart in 1072) [PerFieldSimilarity], result of:
#     0.542948, score(doc=1072,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.1397724, fieldWeight in 1072, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.1875, fieldNorm(doc=1072)
#
# *************************************
# 15	0.54294795		X-Men: The Last Stand
# X-Men: The Last Stand
# Take a Stand
# When a cure is found to treat mutations, lines are drawn amongst the X-Men, led by Professor Charles Xavier, and the Brotherhood, a band of powerful mutants organized under Xavier's former ally, Magneto.
# 36668
# DIRS [u'Brett Ratner']
# CAST [u'Hugh Jackman', u'Halle Berry', u'Ian McKellen', u'Patrick Stewart', u'Famke Janssen', u'Anna Paquin', u'Kelsey Grammer', u'James Marsden', u'Rebecca Romijn', u'Shawn Ashmore', u'Aaron Stanford', u'Vinnie Jones', u'Ellen Page', u'Daniel Cudmore', u'Ben Foster', u'Michael Murphy', u'Dania Ramirez', u'Shohreh Aghdashloo', u'Josef Sommer', u'Bill Duke', u'Eric Dane', u'Cameron Bright', u'Ken Leung', u'Omahyra Mota', u'Stan Lee']
# CHAR [u'Logan / Wolverine', u'Ororo Munroe / Storm', u'Eric Lehnsherr / Magneto', u'Charles Xavier / Professor X', u'Jean Grey / Phoenix', u'Marie / Rogue', u"Dr. Henry 'Hank' McCoy / Beast", u'Scott Summers / Cyclops', u'Raven Darkholme / Mystique', u'Bobby Drake / Iceman', u'John Allerdyce / Pyro', u'Cain Marko / Juggernaut', u'Kitty Pryde / Shadowcat', u'Peter Rasputin / Colossus', u'Warren Worthington III / Angel', u'Warren Worthington II', u'Callisto', u'Dr. Kavita Rao', u'The President', u'Trask', u'Multiple Man', u'Jimmy/Leech', u'Kid Omega', u'Arclight', u'Waterhose Man']
# 0.542948, max of:
#   0.542948, weight(cast.name.bigramed:patrick stewart in 325) [PerFieldSimilarity], result of:
#     0.542948, score(doc=325,freq=1.0), product of:
#       0.47636527, queryWeight, product of:
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.0783652, queryNorm
#       1.1397724, fieldWeight in 325, product of:
#         1.0, tf(freq=1.0), with freq of:
#           1.0, termFreq=1.0
#         6.078786, idf(docFreq=18, maxDocs=3051)
#         0.1875, fieldNorm(doc=325)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:patrick overview:stewart) | directors.name.bigramed:patrick stewart | (title:patrick title:stewart) | cast.name.bigramed:patrick stewart))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Best Fields with tie_breaker

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'best_fields',
            'tie_breaker': 0.4
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.2915788		Star Trek
# 2	1.1068168		Star Trek: Generations
# 3	1.0999181		Star Trek: Insurrection
# 4	1.0999181		Star Trek: First Contact
# 5	1.0915862		Star Trek: Nemesis
# ===============
# Num	Relevance Score		Movie Title
# 1	1.2915788		Star Trek
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 1.2915788, max plus 0.4 times others of:
#   1.2915788, product of:
#     2.5831575, sum of:
#       1.1724579, weight(title:star in 225) [PerFieldSimilarity], result of:
#         1.1724579, score(doc=225,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           3.6798315, fieldWeight in 225, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.625, fieldNorm(doc=225)
#       1.4106996, weight(title:trek in 225) [PerFieldSimilarity], result of:
#         1.4106996, score(doc=225,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           4.0364223, fieldWeight in 225, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.625, fieldNorm(doc=225)
#     0.5, coord(2/4)
#
# *************************************
# 2	1.1068168		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 1.1068168, max plus 0.4 times others of:
#   0.038076136, product of:
#     0.15230455, sum of:
#       0.15230455, weight(overview:star in 890) [PerFieldSimilarity], result of:
#         0.15230455, score(doc=890,freq=1.0), product of:
#           0.22967151, queryWeight, product of:
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.054115467, queryNorm
#           0.6631408, fieldWeight in 890, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             4.244101, idf(docFreq=118, maxDocs=3051)
#             0.15625, fieldNorm(doc=890)
#     0.25, coord(1/4)
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 890) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=890,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 890, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=890)
#       1.1285597, weight(title:trek in 890) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=890,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 890, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=890)
#     0.5, coord(2/4)
#   0.14580819, product of:
#     0.43742457, sum of:
#       0.43742457, weight(cast.name.bigramed:patrick stewart in 890) [PerFieldSimilarity], result of:
#         0.43742457, score(doc=890,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.3297344, fieldWeight in 890, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.21875, fieldNorm(doc=890)
#     0.33333334, coord(1/3)
#
# *************************************
# 3	1.0999181		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 1.0999181, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 426) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=426,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 426, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=426)
#       1.1285597, weight(title:trek in 426) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=426,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 426, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=426)
#     0.5, coord(2/4)
#   0.16663793, product of:
#     0.49991378, sum of:
#       0.49991378, weight(cast.name.bigramed:patrick stewart in 426) [PerFieldSimilarity], result of:
#         0.49991378, score(doc=426,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.5196965, fieldWeight in 426, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.25, fieldNorm(doc=426)
#     0.33333334, coord(1/3)
#
# *************************************
# 4	1.0999181		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 1.0999181, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 882) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=882,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 882, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=882)
#       1.1285597, weight(title:trek in 882) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=882,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 882, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=882)
#     0.5, coord(2/4)
#   0.16663793, product of:
#     0.49991378, sum of:
#       0.49991378, weight(cast.name.bigramed:patrick stewart in 882) [PerFieldSimilarity], result of:
#         0.49991378, score(doc=882,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.5196965, fieldWeight in 882, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.25, fieldNorm(doc=882)
#     0.33333334, coord(1/3)
#
# *************************************
# 5	1.0915862		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 1.0915862, max plus 0.4 times others of:
#   1.033263, product of:
#     2.066526, sum of:
#       0.93796635, weight(title:star in 425) [PerFieldSimilarity], result of:
#         0.93796635, score(doc=425,freq=1.0), product of:
#           0.31861728, queryWeight, product of:
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.054115467, queryNorm
#           2.9438653, fieldWeight in 425, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             5.8877306, idf(docFreq=22, maxDocs=3051)
#             0.5, fieldNorm(doc=425)
#       1.1285597, weight(title:trek in 425) [PerFieldSimilarity], result of:
#         1.1285597, score(doc=425,freq=1.0), product of:
#           0.34949258, queryWeight, product of:
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.054115467, queryNorm
#           3.2291377, fieldWeight in 425, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.4582753, idf(docFreq=12, maxDocs=3051)
#             0.5, fieldNorm(doc=425)
#     0.5, coord(2/4)
#   0.14580819, product of:
#     0.43742457, sum of:
#       0.43742457, weight(cast.name.bigramed:patrick stewart in 425) [PerFieldSimilarity], result of:
#         0.43742457, score(doc=425,freq=1.0), product of:
#           0.32895634, queryWeight, product of:
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.054115467, queryNorm
#           1.3297344, fieldWeight in 425, product of:
#             1.0, tf(freq=1.0), with freq of:
#               1.0, termFreq=1.0
#             6.078786, idf(docFreq=18, maxDocs=3051)
#             0.21875, fieldNorm(doc=425)
#     0.33333334, coord(1/3)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered(((overview:star overview:trek overview:patrick overview:stewart) | (directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart) | (title:star title:trek title:patrick title:stewart) | (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart))~0.4)->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Most Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 100,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.57795894		Star Trek: Generations
# 2	0.37984636		Star Trek: Insurrection
# 3	0.37984636		Star Trek: First Contact
# 4	0.37325242		Star Trek: Nemesis
# 5	0.20443419		Star Trek
# 6	0.16354734		Star Trek: The Motion Picture
# 7	0.16354734		Star Trek Into Darkness
# 8	0.14310393		Star Trek VI: The Undiscovered Country
# 9	0.14310393		Star Trek V: The Final Frontier
# 10	0.14310393		Star Trek IV: The Voyage Home
# 11	0.14310393		Star Trek II: The Wrath of Khan
# 12	0.14310393		Star Trek III: The Search for Spock
# 13	0.10484329		Maps to the Stars
# 14	0.086285345		Star Wars: The Clone Wars
# 15	0.06411133		Star Wars: Episode VI - Return of the Jedi
# 16	0.046574958		Hannah Montana: The Movie
# 17	0.046394862		Starred Up
# 18	0.042612664		Ted
# 19	0.037638247		The Beaver
# 20	0.03711589		The Fault in Our Stars
# 21	0.027836919		Star Wars: Episode IV - A New Hope
# 22	0.027836919		Star Wars: Episode V - The Empire Strikes Back
# 23	0.027836919		Star Wars: Episode II - Attack of the Clones
# 24	0.027836919		Star Wars: Episode III - Revenge of the Sith
# 25	0.027836919		Star Wars: Episode I - The Phantom Menace
# 26	0.02681458		Dinosaur
# 27	0.02637585		Gnomeo & Juliet
# 28	0.02637585		Excalibur
# 29	0.02307887		Conspiracy Theory
# 30	0.02307887		The Wolverine
# 31	0.02307887		Dune
# 32	0.02307887		X-Men
# 33	0.02307887		Robin Hood: Men in Tights
# 34	0.020110935		The Lord of the Rings: The Two Towers
# 35	0.019781888		X2: X-Men United
# 36	0.019781888		TMNT
# 37	0.019781888		The Prince of Egypt
# 38	0.019781888		X-Men: The Last Stand
# 39	0.019781888		X-Men: Days of Future Past
# 40	0.019359209		One Flew Over the Cuckoo's Nest
# 41	0.017497124		The Bounty Hunter
# 42	0.014464276		London Boulevard
# 43	0.013997699		Panic Room
# 44	0.013997699		Zathura: A Space Adventure
# 45	0.01340729		Finding Nemo
# 46	0.01340729		World War Z
# 47	0.013187925		Chicken Little
# 48	0.01290614		One for the Money
# 49	0.01290614		The SpongeBob Movie: Sponge Out of Water
# 50	0.01290614		The SpongeBob SquarePants Movie
# 51	0.01290614		10 Things I Hate About You
# 52	0.01290614		The Kings of Summer
# 53	0.011731379		After Earth
# 54	0.010227787		Fanboys
# 55	0.0100554675		True Grit
# 56	0.009679604		The Smurfs 2
# 57	0.009642851		Nanny McPhee
# 58	0.009642851		Pink Floyd - The Wall
# 59	0.009642851		That Thing You Do!
# 60	0.009642851		Sunset Boulevard
# 61	0.008523156		S1m0ne
# 62	0.008523156		xXx: State of the Union
# 63	0.008437494		Top Five
# 64	0.008437494		Strangers on a Train
# 65	0.008437494		Playing for Keeps
# 66	0.008437494		The Hundred-Foot Journey
# 67	0.008437494		This Must Be the Place
# 68	0.008437494		Step Up All In
# 69	0.007232138		Taxi Driver
# 70	0.007232138		The Horse Whisperer
# 71	0.007232138		God Bless America
# 72	0.007232138		Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 73	0.007232138		America's Sweethearts
# 74	0.007232138		Galaxy Quest
# 75	0.007232138		The Artist
# 76	0.007232138		Speed 2: Cruise Control
# 77	0.007232138		The Village
# 78	0.006818525		Camp Rock 2: The Final Jam
# 79	0.006818525		Bolt
# 80	0.006818525		Bedazzled
# 81	0.0060267816		Kick-Ass 2
# 82	0.0060267816		Contact
# 83	0.0060267816		Stardust
# 84	0.0060267816		Rat Race
# 85	0.0060267816		Flatliners
# 86	0.0060267816		Lost in Translation
# 87	0.0060267816		The Wedding Singer
# 88	0.0060267816		Wayne's World 2
# 89	0.0060267816		Moulin Rouge!
# 90	0.0060267816		Dazed and Confused
# 91	0.0060267816		In a World...
# 92	0.0060267816		Quartet
# 93	0.0060267816		Almost Famous
# 94	0.0060267816		Cars 2
# 95	0.0060267816		Under the Skin
# 96	0.0060267816		Who Framed Roger Rabbit
# 97	0.0060267816		The Informant!
# 98	0.0060267816		You Only Live Twice
# 99	0.0060267816		Mars Attacks!
# 100	0.0060267816		Lawrence of Arabia
# ===============
# Num	Relevance Score		Movie Title
# 1	0.57795894		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.57795894, product of:
#   0.77061194, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 890) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=890,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=890)
#       0.25, coord(1/4)
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 890) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=890,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=890)
#         0.7145245, weight(title:trek in 890) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=890,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=890)
#       0.5, coord(2/4)
#     0.09231548, product of:
#       0.27694643, sum of:
#         0.27694643, weight(cast.name.bigramed:patrick stewart in 890) [PerFieldSimilarity], result of:
#           0.27694643, score(doc=890,freq=1.0), product of:
#             0.20827198, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.034262102, queryNorm
#             1.3297344, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=890)
#       0.33333334, coord(1/3)
#   0.75, coord(3/4)
#
# *************************************
# 2	0.37984636		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.37984636, product of:
#   0.7596927, sum of:
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 426) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=426,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=426)
#         0.7145245, weight(title:trek in 426) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=426,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=426)
#       0.5, coord(2/4)
#     0.1055034, product of:
#       0.3165102, sum of:
#         0.3165102, weight(cast.name.bigramed:patrick stewart in 426) [PerFieldSimilarity], result of:
#           0.3165102, score(doc=426,freq=1.0), product of:
#             0.20827198, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.034262102, queryNorm
#             1.5196965, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=426)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 3	0.37984636		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.37984636, product of:
#   0.7596927, sum of:
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 882) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=882,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=882)
#         0.7145245, weight(title:trek in 882) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=882,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=882)
#       0.5, coord(2/4)
#     0.1055034, product of:
#       0.3165102, sum of:
#         0.3165102, weight(cast.name.bigramed:patrick stewart in 882) [PerFieldSimilarity], result of:
#           0.3165102, score(doc=882,freq=1.0), product of:
#             0.20827198, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.034262102, queryNorm
#             1.5196965, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=882)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 4	0.37325242		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.37325242, product of:
#   0.74650484, sum of:
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 425) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=425,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=425)
#         0.7145245, weight(title:trek in 425) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=425,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=425)
#       0.5, coord(2/4)
#     0.09231548, product of:
#       0.27694643, sum of:
#         0.27694643, weight(cast.name.bigramed:patrick stewart in 425) [PerFieldSimilarity], result of:
#           0.27694643, score(doc=425,freq=1.0), product of:
#             0.20827198, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.034262102, queryNorm
#             1.3297344, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=425)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 5	0.20443419		Star Trek
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 0.20443419, product of:
#   0.81773674, sum of:
#     0.81773674, product of:
#       1.6354735, sum of:
#         0.7423178, weight(title:star in 225) [PerFieldSimilarity], result of:
#           0.7423178, score(doc=225,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             3.6798315, fieldWeight in 225, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.625, fieldNorm(doc=225)
#         0.8931557, weight(title:trek in 225) [PerFieldSimilarity], result of:
#           0.8931557, score(doc=225,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             4.0364223, fieldWeight in 225, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.625, fieldNorm(doc=225)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 6	0.16354734		Star Trek: The Motion Picture
# Star Trek: The Motion Picture
# The human adventure is just beginning.
# When a destructive space entity is spotted approaching Earth, Admiral Kirk resumes command of the Starship Enterprise in order to intercept, examine, and hopefully stop it.
# 152
# DIRS [u'Robert Wise']
# CAST [u'William Shatner', u'Leonard Nimoy', u'George Takei', u'James Doohan', u'Walter Koenig', u'Nichelle Nichols', u'DeForest Kelley', u'Majel Barrett', u'Stephen Collins', u'Persis Khambatta', u'Grace Lee Whitney', u'Mark Lenard', u'Billy Van Zandt', u'Roger Aaron Brown', u'Gary Faga', u'Franklyn Seales']
# CHAR [u'Captain James T. Kirk', u'Mr. Spock', u'Lt. Cmdr. Hikaru Sulu', u'Montgomery Scott', u'Lt. Pavel Chekov', u'Lt. Cmdr. Uhura', u'Dr. Leonard McCoy', u'Dr. Christine Chapel', u'Capt./Cmdr. Willard Decker', u'Lieutenant Ilia', u'CPO Janice Rand', u'Klingon Captain', u'Alien Boy', u'Epsilon Technician', u'Airlock Technician', u'Crew Member']
# 0.16354734, product of:
#   0.65418935, sum of:
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 12) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=12,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 12, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=12)
#         0.7145245, weight(title:trek in 12) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=12,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 12, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=12)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 7	0.16354734		Star Trek Into Darkness
# Star Trek Into Darkness
# Earth Will Fall
# When the crew of the Enterprise is called back home, they find an unstoppable force of terror from within their own organization has detonated the fleet and everything it stands for, leaving our world in a state of crisis.  With a personal score to settle, Captain Kirk leads a manhunt to a war-zone world to capture a one man weapon of mass destruction. As our heroes are propelled into an epic chess game of life and death, love will be challenged, friendships will be torn apart, and sacrifices must be made for the only family Kirk has left: his crew.
# 54138
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Zoe Saldana', u'Karl Urban', u'Simon Pegg', u'John Cho', u'Benedict Cumberbatch', u'Anton Yelchin', u'Bruce Greenwood', u'Peter Weller', u'Alice Eve', u'Noel Clarke', u'Nazneen Contractor', u'Amanda Foreman', u'Jay Scully', u'Jonathan Dixon', u'Aisha Hinds', u'Joseph Gatt', u'Jeremy Raymond', u'Tony Guma', u'Kimberly Arland', u'Sean Blakemore', u'Nick E. Tarabay', u'Beau Billingslea', u'Deep Roy', u'Anjini Taneja Azhar', u'Jack Laufer', u'Katie Cockrell', u'Kellie Cockrell', u'Jason Matthew Smith', u'Chris Hemsworth', u'Jennifer Morrison', u'Seth Ayott', u'Marco Sanchez', u'Lee Reherman', u'Scott Lawrence', u'Usman Ally', u'Nolan North', u'James Hiroyuki Liao', u'Rob Moran', u'Berit Francis', u'Akiva Goldsman', u'Benjamin P. Binswanger', u'Christopher Doohan', u'Andy Demetrio', u'Gianna Simone', u'Rene Rosado', u'Jacquelynn King', u'Long Tran', u'Ningning Deng', u'Jodi Johnston', u'Colleen Harris', u'Jeff Chase', u'Monisola Akiwowo', u'Paul K. Daniel', u"Ser'Darius Blain", u'Heather Langenkamp', u'David C. Waite', u'Melissa Paulo', u'Cynthia Addai-Robinson', u'Drew Grey', u'Douglas Weng', u'Charlie Haugk', u'Max Chernov', u'Marc Primiani', u'Jesper Inglis', u'Jacob Rhodes', u'Kentucky Rhodes', u'Anthony Wilson', u'Eric Greitens', u'Melissa Steinman', u'Adam McCann', u'Jon Orvasky', u'Gerald W. Abrams', u'James McGrath', u'Brian T. Delaney', u'Arlen Escarpeta', u'Chris Gardner', u'Joe Hanna', u'David Acord', u'Joe Moses', u'Kevin Michael Richardson', u'David Sobolov', u'Matthew Wood', u'Fred Tatasciore', u'Kiff VandenHeuvel', u'Julianne Buescher', u'Ellie Newlands', u'Candice Renee', u'Audrey Wasilewski', u'Emily Towers', u'Gina Hirsch', u'Bill Hader', u'Leonard Nimoy', u'Tom Archdeacon', u'Jon Lee Brody', u'Britanni Johnson', u'Hiram A. Murray']
# CHAR [u'Kirk', u'Spock', u'Uhura', u'Bones', u'Scotty', u'Sulu', u'Khan', u'Chekov', u'Pike', u'Marcus', u'Carol', u'Thomas Harewood', u'Rima Harewood', u'Ensign Brackett', u'Lieutenant Chapin', u'Ensign Froman', u'Navigation Officer Darwin', u'Science Officer 0718', u'Lead Nibiran', u'Nibiran', u'Madeline', u'Klingon', u'Klingon', u'Captain Abbot', u'Keenser', u'Lucille Harewood', u'Doctor', u'Girl', u'Girl', u'Cupcake', u'George Kirk', u'Winona Kirk', u'U.S.S. Enterprise Shuttle Ensign', u'Torpedo Security', u'Uniformed Mercenary', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Ensign', u'Starfleet Admiral', u'Starfleet Admiral', u'Starfleet Admiral', u'Transport Officer', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'Lady V', u'U.S.S. Enterprise Security', u'U.S.S. Enterprise Nurse', u'Shuttle Pilot', u'U.S.S. Enterprise Red Shirt', u'Moto', u'U.S.S. Enterprise Crew', u'Bar Girl', u'San Francisco Woman', u'San Francisco Bar Patron', u'U.S.S. Vengeance Security', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'Nibiru Child', u'Nibiru Child', u'Shaku', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Memorial Admiral', u'Starfleet Memorial Admiral', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Spock Prime', u'Ensign Spyke (uncredited)', u'U.S.S. Enterprise Security (uncredited)', u'NYU Nurse (uncredited)', u'Bar Patron (uncredited)']
# 0.16354734, product of:
#   0.65418935, sum of:
#     0.65418935, product of:
#       1.3083787, sum of:
#         0.59385425, weight(title:star in 372) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=372,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.9438653, fieldWeight in 372, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=372)
#         0.7145245, weight(title:trek in 372) [PerFieldSimilarity], result of:
#           0.7145245, score(doc=372,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             3.2291377, fieldWeight in 372, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=372)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 8	0.14310393		Star Trek VI: The Undiscovered Country
# Star Trek VI: The Undiscovered Country
# The battle for peace has begun.
# The crews of the Enterprise and the Excelsior must stop a plot to prevent a peace treaty between the Klingon Empire and the Federation
# 174
# DIRS [u'Nicholas Meyer']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'Christopher Plummer', u'Kim Cattrall', u'David Warner', u'Rosanna DeSoto', u'Brock Peters', u'Kurtwood Smith', u'Iman', u'Mark Lenard', u'Grace Lee Whitney', u'Leon Russom', u'John Schuck', u'Michael Dor', u'Paul Rossilli', u'Robert Easton', u'Michael Dorn']
# CHAR [u'James Tiberius Kirk', u'Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Hikaru Sulu', u'Uhura', u'Pavel Chekov', u'General Chang', u'Lieutenant Valeris', u'Chancellor Gorkon', u'Azetbur', u'Admiral Cartwright', u'Federation President', u'Martia', u'Sarek', u'Excelsior Communications Officer', u'Chief in Command', u'Klingon Ambassador', u'Klingon Defense Attorney', u'Kerla', u'Klingon Judge', u'Klingon Defense Attorney']
# 0.14310393, product of:
#   0.5724157, sum of:
#     0.5724157, product of:
#       1.1448314, sum of:
#         0.5196225, weight(title:star in 281) [PerFieldSimilarity], result of:
#           0.5196225, score(doc=281,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.5758822, fieldWeight in 281, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=281)
#         0.625209, weight(title:trek in 281) [PerFieldSimilarity], result of:
#           0.625209, score(doc=281,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             2.8254955, fieldWeight in 281, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=281)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 9	0.14310393		Star Trek V: The Final Frontier
# Star Trek V: The Final Frontier
# Adventure and imagination will meet at the final frontier.
# Capt. Kirk and his crew must deal with Mr. Spock's half brother who kidnaps three diplomats and hijacks the Enterprise in his obsessive search for God.
# 172
# DIRS [u'William Shatner']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'David Warner', u'Laurence Luckinbill', u'Charles Cooper', u'Cynthia Gouw', u'Todd Bryant', u'George Murdock', u'Jonathan Simpson']
# CHAR [u'Captain James T. Kirk', u'Captain Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Cmdr. Hikaru Sulu', u'Cmdr. Uhura', u'Cmdr. Pavel Chekov', u'St. John Talbot', u'Sybok', u'Gen. Korrd', u'Caithlin Dar', u'Capt. Klaa', u'God', u'Young Sarek']
# 0.14310393, product of:
#   0.5724157, sum of:
#     0.5724157, product of:
#       1.1448314, sum of:
#         0.5196225, weight(title:star in 282) [PerFieldSimilarity], result of:
#           0.5196225, score(doc=282,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.5758822, fieldWeight in 282, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=282)
#         0.625209, weight(title:trek in 282) [PerFieldSimilarity], result of:
#           0.625209, score(doc=282,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             2.8254955, fieldWeight in 282, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=282)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 10	0.14310393		Star Trek IV: The Voyage Home
# Star Trek IV: The Voyage Home
# The key to saving the future can only be found in the past.
# Fugitives of the Federation for their daring rescue of Spock from the doomed Genesis Planet, Admiral Kirk (William Shatner) and his crew begin their journey home to face justice for their actions. But as they near Earth, they find it at the mercy of a mysterious alien presence whose signals are slowly destroying the planet. In a desperate attempt to answer the call of the probe, Kirk and his crew race back to the late twentieth century. However they soon find the world they once knew to be more alien than anything they've encountered in the far reaches of the galaxy!
# 168
# DIRS [u'Leonard Nimoy']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Walter Koenig', u'Nichelle Nichols', u'Jane Wyatt', u'Catherine Hicks', u'Mark Lenard', u'Robin Curtis', u'Robert Ellenstein', u'John Schuck', u'Brock Peters', u'Michael Snyder']
# CHAR [u'Admiral/Captain James T. Kirk', u'Captain Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Cmdr. Hikaru Sulu', u'Cmdr. Pavel Chekov', u'Cmdr. Uhura', u'Amanda', u'Dr. Gillian Taylor', u'Ambassador Sarek', u'Lt. Saavik', u'Federation Council President', u'Klingon Ambassador', u'Admiral Cartwright', u'Starfleet Communications Officer']
# 0.14310393, product of:
#   0.5724157, sum of:
#     0.5724157, product of:
#       1.1448314, sum of:
#         0.5196225, weight(title:star in 474) [PerFieldSimilarity], result of:
#           0.5196225, score(doc=474,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.5758822, fieldWeight in 474, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=474)
#         0.625209, weight(title:trek in 474) [PerFieldSimilarity], result of:
#           0.625209, score(doc=474,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             2.8254955, fieldWeight in 474, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=474)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 11	0.14310393		Star Trek II: The Wrath of Khan
# Star Trek II: The Wrath of Khan
# At the end of the universe lies the beginning of vengeance.
# Admiral James T. Kirk is feeling old; the prospect of accompanying his old ship the Enterprise on a two week cadet cruise is not making him feel any younger. But the training cruise becomes a a life or death struggle when Khan escapes from years of exile and captures the power of creation itself.
# 154
# DIRS [u'Nicholas Meyer']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'Ricardo Montalban', u'Bibi Besch', u'Merritt Butrick', u'Kirstie Alley', u'Paul Winfield']
# CHAR [u'Admiral James T. Kirk', u'Captain Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Cmdr. Hikaru Sulu', u'Cmdr. Uhura', u'Cmdr. Pavel Chekov', u'Khan Noonien Singh', u'Dr. Carol Marcus', u'Dr. David Marcus', u'Lt. Saavik', u'Captain Clark Terrell']
# 0.14310393, product of:
#   0.5724157, sum of:
#     0.5724157, product of:
#       1.1448314, sum of:
#         0.5196225, weight(title:star in 14) [PerFieldSimilarity], result of:
#           0.5196225, score(doc=14,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.5758822, fieldWeight in 14, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=14)
#         0.625209, weight(title:trek in 14) [PerFieldSimilarity], result of:
#           0.625209, score(doc=14,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             2.8254955, fieldWeight in 14, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=14)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 12	0.14310393		Star Trek III: The Search for Spock
# Star Trek III: The Search for Spock
# A dying planet. A fight for life.
# Admiral Kirk and his bridge crew risk their careers stealing the decommissioned Enterprise to return to the restricted Genesis planet to recover Spock's body.
# 157
# DIRS [u'Leonard Nimoy']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'Merritt Butrick', u'Christopher Lloyd', u'Robin Curtis', u'Mark Lenard', u'Carl Steven', u'Vadia Potenza', u'Stephen Manley', u'Joe W. Davis', u'Judith Anderson']
# CHAR [u'Admiral James T. Kirk', u'Capt. Spock/Elevator Voice', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Hikaru Sulu', u'Cmdr. Uhura', u'Pavel Chekov', u'Dr. David Marcus', u'Cmdr. Kruge', u'Lt. Saavik', u'Ambassador Sarek', u'Spock...Age 9', u'Spock...Age 13', u'Spock...Age 17', u'Spock at age 25', u'Vulcan High Priestess']
# 0.14310393, product of:
#   0.5724157, sum of:
#     0.5724157, product of:
#       1.1448314, sum of:
#         0.5196225, weight(title:star in 15) [PerFieldSimilarity], result of:
#           0.5196225, score(doc=15,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             2.5758822, fieldWeight in 15, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=15)
#         0.625209, weight(title:trek in 15) [PerFieldSimilarity], result of:
#           0.625209, score(doc=15,freq=1.0), product of:
#             0.2212741, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.034262102, queryNorm
#             2.8254955, fieldWeight in 15, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=15)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 13	0.10484329		Maps to the Stars
# Maps to the Stars
# A Film By David Cronenberg
# Led by the loathsome yet funny and touching child-star Benjie, we witness the convoluted world of shallow, selfish celebrities and their minions, all of whom are about to be manipulated and destroyed by the young woman who literally represents the fruit of their twisted machinations, Agatha, Benjie’s tormented, apparently psychotic sister.
# 157851
# DIRS [u'David Cronenberg']
# CAST [u'Julianne Moore', u'Mia Wasikowska', u'Evan Bird', u'John Cusack', u'Robert Pattinson', u'Sarah Gadon', u'Carrie Fisher', u'Olivia Williams', u'Emilia McCarthy', u'Niamh Wilson', u'Amanda Brugel', u'Jayne Heitmeyer', u'Clara Pasieka', u'Jennifer Gibson', u'Joe Pingue', u'Jonathan Watton']
# CHAR [u'Havana Segrand', u'Agatha Weiss', u'Benjie Weiss', u'Dr. Stafford Weiss', u'Jerome Fontana', u'Clarice Taggart', u'herself', u'Christina Weiss', u'Kayla', u'Sam', u'Victoria', u'Azita Wachtel', u'Gretchen', u'Starla Gent', u'Arnold', u'Sterl Carruth']
# 0.10484329, product of:
#   0.20968658, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 367) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=367,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 367, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=367)
#       0.25, coord(1/4)
#     0.18557945, product of:
#       0.7423178, sum of:
#         0.7423178, weight(title:star in 367) [PerFieldSimilarity], result of:
#           0.7423178, score(doc=367,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
#             3.6798315, fieldWeight in 367, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.625, fieldNorm(doc=367)
#       0.25, coord(1/4)
#   0.5, coord(2/4)
#
# *************************************
# 14	0.086285345		Star Wars: The Clone Wars
# Star Wars: The Clone Wars
#
# Set between Episode II and III the Clone Wars is the first computer animated Star Wars film. Anakin and Obi Wan must find out who kidnapped Jabba the Hutts son and return him safely. The Seperatists will try anything to stop them and ruin any chance of a diplomatic agreement between the Hutt's and the Republic.
# 12180
# DIRS [u'Dave Filoni']
# CAST [u'Samuel L. Jackson', u'Christopher Lee', u'Anthony Daniels', u'Matt Lanter', u'Tom Kane', u'Matthew Wood', u'Ian Abercrombie', u'Nika Futterman', u'Ashley Eckstein']
# CHAR [u'Mace Windu (voice)', u'Count Dooku (voice)', u'C-3PO (voice)', u'Anakin Skywalker (voice)', u'Yoda (voice)', u'General Grievous (voice)', u'Palpatine (voice)', u'Asajj Ventress (voice)', u'Ahsoka Tano (voice)']
# 0.086285345, product of:
#   0.17257069, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 463) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=463,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 463, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=463)
#       0.25, coord(1/4)
#     0.14846356, product of:
#       0.59385425, sum of:
#         0.59385425, weight(title:star in 463) [PerFieldSimilarity], result of:
#           0.59385425, score(doc=463,freq=1.0), product of:
#             0.20172603, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.034262102, queryNorm
# ...
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 461, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=461)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 93	0.0060267816		Almost Famous
# Almost Famous
# Experience it. Enjoy it. Just don't fall for it.
# Almost Famous is an autobiographical inspired film about a 15-year-old who is hired by Rolling Stone magazine to follow and interview a rock band during their tour. A film about growing up, first love, disappointment, and the life of a rock star.
# 786
# DIRS [u'Cameron Crowe']
# CAST [u'Kate Hudson', u'Billy Crudup', u'Frances McDormand', u'Jason Lee', u'Patrick Fugit', u'Zooey Deschanel', u'Michael Angarano', u'Anna Paquin', u'Fairuza Balk', u'Noah Taylor', u'Philip Seymour Hoffman', u'Jimmy Fallon', u'Rainn Wilson']
# CHAR [u'Penny Lane', u'Russell Hammond', u'Elaine Miller', u'Jeff Bebe', u'William Miller', u'Anita Miller', u'Young William', u'Polexia Aphrodisia', u'Sapphire', u'Dick Roswell', u'Lester Bangs', u'Dennis Hope', u'David Felton']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 543) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=543,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 543, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=543)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 94	0.0060267816		Cars 2
# Cars 2
# Ka-ciao!
# Star race car Lightning McQueen and his pal Mater head overseas to compete in the World Grand Prix race. But the road to the championship becomes rocky as Mater gets caught up in an intriguing adventure of his own: international espionage.
# 49013
# DIRS [u'John Lasseter', u'Brad Lewis']
# CAST [u'Owen Wilson', u'Michael Caine', u'Emily Mortimer', u'Michael Keaton', u'Jason Isaacs', u'Bonnie Hunt', u'John Ratzenberger', u'Tony Shalhoub', u'Larry the Cable Guy', u'Eddie Izzard', u'John Turturro', u'Brent Musburger', u'Joe Mantegna', u'Thomas Kretschmann', u'Darrell Waltrip', u'Franco Nero', u'David Hobbs', u'Patrick Walker', u'Jeff Garlin', u'Michel Michelis', u'Vanessa Redgrave', u'Cheech Marin', u'Peter Jacobson', u'Lloyd Sherr', u'Bruce Campbell', u'Teresa Gallagher', u'Jenifer Lewis', u'Stanley Townsend', u'Velibor Topi\u0107', u'Sig Hansen', u'Guido Quaroni', u'John Mainieri', u'Brad Lewis', u'Jeff Gordon', u'Paul Dooley', u'Edie McClurg', u'Richard Kind', u'Katherine Helmond', u'Michael Wallis', u'Lewis Hamilton', u'Catherine Bolt', u'Gillian Bolt', u'Jess Fulton', u'Sonoko Konishi', u'John Lasseter', u"Daisuke 'Dice' Tsutsumi", u'Fernando Alonso', u'Jan Nilsson', u'Vitaly Petrov', u'Memo Rojas', u'Sebastian Vettel', u'Jacques Villeneuve', u'Mark Winterbottom', u'Jess Harnell', u'Junichi Kajioka', u'Barbara Kottmeier', u"Colleen O'Shaughnessey", u'Daniel Okeefe']
# CHAR [u'Lightning McQueen (voice)', u'Finn McMissile (voice)', u'Holley Shiftwell (voice)', u'Chick Hicks (voice)', u'Siddeley (voice)', u'Sally Carrera (voice)', u'Mack (voice)', u'Luigi (voice)', u'Mater (voice)', u'Sir Miles Axlerod (voice)', u'Francesco Bernoulli (voice)', u'Brent Mustangburger (voice)', u'Grem (voice)', u'Professor Z (voice)', u'Darrell Cartrip (voice)', u'Uncle Topolino (voice)', u'David Hobbscap (voice)', u'Mel Dorado (voice)', u'Otis (voice)', u'Tomber (voice)', u'The Queen / Mama Topolino (voice)', u'Ramone (voice)', u'Acer (voice)', u'Fillmore / Combat Ship (voice)', u"Rod 'Torque' Redline (voice)", u"Mater's Computer (voice)", u'Flo (voice)', u'Victor Hugo / Vladimir Trunkov / Ivan the Tow Truck (voice)', u'Alexander Hugo (voice)', u'Crabby (voice)', u'Guido (voice)', u'J. Curby Gremlin (voice)', u'Tubbs Pacer (voice)', u'Jeff Gorvette (voice)', u'Sarge (voice)', u'Minny (voice)', u'Van (voice)', u'Lizzie (voice)', u'Sheriff (voice)', u'Lewis Hamilton (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice) (as Dice Tsutsumi)', u'Fernando Alonso (voice)', u'Flash (voice)', u'Vitaly Petrov (voice)', u'Memo Rojas (voice)', u'Sebastian Schnell (voice)', u'Jacques Villeneuve (voice)', u'Frosty (voice)', u'Additional Voices (voice) (uncredited)', u'Additional Voices (voice) (uncredited)', u'Additional Voices (voice) (uncredited)', u'Additional Voices (voice) (uncredited)', u'Additional Voices (voice) (uncredited)']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 663) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=663,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 663, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=663)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 95	0.0060267816		Under the Skin
# Under the Skin
# A mysterious seductress preys upon the population of Scotland
# Jonathan Glazer's atmospheric, visually arresting abstraction stars Scarlett Johansson as a seductive alien who prowls the streets of Glasgow in search of prey: unsuspecting men who fall under her spell, only to be consumed by a strange liquid pool.
# 97370
# DIRS [u'Jonathan Glazer']
# CAST [u'Scarlett Johansson', u'Kry\u0161tof H\xe1dek', u'Paul Brannigan', u'Michael Moreland', u'Scott Dymond', u'Jeremy McWilliams']
# CHAR [u'Laura', u'The Swimmer', u'Andrew', u'The Quiet Man', u'The Nervous Man', u'The Bad Man']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 665) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=665,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 665, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=665)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 96	0.0060267816		Who Framed Roger Rabbit
# Who Framed Roger Rabbit
# It's the story of a man, a woman, and a rabbit in a triangle of trouble.
# 'Toon star Roger is worried that his wife Jessica is playing pattycake with someone else, so the studio hires detective Eddie Valiant to snoop on her. But the stakes are quickly raised when Marvin Acme is found dead and Roger is the prime suspect.
# 856
# DIRS [u'Robert Zemeckis']
# CAST [u'Bob Hoskins', u'Christopher Lloyd', u'Joanna Cassidy', u'Charles Fleischer', u'Kathleen Turner', u'Stubby Kaye', u'Alan Tilvern', u'Richard LeParmentier', u'Lou Hirsch', u'Betsy Brantley', u'Mel Blanc', u'Mae Questel', u'Frank Sinatra', u'Richard Williams', u'Wayne Allwine', u'Frank Welker']
# CHAR [u'Eddie Valiant', u'Judge Doom', u'Dolores', u'Roger Rabbit/Benny The Cab/Greasy/Psycho', u'Jessica Rabbit', u'Marvin Acme', u'R.K. Maroon', u'Lt. Santino', u'Baby Herman', u"Jessica's Performance Model", u'Bugs Bunny/Daffy Duck/Tweety Bird', u'Betty Boop', u'Singer', u'Droopy', u'Mickey Mouse', u'Dumbo']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 965) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=965,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 965, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=965)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 97	0.0060267816		The Informant!
# The Informant!
# Based on a tattle-tale.
# A rising star at agri-industry giant Archer Daniels Midland (ADM), Mark Whitacre suddenly turns whistleblower. Even as he exposes his company’s multi-national price-fixing conspiracy to the FBI, Whitacre envisions himself being hailed as a hero of the common man and handed a promotion.
# 11323
# DIRS [u'Steven Soderbergh']
# CAST [u'Matt Damon', u'Melanie Lynskey', u'Scott Bakula', u'Patton Oswalt', u'Joel McHale', u'Ann Dowd', u'Tom Papa', u'Eddie Jemison', u'Clancy Brown', u'Tony Hale', u'Dick Smothers', u'Tom Smothers', u'Paul F. Tompkins', u'Candy Clark', u'Frank Welker', u'Andrew Daly', u'Thomas F. Wilson', u'Rick Overton']
# CHAR [u'Mark Whitacre', u'Ginger Whitacre', u'Brian Shepard', u'Ed Herbst', u'Robert Herndon', u'Kate Medford', u'Mick Andreas', u'Kirk Schmidt', u'Aubrey Daniel', u'James Epstein', u'Judge Harold Baker', u'Dwayne Andreas', u"Anthony D'Angelo", u"Mark Whitacre's Mother", u"Mark Whitacre's Father", u'Marty Allison', u'Mark Cheviron', u'Terry Wilson']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 989) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=989,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 989, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=989)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 98	0.0060267816		You Only Live Twice
# You Only Live Twice
# You Only Live Twice...and Twice is the only way to live!
# A mysterious space craft kidnaps a Russian and American space capsule and brings the world on the verge of another World War. James Bond investigates the case in Japan and meets with his archenemy Blofeld. The fifth film from the legendary James Bond series starring Sean Connery as the British super agent.
# 667
# DIRS [u'Lewis Gilbert']
# CAST [u'Sean Connery', u'Akiko Wakabayashi', u'Karin Dor', u'Mie Hama', u'Tetsur\u014d Tamba', u'Teru Shimada', u'Donald Pleasence', u'Bernard Lee', u'Lois Maxwell', u'Desmond Llewelyn', u'Charles Gray', u'Tsai Chin', u'Burt Kwouk', u'Michael Chow', u'Ronald Rich', u'Jeanne Roland']
# CHAR [u'James Bond', u'Aki', u'Helga Brandt', u'Kissy Suzuki', u'Tiger Tanaka', u'Mr. Osato', u'Ernst Stavro Blofeld', u'M', u'Miss Moneypenny', u'Q', u'Dikko Henderson', u'Ling', u'Spectre 3', u'Spectre 4', u'Hans', u"Bond's Masseuse"]
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 1259) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=1259,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 1259, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=1259)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 99	0.0060267816		Mars Attacks!
# Mars Attacks!
# Nice planet. We'll take it!
# 'We come in peace' is not what those green men from Mars mean when they invade our planet, armed with irresistible weapons and a cruel sense of humor.  This star studded cast must play victim to the alien’s fun and games in this comedy homage to science fiction films of the '50s and '60s.
# 75
# DIRS [u'Tim Burton']
# CAST [u'Jack Nicholson', u'Glenn Close', u'Annette Bening', u'Pierce Brosnan', u'Danny DeVito', u'Martin Short', u'Sarah Jessica Parker', u'Michael J. Fox', u'Rod Steiger', u'Tom Jones', u'Natalie Portman', u'Lukas Haas', u'Sylvia Sidney', u'Lisa Marie', u'Jim Brown', u'Pam Grier']
# CHAR [u'President James Dale / Art Land', u'First Lady Marsha Dale', u'Barbara Land', u'Professor Donald Kessler', u'Rude Gambler', u'Press Secretary Jerry Ross', u'Nathalie Lake', u'Jason Stone', u'General Decker', u'Himself', u'Taffy Dale', u'Richie Norris', u'Grandma Florence Norris', u'Martian Girl', u'Byron Williams', u'Louise Williams']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 221) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=221,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 221, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=221)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 100	0.0060267816		Lawrence of Arabia
# Lawrence of Arabia
# A Mighty Motion Picture Of Action And Adventure!
# Lawrence of Arabia is the classic film from David Lean starring Peter O’Toole and based on the autobiography from Thomas Edward Lawrence who during the first World War was on assignment by the British Empire in Arabia. The film would become a cult classic and is known today as a masterpiece.
# 947
# DIRS [u'David Lean']
# CAST [u"Peter O'Toole", u'Alec Guinness', u'Anthony Quinn', u'Jack Hawkins', u'Omar Sharif', u'Claude Rains', u'Anthony Quayle', u'Jos\xe9 Ferrer', u'Arthur Kennedy', u'Donald Wolfit', u'Zia Mohyeddin', u'I.S. Johar', u'Gamil Ratib', u'Michel Ray', u'John Dimech']
# CHAR [u'T.E. Lawrence', u'Prince Feisal', u'Auda abu Tayi', u'General Lord Edmund Allenby', u'Sherif Ali', u'Mr. Dryden', u'Colonel Brighton', u'Turkish Bey', u'Jackson Bentley', u'General Sir Archibald Murray', u'Tafas', u'Gasim', u'Majid', u'Farraj', u'Daud']
# 0.0060267816, product of:
#   0.024107127, sum of:
#     0.024107127, product of:
#       0.096428506, sum of:
#         0.096428506, weight(overview:star in 482) [PerFieldSimilarity], result of:
#           0.096428506, score(doc=482,freq=1.0), product of:
#             0.14541182, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.034262102, queryNorm
#             0.6631408, fieldWeight in 482, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=482)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((overview:star overview:trek overview:patrick overview:stewart) (directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart) (title:star title:trek title:patrick title:stewart) (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Most Fields With Boost

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.2', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 100,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.21698442		Star Trek: Generations
# 2	0.13826816		Star Trek: Insurrection
# 3	0.13826816		Star Trek: First Contact
# 4	0.13055275		Star Trek: Nemesis
# 5	0.054496057		Hannah Montana: The Movie
# 6	0.04985989		Ted
# 7	0.047840547		Star Trek
# 8	0.044039465		The Beaver
# 9	0.038272437		Star Trek: The Motion Picture
# 10	0.038272437		Star Trek Into Darkness
# 11	0.035817675		Maps to the Stars
# 12	0.03348838		Star Trek VI: The Undiscovered Country
# 13	0.03348838		Star Trek V: The Final Frontier
# 14	0.03348838		Star Trek IV: The Voyage Home
# 15	0.03348838		Star Trek II: The Wrath of Khan
# 16	0.03348838		Star Trek III: The Search for Spock
# 17	0.031474847		Star Wars: The Clone Wars
# 18	0.03137499		Dinosaur
# 19	0.030861644		Gnomeo & Juliet
# 20	0.030861644		Excalibur
# 21	0.02700394		Conspiracy Theory
# 22	0.02700394		The Wolverine
# 23	0.02700394		Dune
# 24	0.02700394		X-Men
# 25	0.02700394		Robin Hood: Men in Tights
# 26	0.023531243		The Lord of the Rings: The Two Towers
# 27	0.023146233		X2: X-Men United
# 28	0.023146233		TMNT
# 29	0.023146233		The Prince of Egypt
# 30	0.023146233		X-Men: The Last Stand
# 31	0.023146233		X-Men: Days of Future Past
# 32	0.022900958		Star Wars: Episode VI - Return of the Jedi
# 33	0.022651669		One Flew Over the Cuckoo's Nest
# 34	0.020472895		The Bounty Hunter
# 35	0.016924245		London Boulevard
# 36	0.016378317		Panic Room
# 37	0.016378317		Zathura: A Space Adventure
# 38	0.015687495		Finding Nemo
# 39	0.015687495		World War Z
# 40	0.015430822		Chicken Little
# 41	0.015101112		One for the Money
# 42	0.015101112		The SpongeBob Movie: Sponge Out of Water
# 43	0.015101112		The SpongeBob SquarePants Movie
# 44	0.015101112		10 Things I Hate About You
# 45	0.015101112		The Kings of Summer
# 46	0.013726559		After Earth
# 47	0.011967248		Fanboys
# 48	0.011765622		True Grit
# 49	0.011325834		The Smurfs 2
# 50	0.0112828305		Nanny McPhee
# 51	0.0112828305		Pink Floyd - The Wall
# 52	0.0112828305		That Thing You Do!
# 53	0.0112828305		Sunset Boulevard
# 54	0.010857068		Starred Up
# 55	0.009972706		S1m0ne
# 56	0.009972706		xXx: State of the Union
# 57	0.009872477		Top Five
# 58	0.009872477		Strangers on a Train
# 59	0.009872477		Playing for Keeps
# 60	0.009872477		The Hundred-Foot Journey
# 61	0.009872477		This Must Be the Place
# 62	0.009872477		Step Up All In
# 63	0.008685654		The Fault in Our Stars
# 64	0.008462123		Taxi Driver
# 65	0.008462123		The Horse Whisperer
# 66	0.008462123		God Bless America
# 67	0.008462123		Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 68	0.008462123		America's Sweethearts
# 69	0.008462123		Galaxy Quest
# 70	0.008462123		The Artist
# 71	0.008462123		Speed 2: Cruise Control
# 72	0.008462123		The Village
# 73	0.0079781655		Camp Rock 2: The Final Jam
# 74	0.0079781655		Bolt
# 75	0.0079781655		Bedazzled
# 76	0.007051769		Kick-Ass 2
# 77	0.007051769		Contact
# 78	0.007051769		Stardust
# 79	0.007051769		Rat Race
# 80	0.007051769		Flatliners
# 81	0.007051769		Lost in Translation
# 82	0.007051769		The Wedding Singer
# 83	0.007051769		Wayne's World 2
# 84	0.007051769		Moulin Rouge!
# 85	0.007051769		Dazed and Confused
# 86	0.007051769		In a World...
# 87	0.007051769		Quartet
# 88	0.007051769		Almost Famous
# 89	0.007051769		Cars 2
# 90	0.007051769		Under the Skin
# 91	0.007051769		Who Framed Roger Rabbit
# 92	0.007051769		The Informant!
# 93	0.007051769		You Only Live Twice
# 94	0.007051769		Mars Attacks!
# 95	0.007051769		Lawrence of Arabia
# 96	0.007051769		RockNRolla
# 97	0.007051769		A Knight's Tale
# 98	0.007051769		Casablanca
# 99	0.007051769		Any Given Sunday
# 100	0.007051769		The Awakening
# ===============
# Num	Relevance Score		Movie Title
# 1	0.21698442		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 0.21698445, product of:
#   0.2893126, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 890) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=890,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=890)
#       0.25, coord(1/4)
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 890) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=890,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=890)
#         0.16720903, weight(title:trek in 890) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=890,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=890)
#       0.5, coord(2/4)
#     0.10801576, product of:
#       0.32404727, sum of:
#         0.32404727, weight(cast.name.bigramed:patrick stewart in 890) [PerFieldSimilarity], result of:
#           0.32404727, score(doc=890,freq=1.0), product of:
#             0.24369322, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.040089127, queryNorm
#             1.3297344, fieldWeight in 890, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=890)
#       0.33333334, coord(1/3)
#   0.75, coord(3/4)
#
# *************************************
# 2	0.13826816		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 0.13826816, product of:
#   0.27653632, sum of:
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 426) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=426,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=426)
#         0.16720903, weight(title:trek in 426) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=426,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=426)
#       0.5, coord(2/4)
#     0.12344658, product of:
#       0.37033972, sum of:
#         0.37033972, weight(cast.name.bigramed:patrick stewart in 426) [PerFieldSimilarity], result of:
#           0.37033972, score(doc=426,freq=1.0), product of:
#             0.24369322, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.040089127, queryNorm
#             1.5196965, fieldWeight in 426, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=426)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 3	0.13826816		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 0.13826816, product of:
#   0.27653632, sum of:
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 882) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=882,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=882)
#         0.16720903, weight(title:trek in 882) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=882,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=882)
#       0.5, coord(2/4)
#     0.12344658, product of:
#       0.37033972, sum of:
#         0.37033972, weight(cast.name.bigramed:patrick stewart in 882) [PerFieldSimilarity], result of:
#           0.37033972, score(doc=882,freq=1.0), product of:
#             0.24369322, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.040089127, queryNorm
#             1.5196965, fieldWeight in 882, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.25, fieldNorm(doc=882)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 4	0.13055275		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 0.13055275, product of:
#   0.2611055, sum of:
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 425) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=425,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=425)
#         0.16720903, weight(title:trek in 425) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=425,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=425)
#       0.5, coord(2/4)
#     0.10801576, product of:
#       0.32404727, sum of:
#         0.32404727, weight(cast.name.bigramed:patrick stewart in 425) [PerFieldSimilarity], result of:
#           0.32404727, score(doc=425,freq=1.0), product of:
#             0.24369322, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.040089127, queryNorm
#             1.3297344, fieldWeight in 425, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.21875, fieldNorm(doc=425)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 5	0.054496057		Hannah Montana: The Movie
# Hannah Montana: The Movie
# She has the best of both worlds...now she has to choose just one.
# When Miley Stewart (aka pop-star Hannah Montana) gets too caught up in the superstar celebrity lifestyle, her dad decides it's time for a total change of scenery. But sweet nibblets! Miley must trade in all the glitz and glamour of Hollywood for some ol' blue jeans on the family farm in Tennessee, and question if she can be both Miley Stewart and Hannah Montana. With a little help from her friends – and awesome guest stars Taylor Swift, Rascal Flatts and Vanessa Williams – will she figure out whether to choose Hannah or Miley?
# 18126
# DIRS [u'Peter Chelsom']
# CAST [u'Miley Cyrus', u'Billy Ray Cyrus', u'Emily Osment', u'Jason Earles', u'Taylor Swift', u'Lucas Till', u'Mitchel Musso', u'Mois\xe9s Arias', u'Vanessa Williams', u'Margo Martindale', u'Melora Hardin', u'Brooke Shields', u'Brandon Cyrus']
# CHAR [u'Miley Stewart/Hannah Montana', u'Billy Ray Stewart', u'Lilly Truscott', u'Jackson Rod Stewart', u'Herself', u'Travis Brody', u'Oliver Oken', u'Rico', u'Vita', u'Ruby', u'Lorelai', u"Miley's Mom", u'Extra']
# 0.054496054, product of:
#   0.21798421, sum of:
#     0.21798421, product of:
#       0.43596843, sum of:
#         0.11169433, weight(overview:star in 822) [PerFieldSimilarity], result of:
#           0.11169433, score(doc=822,freq=2.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6564759, fieldWeight in 822, product of:
#               1.4142135, tf(freq=2.0), with freq of:
#                 2.0, termFreq=2.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.109375, fieldNorm(doc=822)
#         0.3242741, weight(overview:stewart in 822) [PerFieldSimilarity], result of:
#           0.3242741, score(doc=822,freq=2.0), product of:
#             0.28990313, queryWeight, product of:
#               7.2314653, idf(docFreq=5, maxDocs=3051)
#               0.040089127, queryNorm
#             1.1185602, fieldWeight in 822, product of:
#               1.4142135, tf(freq=2.0), with freq of:
#                 2.0, termFreq=2.0
#               7.2314653, idf(docFreq=5, maxDocs=3051)
#               0.109375, fieldNorm(doc=822)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 6	0.04985989		Ted
# Ted
# Ted is coming.
# Family Guy creator Seth MacFarlane brings his boundary-pushing brand of humor to the big screen for the first time as writer, director and voice star of Ted. In the live action/CG-animated comedy, he tells the story of John Bennett, a grown man who must deal with the cherished teddy bear who came to life as the result of a childhood wish, and has refused to leave his side ever since.
# 72105
# DIRS [u'Seth MacFarlane']
# CAST [u'Mark Wahlberg', u'Mila Kunis', u'Seth MacFarlane', u'Joel McHale', u'Giovanni Ribisi', u'Patrick Warburton', u'Matt Walsh', u'Jessica Barth', u'Aedin Mincks', u'Bill Smitrovich', u'Patrick Stewart', u'Laura Vandervoort', u'Bretton Manley', u'Alex Borstein', u'Jessica Stroup', u'Tara Strong', u'Norah Jones', u'Sam J. Jones', u'Robert Wu', u'John Viener', u'Ginger Gonzaga', u'Melissa Ordway', u'Max Harris', u'Tom Skerritt', u'Kristina Ellery', u'Katelyn Lorren', u'Chanty Sok', u'Sarah Fischer', u'Ryan Reynolds', u'Ted Danson']
# CHAR [u'John Bennett', u'Lori Collins', u'Ted (voice)', u'Rex', u'Donny', u'Guy', u'Thomas', u'Tami-Lynn', u'Robert', u'Frank', u'Narrator', u'Tanya', u'Young John', u"John's Mom", u'Tracy', u'Bellybutton', u'Herself', u'Himself', u"Asian Man 'Ming'", u'Alix', u'Gina', u'Michelle', u'Greenbaum Kid', u'Himself', u'Heavenly', u'Cherene', u'Angelique', u'Sauvignon Blanc', u'Jared (uncredited)', u'Ted Danson (uncredited)']
# 0.049859885, product of:
#   0.09971977, sum of:
#     0.022565661, product of:
#       0.090262644, sum of:
#         0.090262644, weight(overview:star in 831) [PerFieldSimilarity], result of:
#           0.090262644, score(doc=831,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.53051263, fieldWeight in 831, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.125, fieldNorm(doc=831)
#       0.25, coord(1/4)
#     0.07715411, product of:
#       0.23146231, sum of:
#         0.23146231, weight(cast.name.bigramed:patrick stewart in 831) [PerFieldSimilarity], result of:
#           0.23146231, score(doc=831,freq=1.0), product of:
#             0.24369322, queryWeight, product of:
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.040089127, queryNorm
#             0.94981027, fieldWeight in 831, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.078786, idf(docFreq=18, maxDocs=3051)
#               0.15625, fieldNorm(doc=831)
#       0.33333334, coord(1/3)
#   0.5, coord(2/4)
#
# *************************************
# 7	0.047840547		Star Trek
# Star Trek
# The future begins
# The fate of the galaxy rests in the hands of bitter rivals. One, James Kirk, is a delinquent, thrill-seeking Iowa farm boy. The other, Spock, a Vulcan, was raised in a logic-based society that rejects all emotion. As fiery instinct clashes with calm reason, their unlikely but powerful partnership is the only thing capable of leading their crew through unimaginable danger, boldly going where no one has gone before. The human adventure has begun again.
# 13475
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Leonard Nimoy', u'Eric Bana', u'Bruce Greenwood', u'Karl Urban', u'Zoe Saldana', u'Simon Pegg', u'John Cho', u'Anton Yelchin', u'Ben Cross', u'Winona Ryder', u'Chris Hemsworth', u'Jennifer Morrison', u'Rachel Nichols', u'Faran Tahir', u'Clifton Collins, Jr.', u'Greg Ellis', u'Scottie Thompson', u'Paul McGillion', u'Lucia Rijker', u'Jimmy Bennett', u'Greg Grunberg', u'Lisa Vidal', u'Jacob Kogan', u'Tyler Perry', u'Amanda Foreman', u'Diora Baird', u'Sufe Bradshaw', u'Tony Elias', u'Sean Gerace', u'Randy Pausch', u'Tim Griffin', u'Freda Foh Shen', u'Kasia Kowalczyk', u'Jason Brooks', u'Sonita Henry', u'Kelvin Yu', u'Marta Martin', u'Tavarus Conley', u'Jeff Castle', u'Billy Brown', u'Spencer Daniels', u'Jeremy Fitzgerald', u'Zoe Chernov', u'Max Chernov', u'Lorenzo James Henrie', u'Colby Paul', u'Cody Klop', u'Akiva Goldsman', u'Anna Katarina', u'Douglas Tait', u'Tony Guma', u'Gerald W. Abrams', u'James McGrath', u'Jason Matthew Smith', u'Marcus Young', u'Bob Clendenin', u'Darlene Tejeiro', u'Reggie Lee', u'Jeffrey Byron', u'Jonathan Dixon', u'Ben Binswagner', u'Margot Farley', u'Alex Nevil', u'Kimberly Arland', u'Jeff Chase', u'Charles Haugk', u'Nana Hill', u'Michael Saglimbeni', u'John Blackman', u'Jack Millard', u'Shaela Luter', u'Sabrina Morris', u'Michelle Parylak', u'Oz Perkins', u'Michael Berry Jr.', u'Matthew Beisner', u'Neville Page', u'Jesper Inglis', u'Marlene Forte', u'Leonard O. Turner', u'Mark Bramhall', u'Ronald F. Hoiseck', u'Irene Roseen', u"Jeff O'Haco", u'Deep Roy', u'Majel Barrett', u'Rico E. Anderson', u'Richard Arnold', u'Tad Atkinson', u'Leslie Augustine', u'Johnny Baca', u'Sala Baker', u'Leo Baligaya', u'Corey Becker', u'Jessica Boss', u'Neil S. Bulk', u'James Cawley', u'Brad Champagne', u'Zachary Culbertson', u'Calvin Dean', u'Christopher Doohan', u'Claire Dor\xe9', u'Mark Casimir Dyniewicz', u'Etienne Eckert', u'Ken Edling', u'Aliza Finley', u'Ian Fisher', u'Mathew Thomas Foss', u'Massi Furlan', u'Victor Garber', u'Tommy Germanovich Jr.', u'Mary Grace', u'Wyatt Gray', u'Joshua Greene', u'Nancy Guerriero', u'Justin Rodgers Hall', u'Jeffery Hauser', u'Brad William Henke', u'Elizabeth Ingalls', u'Christopher Karl Johnson', u'Jolene Kay', u'Sarah Klaren', u'Makiko Konishi', u'Bryan Lee', u'Daniel D. Lee', u'Anne Leighton', u'Steve Luna', u'Aaron Lynch', u'Justin Malachi', u'Nav Mann', u'Paul Marshall', u'Owen Martin', u'Taylor McCluskey', u'Matthew McGregor', u'Caitlin McKenna-Wilkinson', u'Patrizia Milano', u'Kevin Moser', u'Jonathan W.D. Newkerk', u'Westley Nguyen', u'Jim Nieb', u'Andres Perez-Molina', u'Mark Phelan', u'Damion Poitier', u'Rahvaunia', u'Bertrand Roberson Jr.', u'Deborah Rombaut', u'Leonard Jonathan Ruebe', u'Ramona Seymour', u'William Morgan Sheppard', u'Katie Soo', u'Arne Starr', u'Ronnie Steadman', u'Joseph Stephens Jr.', u'Joseph Steven', u'T.J. Storm', u'Paul Townsend', u'Scott Trimble', u'Errik Tustenuggee', u'Ravi Valleti', u'Jason Vaughn', u'A.J. Verel', u'Brian Waller', u'Steve Wharton', u'Wil Wheaton', u'Brianna Womick', u'Lynnanne Zager', u'Pavel Lychnikoff']
# CHAR [u'Kirk', u'Spock', u'Old Spock', u'Nero', u'Christopher Pike', u"Leonard 'Bones' McCoy", u'Nyota Uhura', u'Scotty', u'Hikaru Sulu', u'Pavel Chekov', u'Sarek', u'Amanda Grayson', u'George Kirk', u'Winona Kirk', u'Galia', u'Captain Robau', u'Ayel', u'Chief Engineer Olsen', u"Nero's Wife", u'Barracks Officer', u'Romulan Communications Officer', u'Young James T. Kirk', u'Stepdad (voice)', u'Barracks Officer', u'Young Spock', u'Admiral Richard Barnett', u'Hannity', u'The Wrong Orion', u'Cadet Alien', u'Officer Pitts (as Antonio Elias)', u'Tactical Officer', u'Kelvin Crew Member', u'Kelvin Engineer', u'Kelvin Helmsman', u'Kelvin Alien (as Katarzyna Kowalczyk)', u'Romulan Helmsman', u'Kelvin Doctor', u'Medical Technician', u'Medical Technician', u'Kelvin Crew Member', u'Kelvin Crew Member', u'Med Evac Pilot', u'Johnny', u'Iowa Cop', u'Vulcan Student', u'Vulcan Student', u'Vulcan Bully (as James Henrie)', u'Vulcan Bully', u'Vulcan Bully', u'Vulcan Council Member', u'Vulcan Council Member', u'Long Face Bar Alien', u'Lew the Bartender', u'Barfly', u'Barfly (as James McGrath Jr.)', u'Burly Cadet', u'Burly Cadet', u'Shipyard Worker (as Robert Clendenin)', u'Flight Officer (as Darlena Tejeiro)', u'Test Administrator', u'Test Administrator', u'Simulator Tactical Officer', u'Admiral James Komack', u'College Council Stenographer', u'Shuttle Officer', u'Kimberly Arland', u'Cadet Alien', u'Enterprise Crew Member (as Charlie Haugk)', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Crew Member', u'Enterprise Communiations Officer', u'Romulan Tactical Officer', u'Romulan Crew Member', u'Romulan Crew Member', u'Romulan Crew Member', u'Transport Chief', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Vulcan Elder', u'Keenser', u'Starfleet Computer (voice) (as Majel Barrett Roddenberry)', u'Council Member - Captain Kelley Bogel (uncredited)', u'Romulan Science Tech (uncredited)', u'Amphibian Prisoner (uncredited)', u'Doctor (uncredited)', u'Starfleet Cadet (uncredited)', u'Drill Tower Romulan (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Bridgeport Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crewmember (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Cadet (uncredited)', u'Security Officer Daniels (uncredited)', u'Starfleet Officer (uncredited)', u'Enterprise Crew Member (uncredited)', u"Klingon Prisoner - Nero's Flashback (uncredited)", u'Vulcan Federation Officer (uncredited)', u'Doctor (uncredited)', u'Hurried Cadet with Clipboard (uncredited)', u'Shipyard Worker (uncredited)', u'Starfleet Cadet (uncredited)', u'Missile Launcher (uncredited)', u'Klingon Interrogator (scenes deleted) (uncredited)', u'FourSquare (uncredited)', u'Shipyard Bar Patron (uncredited)', u'Starfleet Cadet (uncredited)', u'Child Running in Snow (uncredited)', u'Crew Member (uncredited)', u'Starfleet Security Officer (uncredited)', u'Kelvin Crew Member (uncredited)', u'Uncle Frank (uncredited) (unconfirmed)', u'Enterprise Nurse (uncredited)', u'Shipyard Worker (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Starfleet Cadet (uncredited)', u'Starfleet Commander (uncredited)', u'Enterprise Crew Member (uncredited)', u'Lieutenant Star Fleet Command (uncredited)', u'Flight Operational Air Safety Conductor (uncredited)', u'Starfleet Cadet (uncredited)', u'Romulan Crew Member Placing Bomb (uncredited)', u'Bar Patron (uncredited)', u'Alien Cadet / Enterprise Crew (uncredited)', u'Kelvin Alien (uncredited)', u'Starfleet Cadet (uncredited)', u'Kelvin Computer (uncredited)', u'Councilwoman (uncredited)', u'Enterprise Crewman (uncredited)', u'Starfleet Cadet (uncredited)', u'Enterprise Crew Member (uncredited)', u'Sal (uncredited)', u'Romulan Crew Member (uncredited)', u'Romulan (uncre ...
# 0.047840547, product of:
#   0.19136219, sum of:
#     0.19136219, product of:
#       0.38272437, sum of:
#         0.17371307, weight(title:star in 225) [PerFieldSimilarity], result of:
#           0.17371307, score(doc=225,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             3.6798315, fieldWeight in 225, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.625, fieldNorm(doc=225)
#         0.2090113, weight(title:trek in 225) [PerFieldSimilarity], result of:
#           0.2090113, score(doc=225,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             4.0364223, fieldWeight in 225, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.625, fieldNorm(doc=225)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 8	0.044039465		The Beaver
# The Beaver
# He's here to save Walter's life.
# Suffering from a severe case of depression, toy company CEO Walter Black (Mel Gibson) begins using a beaver hand puppet to help him open up to his family. With his father seemingly going insane, adolescent son Porter (Anton Yelchin) pushes for his parents to get a divorce. Jodie Foster directs and co-stars as Walter's wife in this dark comedy that also features Riley Thomas Stewart and Jennifer Lawrence.
# 50780
# DIRS [u'Jodie Foster']
# CAST [u'Jodie Foster', u'Mel Gibson', u'Jennifer Lawrence', u'Anton Yelchin']
# CHAR [u'Meredith Black', u'Walter Black', u'Norah', u'Porter Black']
# 0.044039465, product of:
#   0.17615786, sum of:
#     0.17615786, product of:
#       0.35231572, sum of:
#         0.090262644, weight(overview:star in 849) [PerFieldSimilarity], result of:
#           0.090262644, score(doc=849,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.53051263, fieldWeight in 849, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.125, fieldNorm(doc=849)
#         0.26205307, weight(overview:stewart in 849) [PerFieldSimilarity], result of:
#           0.26205307, score(doc=849,freq=1.0), product of:
#             0.28990313, queryWeight, product of:
#               7.2314653, idf(docFreq=5, maxDocs=3051)
#               0.040089127, queryNorm
#             0.90393317, fieldWeight in 849, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               7.2314653, idf(docFreq=5, maxDocs=3051)
#               0.125, fieldNorm(doc=849)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 9	0.038272437		Star Trek: The Motion Picture
# Star Trek: The Motion Picture
# The human adventure is just beginning.
# When a destructive space entity is spotted approaching Earth, Admiral Kirk resumes command of the Starship Enterprise in order to intercept, examine, and hopefully stop it.
# 152
# DIRS [u'Robert Wise']
# CAST [u'William Shatner', u'Leonard Nimoy', u'George Takei', u'James Doohan', u'Walter Koenig', u'Nichelle Nichols', u'DeForest Kelley', u'Majel Barrett', u'Stephen Collins', u'Persis Khambatta', u'Grace Lee Whitney', u'Mark Lenard', u'Billy Van Zandt', u'Roger Aaron Brown', u'Gary Faga', u'Franklyn Seales']
# CHAR [u'Captain James T. Kirk', u'Mr. Spock', u'Lt. Cmdr. Hikaru Sulu', u'Montgomery Scott', u'Lt. Pavel Chekov', u'Lt. Cmdr. Uhura', u'Dr. Leonard McCoy', u'Dr. Christine Chapel', u'Capt./Cmdr. Willard Decker', u'Lieutenant Ilia', u'CPO Janice Rand', u'Klingon Captain', u'Alien Boy', u'Epsilon Technician', u'Airlock Technician', u'Crew Member']
# 0.038272437, product of:
#   0.15308975, sum of:
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 12) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=12,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 12, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=12)
#         0.16720903, weight(title:trek in 12) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=12,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 12, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=12)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 10	0.038272437		Star Trek Into Darkness
# Star Trek Into Darkness
# Earth Will Fall
# When the crew of the Enterprise is called back home, they find an unstoppable force of terror from within their own organization has detonated the fleet and everything it stands for, leaving our world in a state of crisis.  With a personal score to settle, Captain Kirk leads a manhunt to a war-zone world to capture a one man weapon of mass destruction. As our heroes are propelled into an epic chess game of life and death, love will be challenged, friendships will be torn apart, and sacrifices must be made for the only family Kirk has left: his crew.
# 54138
# DIRS [u'J.J. Abrams']
# CAST [u'Chris Pine', u'Zachary Quinto', u'Zoe Saldana', u'Karl Urban', u'Simon Pegg', u'John Cho', u'Benedict Cumberbatch', u'Anton Yelchin', u'Bruce Greenwood', u'Peter Weller', u'Alice Eve', u'Noel Clarke', u'Nazneen Contractor', u'Amanda Foreman', u'Jay Scully', u'Jonathan Dixon', u'Aisha Hinds', u'Joseph Gatt', u'Jeremy Raymond', u'Tony Guma', u'Kimberly Arland', u'Sean Blakemore', u'Nick E. Tarabay', u'Beau Billingslea', u'Deep Roy', u'Anjini Taneja Azhar', u'Jack Laufer', u'Katie Cockrell', u'Kellie Cockrell', u'Jason Matthew Smith', u'Chris Hemsworth', u'Jennifer Morrison', u'Seth Ayott', u'Marco Sanchez', u'Lee Reherman', u'Scott Lawrence', u'Usman Ally', u'Nolan North', u'James Hiroyuki Liao', u'Rob Moran', u'Berit Francis', u'Akiva Goldsman', u'Benjamin P. Binswanger', u'Christopher Doohan', u'Andy Demetrio', u'Gianna Simone', u'Rene Rosado', u'Jacquelynn King', u'Long Tran', u'Ningning Deng', u'Jodi Johnston', u'Colleen Harris', u'Jeff Chase', u'Monisola Akiwowo', u'Paul K. Daniel', u"Ser'Darius Blain", u'Heather Langenkamp', u'David C. Waite', u'Melissa Paulo', u'Cynthia Addai-Robinson', u'Drew Grey', u'Douglas Weng', u'Charlie Haugk', u'Max Chernov', u'Marc Primiani', u'Jesper Inglis', u'Jacob Rhodes', u'Kentucky Rhodes', u'Anthony Wilson', u'Eric Greitens', u'Melissa Steinman', u'Adam McCann', u'Jon Orvasky', u'Gerald W. Abrams', u'James McGrath', u'Brian T. Delaney', u'Arlen Escarpeta', u'Chris Gardner', u'Joe Hanna', u'David Acord', u'Joe Moses', u'Kevin Michael Richardson', u'David Sobolov', u'Matthew Wood', u'Fred Tatasciore', u'Kiff VandenHeuvel', u'Julianne Buescher', u'Ellie Newlands', u'Candice Renee', u'Audrey Wasilewski', u'Emily Towers', u'Gina Hirsch', u'Bill Hader', u'Leonard Nimoy', u'Tom Archdeacon', u'Jon Lee Brody', u'Britanni Johnson', u'Hiram A. Murray']
# CHAR [u'Kirk', u'Spock', u'Uhura', u'Bones', u'Scotty', u'Sulu', u'Khan', u'Chekov', u'Pike', u'Marcus', u'Carol', u'Thomas Harewood', u'Rima Harewood', u'Ensign Brackett', u'Lieutenant Chapin', u'Ensign Froman', u'Navigation Officer Darwin', u'Science Officer 0718', u'Lead Nibiran', u'Nibiran', u'Madeline', u'Klingon', u'Klingon', u'Captain Abbot', u'Keenser', u'Lucille Harewood', u'Doctor', u'Girl', u'Girl', u'Cupcake', u'George Kirk', u'Winona Kirk', u'U.S.S. Enterprise Shuttle Ensign', u'Torpedo Security', u'Uniformed Mercenary', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Bridge Officer', u'U.S.S. Vengeance Ensign', u'Starfleet Admiral', u'Starfleet Admiral', u'Starfleet Admiral', u'Transport Officer', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'U.S.S. Enterprise Bridge Crew', u'Lady V', u'U.S.S. Enterprise Security', u'U.S.S. Enterprise Nurse', u'Shuttle Pilot', u'U.S.S. Enterprise Red Shirt', u'Moto', u'U.S.S. Enterprise Crew', u'Bar Girl', u'San Francisco Woman', u'San Francisco Bar Patron', u'U.S.S. Vengeance Security', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'San Francisco Resident', u'Nibiru Child', u'Nibiru Child', u'Shaku', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Ceremonial Guard', u'Starfleet Memorial Admiral', u'Starfleet Memorial Admiral', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Additional Voices (voice)', u'Spock Prime', u'Ensign Spyke (uncredited)', u'U.S.S. Enterprise Security (uncredited)', u'NYU Nurse (uncredited)', u'Bar Patron (uncredited)']
# 0.038272437, product of:
#   0.15308975, sum of:
#     0.15308975, product of:
#       0.3061795, sum of:
#         0.13897046, weight(title:star in 372) [PerFieldSimilarity], result of:
#           0.13897046, score(doc=372,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.9438653, fieldWeight in 372, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.5, fieldNorm(doc=372)
#         0.16720903, weight(title:trek in 372) [PerFieldSimilarity], result of:
#           0.16720903, score(doc=372,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             3.2291377, fieldWeight in 372, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.5, fieldNorm(doc=372)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 11	0.035817675		Maps to the Stars
# Maps to the Stars
# A Film By David Cronenberg
# Led by the loathsome yet funny and touching child-star Benjie, we witness the convoluted world of shallow, selfish celebrities and their minions, all of whom are about to be manipulated and destroyed by the young woman who literally represents the fruit of their twisted machinations, Agatha, Benjie’s tormented, apparently psychotic sister.
# 157851
# DIRS [u'David Cronenberg']
# CAST [u'Julianne Moore', u'Mia Wasikowska', u'Evan Bird', u'John Cusack', u'Robert Pattinson', u'Sarah Gadon', u'Carrie Fisher', u'Olivia Williams', u'Emilia McCarthy', u'Niamh Wilson', u'Amanda Brugel', u'Jayne Heitmeyer', u'Clara Pasieka', u'Jennifer Gibson', u'Joe Pingue', u'Jonathan Watton']
# CHAR [u'Havana Segrand', u'Agatha Weiss', u'Benjie Weiss', u'Dr. Stafford Weiss', u'Jerome Fontana', u'Clarice Taggart', u'herself', u'Christina Weiss', u'Kayla', u'Sam', u'Victoria', u'Azita Wachtel', u'Gretchen', u'Starla Gent', u'Arnold', u'Sterl Carruth']
# 0.03581767, product of:
#   0.07163534, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 367) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=367,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 367, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=367)
#       0.25, coord(1/4)
#     0.04342827, product of:
#       0.17371307, sum of:
#         0.17371307, weight(title:star in 367) [PerFieldSimilarity], result of:
#           0.17371307, score(doc=367,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             3.6798315, fieldWeight in 367, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.625, fieldNorm(doc=367)
#       0.25, coord(1/4)
#   0.5, coord(2/4)
#
# *************************************
# 12	0.03348838		Star Trek VI: The Undiscovered Country
# Star Trek VI: The Undiscovered Country
# The battle for peace has begun.
# The crews of the Enterprise and the Excelsior must stop a plot to prevent a peace treaty between the Klingon Empire and the Federation
# 174
# DIRS [u'Nicholas Meyer']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'Christopher Plummer', u'Kim Cattrall', u'David Warner', u'Rosanna DeSoto', u'Brock Peters', u'Kurtwood Smith', u'Iman', u'Mark Lenard', u'Grace Lee Whitney', u'Leon Russom', u'John Schuck', u'Michael Dor', u'Paul Rossilli', u'Robert Easton', u'Michael Dorn']
# CHAR [u'James Tiberius Kirk', u'Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Hikaru Sulu', u'Uhura', u'Pavel Chekov', u'General Chang', u'Lieutenant Valeris', u'Chancellor Gorkon', u'Azetbur', u'Admiral Cartwright', u'Federation President', u'Martia', u'Sarek', u'Excelsior Communications Officer', u'Chief in Command', u'Klingon Ambassador', u'Klingon Defense Attorney', u'Kerla', u'Klingon Judge', u'Klingon Defense Attorney']
# 0.03348838, product of:
#   0.13395353, sum of:
#     0.13395353, product of:
#       0.26790705, sum of:
#         0.12159916, weight(title:star in 281) [PerFieldSimilarity], result of:
#           0.12159916, score(doc=281,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.5758822, fieldWeight in 281, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=281)
#         0.1463079, weight(title:trek in 281) [PerFieldSimilarity], result of:
#           0.1463079, score(doc=281,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             2.8254955, fieldWeight in 281, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=281)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 13	0.03348838		Star Trek V: The Final Frontier
# Star Trek V: The Final Frontier
# Adventure and imagination will meet at the final frontier.
# Capt. Kirk and his crew must deal with Mr. Spock's half brother who kidnaps three diplomats and hijacks the Enterprise in his obsessive search for God.
# 172
# DIRS [u'William Shatner']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Nichelle Nichols', u'Walter Koenig', u'David Warner', u'Laurence Luckinbill', u'Charles Cooper', u'Cynthia Gouw', u'Todd Bryant', u'George Murdock', u'Jonathan Simpson']
# CHAR [u'Captain James T. Kirk', u'Captain Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Cmdr. Hikaru Sulu', u'Cmdr. Uhura', u'Cmdr. Pavel Chekov', u'St. John Talbot', u'Sybok', u'Gen. Korrd', u'Caithlin Dar', u'Capt. Klaa', u'God', u'Young Sarek']
# 0.03348838, product of:
#   0.13395353, sum of:
#     0.13395353, product of:
#       0.26790705, sum of:
#         0.12159916, weight(title:star in 282) [PerFieldSimilarity], result of:
#           0.12159916, score(doc=282,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
#             2.5758822, fieldWeight in 282, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.4375, fieldNorm(doc=282)
#         0.1463079, weight(title:trek in 282) [PerFieldSimilarity], result of:
#           0.1463079, score(doc=282,freq=1.0), product of:
#             0.051781327, queryWeight, product of:
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.008017826, queryNorm
#             2.8254955, fieldWeight in 282, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.4582753, idf(docFreq=12, maxDocs=3051)
#               0.4375, fieldNorm(doc=282)
#       0.5, coord(2/4)
#   0.25, coord(1/4)
#
# *************************************
# 14	0.03348838		Star Trek IV: The Voyage Home
# Star Trek IV: The Voyage Home
# The key to saving the future can only be found in the past.
# Fugitives of the Federation for their daring rescue of Spock from the doomed Genesis Planet, Admiral Kirk (William Shatner) and his crew begin their journey home to face justice for their actions. But as they near Earth, they find it at the mercy of a mysterious alien presence whose signals are slowly destroying the planet. In a desperate attempt to answer the call of the probe, Kirk and his crew race back to the late twentieth century. However they soon find the world they once knew to be more alien than anything they've encountered in the far reaches of the galaxy!
# 168
# DIRS [u'Leonard Nimoy']
# CAST [u'William Shatner', u'Leonard Nimoy', u'DeForest Kelley', u'James Doohan', u'George Takei', u'Walter Koenig', u'Nichelle Nichols', u'Jane Wyatt', u'Catherine Hicks', u'Mark Lenard', u'Robin Curtis', u'Robert Ellenstein', u'John Schuck', u'Brock Peters', u'Michael Snyder']
# CHAR [u'Admiral/Captain James T. Kirk', u'Captain Spock', u'Dr. Leonard McCoy', u'Montgomery Scott', u'Cmdr. Hikaru Sulu', u'Cmdr. Pavel Chekov', u'Cmdr. Uhura', u'Amanda', u'Dr. Gillian Taylor', u'Ambassador Sarek', u'Lt. Saavik', u'Federation Council President', u'Klingon Ambassador', u'Admiral Cartwright', u'Starfleet Communications Officer']
# 0.03348838, product of:
#   0.13395353, sum of:
#     0.13395353, product of:
#       0.26790705, sum of:
#         0.12159916, weight(title:star in 474) [PerFieldSimilarity], result of:
#           0.12159916, score(doc=474,freq=1.0), product of:
#             0.0472068, queryWeight, product of:
#               5.8877306, idf(docFreq=22, maxDocs=3051)
#               0.008017826, queryNorm
# ...
# CHAR [u'President James Dale / Art Land', u'First Lady Marsha Dale', u'Barbara Land', u'Professor Donald Kessler', u'Rude Gambler', u'Press Secretary Jerry Ross', u'Nathalie Lake', u'Jason Stone', u'General Decker', u'Himself', u'Taffy Dale', u'Richie Norris', u'Grandma Florence Norris', u'Martian Girl', u'Byron Williams', u'Louise Williams']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 221) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=221,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 221, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=221)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 95	0.007051769		Lawrence of Arabia
# Lawrence of Arabia
# A Mighty Motion Picture Of Action And Adventure!
# Lawrence of Arabia is the classic film from David Lean starring Peter O’Toole and based on the autobiography from Thomas Edward Lawrence who during the first World War was on assignment by the British Empire in Arabia. The film would become a cult classic and is known today as a masterpiece.
# 947
# DIRS [u'David Lean']
# CAST [u"Peter O'Toole", u'Alec Guinness', u'Anthony Quinn', u'Jack Hawkins', u'Omar Sharif', u'Claude Rains', u'Anthony Quayle', u'Jos\xe9 Ferrer', u'Arthur Kennedy', u'Donald Wolfit', u'Zia Mohyeddin', u'I.S. Johar', u'Gamil Ratib', u'Michel Ray', u'John Dimech']
# CHAR [u'T.E. Lawrence', u'Prince Feisal', u'Auda abu Tayi', u'General Lord Edmund Allenby', u'Sherif Ali', u'Mr. Dryden', u'Colonel Brighton', u'Turkish Bey', u'Jackson Bentley', u'General Sir Archibald Murray', u'Tafas', u'Gasim', u'Majid', u'Farraj', u'Daud']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 482) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=482,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 482, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=482)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 96	0.007051769		RockNRolla
# RockNRolla
# A story of sex, thugs and rock 'n roll.
# When a Russian mobster sets up a real estate scam that generates millions of pounds, various members of London's criminal underworld pursue their share of the fortune. Various shady characters, including Mr One-Two, Stella the accountant, and Johnny Quid, a druggie rock-star, try to claim their slice.
# 13809
# DIRS [u'Guy Ritchie']
# CAST [u'Mark Strong', u'Tom Wilkinson', u'Toby Kebbell', u'Gerard Butler', u'Tom Hardy', u'Idris Elba', u'Karel Roden', u'Thandie Newton', u'Matt King', u'Gemma Arterton', u'Jeremy Piven', u'Jimi Mistry', u'Jamie Campbell Bower', u'Nonso Anozie', u'Charlotte Armer', u'Ludacris']
# CHAR [u'Archy', u'Lenny Cole', u'Johnny Quid', u'One-Two', u'Handsome Bob', u'Mumbles', u'Uri Omovich', u'Stella', u'Cookie', u'June', u'Roman', u'Councillor', u'Rocker', u'Tank', u'Nurse', u'Mickey']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 636) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=636,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 636, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=636)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 97	0.007051769		A Knight's Tale
# A Knight's Tale
# He Will Rock You
# William Thatcher, a peasant, is sent to apprentice with a Knight named Hector as a young boy. Urged by his father to "change his Stars", he assumes Sir Hector's place in a tournament when Hector dies in the middle of it. He wins. With the other apprentices, he trains and assumes the title of Sir Ulrich von Lichtenstein.
# 9476
# DIRS [u'Brian Helgeland']
# CAST [u'Heath Ledger', u'Rufus Sewell', u'Shannyn Sossamon', u'Paul Bettany', u'Laura Fraser', u'Mark Addy', u'Alan Tudyk', u'James Purefoy', u'B\xe9r\xe9nice Bejo']
# CHAR [u'Sir William Thatcher / Sir Ulrich von Lichtenstein of Gelderland', u'Count Adhemar of Anjou', u'Lady Jocelyn', u'Geoffrey Chaucer', u'Kate', u'Roland', u'Wat', u'Edward, the Black Prince of Wales/Sir Thomas Colville', u'Christiana']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 697) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=697,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 697, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=697)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 98	0.007051769		Casablanca
# Casablanca
# They had a date with fate in Casablanca!
# Casablanca is a classic and one of the most revered films of all time. Starring Humphrey Bogart and Ingrid Bergman in a love triangle in the city of Casablanca which is a refuge for many fleeing foreigners looking for a new life during the war. Political romance with a backdrop of war conflict between democracy and totalitarianism. A landmark in film history.
# 289
# DIRS [u'Michael Curtiz']
# CAST [u'Humphrey Bogart', u'Ingrid Bergman', u'Paul Henreid', u'Claude Rains', u'Conrad Veidt', u'Sydney Greenstreet', u'Peter Lorre', u'Madeleine Lebeau', u'Dooley Wilson', u'Joy Page', u'John Qualen', u'Leonid Kinskey', u'Curt Bois', u'Marcel Dalio', u'Helmut Dantine', u'Hans Heinrich von Twardowski', u'S.Z. Sakall', u'Norma Varden', u'Gino Corrado', u'Enrique Acosta', u'Ed Agresti', u'Louis V. Arco', u'Frank Arnold', u'Leon Belasco', u'Nino Bellini', u'Oliver Blake', u'Monte Blue', u'Eugene Borden', u'Dick Botiller', u'Maurice Brierre', u'Sebastian Cabot', u'Anita Camargo', u'George M. Carleton', u'Spencer Chan', u'Melie Chang', u'Franco Corsaro', u"Adrienne D'Ambricourt", u'Jean De Briac', u'George Dee', u'Jean Del Val', u'Carl Deloro', u'Joseph DeVillard', u'Arthur Dulac', u'William Edmunds', u'Herbert Evans', u'Fred Farrell', u'Adolph Faylauer', u'O.K. Ford', u'Martin Garralaga', u'Gregory Gaye', u'Gregory Golubeff', u'Ilka Gr\xfcning', u'Creighton Hale', u'Winifred Harris', u'Jamiel Hasson', u'Arthur Stuart Hull', u'Olaf Hytten', u'Paul Irving', u'Charles La Torre', u'George J. Lewis', u'Manuel Lopez', u'Jacques Lory', u'Lou Marcelle', u'Michael Mark', u'Tony Martelli', u'George Meeker', u'Lal Chand Mehra', u'Hercules Mendez', u'Louis Mercier', u'Torben Meyer', u'Alberto Morin', u'Leo Mostovoy', u'Corinna Mura', u'Barry Norton', u'Lotte Palfi Andor', u'Paul Panzer', u'Manuel Par\xeds', u'Alexander Pollard', u'Frank Puglia', u'Georges Renavent', u'Dewey Robinson', u'Richard Ryen', u'Dan Seymour', u'Lester Sharpe', u'Dina Smirnova', u'Gerald Oliver Smith', u'George Sorel', u'Geoffrey Steele', u'Ludwig St\xf6ssel', u'Mike Tellegen', u'Rafael Trujillo', u'Jacques Vanaire', u'Ellinor Vanderveer', u'Ellinor Vanderveer', u'Jack Wise', u'Wolfgang Zilzer', u'Trude Berliner', u'Paul Porcasi']
# CHAR [u'Rick Blaine', u'Ilsa Lund', u'Victor Laszlo', u'Capt. Renault', u'Maj. Strasser', u'Signor Ferrari', u'Ugarte', u'Yvonne', u'Sam', u'Annina Brandel', u'Berger', u'Sascha', u'Pickpocket', u'Emil', u'Jan Brandel', u'German officer with Yvonne', u'Carl', u'Wife of Pickpocketed Englishman (uncredited)', u"Waiter at Rick's (uncredited)", u"Guest at Rick's (uncredited)", u'Bar Patron (uncredited)', u"Refugee at Rick's (uncredited)", u'Overseer (uncredited)', u"Dealer at Rick's (uncredited)", u'Gendarme (uncredited)', u'Waiter at the Blue Parrot (uncredited)', u'American (uncredited)', u'Policeman (uncredited)', u'Native Officer (uncredited)', u"Baccarat Dealer at Rick's (uncredited)", u'Bearded man in street watching plane in flight to Lisbon. (uncredited)', u'Woman Companion (uncredited)', u'American (uncredited)', u"Guest at Rick's (uncredited)", u"Oriental at Rick's (uncredited)", u'French Police Officer (uncredited)', u'Concierge (uncredited)', u'Orderly (uncredited)', u'Lt. Casselle (uncredited)', u'Police Officer (uncredited)', u'Arab Guest with Fez (uncredited)', u'Moroccan (uncredited)', u'News Vendor (uncredited)', u"Second Contact Man at Rick's (uncredited)", u"Englishman Questioning Casino's Honesty (uncredited)", u'Singing Frenchman (uncredited)', u"Gambler at Rick's (uncredited)", u'Conspirator (uncredited)', u"Headwaiter at Rick's (uncredited)", u'German Banker Refused by Rick (uncredited)', u"Cashier at Rick's (uncredited)", u"Mrs. Leuchtag - Carl's Immigrating Friend (uncredited)", u'Customer (uncredited)', u'Englishwoman (uncredited)', u'Muezzini (uncredited)', u'Elderly Admirer (uncredited)', u'Pickpocketed Prosperous Man (uncredited)', u'Prosperous Tourist (uncredited)', u'Italian Officer Tonnelli (uncredited)', u'Haggling Arab Monkey Seller (uncredited)', u'Policeman (uncredited)', u'Moor Buying Diamonds (uncredited)', u'Narrator (voice) (uncredited)', u'Vendor (uncredited)', u'Bartender (uncredited)', u"Rick's Friend (uncredited)", u'Policeman (uncredited)', u'Arab Guest with Fez (uncredited)', u'Conspirator (uncredited)', u'Dutch Banker at Cafe Table (uncredited)', u'French Officer Insulting Yvonne (uncredited)', u'Fydor (uncredited)', u'Singer with Guitar (uncredited)', u"Gambler at Rick's (uncredited)", u'Woman Selling Her Diamonds (uncredited)', u"Paul - Waiter at Rick's (uncredited)", u"Guest at Rick's (uncredited)", u'Croupier (uncredited)', u'Arab Vendor (uncredited)', u'Conspirator (uncredited)', u"Bouncer at Rick's (uncredited)", u"Col. Heinz - Strasser's Aide (uncredited)", u'Abdul (uncredited)', u'Refugee (uncredited)', u'Woman Customer (uncredited)', u'Pickpocketed Englishman (uncredited)', u'Native Officer (uncredited)', u'Customer (uncredited)', u'Mr. Leuchtag (uncredited)', u'Gambler (uncredited)', u'Man Turning Propeller at Airport (uncredited)', u'Frenchman (uncredited)', u"Woman Gambler at Rick's Next to Croupier (uncredited)", u'Emile - Waiter (uncredited)', u'Waiter (uncredited)', u'Man with Expired Papers (uncredited)', u"Baccarat Player at Rick's (uncredited)", u'Native Introducing Ferrari (uncredited)']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 887) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=887,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 887, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=887)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 99	0.007051769		Any Given Sunday
# Any Given Sunday
# Play or be Played.
# A star quarterback gets knocked out of the game and an unknown third stringer is called in to replace him. The unknown gives a stunning performance and forces the aging coach to reevaluate his game plans and life. A new co-owner/president adds to the pressure of winning. The new owner must prove her self in a male dominated world.
# 9563
# DIRS [u'Oliver Stone']
# CAST [u'Al Pacino', u'Cameron Diaz', u'Dennis Quaid', u'James Woods', u'Jamie Foxx', u'LL Cool J', u'Matthew Modine', u'Jim Brown', u'Lawrence Taylor', u'Bill Bellamy', u'Aaron Eckhart', u'John C. McGinley', u'Andrew Bryniarski', u'Lauren Holly', u'Ann-Margret', u'Lela Rochon', u'Ron Madoff', u'Elizabeth Berkley', u'Charlton Heston']
# CHAR [u"Tony D'Amato", u'Christina Pagniacci', u"Jack 'Cap' Rooney", u'Dr. Harvey Mandrake', u'Willie Beamen', u'Julian Washington', u'Dr. Ollie Powers', u'Montezuma Monroe', u"Luther 'Shark' Lavay", u'Jimmy Sanderson', u'Nick Crozier', u'Jack Rose', u"Patrick 'Madman' Kelly", u'Cindy Rooney', u'Margaret Pagniacci', u'Vanessa Struthers', u'Assistant Coach', u'Mandy Murphy', u'Commissioner']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 902) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=902,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 902, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=902)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# 100	0.007051769		The Awakening
# The Awakening
# Sometimes dead does not mean gone.
# The Awakening is a British horror thriller film directed by Nick Murphy, starring Rebecca Hall, Dominic West, and Imelda Staunton. 1921 England is overwhelmed by the loss and grief of World War I. Hoax exposer Florence Cathcart (Hall) visits a boarding school to explain sightings of a child ghost.
# 77949
# DIRS [u'Nick Murphy ']
# CAST [u'Rebecca Hall', u'Dominic West', u'Imelda Staunton', u'Isaac Hempstead Wright', u'Lucy Cohu', u'John Shrapnel', u'Diana Kent', u'Richard Durden', u'Alfie Field ', u'Tilly Vosburgh', u'Anastasia Hille', u'Andrew Havill', u'Joseph Mawle', u'Neil Broome', u'Shaun Dooley', u'Kasity Koehn']
# CHAR [u'Florence Cathcart', u'Robert Mallory', u'Maud Hill', u'Tom', u'Constance Strickland', u'Reverend Hugh Purslow', u'Harriet Cathcart', u'Alexander Cathcart', u'Victor Parry', u'Vera Flood', u'Katherine Vandermeer', u'George Vandermeer', u'Edward Judd', u'School Master', u'Malcolm McNair', u'Sonya Wright']
# 0.0070517687, product of:
#   0.028207075, sum of:
#     0.028207075, product of:
#       0.1128283, sum of:
#         0.1128283, weight(overview:star in 1044) [PerFieldSimilarity], result of:
#           0.1128283, score(doc=1044,freq=1.0), product of:
#             0.17014231, queryWeight, product of:
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.040089127, queryNorm
#             0.6631408, fieldWeight in 1044, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.244101, idf(docFreq=118, maxDocs=3051)
#               0.15625, fieldNorm(doc=1044)
#       0.25, coord(1/4)
#   0.25, coord(1/4)
#
# *************************************
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'filtered((overview:star overview:trek overview:patrick overview:stewart) (directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart) ((title:star title:trek title:patrick title:stewart)^0.2) (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart))->cache(_type:movie)', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # Most Fields undue promotion due to director AND cast member

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.5415871		Star Trek V: The Final Frontier
# 2	0.39785004		Star Trek: Generations
# 3	0.35108924		Star Trek IV: The Voyage Home
# 4	0.3037074		Star Trek: Nemesis
# 5	0.19542062		Star Trek: Insurrection
