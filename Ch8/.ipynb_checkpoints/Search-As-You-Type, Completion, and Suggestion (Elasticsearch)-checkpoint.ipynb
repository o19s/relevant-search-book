# %%
#import
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import pickle

# %%
#initialize
es = Elasticsearch()
movies=pickle.load(open("../../movies_list.p","rb"))

# %%
#doc indexer
def make_action(doc):
    action = {
        "_index": "tmdb",
        "_type": "movie",
        "_id": doc['id'],
        "_source": doc
        }
    return action

def index_movies():
    actions = (make_action(doc) for doc in movies)
    results = [details for success,details in helpers.streaming_bulk(es, actions) if not success]
    return results

# %%
try:
    es.indices.delete("tmdb")
except:
    pass

#create index here?
# genres.name needs to be keyword tokenized so that 'science fiction' doesn't get split on white space
# maybe create a text field with title and overview to search against
body = {
    "settings": {
    "analysis": {
      "filter": {
        "shingle_2": {
          "type":"shingle",
          "output_unigrams":"false"}},
      "analyzer": {
        "completion_analyzer": {
          "tokenizer":  "standard",
          "filter": [
            "standard", 
            "lowercase", 
            "shingle_2"]}}}},
    "mappings": {
        "movie": {
            "properties": {
                "genres": {
                    "properties": {
                        "name": { 
                            "type": "string",
                            "index": "not_analyzed"
                        }
                    }
                },
                "title": {
                    "type": "string",
                    "analyzer": "english",
                    "copy_to":["completion"]
                },
                "completion": {
                    "type": "string",
                    "analyzer": "completion_analyzer",
                }}}}}
es.indices.create("tmdb",body=body)
# Out:
# {u'acknowledged': True}

# %%
results = index_movies()

# %%
def get_completion_query(input_string):
    query = {}
    
    # get portion of the query string that has been completed 
    # (as indicated by a space following the last completed word)
    input_string = input_string.lstrip()
    last_space_index = input_string.rfind(' ')
    if last_space_index > 1:
        completed_string = input_string[:last_space_index]
    else:
        completed_string = ''
    
    # get the prefix (unfinished word)
    prefix = input_string[last_space_index+1:]
    # and if it's too short tack on the previous word
    if len(prefix) < 2 and completed_string:
        # then add on the previous word
        last_space_index = completed_string.rfind(' ')
        prefix =  "%s %s" % (completed_string[last_space_index+1:],prefix)
        prefix = prefix.strip()
    # and if it's still too short and there's no completed_string
    # to filter the results at least a bit, then just don't use a prefix
    if len(prefix) < 3 and not completed_string:
        prefix = ''

    #stick the completed string and the prefix into the query body
    if completed_string:
        query['query'] = {
            'multi_match': {
                'query': completed_string,
                'fields': ['title', 'overview'],
            }
        }
    if prefix:
        query['aggs'] = {
            'suggest': {
                'terms': {
                    'field':'completion',
                    'include': '%s.*' % prefix
                }
            }
        }
    return query
    
get_completion_query = get_query("star wars ep")
es.search(index="tmdb",doc_type="movie",body=query_body)
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'aggregations': {u'suggest': {u'buckets': [{u'doc_count': 2,
#      u'key': u'episode iii'},
#     {u'doc_count': 1, u'key': u'episode i'},
#     {u'doc_count': 1, u'key': u'episode ii'},
#     {u'doc_count': 1, u'key': u'episode iv'},
#     {u'doc_count': 1, u'key': u'episode ix'},
#     {u'doc_count': 1, u'key': u'episode v'},
#     {u'doc_count': 1, u'key': u'episode vi'},
#     {u'doc_count': 1, u'key': u'episode vii'},
#     {u'doc_count': 1, u'key': u'episode viii'}],
#    u'doc_count_error_upper_bound': 0,
#    u'sum_other_doc_count': 0}},
#  u'hits': {u'hits': [{u'_id': u'12180',
#     u'_index': u'tmdb',
#     u'_score': 5.1410027,
#     u'_source': {u'adult': False,
#      u'backdrop_path': u'/gmLMaDXi4lFWG8WitaCYOJS5GtL.jpg',
#      u'belongs_to_collection': None,
#      u'budget': 8500000,
#      u'genres': [{u'id': 28, u'name': u'Action'},
#       {u'id': 12, u'name': u'Adventure'},
# ...

# %%
a = ("123" "345"  "2345")
a
# Out:
# '1233452345'
